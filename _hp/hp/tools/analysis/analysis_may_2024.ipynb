# %%
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Setup

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import re
import json

from datetime import datetime

from utils import get_data, Config, clean_url, make_clickable, add_columns

# %%
# Load all data (except unknown/manual testing)
# Parsing + Basic 5x+ each, and reruns (such that all tests have 5+ results)
# Ubuntu 22.04, Android 11, MacOS 14.3.1, iPadOS 17.3.1
# All runs performed between 2024-03-07 and 2024-05-14
initial_data = """
SELECT "Result".*, 
"Response".raw_header, "Response".status_code, "Response".label, "Response".resp_type,
"Browser".name, "Browser".version, "Browser".headless_mode, "Browser".os, "Browser".automation_mode, "Browser".add_info
FROM "Result"
JOIN "Response" ON "Result".response_id = "Response".id JOIN "Browser" ON "Result".browser_id = "Browser".id
WHERE "Browser".name != 'Unknown';
"""
config = Config()
config.DB_NAME = "http_header_original"
df = get_data(config, initial_data)
df = add_columns(df)
# Out:
# Config(DB_HOST='postgres', DB_NAME='http_header_original', DB_USER='header_user', DB_PASSWORD='header_password', DB_PORT='5432')
# Connecting to the PostgreSQL database...
# Connection successful

# %%
df["raw_header"] = df["raw_header"].apply(bytes).apply(lambda x: json.loads(x.decode("utf-8"))).astype(str)
def create_test_id(row):
    return f'{row["test_name"]}_{row["relation_info"]}_{row["org_scheme"]}_{row["org_host"]}_{row["resp_scheme"]}_{row["resp_host"]}_{row["response_id"]}_{row["resp_type"]}'

df["browser_id"] = df["browser_id"].astype("category")
# Takes a while (1000s+) (might be faster to already do it with postgres but not too important)
df["test_id"] = df.apply(create_test_id, axis=1)
df["test_id"] = df["test_id"].astype("category")

# %%
responses = """
SELECT * from "Response";
"""
responses = get_data(config, responses)
# Out:
# Connecting to the PostgreSQL database...
# Connection successful

# %% [markdown]
# # Overview
# - Collected between 885730 and 1558656 results for 12 browsers

# %%
# Drop the browsers added in the second experiment in December
df = df.loc[~df["browser_id"].isin([73, 74, 75, 76])]

# %%
# Both basic + parsing mode
# Each test should have results 5+ times (such that we can better reason about noise + majority voting makes sense)
df.groupby(["automation_mode", "browser_id", "name", "version", "os", "headless_mode"], observed=True)["id"].count().sort_values(ascending=False).to_frame().reset_index()
# Out:
#    automation_mode browser_id          name                     version  \
# 0           intent         68         brave             1.62.165_shield
# 1           intent         64  firefox_beta                     123.0b9
# 2           intent         62        chrome              121.0.6167.180
# 3         selenium         51        safari                      17.3.1
# 4           intent         60        chrome               122.0.6261.89
# 5         selenium         47        chrome                         122
# 6         selenium         45         brave  v1.62.156 (121.0.6167.139)
# 7         selenium         49       firefox                         121
# 8         selenium         61       firefox                         123
# 9         selenium         43       firefox                         122
# 10        selenium         42        chrome                         121
# 11        selenium         48        chrome                         120
#
#                os headless_mode       id
# 0      Android 11          real  1558656
# 1      Android 11          real   968298
# 2      Android 11          real   921540
# 3    macOS 14.3.1          real   907865
# 4   iPadOS 17.3.1          real   890198
# 5    Ubuntu 22.04  headless-new   886198
# 6    Ubuntu 22.04  headless-new   885810
# 7    Ubuntu 22.04      headless   885746
# 8    Ubuntu 22.04      headless   885746
# 9    Ubuntu 22.04      headless   885730
# 10   Ubuntu 22.04  headless-new   885730
# 11   Ubuntu 22.04  headless-new   885730

# %%
len(df)
# Out:
# 11447247

# %%
# Number of Test URLs visited (all, including timeouts and co.)
df.groupby(["browser"])["full_url"].agg(["count", "nunique"])
# Out:
#                                                       count  nunique
# browser
# brave Android 11 1.62.165_shield intent real        1558656   195549
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...   885810    23083
# chrome Android 11 121.0.6167.180 intent real         921540   123661
# chrome Ubuntu 22.04 120 selenium headless-new        885730    22130
# chrome Ubuntu 22.04 121 selenium headless-new        885730    22139
# chrome Ubuntu 22.04 122 selenium headless-new        886198    25918
# chrome iPadOS 17.3.1 122.0.6261.89 intent real       890198    27256
# firefox Ubuntu 22.04 121 selenium headless           885746    22072
# firefox Ubuntu 22.04 122 selenium headless           885730    22556
# firefox Ubuntu 22.04 123 selenium headless           885746    22058
# firefox_beta Android 11 123.0b9 intent real          968298   189711
# safari macOS 14.3.1 17.3.1 selenium real             907865    25025

# %% [markdown]
# ## Error + Timeout Analysis
# - Small number of random timeouts in both parsing/basic mode
# - Very small number of not-run in Opera and Brave Android and MacOS Safari (all HSTS)
# - Iterativily designed (we had more issues in the past):
#   - We use higher timeouts for certain tests that timed out more often in debug runs
#   - We use higher timeouts for Android
#   - We use higher timeouts for the repeat runs

# %%
# Timeout (2), Fail (1), Not-run (3)
display(df.groupby(["browser"])["test_status"].value_counts().to_frame().unstack().T)

display(df["test_status"].value_counts())
# Out:
# browser            brave Android 11 1.62.165_shield intent real  \
#       test_status
# count 0                                               1558651.0
#       2                                                     5.0
#       3                                                     NaN
#
# browser            brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  \
#       test_status
# count 0                                                     885802.0
#       2                                                          8.0
#       3                                                          NaN
#
# browser            chrome Android 11 121.0.6167.180 intent real  \
#       test_status
# count 0                                                921539.0
#       2                                                     1.0
#       3                                                     NaN
#
# browser            chrome Ubuntu 22.04 120 selenium headless-new  \
#       test_status
# count 0                                                 885730.0
#       2                                                      NaN
#       3                                                      NaN
#
# browser            chrome Ubuntu 22.04 121 selenium headless-new  \
#       test_status
# count 0                                                 885730.0
#       2                                                      NaN
#       3                                                      NaN
#
# browser            chrome Ubuntu 22.04 122 selenium headless-new  \
#       test_status
# count 0                                                 886181.0
#       2                                                     17.0
#       3                                                      NaN
#
# browser            chrome iPadOS 17.3.1 122.0.6261.89 intent real  \
#       test_status
# count 0                                                  890197.0
#       2                                                       1.0
#       3                                                       NaN
#
# browser            firefox Ubuntu 22.04 121 selenium headless  \
#       test_status
# count 0                                              885745.0
#       2                                                   1.0
#       3                                                   NaN
#
# browser            firefox Ubuntu 22.04 122 selenium headless  \
#       test_status
# count 0                                              885730.0
#       2                                                   NaN
#       3                                                   NaN
#
# browser            firefox Ubuntu 22.04 123 selenium headless  \
#       test_status
# count 0                                              885745.0
#       2                                                   1.0
#       3                                                   NaN
#
# browser            firefox_beta Android 11 123.0b9 intent real  \
#       test_status
# count 0                                               968233.0
#       2                                                   65.0
#       3                                                    NaN
#
# browser            safari macOS 14.3.1 17.3.1 selenium real
#       test_status
# count 0                                            907806.0
#       2                                                31.0
#       3                                                28.0
# test_status
# 0    11447089
# 2         130
# 3          28
# Name: count, dtype: int64

# %%
# Teststatus == 2 (timeout)

# Rare timeouts in some browsers
display(df[df["test_status"] == 2]["browser"].value_counts().to_frame())

with pd.option_context("display.max_rows", 80):
    display(df.loc[(df["test_status"] == 2)].groupby(["resp_type", "status_code", "test_name"])["browser"].value_counts().to_frame().sort_values(by="count", ascending=False))
# Out:
#                                                     count
# browser
# firefox_beta Android 11 123.0b9 intent real            65
# safari macOS 14.3.1 17.3.1 selenium real               31
# chrome Ubuntu 22.04 122 selenium headless-new          17
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      8
# brave Android 11 1.62.165_shield intent real            5
# chrome Android 11 121.0.6167.180 intent real            1
# chrome iPadOS 17.3.1 122.0.6261.89 intent real          1
# firefox Ubuntu 22.04 121 selenium headless              1
# firefox Ubuntu 22.04 123 selenium headless              1
#                                                                                                 count
# resp_type status_code test_name             browser
# basic     200         referrer_iframe       firefox_beta Android 11 123.0b9 intent real            42
# parsing   200         framing_iframe        safari macOS 14.3.1 17.3.1 selenium real               20
#                       accesswindow_direct   firefox_beta Android 11 123.0b9 intent real            14
# basic     200         referrer_iframe       brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      6
# parsing   200         upgradeHSTS_subdomain safari macOS 14.3.1 17.3.1 selenium real                6
#                       framing_iframe        firefox_beta Android 11 123.0b9 intent real             5
#                       fullscreen_iframe     brave Android 11 1.62.165_shield intent real            5
# basic     200         fullscreen_iframe     chrome Ubuntu 22.04 122 selenium headless-new           5
# parsing   200         upgradeHSTS_direct    safari macOS 14.3.1 17.3.1 selenium real                4
# basic     200         framing_object        chrome Ubuntu 22.04 122 selenium headless-new           4
#                       framing_embed         chrome Ubuntu 22.04 122 selenium headless-new           4
#           302         referrer_iframe       firefox_beta Android 11 123.0b9 intent real             4
#           200         framing_iframe        chrome Ubuntu 22.04 122 selenium headless-new           3
#                       fullscreen_iframe     brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      2
#                       referrer_iframe       firefox Ubuntu 22.04 121 selenium headless              1
#                                             chrome Ubuntu 22.04 122 selenium headless-new           1
#           302         framing_embed         chrome Android 11 121.0.6167.180 intent real            1
#           200         referrer_iframe       firefox Ubuntu 22.04 123 selenium headless              1
# parsing   200         accesswindow_direct   safari macOS 14.3.1 17.3.1 selenium real                1
#                       upgradeHSTS_subdomain chrome iPadOS 17.3.1 122.0.6261.89 intent real          1

# %%
# Teststatus == 3 (not-run)

display(df[df["test_status"] == 3]["browser"].value_counts().to_frame())

display(df.loc[(df["test_status"] == 3)].groupby(["resp_type", "status_code", "test_name"])["browser"].value_counts().to_frame().sort_values(by="count", ascending=False))
# Out:
#                                           count
# browser
# safari macOS 14.3.1 17.3.1 selenium real     28
#                                                                                       count
# resp_type status_code test_name             browser
# parsing   200         upgradeHSTS_subdomain safari macOS 14.3.1 17.3.1 selenium real     21
#                       upgradeHSTS_direct    safari macOS 14.3.1 17.3.1 selenium real      7

# %% [markdown]
# ## General Test Statistics
# - 9784 basic tests
# - 165376 parsing tests
# - We collected between 5 and 54 outcomes for each test
# - If we have more than 5 outcomes this is either due to a repeat run that included tests that already had all 5 results
# - Or in Android where our intent-based test infrastructure cannot close tabs and sometimes they are executed again

# %%
df["file_name"] = df["clean_url"].apply(lambda x: x.split("tests/")[1].split(".")[0])

# %%
# Number of test_ids for each "group": resp_type, test_name, relation_info
df.groupby(["resp_type", "file_name", "test_name", "relation_info"])["test_id"].nunique().to_frame().unstack(0)
# Out:
#                                                                       test_id  \
# resp_type                                                               basic
# file_name                test_name                     relation_info
# fetch-cors               fetch_GET                     credentials       96.0
#                                                        custom_headers    96.0
#                                                        simple            96.0
#                          fetch_TEST                    custom_method     96.0
# framing                  framing_embed                 direct           560.0
#                                                        nested           560.0
#                                                        sandbox          560.0
#                          framing_iframe                direct           560.0
#                                                        nested           560.0
#                                                        sandbox          560.0
#                          framing_object                direct           560.0
#                                                        nested           560.0
#                                                        sandbox          560.0
# fullscreen-api-pp        fullscreen_iframe             child            384.0
#                                                        child_allow      384.0
#                                                        child_sandbox    384.0
#                                                        direct           384.0
# perfAPI-tao              perfAPI_img                   direct           208.0
# referrer-access-rp       referrer_iframe               iframe           256.0
#                                                        window.open      256.0
# script-execution-csp     script_execution_iframe       direct           272.0
#                                                        sandbox          272.0
# script-execution-xcto    sniffing_script               direct           208.0
# subresource-loading-coep subresourceloadingCOEP_img    direct           176.0
#                                                        sandbox          176.0
# subresource-loading-corp subresourceloadingCORP_img    direct           176.0
#                                                        nested           176.0
#                                                        sandbox          176.0
#                          subresourceloadingCORP_object direct           176.0
# subresource-loading-csp  imgloading_iframe             direct           272.0
# upgrade-hsts             upgradeHSTS_direct            direct            28.0
#                          upgradeHSTS_subdomain         subdomain         28.0
# window-references-coop   accesswindow_direct           direct           176.0
#
#
# resp_type                                                              parsing
# file_name                test_name                     relation_info
# fetch-cors               fetch_GET                     credentials     16118.0
#                                                        custom_headers  16118.0
#                                                        simple          16118.0
#                          fetch_TEST                    custom_method   16118.0
# framing                  framing_embed                 direct              NaN
#                                                        nested              NaN
#                                                        sandbox             NaN
#                          framing_iframe                direct          17560.0
#                                                        nested          17560.0
#                                                        sandbox             NaN
#                          framing_object                direct              NaN
#                                                        nested              NaN
#                                                        sandbox             NaN
# fullscreen-api-pp        fullscreen_iframe             child               NaN
#                                                        child_allow      7760.0
#                                                        child_sandbox       NaN
#                                                        direct           7760.0
# perfAPI-tao              perfAPI_img                   direct           3202.0
# referrer-access-rp       referrer_iframe               iframe           5594.0
#                                                        window.open         NaN
# script-execution-csp     script_execution_iframe       direct           5452.0
#                                                        sandbox             NaN
# script-execution-xcto    sniffing_script               direct           1778.0
# subresource-loading-coep subresourceloadingCOEP_img    direct           5274.0
#                                                        sandbox             NaN
# subresource-loading-corp subresourceloadingCORP_img    direct           6714.0
#                                                        nested              NaN
#                                                        sandbox             NaN
#                          subresourceloadingCORP_object direct              NaN
# subresource-loading-csp  imgloading_iframe             direct           5420.0
# upgrade-hsts             upgradeHSTS_direct            direct           6648.0
#                          upgradeHSTS_subdomain         subdomain        6648.0
# window-references-coop   accesswindow_direct           direct           5312.0

# %%
all_test_functions = df[["test_name", "relation_info"]].drop_duplicates()
print(len(all_test_functions))
display(all_test_functions)
# Out:
# 35
#                              test_name   relation_info
# 0                   upgradeHSTS_direct          direct
# 1                upgradeHSTS_subdomain       subdomain
# 7                  accesswindow_direct          direct
# 66                           fetch_GET          simple
# 67                          fetch_TEST   custom_method
# 68                           fetch_GET  custom_headers
# 69                           fetch_GET     credentials
# 1005                    framing_iframe          direct
# 1006                    framing_iframe          nested
# 1168                   referrer_iframe          iframe
# 1173                 imgloading_iframe          direct
# 1185           script_execution_iframe          direct
# 1211                 fullscreen_iframe          direct
# 1212                 fullscreen_iframe     child_allow
# 1294        subresourceloadingCOEP_img          direct
# 3155        subresourceloadingCORP_img          direct
# 4025                       perfAPI_img          direct
# 272916                 referrer_iframe     window.open
# 273031         script_execution_iframe         sandbox
# 273039               fullscreen_iframe           child
# 273041               fullscreen_iframe   child_sandbox
# 273312                  framing_object          direct
# 273313                   framing_embed          direct
# 273314                  framing_iframe         sandbox
# 273315                  framing_object         sandbox
# 273316                   framing_embed         sandbox
# 273318                  framing_object          nested
# 273319                   framing_embed          nested
# 273415   subresourceloadingCORP_object          direct
# 273416      subresourceloadingCORP_img         sandbox
# 273417      subresourceloadingCORP_img          nested
# 275495      subresourceloadingCOEP_img         sandbox
# 1365381                sniffing_script          direct
# 2918417          upgradeHSTS_subdomain            None
# 4806775             upgradeHSTS_direct            None

# %%
display(df.groupby(["resp_type"])["response_id"].nunique())

display(df.groupby(["resp_type", "label"])["response_id"].nunique())
# Out:
# resp_type
# basic        188
# parsing    43416
# Name: response_id, dtype: int64
# resp_type  label
# basic      COEP            11
#            COOP            11
#            CORP            11
#            CORS             6
#            CSP-FA          17
#            CSP-IMG         17
#            CSP-SCRIPT      17
#            CSPvsXFO         7
#            HSTS            14
#            PP              24
#            RP              16
#            TAO             13
#            XCTO            13
#            XFO             11
# parsing    COEP          2637
#            COOP          2656
#            CORP          3357
#            CORS-ACAC      864
#            CORS-ACAH     1577
#            CORS-ACAM     1576
#            CORS-ACAO     2465
#            CORS-ACEH     1577
#            CSP-FA        2744
#            CSP-IMG       2710
#            CSP-SCRIPT    2726
#            CSPvsXFO      1440
#            HSTS          3324
#            PP            3880
#            RP            2797
#            TAO           1601
#            XCTO           889
#            XFO           4596
# Name: response_id, dtype: int64

# %%
4596+1440+2744 , 864+1577+1576+2465+1577
# Out:
# (8780, 8059)

# %%
8780*2
# Out:
# 17560

# %%
8059*2
# Out:
# 16118

# %%
# 175 basic responses (/13 label groups) * 32 test functions * 16 origin relations * 4
(188/13)*33*16
# Out:
# 7635.692307692308

# %%
len(df.loc[df["resp_type"] == "parsing"][["test_name","relation_info"]].drop_duplicates())
# Out:
# 20

# %%
43416/17 * 17 * 4
# Out:
# 173664.0

# %%
# Number of test_ids per browser
# Should be 9992 and 167154
df.loc[df["test_status"] == 0].groupby(["resp_type", "browser"])["test_id"].nunique()
# Out:
# resp_type  browser
# basic      brave Android 11 1.62.165_shield intent real                             9992
#            brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new      9992
#            chrome Android 11 121.0.6167.180 intent real                             9992
#            chrome Ubuntu 22.04 120 selenium headless-new                            9992
#            chrome Ubuntu 22.04 121 selenium headless-new                            9992
#            chrome Ubuntu 22.04 122 selenium headless-new                            9992
#            chrome iPadOS 17.3.1 122.0.6261.89 intent real                           9992
#            firefox Ubuntu 22.04 121 selenium headless                               9992
#            firefox Ubuntu 22.04 122 selenium headless                               9992
#            firefox Ubuntu 22.04 123 selenium headless                               9992
#            firefox_beta Android 11 123.0b9 intent real                              9992
#            safari macOS 14.3.1 17.3.1 selenium real                                 9992
# parsing    brave Android 11 1.62.165_shield intent real                           167154
#            brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new    167154
#            chrome Android 11 121.0.6167.180 intent real                           167154
#            chrome Ubuntu 22.04 120 selenium headless-new                          167154
#            chrome Ubuntu 22.04 121 selenium headless-new                          167154
#            chrome Ubuntu 22.04 122 selenium headless-new                          167154
#            chrome iPadOS 17.3.1 122.0.6261.89 intent real                         167154
#            firefox Ubuntu 22.04 121 selenium headless                             167154
#            firefox Ubuntu 22.04 122 selenium headless                             167154
#            firefox Ubuntu 22.04 123 selenium headless                             167154
#            firefox_beta Android 11 123.0b9 intent real                            167154
#            safari macOS 14.3.1 17.3.1 selenium real                               167154
# Name: test_id, dtype: int64

# %%
# Which tests have how many outcomes?

grouped = df.loc[df["test_status"] == 0].groupby(["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id", "browser", "resp_type"])['outcome_str'].count().reset_index()

with pd.option_context("display.max_rows", 256):
    display(grouped.groupby("browser")["outcome_str"].agg(["mean", "min", "max"]).T)
    res = grouped.groupby(["browser", "resp_type", "test_name"])["outcome_str"].agg(["mean", "min", "max", "count", "sum"]).sort_values(by="mean", ascending=False)
    display(res.loc[res["mean"] > 0].head(10))
    display(res.loc[res["mean"] > 0].tail(10))
# Out:
# browser  brave Android 11 1.62.165_shield intent real  \
# mean                                          8.79868
# min                                           5.00000
# max                                          22.00000
#
# browser  brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  \
# mean                                              5.000406
# min                                               5.000000
# max                                               6.000000
#
# browser  chrome Android 11 121.0.6167.180 intent real  \
# mean                                         5.202144
# min                                          5.000000
# max                                         52.000000
#
# browser  chrome Ubuntu 22.04 120 selenium headless-new  \
# mean                                               5.0
# min                                                5.0
# max                                                5.0
#
# browser  chrome Ubuntu 22.04 121 selenium headless-new  \
# mean                                               5.0
# min                                                5.0
# max                                                5.0
#
# browser  chrome Ubuntu 22.04 122 selenium headless-new  \
# mean                                          5.002546
# min                                           5.000000
# max                                           6.000000
#
# browser  chrome iPadOS 17.3.1 122.0.6261.89 intent real  \
# mean                                           5.025216
# min                                            5.000000
# max                                           16.000000
#
# browser  firefox Ubuntu 22.04 121 selenium headless  \
# mean                                       5.000085
# min                                        5.000000
# max                                        6.000000
#
# browser  firefox Ubuntu 22.04 122 selenium headless  \
# mean                                            5.0
# min                                             5.0
# max                                             5.0
#
# browser  firefox Ubuntu 22.04 123 selenium headless  \
# mean                                       5.000085
# min                                        5.000000
# max                                        6.000000
#
# browser  firefox_beta Android 11 123.0b9 intent real  \
# mean                                        5.465734
# min                                         5.000000
# max                                        54.000000
#
# browser  safari macOS 14.3.1 17.3.1 selenium real
# mean                                      5.12462
# min                                       5.00000
# max                                      10.00000
#                                                                                         mean  \
# browser                                      resp_type test_name
# chrome Android 11 121.0.6167.180 intent real parsing   sniffing_script             13.415073
# firefox_beta Android 11 123.0b9 intent real  parsing   accesswindow_direct         12.941453
# brave Android 11 1.62.165_shield intent real basic     upgradeHSTS_direct          10.642857
#                                                        upgradeHSTS_subdomain       10.642857
# firefox_beta Android 11 123.0b9 intent real  basic     sniffing_script             10.346154
# brave Android 11 1.62.165_shield intent real parsing   subresourceloadingCOEP_img   9.405954
# firefox_beta Android 11 123.0b9 intent real  parsing   imgloading_iframe            9.383395
# brave Android 11 1.62.165_shield intent real parsing   fetch_GET                    9.276275
#                                                        fetch_TEST                   9.276275
#                                                        perfAPI_img                  9.219863
#
#                                                                                    min  \
# browser                                      resp_type test_name
# chrome Android 11 121.0.6167.180 intent real parsing   sniffing_script               5
# firefox_beta Android 11 123.0b9 intent real  parsing   accesswindow_direct           5
# brave Android 11 1.62.165_shield intent real basic     upgradeHSTS_direct            5
#                                                        upgradeHSTS_subdomain         5
# firefox_beta Android 11 123.0b9 intent real  basic     sniffing_script               5
# brave Android 11 1.62.165_shield intent real parsing   subresourceloadingCOEP_img    5
# firefox_beta Android 11 123.0b9 intent real  parsing   imgloading_iframe             5
# brave Android 11 1.62.165_shield intent real parsing   fetch_GET                     5
#                                                        fetch_TEST                    5
#                                                        perfAPI_img                   6
#
#                                                                                    max  \
# browser                                      resp_type test_name
# chrome Android 11 121.0.6167.180 intent real parsing   sniffing_script              52
# firefox_beta Android 11 123.0b9 intent real  parsing   accesswindow_direct          54
# brave Android 11 1.62.165_shield intent real basic     upgradeHSTS_direct           17
#                                                        upgradeHSTS_subdomain        17
# firefox_beta Android 11 123.0b9 intent real  basic     sniffing_script              17
# brave Android 11 1.62.165_shield intent real parsing   subresourceloadingCOEP_img   20
# firefox_beta Android 11 123.0b9 intent real  parsing   imgloading_iframe            54
# brave Android 11 1.62.165_shield intent real parsing   fetch_GET                    22
#                                                        fetch_TEST                   22
#                                                        perfAPI_img                  18
#
#                                                                                    count  \
# browser                                      resp_type test_name
# chrome Android 11 121.0.6167.180 intent real parsing   sniffing_script              1778
# firefox_beta Android 11 123.0b9 intent real  parsing   accesswindow_direct          5312
# brave Android 11 1.62.165_shield intent real basic     upgradeHSTS_direct             28
#                                                        upgradeHSTS_subdomain          28
# firefox_beta Android 11 123.0b9 intent real  basic     sniffing_script               208
# brave Android 11 1.62.165_shield intent real parsing   subresourceloadingCOEP_img   5274
# firefox_beta Android 11 123.0b9 intent real  parsing   imgloading_iframe            5420
# brave Android 11 1.62.165_shield intent real parsing   fetch_GET                   48354
#                                                        fetch_TEST                  16118
#                                                        perfAPI_img                  3202
#
#                                                                                       sum
# browser                                      resp_type test_name
# chrome Android 11 121.0.6167.180 intent real parsing   sniffing_script              23852
# firefox_beta Android 11 123.0b9 intent real  parsing   accesswindow_direct          68745
# brave Android 11 1.62.165_shield intent real basic     upgradeHSTS_direct             298
#                                                        upgradeHSTS_subdomain          298
# firefox_beta Android 11 123.0b9 intent real  basic     sniffing_script               2152
# brave Android 11 1.62.165_shield intent real parsing   subresourceloadingCOEP_img   49607
# firefox_beta Android 11 123.0b9 intent real  parsing   imgloading_iframe            50858
# brave Android 11 1.62.165_shield intent real parsing   fetch_GET                   448545
#                                                        fetch_TEST                  149515
#                                                        perfAPI_img                  29522
#                                                                                     mean  \
# browser                                       resp_type test_name
# chrome Ubuntu 22.04 122 selenium headless-new basic     accesswindow_direct          5.0
# chrome Ubuntu 22.04 121 selenium headless-new parsing   upgradeHSTS_subdomain        5.0
#                                                         upgradeHSTS_direct           5.0
#                                                         subresourceloadingCORP_img   5.0
#                                                         subresourceloadingCOEP_img   5.0
#                                                         sniffing_script              5.0
#                                                         script_execution_iframe      5.0
#                                                         referrer_iframe              5.0
#                                                         perfAPI_img                  5.0
# chrome Ubuntu 22.04 122 selenium headless-new basic     fetch_GET                    5.0
#
#                                                                                     min  \
# browser                                       resp_type test_name
# chrome Ubuntu 22.04 122 selenium headless-new basic     accesswindow_direct           5
# chrome Ubuntu 22.04 121 selenium headless-new parsing   upgradeHSTS_subdomain         5
#                                                         upgradeHSTS_direct            5
#                                                         subresourceloadingCORP_img    5
#                                                         subresourceloadingCOEP_img    5
#                                                         sniffing_script               5
#                                                         script_execution_iframe       5
#                                                         referrer_iframe               5
#                                                         perfAPI_img                   5
# chrome Ubuntu 22.04 122 selenium headless-new basic     fetch_GET                     5
#
#                                                                                     max  \
# browser                                       resp_type test_name
# chrome Ubuntu 22.04 122 selenium headless-new basic     accesswindow_direct           5
# chrome Ubuntu 22.04 121 selenium headless-new parsing   upgradeHSTS_subdomain         5
#                                                         upgradeHSTS_direct            5
#                                                         subresourceloadingCORP_img    5
#                                                         subresourceloadingCOEP_img    5
#                                                         sniffing_script               5
#                                                         script_execution_iframe       5
#                                                         referrer_iframe               5
#                                                         perfAPI_img                   5
# chrome Ubuntu 22.04 122 selenium headless-new basic     fetch_GET                     5
#
#                                                                                     count  \
# browser                                       resp_type test_name
# chrome Ubuntu 22.04 122 selenium headless-new basic     accesswindow_direct           176
# chrome Ubuntu 22.04 121 selenium headless-new parsing   upgradeHSTS_subdomain        6648
#                                                         upgradeHSTS_direct           6648
#                                                         subresourceloadingCORP_img   6714
#                                                         subresourceloadingCOEP_img   5274
#                                                         sniffing_script              1778
#                                                         script_execution_iframe      5452
#                                                         referrer_iframe              5594
#                                                         perfAPI_img                  3202
# chrome Ubuntu 22.04 122 selenium headless-new basic     fetch_GET                     288
#
#                                                                                       sum
# browser                                       resp_type test_name
# chrome Ubuntu 22.04 122 selenium headless-new basic     accesswindow_direct           880
# chrome Ubuntu 22.04 121 selenium headless-new parsing   upgradeHSTS_subdomain       33240
#                                                         upgradeHSTS_direct          33240
#                                                         subresourceloadingCORP_img  33570
#                                                         subresourceloadingCOEP_img  26370
#                                                         sniffing_script              8890
#                                                         script_execution_iframe     27260
#                                                         referrer_iframe             27970
#                                                         perfAPI_img                 16010
# chrome Ubuntu 22.04 122 selenium headless-new basic     fetch_GET                    1440

# %% [markdown]
# ## Stability
# - How many tests have more than one result for the 5+ repetitions in a browser?

# %% [markdown]
# ### General
# - Basic:
#     - total of 226 tests (0.19%) have different results
#     - subresourceloadingCOEP_img is the worst offender (mostly caused by random behavior Firefox bug!, has nothing to do with our test infrastructure)
#     - apart from subresourceloadingCOEP_img seems to be mostly timeout related and thus should be "fixed" by majority voting
# - Parsing:
#     - total of 1306 tests (0.07%) have different results
#     - subresourceloadingCOEP_img worst offender
#     - fetch_GET (Safari only), and upgrade_HSTS (several browsers) also occurs
#     - Safari (MacOS + iPad) has slightly higher rates than the other browsers

# %%
len(df), len(df.loc[df["test_status"] == 0])
# Out:
# (11447247, 11447089)

# %%
df.loc[df["test_status"] == 0].groupby("resp_type")[["browser", "test_id"]].nunique()
# Out:
#            browser  test_id
# resp_type
# basic           12     9992
# parsing         12   167154

# %%
(226+1306)/(9992*12+167154*12)*100
# Out:
# 0.07206861383642119

# %%
226/(9992*12)*100
# Out:
# 0.1884841206298372

# %%
1306/(167154*12)*100
# Out:
# 0.06510961947266193

# %%
# Remove all tests that timed out (test_status == 0), each test should have at least 5 results that did not time out in each browser
df_org = df
df = df.loc[df["test_status"] == 0]

# %%
details = False
for group_name, resp_type_group in df.groupby("resp_type"):
    print(group_name)
    stab = resp_type_group.groupby(["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id", "browser"])[["outcome_str"]].agg(["count", "nunique"])    # Tests with more than one outcome
    diff_outcomes = stab.loc[stab[("outcome_str", "nunique")] != 1]
    print(f"{len(diff_outcomes)} tests have different outcomes!")
    display(diff_outcomes.reset_index()["browser"].value_counts().to_frame())
    with pd.option_context("display.max_rows", 100):
        display(diff_outcomes.reset_index()[["test_name", "browser"]].value_counts().to_frame())

    diff_with_responses = diff_outcomes.reset_index().groupby(["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "browser"])["response_id"].agg(list).to_frame().reset_index()

    if not details:
        continue
    for id, (test_name, org_scheme, org_host, resp_scheme, resp_host, relation_info, browser, response_ids) in diff_with_responses.iterrows():
        print(test_name, response_ids)
        rows = df.loc[(df["org_scheme"] == org_scheme) & (df["test_name"] == test_name) & (df["resp_scheme"] == resp_scheme) & (df["resp_host"] == resp_host) & (df["relation_info"] == relation_info) & (df["response_id"].isin(response_ids)) & (df["browser"] == browser)]
        with pd.option_context("display.max_colwidth", 200):
            display(rows[["outcome_str", "browser"]].value_counts().to_frame())
            disp = rows.drop_duplicates(subset="outcome_str")[["browser", "outcome_str", "raw_header", "test_name", "org_scheme", "org_host", "resp_scheme", "relation_info", "resp_host", "full_url"]]
            disp = disp.style.format({'full_url': make_clickable})
            display(disp)
# Out:
# basic
# 226 tests have different outcomes!
#                                                     count
# browser
# firefox_beta Android 11 123.0b9 intent real            95
# firefox Ubuntu 22.04 123 selenium headless             35
# firefox Ubuntu 22.04 121 selenium headless             32
# firefox Ubuntu 22.04 122 selenium headless             31
# chrome Ubuntu 22.04 120 selenium headless-new           8
# safari macOS 14.3.1 17.3.1 selenium real                7
# chrome Android 11 121.0.6167.180 intent real            6
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      5
# chrome iPadOS 17.3.1 122.0.6261.89 intent real          5
# chrome Ubuntu 22.04 121 selenium headless-new           1
# brave Android 11 1.62.165_shield intent real            1
#                                                                                count
# (test_name, )              (browser, )
# subresourceloadingCOEP_img firefox_beta Android 11 123.0b9 intent real            95
#                            firefox Ubuntu 22.04 123 selenium headless             34
#                            firefox Ubuntu 22.04 121 selenium headless             32
#                            firefox Ubuntu 22.04 122 selenium headless             30
# perfAPI_img                chrome Ubuntu 22.04 120 selenium headless-new           7
# subresourceloadingCOEP_img safari macOS 14.3.1 17.3.1 selenium real                7
# referrer_iframe            brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      5
# subresourceloadingCOEP_img chrome iPadOS 17.3.1 122.0.6261.89 intent real          5
# accesswindow_direct        chrome Android 11 121.0.6167.180 intent real            3
# referrer_iframe            chrome Android 11 121.0.6167.180 intent real            3
# framing_embed              firefox Ubuntu 22.04 123 selenium headless              1
# referrer_iframe            brave Android 11 1.62.165_shield intent real            1
# framing_object             firefox Ubuntu 22.04 122 selenium headless              1
# referrer_iframe            chrome Ubuntu 22.04 120 selenium headless-new           1
#                            chrome Ubuntu 22.04 121 selenium headless-new           1
# parsing
# 1306 tests have different outcomes!
#                                                     count
# browser
# safari macOS 14.3.1 17.3.1 selenium real              375
# chrome iPadOS 17.3.1 122.0.6261.89 intent real        161
# firefox Ubuntu 22.04 123 selenium headless            121
# chrome Ubuntu 22.04 122 selenium headless-new         113
# chrome Ubuntu 22.04 121 selenium headless-new         112
# chrome Android 11 121.0.6167.180 intent real           97
# chrome Ubuntu 22.04 120 selenium headless-new          83
# firefox Ubuntu 22.04 122 selenium headless             76
# firefox Ubuntu 22.04 121 selenium headless             59
# firefox_beta Android 11 123.0b9 intent real            47
# brave Android 11 1.62.165_shield intent real           37
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...     25
#                                                                                count
# (test_name, )              (browser, )
# subresourceloadingCOEP_img safari macOS 14.3.1 17.3.1 selenium real              152
#                            chrome iPadOS 17.3.1 122.0.6261.89 intent real        144
# fetch_GET                  safari macOS 14.3.1 17.3.1 selenium real               73
# subresourceloadingCOEP_img chrome Ubuntu 22.04 121 selenium headless-new          65
#                            firefox Ubuntu 22.04 121 selenium headless             56
# upgradeHSTS_direct         chrome Ubuntu 22.04 120 selenium headless-new          55
# subresourceloadingCOEP_img firefox Ubuntu 22.04 123 selenium headless             53
# upgradeHSTS_direct         firefox Ubuntu 22.04 123 selenium headless             49
# subresourceloadingCOEP_img firefox Ubuntu 22.04 122 selenium headless             48
#                            firefox_beta Android 11 123.0b9 intent real            45
# upgradeHSTS_direct         chrome Android 11 121.0.6167.180 intent real           44
# subresourceloadingCOEP_img chrome Ubuntu 22.04 122 selenium headless-new          44
# imgloading_iframe          chrome Ubuntu 22.04 121 selenium headless-new          42
# upgradeHSTS_subdomain      safari macOS 14.3.1 17.3.1 selenium real               37
# script_execution_iframe    safari macOS 14.3.1 17.3.1 selenium real               35
# upgradeHSTS_direct         safari macOS 14.3.1 17.3.1 selenium real               27
# fetch_TEST                 safari macOS 14.3.1 17.3.1 selenium real               24
# upgradeHSTS_direct         brave Android 11 1.62.165_shield intent real           23
# subresourceloadingCOEP_img chrome Android 11 121.0.6167.180 intent real           19
# framing_iframe             chrome Ubuntu 22.04 122 selenium headless-new          19
# upgradeHSTS_subdomain      firefox Ubuntu 22.04 123 selenium headless             19
# subresourceloadingCOEP_img chrome Ubuntu 22.04 120 selenium headless-new          17
# upgradeHSTS_subdomain      chrome Ubuntu 22.04 122 selenium headless-new          15
# script_execution_iframe    firefox Ubuntu 22.04 122 selenium headless             14
# upgradeHSTS_subdomain      chrome Android 11 121.0.6167.180 intent real           13
# upgradeHSTS_direct         chrome Ubuntu 22.04 122 selenium headless-new          12
# imgloading_iframe          brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...     11
# perfAPI_img                chrome Ubuntu 22.04 122 selenium headless-new          10
# imgloading_iframe          firefox Ubuntu 22.04 122 selenium headless             10
#                            chrome Ubuntu 22.04 120 selenium headless-new           9
# framing_iframe             safari macOS 14.3.1 17.3.1 selenium real                9
# imgloading_iframe          safari macOS 14.3.1 17.3.1 selenium real                9
# accesswindow_direct        brave Android 11 1.62.165_shield intent real            8
# fullscreen_iframe          safari macOS 14.3.1 17.3.1 selenium real                8
# script_execution_iframe    chrome Android 11 121.0.6167.180 intent real            8
# upgradeHSTS_direct         chrome iPadOS 17.3.1 122.0.6261.89 intent real          7
# imgloading_iframe          chrome Ubuntu 22.04 122 selenium headless-new           7
# fetch_GET                  brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      7
# upgradeHSTS_subdomain      chrome iPadOS 17.3.1 122.0.6261.89 intent real          6
# imgloading_iframe          chrome Android 11 121.0.6167.180 intent real            6
# subresourceloadingCOEP_img brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      5
# upgradeHSTS_subdomain      brave Android 11 1.62.165_shield intent real            5
# script_execution_iframe    chrome Ubuntu 22.04 122 selenium headless-new           4
# accesswindow_direct        chrome Android 11 121.0.6167.180 intent real            4
# script_execution_iframe    firefox Ubuntu 22.04 121 selenium headless              3
# upgradeHSTS_direct         firefox_beta Android 11 123.0b9 intent real             2
# fullscreen_iframe          firefox Ubuntu 22.04 122 selenium headless              2
# framing_iframe             chrome Ubuntu 22.04 121 selenium headless-new           2
# accesswindow_direct        chrome iPadOS 17.3.1 122.0.6261.89 intent real          2
# subresourceloadingCORP_img chrome Android 11 121.0.6167.180 intent real            2
# fetch_TEST                 brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      1
# fetch_GET                  firefox Ubuntu 22.04 122 selenium headless              1
#                            chrome Android 11 121.0.6167.180 intent real            1
#                            chrome iPadOS 17.3.1 122.0.6261.89 intent real          1
# accesswindow_direct        chrome Ubuntu 22.04 122 selenium headless-new           1
# script_execution_iframe    chrome Ubuntu 22.04 120 selenium headless-new           1
# referrer_iframe            chrome Ubuntu 22.04 122 selenium headless-new           1
#                            chrome Ubuntu 22.04 121 selenium headless-new           1
# fullscreen_iframe          chrome Ubuntu 22.04 121 selenium headless-new           1
# subresourceloadingCORP_img brave Android 11 1.62.165_shield intent real            1
# script_execution_iframe    chrome Ubuntu 22.04 121 selenium headless-new           1
# fetch_TEST                 chrome iPadOS 17.3.1 122.0.6261.89 intent real          1
# framing_iframe             brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      1
# fetch_TEST                 firefox Ubuntu 22.04 122 selenium headless              1
# framing_iframe             chrome Ubuntu 22.04 120 selenium headless-new           1
# subresourceloadingCORP_img safari macOS 14.3.1 17.3.1 selenium real                1

# %% [markdown]
# ### Test groups that are the most unstable
# - Overall mean: 0.07% of tests have more than one outcome
# - Browsers:
#     - worst: safari MacOS with 0.2%
#     - best: brave Ubuntu with 0.02%
# - Test groups:
#     - worst: subresourceloadingCOEP_img has the highest values with: 4% (basic) and 0.9% (parsing)
#     - best: many have 0 or near 0 values
# - Browsers + Test groups:
#     - worst: firefox_beta Android subresourceloadingCOEP_img 26.99% (basic)
#     - best: many have 0
# - If a test has unstable results, is it because one noisy result occured once, or because two results occurr roughly with the same frequency?
#     - I.e., does majority voting makes sense, is likely to result in the correct outcome?!
#     - Most tests have 80%/20% rations (i.e., 4x the same result, 1x an incorrect result)
#     - Out of the tests with more than one result: mean ration of the majority winner: 0.763062, highest mean: 0.821693 (fetch_TEST) lowest mean: 0.724169 (subresourceloadingCOEP_img)
#     - Main exception: subresourceloadingCOEP_img
#     - Other smaller exceptions: upgradeHSTS_\*, ~~oac_\*~~, referrer_iframe, accesswindow_direct

# %%
# Different outcomes (in percentage for a test group (test_name)
# (Does not take into account how often each test was executed only if any of the 5+ repetitions had a different value)

grouped = df.groupby(["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id", "browser", "resp_type"])['outcome_str'].nunique().reset_index()

grouped["diff_outcome"] = grouped["outcome_str"] > 1
with pd.option_context("display.max_rows", 100):
    display(grouped["diff_outcome"].agg(["count", "mean", "median", "min", "max"]).to_frame())
    display(grouped.groupby(["browser"])["diff_outcome"].agg(["mean", "count", "sum"]).sort_values(by="mean", ascending=False))
    display(grouped.groupby(["test_name", "resp_type"])["diff_outcome"].agg(["mean", "count", "sum"]).sort_values(by="mean", ascending=False))
    res = grouped.groupby(["browser", "resp_type", "test_name"])["diff_outcome"].agg(["mean", "count", "sum"]).sort_values(by="mean", ascending=False)
    display(res.loc[res["mean"] > 0].head(20))
# Out:
#        diff_outcome
# count       2125752
# mean       0.000721
# median          0.0
# min           False
# max            True
#                                                         mean   count  sum
# browser
# safari macOS 14.3.1 17.3.1 selenium real            0.002156  177146  382
# chrome iPadOS 17.3.1 122.0.6261.89 intent real      0.000937  177146  166
# firefox Ubuntu 22.04 123 selenium headless          0.000881  177146  156
# firefox_beta Android 11 123.0b9 intent real         0.000802  177146  142
# chrome Ubuntu 22.04 121 selenium headless-new       0.000638  177146  113
# chrome Ubuntu 22.04 122 selenium headless-new       0.000638  177146  113
# firefox Ubuntu 22.04 122 selenium headless          0.000604  177146  107
# chrome Android 11 121.0.6167.180 intent real        0.000581  177146  103
# chrome Ubuntu 22.04 120 selenium headless-new       0.000514  177146   91
# firefox Ubuntu 22.04 121 selenium headless          0.000514  177146   91
# brave Android 11 1.62.165_shield intent real        0.000215  177146   38
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...  0.000169  177146   30
#                                              mean   count  sum
# test_name                     resp_type
# subresourceloadingCOEP_img    basic      0.048059    4224  203
#                               parsing    0.010239   63288  648
# perfAPI_img                   basic      0.002804    2496    7
# upgradeHSTS_direct            parsing    0.002745   79776  219
# referrer_iframe               basic      0.001790    6144   11
# imgloading_iframe             parsing    0.001445   65040   94
# accesswindow_direct           basic      0.001420    2112    3
# upgradeHSTS_subdomain         parsing    0.001191   79776   95
# script_execution_iframe       parsing    0.001009   65424   66
# perfAPI_img                   parsing    0.000260   38424   10
# accesswindow_direct           parsing    0.000235   63744   15
# fetch_GET                     parsing    0.000143  580248   83
# fetch_TEST                    parsing    0.000140  193416   27
# framing_iframe                parsing    0.000076  421440   32
# fullscreen_iframe             parsing    0.000059  186240   11
# subresourceloadingCORP_img    parsing    0.000050   80568    4
# framing_object                basic      0.000050   20160    1
# framing_embed                 basic      0.000050   20160    1
# referrer_iframe               parsing    0.000030   67128    2
# fetch_GET                     basic      0.000000    3456    0
# fullscreen_iframe             basic      0.000000   18432    0
# framing_iframe                basic      0.000000   20160    0
# fetch_TEST                    basic      0.000000    1152    0
# imgloading_iframe             basic      0.000000    3264    0
# sniffing_script               parsing    0.000000   21336    0
# script_execution_iframe       basic      0.000000    6528    0
# sniffing_script               basic      0.000000    2496    0
# subresourceloadingCORP_object basic      0.000000    2112    0
# subresourceloadingCORP_img    basic      0.000000    6336    0
# upgradeHSTS_direct            basic      0.000000     336    0
# upgradeHSTS_subdomain         basic      0.000000     336    0
#                                                                                              mean  \
# browser                                            resp_type test_name
# firefox_beta Android 11 123.0b9 intent real        basic     subresourceloadingCOEP_img  0.269886
# firefox Ubuntu 22.04 123 selenium headless         basic     subresourceloadingCOEP_img  0.096591
# firefox Ubuntu 22.04 121 selenium headless         basic     subresourceloadingCOEP_img  0.090909
# firefox Ubuntu 22.04 122 selenium headless         basic     subresourceloadingCOEP_img  0.085227
# chrome Ubuntu 22.04 120 selenium headless-new      basic     perfAPI_img                 0.033654
# safari macOS 14.3.1 17.3.1 selenium real           parsing   subresourceloadingCOEP_img  0.028821
# chrome iPadOS 17.3.1 122.0.6261.89 intent real     parsing   subresourceloadingCOEP_img  0.027304
# safari macOS 14.3.1 17.3.1 selenium real           basic     subresourceloadingCOEP_img  0.019886
# chrome Android 11 121.0.6167.180 intent real       basic     accesswindow_direct         0.017045
# chrome iPadOS 17.3.1 122.0.6261.89 intent real     basic     subresourceloadingCOEP_img  0.014205
# chrome Ubuntu 22.04 121 selenium headless-new      parsing   subresourceloadingCOEP_img  0.012325
# firefox Ubuntu 22.04 121 selenium headless         parsing   subresourceloadingCOEP_img  0.010618
# firefox Ubuntu 22.04 123 selenium headless         parsing   subresourceloadingCOEP_img  0.010049
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s... basic     referrer_iframe             0.009766
# firefox Ubuntu 22.04 122 selenium headless         parsing   subresourceloadingCOEP_img  0.009101
# firefox_beta Android 11 123.0b9 intent real        parsing   subresourceloadingCOEP_img  0.008532
# chrome Ubuntu 22.04 122 selenium headless-new      parsing   subresourceloadingCOEP_img  0.008343
# chrome Ubuntu 22.04 120 selenium headless-new      parsing   upgradeHSTS_direct          0.008273
# chrome Ubuntu 22.04 121 selenium headless-new      parsing   imgloading_iframe           0.007749
# firefox Ubuntu 22.04 123 selenium headless         parsing   upgradeHSTS_direct          0.007371
#
#                                                                                          count  \
# browser                                            resp_type test_name
# firefox_beta Android 11 123.0b9 intent real        basic     subresourceloadingCOEP_img    352
# firefox Ubuntu 22.04 123 selenium headless         basic     subresourceloadingCOEP_img    352
# firefox Ubuntu 22.04 121 selenium headless         basic     subresourceloadingCOEP_img    352
# firefox Ubuntu 22.04 122 selenium headless         basic     subresourceloadingCOEP_img    352
# chrome Ubuntu 22.04 120 selenium headless-new      basic     perfAPI_img                   208
# safari macOS 14.3.1 17.3.1 selenium real           parsing   subresourceloadingCOEP_img   5274
# chrome iPadOS 17.3.1 122.0.6261.89 intent real     parsing   subresourceloadingCOEP_img   5274
# safari macOS 14.3.1 17.3.1 selenium real           basic     subresourceloadingCOEP_img    352
# chrome Android 11 121.0.6167.180 intent real       basic     accesswindow_direct           176
# chrome iPadOS 17.3.1 122.0.6261.89 intent real     basic     subresourceloadingCOEP_img    352
# chrome Ubuntu 22.04 121 selenium headless-new      parsing   subresourceloadingCOEP_img   5274
# firefox Ubuntu 22.04 121 selenium headless         parsing   subresourceloadingCOEP_img   5274
# firefox Ubuntu 22.04 123 selenium headless         parsing   subresourceloadingCOEP_img   5274
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s... basic     referrer_iframe               512
# firefox Ubuntu 22.04 122 selenium headless         parsing   subresourceloadingCOEP_img   5274
# firefox_beta Android 11 123.0b9 intent real        parsing   subresourceloadingCOEP_img   5274
# chrome Ubuntu 22.04 122 selenium headless-new      parsing   subresourceloadingCOEP_img   5274
# chrome Ubuntu 22.04 120 selenium headless-new      parsing   upgradeHSTS_direct           6648
# chrome Ubuntu 22.04 121 selenium headless-new      parsing   imgloading_iframe            5420
# firefox Ubuntu 22.04 123 selenium headless         parsing   upgradeHSTS_direct           6648
#
#                                                                                          sum
# browser                                            resp_type test_name
# firefox_beta Android 11 123.0b9 intent real        basic     subresourceloadingCOEP_img   95
# firefox Ubuntu 22.04 123 selenium headless         basic     subresourceloadingCOEP_img   34
# firefox Ubuntu 22.04 121 selenium headless         basic     subresourceloadingCOEP_img   32
# firefox Ubuntu 22.04 122 selenium headless         basic     subresourceloadingCOEP_img   30
# chrome Ubuntu 22.04 120 selenium headless-new      basic     perfAPI_img                   7
# safari macOS 14.3.1 17.3.1 selenium real           parsing   subresourceloadingCOEP_img  152
# chrome iPadOS 17.3.1 122.0.6261.89 intent real     parsing   subresourceloadingCOEP_img  144
# safari macOS 14.3.1 17.3.1 selenium real           basic     subresourceloadingCOEP_img    7
# chrome Android 11 121.0.6167.180 intent real       basic     accesswindow_direct           3
# chrome iPadOS 17.3.1 122.0.6261.89 intent real     basic     subresourceloadingCOEP_img    5
# chrome Ubuntu 22.04 121 selenium headless-new      parsing   subresourceloadingCOEP_img   65
# firefox Ubuntu 22.04 121 selenium headless         parsing   subresourceloadingCOEP_img   56
# firefox Ubuntu 22.04 123 selenium headless         parsing   subresourceloadingCOEP_img   53
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s... basic     referrer_iframe               5
# firefox Ubuntu 22.04 122 selenium headless         parsing   subresourceloadingCOEP_img   48
# firefox_beta Android 11 123.0b9 intent real        parsing   subresourceloadingCOEP_img   45
# chrome Ubuntu 22.04 122 selenium headless-new      parsing   subresourceloadingCOEP_img   44
# chrome Ubuntu 22.04 120 selenium headless-new      parsing   upgradeHSTS_direct           55
# chrome Ubuntu 22.04 121 selenium headless-new      parsing   imgloading_iframe            42
# firefox Ubuntu 22.04 123 selenium headless         parsing   upgradeHSTS_direct           49

# %%
# What is the ration of different outcomes for tests with more than one outcome?
test = df.groupby(["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id", "browser", "resp_type"])['outcome_str'].value_counts(normalize=True).reset_index()

# General information on tests with more than one outcome
mean_max_value = test.loc[test["proportion"] != 1.0].groupby(["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id", "browser", "resp_type"])["proportion"].max().reset_index()
display(mean_max_value["proportion"].agg(["count", "mean", "std", "min", "median", "max"]))        
display(mean_max_value.groupby("test_name")["proportion"].agg(["count", "mean", "std", "min", "median", "max"]))

# Tests where the most common and second most commont outcome is close (majority vote only is between 0.5 and 0.79) -> noisy test, majority vote might be wrong?
display(test.loc[(test['proportion'] >= 0.5) & (test['proportion'] <= 0.79)]["test_name"].value_counts())

# As a density plot
ax = test.loc[test["proportion"] != 1.0].groupby("test_name")["proportion"].plot(kind="kde", xlim=(0, 1), legend=True, figsize=(20, 6))
ax.iloc[0].legend(loc='lower right')  # Customize the legend location
plt.show()

# Same grouped by browsers
display(test.loc[(test['proportion'] >= 0.5) & (test['proportion'] <= 0.79)].groupby("browser")["test_name"].value_counts().to_frame().sort_values(by="count", ascending=False))

# Raw value counts of proportions
with pd.option_context("display.max_rows", 77):
    display(test.loc[test["proportion"] != 1.0]["proportion"].value_counts())
# Out:
# count     1532.000000
# mean         0.758686
# std          0.090448
# min          0.400000
# median       0.800000
# max          0.937500
# Name: proportion, dtype: float64
#                             count      mean       std       min    median  \
# test_name
# accesswindow_direct            18  0.814881  0.089232  0.555556  0.816667
# fetch_GET                      83  0.821170  0.022572  0.800000  0.833333
# fetch_TEST                     27  0.821693  0.022888  0.800000  0.833333
# framing_embed                   1  0.800000       NaN  0.800000  0.800000
# framing_iframe                 32  0.793750  0.035355  0.600000  0.800000
# framing_object                  1  0.800000       NaN  0.800000  0.800000
# fullscreen_iframe              11  0.800000  0.000000  0.800000  0.800000
# imgloading_iframe              94  0.802432  0.011596  0.800000  0.800000
# perfAPI_img                    17  0.800000  0.000000  0.800000  0.800000
# referrer_iframe                13  0.808974  0.024167  0.750000  0.800000
# script_execution_iframe        66  0.800000  0.000000  0.800000  0.800000
# subresourceloadingCOEP_img    851  0.719653  0.102056  0.400000  0.800000
# subresourceloadingCORP_img      4  0.814286  0.028571  0.800000  0.800000
# upgradeHSTS_direct            219  0.807898  0.041281  0.500000  0.800000
# upgradeHSTS_subdomain          95  0.805682  0.031899  0.666667  0.800000
#
#                                  max
# test_name
# accesswindow_direct         0.900000
# fetch_GET                   0.857143
# fetch_TEST                  0.857143
# framing_embed               0.800000
# framing_iframe              0.800000
# framing_object              0.800000
# fullscreen_iframe           0.800000
# imgloading_iframe           0.857143
# perfAPI_img                 0.800000
# referrer_iframe             0.833333
# script_execution_iframe     0.800000
# subresourceloadingCOEP_img  0.875000
# subresourceloadingCORP_img  0.857143
# upgradeHSTS_direct          0.937500
# upgradeHSTS_subdomain       0.900000
# test_name
# subresourceloadingCOEP_img    330
# upgradeHSTS_direct              8
# upgradeHSTS_subdomain           2
# accesswindow_direct             2
# framing_iframe                  1
# referrer_iframe                 1
# Name: count, dtype: int64
#                                                                            count
# browser                                        test_name
# firefox_beta Android 11 123.0b9 intent real    subresourceloadingCOEP_img     76
# chrome iPadOS 17.3.1 122.0.6261.89 intent real subresourceloadingCOEP_img     72
# safari macOS 14.3.1 17.3.1 selenium real       subresourceloadingCOEP_img     57
# firefox Ubuntu 22.04 121 selenium headless     subresourceloadingCOEP_img     46
# firefox Ubuntu 22.04 123 selenium headless     subresourceloadingCOEP_img     46
# firefox Ubuntu 22.04 122 selenium headless     subresourceloadingCOEP_img     33
# brave Android 11 1.62.165_shield intent real   upgradeHSTS_direct              4
# chrome Android 11 121.0.6167.180 intent real   upgradeHSTS_direct              3
# chrome Ubuntu 22.04 121 selenium headless-new  framing_iframe                  1
# chrome Android 11 121.0.6167.180 intent real   accesswindow_direct             1
# brave Android 11 1.62.165_shield intent real   accesswindow_direct             1
#                                                upgradeHSTS_subdomain           1
# chrome Android 11 121.0.6167.180 intent real   referrer_iframe                 1
# safari macOS 14.3.1 17.3.1 selenium real       upgradeHSTS_direct              1
#                                                upgradeHSTS_subdomain           1
# proportion
# 0.200000    1098
# 0.800000    1062
# 0.400000     330
# 0.600000     328
# 0.833333      48
# 0.166667      48
# 0.142857      31
# 0.857143      31
# 0.100000      12
# 0.900000      12
# 0.875000      11
# 0.125000      11
# 0.888889      10
# 0.111111      10
# 0.750000       5
# 0.250000       5
# 0.777778       3
# 0.222222       3
# 0.846154       2
# 0.666667       2
# 0.700000       2
# 0.300000       2
# 0.153846       2
# 0.333333       2
# 0.500000       2
# 0.555556       1
# 0.444444       1
# 0.642857       1
# 0.090909       1
# 0.909091       1
# 0.357143       1
# 0.916667       1
# 0.083333       1
# 0.923077       1
# 0.076923       1
# 0.062500       1
# 0.937500       1
# 0.071429       1
# 0.928571       1
# Name: count, dtype: int64

# %% [markdown]
# ### Majority Voting
# - Perform majority voting
# - Only firefox_beta Android 11 (basic) subresourceloadingCOEP_img has 8 tests with the same mode, we simply choose the first in such cases

# %%
df = df_org
df = df.loc[df["test_status"] == 0]

# %%
df_stab = df

# Only keep one row for each test
# If the test had non-deterministic results, use majority voting! (only works reliably if there a enough repetitions of the tests runs, >= 5)

print("Original data entries", len(df))

# Majority voting (pd.Series.mode returns the most frequest item) (quite slow)

df = df.groupby(["test_id", "browser"], observed=True)["outcome_str"].agg(pd.Series.mode).reset_index()
print("Only one row for each test (per browser; majority voting)", len(df))
# Out:
# Original data entries 11447089
# Only one row for each test (per browser; majority voting) 2125752

# %%
# Merge back additional required properties!
# ["name", "test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id", "resp_type", "label", 'org_origin', 'resp_origin', 'status_code', 'raw_header']

df = df.merge(df_stab.drop_duplicates(subset=["test_id", "browser"]), on=["test_id", "browser"], how="left", suffixes=["", "_ignore"])

# %%
# Tests with same mode?! maybe rerun again?!
with pd.option_context("display.max_colwidth", None):
    # Firefox subresourceloadingCOEP_img
    # Ignore, indeterminisitc behavior.
    display(df.loc[(df["browser"] == 'firefox_beta Android 11 123.0b9 intent real') & (df['outcome_str'].apply(lambda x: isinstance(x, np.ndarray)))][["outcome_str", "full_url"]])

    # Duckduckgo oac, RP, COOP
    # Rerun all three groups with higher timeouts?
    display(df.loc[(df["browser"] == 'duckduckgo Android 11 5.194.0 intent real') & (df['outcome_str'].apply(lambda x: isinstance(x, np.ndarray)))][["outcome_str", "full_url"]])

    
    # Brave (Android) oac_window.open
    # Rerun one URL! -> fixed
    display(df.loc[(df["browser"] == 'brave Android 11 1.62.165 intent real') & (df['outcome_str'].apply(lambda x: isinstance(x, np.ndarray)))][["outcome_str", "full_url"]])

    # Opera (Android) ugrade_HSTS_direct
    # Rerun one URL! -> fixed
    display(df.loc[(df["browser"] == 'opera Android 11 80.5.4244.78163 intent real') & (df['outcome_str'].apply(lambda x: isinstance(x, np.ndarray)))][["outcome_str", "full_url"]])
# Out:
#                                                                                                                                                                                                                                                                                                                                                      outcome_str  \
# 1841182   [{'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'error', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'load'}, 'window.crossOriginIsolated': False}]
# 1841194    [{'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'load'}, 'window.crossOriginIsolated': False}]
# 1841266   [{'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'error', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'load'}, 'window.crossOriginIsolated': False}]
# 1841542    [{'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'load'}, 'window.crossOriginIsolated': False}]
# 1841650    [{'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'load'}, 'window.crossOriginIsolated': False}]
# 1841674  [{'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'error', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}]
# 1873894   [{'image-events': {'swag.jpg': 'error', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'load'}, 'window.crossOriginIsolated': False}]
# 1874290   [{'image-events': {'swag.jpg': 'error', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'error'}, 'window.crossOriginIsolated': False}, {'image-events': {'swag.jpg': 'load', 'swag-same-site.jpg': 'load', 'swag-cross-site.jpg': 'load', 'swag-same-origin.jpg': 'load'}, 'window.crossOriginIsolated': False}]
#
#                                                                                                                                                                                                                 full_url
# 1841182    http://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=58&last_id=58&scheme=http&run_id=645058ab2c9143599e445a365f502857
# 1841194    http://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=59&last_id=59&scheme=http&run_id=141f1711bc294e1db4f626281598088a
# 1841266    http://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=65&last_id=65&scheme=http&run_id=50b6106d332c437f8a76f52d34f6bbb6
# 1841542    http://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=66&last_id=66&scheme=http&run_id=db5f71465546446eacf64876591928e2
# 1841650    http://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=64&last_id=64&scheme=http&run_id=f0376075d30b402585774303b11dcda4
# 1841674    http://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=66&last_id=66&scheme=http&run_id=db5f71465546446eacf64876591928e2
# 1873894  https://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=59&last_id=59&scheme=https&run_id=c38e1479189245d8a7b5ec707d79f6a0
# 1874290  https://sub.headers.websec.saarland/_hp/tests/subresource-loading-coep.sub.html?timeout=10&resp_type=basic&browser_id=64&label=COEP&first_id=59&last_id=59&scheme=https&run_id=c38e1479189245d8a7b5ec707d79f6a0
# Empty DataFrame
# Columns: [outcome_str, full_url]
# Index: []
# Empty DataFrame
# Columns: [outcome_str, full_url]
# Index: []
# Empty DataFrame
# Columns: [outcome_str, full_url]
# Index: []

# %%
# If several values occur the same, the mode is an np.ndarray and not a string!
# If we have exactly 5 repetitions for each test, the issue cannot exist!
# However, our repeat system only enables us to have 5+ results for each test
print("Tests with the same mode (highest frequency outcome):")
display(df.loc[df['outcome_str'].apply(lambda x: isinstance(x, np.ndarray))].groupby(["browser", "resp_type", "test_name"])["outcome_str"].count())

# In the rare cases, where it actually matters, we can just take the first? (this might be noise in the generated trees and other summaries!)
# These are unstable tests that might indicate random behavior in the browser (e.g., firefox COEP_img)
df['outcome_str'] = df['outcome_str'].apply(lambda x: x[0] if isinstance(x, np.ndarray) else x)
# Out:
# Tests with the same mode (highest frequency outcome):
# browser                                       resp_type  test_name
# brave Android 11 1.62.165_shield intent real  parsing    upgradeHSTS_direct            1
# firefox_beta Android 11 123.0b9 intent real   basic      subresourceloadingCOEP_img    8
# Name: outcome_str, dtype: int64

# %% [markdown]
# # Browser differences
# - Most tests have one outcome only (not interesting for us)
# - 4374 tests have two outcomes, 58 tests have three outcomes
# - All test rows: 2125752, should be: 2125752, Rows with more than one outcome: 53184, Tests with more than one outcome: 4432

# %%
# Most tests have exactly one outcome, quite some have two, couple have three!
res = df.groupby(["resp_type", "test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id", "test_id"], observed=True)
res = res["outcome_str"].agg("nunique")
display(res.value_counts().to_frame())
# Out:
#               count
# outcome_str
# 1            172714
# 2              4374
# 3                58

# %%
4432/(9992+167154)*100
# Out:
# 2.501891095480564

# %% [markdown]
# ## Differences per test group
# - Basic:
#     - subresourceloadingCORP_object 100% of test have different results (WebKit does not support postMessages on objects?)
#     - couple of others have 20%+ differences
#     - others have 0%
# - Parsing:
#     - ~~oac_window.open has 99% (only supported in chromium)~~
#     - other tests with differences are between 0.5% (fetch_GET) and 5% (upgradeHSTS_direct)

# %%
# Basic:
# subresourceloadingCORP_object has different results for 100% of tests
# couple of others have 20%+ differences
# couple have 0%

# Parsing:
# Test groups have between 0.5 - 5% of tests with different outcomes
# Highest: upgradeHSTS_direct with 4.69%
r = res.reset_index()
r["diff"] = r["outcome_str"] != 1
display(r.groupby(["resp_type", "test_name", "relation_info"])["diff"].agg(["count", "sum", "mean"]).sort_values("mean", ascending=False))
display(r.groupby(["resp_type", "test_name", "relation_info"])["diff"].agg(["mean"]).describe())
display(r.groupby(["test_name", "relation_info"])["diff"].agg(["mean"]).describe())
# Out:
#                                                         count  sum      mean
# resp_type test_name                     relation_info
# basic     subresourceloadingCORP_object direct            176  176  1.000000
#           subresourceloadingCOEP_img    direct            176   88  0.500000
#           referrer_iframe               window.open       256  117  0.457031
#           fullscreen_iframe             direct            384  142  0.369792
#           framing_embed                 direct            560  186  0.332143
#           framing_object                direct            560  186  0.332143
#           fullscreen_iframe             child_allow       384  113  0.294271
#           perfAPI_img                   direct            208   55  0.264423
#           framing_object                nested            560  120  0.214286
#           framing_embed                 sandbox           560  120  0.214286
#                                         nested            560  120  0.214286
#           framing_object                sandbox           560  120  0.214286
#           accesswindow_direct           direct            176   28  0.159091
#           script_execution_iframe       sandbox           272   21  0.077206
#           referrer_iframe               iframe            256   18  0.070312
#           fullscreen_iframe             child             384   23  0.059896
#           imgloading_iframe             direct            272   13  0.047794
# parsing   upgradeHSTS_direct            direct           6648  307  0.046179
#           fullscreen_iframe             child_allow      7760  355  0.045747
#           imgloading_iframe             direct           5420  230  0.042435
#           script_execution_iframe       direct           5452  216  0.039618
# basic     upgradeHSTS_direct            direct             28    1  0.035714
# parsing   fullscreen_iframe             direct           7760  272  0.035052
# basic     subresourceloadingCOEP_img    sandbox           176    4  0.022727
# parsing   subresourceloadingCOEP_img    direct           5274  110  0.020857
#           framing_iframe                direct          17560  365  0.020786
#           sniffing_script               direct           1778   34  0.019123
#           referrer_iframe               iframe           5594  101  0.018055
#           upgradeHSTS_subdomain         subdomain        6648  101  0.015193
# basic     framing_iframe                sandbox           560    8  0.014286
# parsing   perfAPI_img                   direct           3202   33  0.010306
#           subresourceloadingCORP_img    direct           6714   68  0.010128
#           accesswindow_direct           direct           5312   44  0.008283
#           framing_iframe                nested          17560  144  0.008200
#           fetch_GET                     simple          16118  104  0.006452
#           fetch_TEST                    custom_method   16118  101  0.006266
#           fetch_GET                     custom_headers  16118  101  0.006266
# basic     subresourceloadingCORP_img    direct            176    1  0.005682
# parsing   fetch_GET                     credentials     16118   86  0.005336
# basic     fetch_GET                     simple             96    0  0.000000
#                                         custom_headers     96    0  0.000000
#                                         credentials        96    0  0.000000
#           framing_iframe                nested            560    0  0.000000
#           fullscreen_iframe             child_sandbox     384    0  0.000000
#           fetch_TEST                    custom_method      96    0  0.000000
#           framing_iframe                direct            560    0  0.000000
#           upgradeHSTS_subdomain         subdomain          28    0  0.000000
#           script_execution_iframe       direct            272    0  0.000000
#           subresourceloadingCORP_img    sandbox           176    0  0.000000
#                                         nested            176    0  0.000000
#           sniffing_script               direct            208    0  0.000000
#             mean
# count  51.000000
# mean    0.103214
# std     0.182667
# min     0.000000
# 25%     0.005509
# 50%     0.020786
# 75%     0.118148
# max     1.000000
#             mean
# count  33.000000
# mean    0.108411
# std     0.197696
# min     0.000000
# 25%     0.010015
# 50%     0.025806
# 75%     0.077206
# max     1.000000

# %%
r.groupby(["test_name", "relation_info"])["diff"].sum()
# Out:
# test_name                      relation_info
# accesswindow_direct            direct             72
# fetch_GET                      credentials        86
#                                custom_headers    101
#                                simple            104
# fetch_TEST                     custom_method     101
# framing_embed                  direct            186
#                                nested            120
#                                sandbox           120
# framing_iframe                 direct            365
#                                nested            144
#                                sandbox             8
# framing_object                 direct            186
#                                nested            120
#                                sandbox           120
# fullscreen_iframe              child              23
#                                child_allow       468
#                                child_sandbox       0
#                                direct            414
# imgloading_iframe              direct            243
# perfAPI_img                    direct             88
# referrer_iframe                iframe            119
#                                window.open       117
# script_execution_iframe        direct            216
#                                sandbox            21
# sniffing_script                direct             34
# subresourceloadingCOEP_img     direct            198
#                                sandbox             4
# subresourceloadingCORP_img     direct             69
#                                nested              0
#                                sandbox             0
# subresourceloadingCORP_object  direct            176
# upgradeHSTS_direct             direct            308
# upgradeHSTS_subdomain          subdomain         101
# Name: diff, dtype: int64

# %%
# Select only test rows with more than one outcome
tests_with_mult_outcomes = r.loc[r["diff"]].set_index(["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id"])
df_mult = df.loc[df[["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id"]].apply(tuple, axis=1).isin(tests_with_mult_outcomes.index)]
tests_with_more_than_one_outcome = df_mult.drop_duplicates(subset=["test_name", "org_scheme", "org_host", "resp_scheme", "resp_host", "relation_info", "response_id"])


all_tests_should_be =  df_org.loc[df_org["test_status"] == 0]["test_id"].nunique() * df_org["browser"].nunique() # (num parsing tests + num_basic_tests) * num_browsers (168774+10456)
print(f"All test rows: {len(df)}, should be: {all_tests_should_be}, Rows with more than one outcome: {len(df_mult)}, Tests with more than one outcome: {len(tests_with_more_than_one_outcome)}")
# Out:
# All test rows: 2125752, should be: 2125752, Rows with more than one outcome: 53184, Tests with more than one outcome: 4432

# %% [markdown]
# ## Browser similarity
# - Matrix for differences between all browsers split by all results, only parsing, only basic, only specific test types
# - In general:
#     - Chromium != Firefox != WebKit
#     - Brave is different to Chrome (whereas Opera, Edge are equal to Chrome?)
#     - Firefox and WebKit are close together
#     - Differences between Mobile and Desktop exist but are small (for all brave, chrome, firefox, safari)

# %%
df["b_short"] = df["os"].apply(lambda x: x.split(" ")[0]) + " " + df["name"] + "(" + df["version"] + ")"

# %%
# Simmilarity between browsers and versions!

# Function to calculate absolute and percentage overlap
def calculate_overlap(df, col1, col2):
    df = df[[col1, col2]].dropna()
    df.columns.values[0] = 0
    df.columns.values[1] = 1
    absolute_overlap = (df[0] == df[1]).sum()
    unique_rows = len(df)
    diff_rows = unique_rows - absolute_overlap
    percentage_diff = (diff_rows / unique_rows) * 100
    return diff_rows, percentage_diff, unique_rows

def rename_rows(df):
    for row_index in df.index:
        for column_name in df.columns:
            if row_index.startswith(column_name.split(',')[0]):
                df.rename(index={row_index: column_name}, inplace=True)
                break  # Stop searching for matching column names once found
    return df


def display_overlap(df, show_all=True, name="All"):
    print(name)
    sim_frame = df.set_index(["test_id", "b_short"])["outcome_str"].unstack().astype("str")
    sim_frame = sim_frame.reset_index().drop(columns=["test_id"])
    # Create a dictionary to store results
    results = {}
    matrix = {}
    
    # Iterate through all pairs of columns
    for i, col1 in enumerate(sim_frame.columns):
        for col2 in sim_frame.columns:
            key = f"{col1}_vs_{col2}"
            results[key] = calculate_overlap(sim_frame, col1, col2)
            try:
                l = matrix[col1]
            except KeyError:
                l = {}
            # 0 for absolute count of differences, 1 for percentage
            l[col2] = results[key][0]
            matrix[col1] = l
            
    # Convert the results to a DataFrame for better visualization
    results_df = pd.DataFrame.from_dict(results, orient='index', columns=['Absolute Diff', 'Percentage Diff', "Count"])

    s = {}
    for key, value in matrix.items():
        value_tuple = tuple(value.items())
        try:
            s[value_tuple].append(key)
        except KeyError:
            s[value_tuple] = [key]
    s_swapped = {", ".join(value): dict(key) for key, value in s.items()}
    # Display difference matrix
    with pd.option_context("display.max_columns", 28):
        final_frame = pd.DataFrame(s_swapped).drop_duplicates()
        final_frame = rename_rows(final_frame)
        display(final_frame)
        return final_frame

# %%
display_overlap(df)

for name, group in df.groupby("resp_type"):
    display_overlap(group, show_all=True, name=name)

for name, group in df.groupby("test_name"):
    display_overlap(group, show_all=False, name=name)
# Out:
# All
#                                           Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                         0
# Android chrome(121.0.6167.180)                                       137
# Android firefox_beta(123.0b9)                                       3083
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              29
# Ubuntu chrome(120)                                                   169
# Ubuntu chrome(121), Ubuntu chrome(122)                               154
# Ubuntu firefox(121)                                                 3075
# Ubuntu firefox(122)                                                 3072
# Ubuntu firefox(123)                                                 3070
# iPadOS chrome(122.0.6261.89)                                        2721
# macOS safari(17.3.1)                                                2752
#
#                                           Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                       137
# Android chrome(121.0.6167.180)                                         0
# Android firefox_beta(123.0b9)                                       3107
# Ubuntu brave(v1.62.156 (121.0.6167.139))                             161
# Ubuntu chrome(120)                                                    36
# Ubuntu chrome(121), Ubuntu chrome(122)                                21
# Ubuntu firefox(121)                                                 3099
# Ubuntu firefox(122)                                                 3096
# Ubuntu firefox(123)                                                 3094
# iPadOS chrome(122.0.6261.89)                                        2759
# macOS safari(17.3.1)                                                2790
#
#                                           Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                     3083
# Android chrome(121.0.6167.180)                                     3107
# Android firefox_beta(123.0b9)                                         0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                           3098
# Ubuntu chrome(120)                                                 3141
# Ubuntu chrome(121), Ubuntu chrome(122)                             3126
# Ubuntu firefox(121)                                                  90
# Ubuntu firefox(122)                                                  83
# Ubuntu firefox(123)                                                  87
# iPadOS chrome(122.0.6261.89)                                       2820
# macOS safari(17.3.1)                                               2769
#
#                                           Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                  29
# Android chrome(121.0.6167.180)                                                 161
# Android firefox_beta(123.0b9)                                                 3098
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                         0
# Ubuntu chrome(120)                                                             157
# Ubuntu chrome(121), Ubuntu chrome(122)                                         142
# Ubuntu firefox(121)                                                           3064
# Ubuntu firefox(122)                                                           3061
# Ubuntu firefox(123)                                                           3059
# iPadOS chrome(122.0.6261.89)                                                  2724
# macOS safari(17.3.1)                                                          2763
#
#                                           Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                           169
# Android chrome(121.0.6167.180)                            36
# Android firefox_beta(123.0b9)                           3141
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 157
# Ubuntu chrome(120)                                         0
# Ubuntu chrome(121), Ubuntu chrome(122)                    17
# Ubuntu firefox(121)                                     3107
# Ubuntu firefox(122)                                     3104
# Ubuntu firefox(123)                                     3102
# iPadOS chrome(122.0.6261.89)                            2781
# macOS safari(17.3.1)                                    2820
#
#                                           Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                               154
# Android chrome(121.0.6167.180)                                                21
# Android firefox_beta(123.0b9)                                               3126
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                     142
# Ubuntu chrome(120)                                                            17
# Ubuntu chrome(121), Ubuntu chrome(122)                                         0
# Ubuntu firefox(121)                                                         3092
# Ubuntu firefox(122)                                                         3089
# Ubuntu firefox(123)                                                         3087
# iPadOS chrome(122.0.6261.89)                                                2766
# macOS safari(17.3.1)                                                        2805
#
#                                           Ubuntu firefox(121)  \
# Android brave(1.62.165_shield)                           3075
# Android chrome(121.0.6167.180)                           3099
# Android firefox_beta(123.0b9)                              90
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 3064
# Ubuntu chrome(120)                                       3107
# Ubuntu chrome(121), Ubuntu chrome(122)                   3092
# Ubuntu firefox(121)                                         0
# Ubuntu firefox(122)                                        27
# Ubuntu firefox(123)                                        33
# iPadOS chrome(122.0.6261.89)                             2796
# macOS safari(17.3.1)                                     2737
#
#                                           Ubuntu firefox(122)  \
# Android brave(1.62.165_shield)                           3072
# Android chrome(121.0.6167.180)                           3096
# Android firefox_beta(123.0b9)                              83
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 3061
# Ubuntu chrome(120)                                       3104
# Ubuntu chrome(121), Ubuntu chrome(122)                   3089
# Ubuntu firefox(121)                                        27
# Ubuntu firefox(122)                                         0
# Ubuntu firefox(123)                                        38
# iPadOS chrome(122.0.6261.89)                             2793
# macOS safari(17.3.1)                                     2740
#
#                                           Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                           3070
# Android chrome(121.0.6167.180)                           3094
# Android firefox_beta(123.0b9)                              87
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 3059
# Ubuntu chrome(120)                                       3102
# Ubuntu chrome(121), Ubuntu chrome(122)                   3087
# Ubuntu firefox(121)                                        33
# Ubuntu firefox(122)                                        38
# Ubuntu firefox(123)                                         0
# iPadOS chrome(122.0.6261.89)                             2789
# macOS safari(17.3.1)                                     2722
#
#                                           iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                    2721
# Android chrome(121.0.6167.180)                                    2759
# Android firefox_beta(123.0b9)                                     2820
# Ubuntu brave(v1.62.156 (121.0.6167.139))                          2724
# Ubuntu chrome(120)                                                2781
# Ubuntu chrome(121), Ubuntu chrome(122)                            2766
# Ubuntu firefox(121)                                               2796
# Ubuntu firefox(122)                                               2793
# Ubuntu firefox(123)                                               2789
# iPadOS chrome(122.0.6261.89)                                         0
# macOS safari(17.3.1)                                               103
#
#                                           macOS safari(17.3.1)
# Android brave(1.62.165_shield)                            2752
# Android chrome(121.0.6167.180)                            2790
# Android firefox_beta(123.0b9)                             2769
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  2763
# Ubuntu chrome(120)                                        2820
# Ubuntu chrome(121), Ubuntu chrome(122)                    2805
# Ubuntu firefox(121)                                       2737
# Ubuntu firefox(122)                                       2740
# Ubuntu firefox(123)                                       2722
# iPadOS chrome(122.0.6261.89)                               103
# macOS safari(17.3.1)                                         0
# basic
#                                           Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                         0
# Android chrome(121.0.6167.180)                                        64
# Android firefox_beta(123.0b9)                                        597
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              16
# Ubuntu chrome(120)                                                    70
# Ubuntu chrome(121), Ubuntu chrome(122)                                71
# Ubuntu firefox(121)                                                  573
# Ubuntu firefox(122)                                                  573
# Ubuntu firefox(123)                                                  574
# iPadOS chrome(122.0.6261.89)                                        1504
# macOS safari(17.3.1)                                                1557
#
#                                           Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                        64
# Android chrome(121.0.6167.180)                                         0
# Android firefox_beta(123.0b9)                                        551
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              77
# Ubuntu chrome(120)                                                     6
# Ubuntu chrome(121), Ubuntu chrome(122)                                 7
# Ubuntu firefox(121)                                                  527
# Ubuntu firefox(122)                                                  527
# Ubuntu firefox(123)                                                  528
# iPadOS chrome(122.0.6261.89)                                        1471
# macOS safari(17.3.1)                                                1524
#
#                                           Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                      597
# Android chrome(121.0.6167.180)                                      551
# Android firefox_beta(123.0b9)                                         0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                            599
# Ubuntu chrome(120)                                                  557
# Ubuntu chrome(121), Ubuntu chrome(122)                              558
# Ubuntu firefox(121)                                                  54
# Ubuntu firefox(122)                                                  54
# Ubuntu firefox(123)                                                  51
# iPadOS chrome(122.0.6261.89)                                       1204
# macOS safari(17.3.1)                                               1155
#
#                                           Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                  16
# Android chrome(121.0.6167.180)                                                  77
# Android firefox_beta(123.0b9)                                                  599
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                         0
# Ubuntu chrome(120)                                                              71
# Ubuntu chrome(121), Ubuntu chrome(122)                                          72
# Ubuntu firefox(121)                                                            575
# Ubuntu firefox(122)                                                            575
# Ubuntu firefox(123)                                                            576
# iPadOS chrome(122.0.6261.89)                                                  1506
# macOS safari(17.3.1)                                                          1559
#
#                                           Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                            70
# Android chrome(121.0.6167.180)                             6
# Android firefox_beta(123.0b9)                            557
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  71
# Ubuntu chrome(120)                                         0
# Ubuntu chrome(121), Ubuntu chrome(122)                     1
# Ubuntu firefox(121)                                      533
# Ubuntu firefox(122)                                      533
# Ubuntu firefox(123)                                      534
# iPadOS chrome(122.0.6261.89)                            1477
# macOS safari(17.3.1)                                    1530
#
#                                           Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                71
# Android chrome(121.0.6167.180)                                                 7
# Android firefox_beta(123.0b9)                                                558
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                      72
# Ubuntu chrome(120)                                                             1
# Ubuntu chrome(121), Ubuntu chrome(122)                                         0
# Ubuntu firefox(121)                                                          534
# Ubuntu firefox(122)                                                          534
# Ubuntu firefox(123)                                                          535
# iPadOS chrome(122.0.6261.89)                                                1478
# macOS safari(17.3.1)                                                        1531
#
#                                           Ubuntu firefox(121)  \
# Android brave(1.62.165_shield)                            573
# Android chrome(121.0.6167.180)                            527
# Android firefox_beta(123.0b9)                              54
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  575
# Ubuntu chrome(120)                                        533
# Ubuntu chrome(121), Ubuntu chrome(122)                    534
# Ubuntu firefox(121)                                         0
# Ubuntu firefox(122)                                        12
# Ubuntu firefox(123)                                        15
# iPadOS chrome(122.0.6261.89)                             1166
# macOS safari(17.3.1)                                     1117
#
#                                           Ubuntu firefox(122)  \
# Android brave(1.62.165_shield)                            573
# Android chrome(121.0.6167.180)                            527
# Android firefox_beta(123.0b9)                              54
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  575
# Ubuntu chrome(120)                                        533
# Ubuntu chrome(121), Ubuntu chrome(122)                    534
# Ubuntu firefox(121)                                        12
# Ubuntu firefox(122)                                         0
# Ubuntu firefox(123)                                        15
# iPadOS chrome(122.0.6261.89)                             1166
# macOS safari(17.3.1)                                     1117
#
#                                           Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                            574
# Android chrome(121.0.6167.180)                            528
# Android firefox_beta(123.0b9)                              51
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  576
# Ubuntu chrome(120)                                        534
# Ubuntu chrome(121), Ubuntu chrome(122)                    535
# Ubuntu firefox(121)                                        15
# Ubuntu firefox(122)                                        15
# Ubuntu firefox(123)                                         0
# iPadOS chrome(122.0.6261.89)                             1167
# macOS safari(17.3.1)                                     1118
#
#                                           iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                    1504
# Android chrome(121.0.6167.180)                                    1471
# Android firefox_beta(123.0b9)                                     1204
# Ubuntu brave(v1.62.156 (121.0.6167.139))                          1506
# Ubuntu chrome(120)                                                1477
# Ubuntu chrome(121), Ubuntu chrome(122)                            1478
# Ubuntu firefox(121)                                               1166
# Ubuntu firefox(122)                                               1166
# Ubuntu firefox(123)                                               1167
# iPadOS chrome(122.0.6261.89)                                         0
# macOS safari(17.3.1)                                                53
#
#                                           macOS safari(17.3.1)
# Android brave(1.62.165_shield)                            1557
# Android chrome(121.0.6167.180)                            1524
# Android firefox_beta(123.0b9)                             1155
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  1559
# Ubuntu chrome(120)                                        1530
# Ubuntu chrome(121), Ubuntu chrome(122)                    1531
# Ubuntu firefox(121)                                       1117
# Ubuntu firefox(122)                                       1117
# Ubuntu firefox(123)                                       1118
# iPadOS chrome(122.0.6261.89)                                53
# macOS safari(17.3.1)                                         0
# parsing
#                                           Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                         0
# Android chrome(121.0.6167.180)                                        73
# Android firefox_beta(123.0b9)                                       2486
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              13
# Ubuntu chrome(120)                                                    99
# Ubuntu chrome(121), Ubuntu chrome(122)                                83
# Ubuntu firefox(121)                                                 2502
# Ubuntu firefox(122)                                                 2499
# Ubuntu firefox(123)                                                 2496
# iPadOS chrome(122.0.6261.89)                                        1217
# macOS safari(17.3.1)                                                1195
#
#                                           Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                        73
# Android chrome(121.0.6167.180)                                         0
# Android firefox_beta(123.0b9)                                       2556
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              84
# Ubuntu chrome(120)                                                    30
# Ubuntu chrome(121), Ubuntu chrome(122)                                14
# Ubuntu firefox(121)                                                 2572
# Ubuntu firefox(122)                                                 2569
# Ubuntu firefox(123)                                                 2566
# iPadOS chrome(122.0.6261.89)                                        1288
# macOS safari(17.3.1)                                                1266
#
#                                           Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                     2486
# Android chrome(121.0.6167.180)                                     2556
# Android firefox_beta(123.0b9)                                         0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                           2499
# Ubuntu chrome(120)                                                 2584
# Ubuntu chrome(121), Ubuntu chrome(122)                             2568
# Ubuntu firefox(121)                                                  36
# Ubuntu firefox(122)                                                  29
# Ubuntu firefox(123)                                                  36
# iPadOS chrome(122.0.6261.89)                                       1616
# macOS safari(17.3.1)                                               1614
#
#                                           Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                  13
# Android chrome(121.0.6167.180)                                                  84
# Android firefox_beta(123.0b9)                                                 2499
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                         0
# Ubuntu chrome(120)                                                              86
# Ubuntu chrome(121), Ubuntu chrome(122)                                          70
# Ubuntu firefox(121)                                                           2489
# Ubuntu firefox(122)                                                           2486
# Ubuntu firefox(123)                                                           2483
# iPadOS chrome(122.0.6261.89)                                                  1218
# macOS safari(17.3.1)                                                          1204
#
#                                           Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                            99
# Android chrome(121.0.6167.180)                            30
# Android firefox_beta(123.0b9)                           2584
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  86
# Ubuntu chrome(120)                                         0
# Ubuntu chrome(121), Ubuntu chrome(122)                    16
# Ubuntu firefox(121)                                     2574
# Ubuntu firefox(122)                                     2571
# Ubuntu firefox(123)                                     2568
# iPadOS chrome(122.0.6261.89)                            1304
# macOS safari(17.3.1)                                    1290
#
#                                           Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                83
# Android chrome(121.0.6167.180)                                                14
# Android firefox_beta(123.0b9)                                               2568
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                      70
# Ubuntu chrome(120)                                                            16
# Ubuntu chrome(121), Ubuntu chrome(122)                                         0
# Ubuntu firefox(121)                                                         2558
# Ubuntu firefox(122)                                                         2555
# Ubuntu firefox(123)                                                         2552
# iPadOS chrome(122.0.6261.89)                                                1288
# macOS safari(17.3.1)                                                        1274
#
#                                           Ubuntu firefox(121)  \
# Android brave(1.62.165_shield)                           2502
# Android chrome(121.0.6167.180)                           2572
# Android firefox_beta(123.0b9)                              36
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 2489
# Ubuntu chrome(120)                                       2574
# Ubuntu chrome(121), Ubuntu chrome(122)                   2558
# Ubuntu firefox(121)                                         0
# Ubuntu firefox(122)                                        15
# Ubuntu firefox(123)                                        18
# iPadOS chrome(122.0.6261.89)                             1630
# macOS safari(17.3.1)                                     1620
#
#                                           Ubuntu firefox(122)  \
# Android brave(1.62.165_shield)                           2499
# Android chrome(121.0.6167.180)                           2569
# Android firefox_beta(123.0b9)                              29
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 2486
# Ubuntu chrome(120)                                       2571
# Ubuntu chrome(121), Ubuntu chrome(122)                   2555
# Ubuntu firefox(121)                                        15
# Ubuntu firefox(122)                                         0
# Ubuntu firefox(123)                                        23
# iPadOS chrome(122.0.6261.89)                             1627
# macOS safari(17.3.1)                                     1623
#
#                                           Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                           2496
# Android chrome(121.0.6167.180)                           2566
# Android firefox_beta(123.0b9)                              36
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 2483
# Ubuntu chrome(120)                                       2568
# Ubuntu chrome(121), Ubuntu chrome(122)                   2552
# Ubuntu firefox(121)                                        18
# Ubuntu firefox(122)                                        23
# Ubuntu firefox(123)                                         0
# iPadOS chrome(122.0.6261.89)                             1622
# macOS safari(17.3.1)                                     1604
#
#                                           iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                    1217
# Android chrome(121.0.6167.180)                                    1288
# Android firefox_beta(123.0b9)                                     1616
# Ubuntu brave(v1.62.156 (121.0.6167.139))                          1218
# Ubuntu chrome(120)                                                1304
# Ubuntu chrome(121), Ubuntu chrome(122)                            1288
# Ubuntu firefox(121)                                               1630
# Ubuntu firefox(122)                                               1627
# Ubuntu firefox(123)                                               1622
# iPadOS chrome(122.0.6261.89)                                         0
# macOS safari(17.3.1)                                                50
#
#                                           macOS safari(17.3.1)
# Android brave(1.62.165_shield)                            1195
# Android chrome(121.0.6167.180)                            1266
# Android firefox_beta(123.0b9)                             1614
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  1204
# Ubuntu chrome(120)                                        1290
# Ubuntu chrome(121), Ubuntu chrome(122)                    1274
# Ubuntu firefox(121)                                       1620
# Ubuntu firefox(122)                                       1623
# Ubuntu firefox(123)                                       1604
# iPadOS chrome(122.0.6261.89)                                50
# macOS safari(17.3.1)                                         0
# accesswindow_direct
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                   2
# Android firefox_beta(123.0b9)                                                   57
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                              11
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              67
# iPadOS chrome(122.0.6261.89)                                                    37
# macOS safari(17.3.1)                                                            29
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                   2
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9)                                                   57
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                              11
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              67
# iPadOS chrome(122.0.6261.89)                                                    37
# macOS safari(17.3.1)                                                            29
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                                 57
# Android chrome(121.0.6167.180)                                                 57
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                             68
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             12
# iPadOS chrome(122.0.6261.89)                                                   36
# macOS safari(17.3.1)                                                           28
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                                     11
# Android chrome(121.0.6167.180)                                                                     11
# Android firefox_beta(123.0b9)                                                                      68
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                  0
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                 56
# iPadOS chrome(122.0.6261.89)                                                                       40
# macOS safari(17.3.1)                                                                               40
#
#                                                     Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                     67
# Android chrome(121.0.6167.180)                                                                     67
# Android firefox_beta(123.0b9)                                                                      12
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                 56
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       40
# macOS safari(17.3.1)                                                                               40
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                                37
# Android chrome(121.0.6167.180)                                                37
# Android firefox_beta(123.0b9)                                                 36
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                            40
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                            40
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                           8
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                        29
# Android chrome(121.0.6167.180)                                        29
# Android firefox_beta(123.0b9)                                         28
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                    40
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                    40
# iPadOS chrome(122.0.6261.89)                                           8
# macOS safari(17.3.1)                                                   0
# fetch_GET
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                291
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 94
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                291
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                197
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 94
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                197
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# fetch_TEST
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                101
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 55
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                101
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 46
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 55
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 46
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# framing_embed
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                426
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                426
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# framing_iframe
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                517
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 95
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                517
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                422
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 95
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                422
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# framing_object
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                426
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                426
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# fullscreen_iframe
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                905
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                900
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                905
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  9
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                900
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  9
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# imgloading_iframe
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                243
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 41
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                243
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                202
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 41
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                202
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# perfAPI_img
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 66
# iPadOS chrome(122.0.6261.89)                                                                       22
# macOS safari(17.3.1)                                                                               74
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 66
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       88
# ...
# Ubuntu firefox(121)                                                                                97
# Ubuntu firefox(122)                                                                                94
# Ubuntu firefox(123)                                                                                92
# iPadOS chrome(122.0.6261.89)                                                                       91
# macOS safari(17.3.1)                                                                               77
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield), Android chrome(...                            117
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu firefox(121)                                                            76
# Ubuntu firefox(122)                                                            69
# Ubuntu firefox(123)                                                            73
# iPadOS chrome(122.0.6261.89)                                                  130
# macOS safari(17.3.1)                                                          136
#
#                                                     Ubuntu firefox(121)  \
# Android brave(1.62.165_shield), Android chrome(...                   97
# Android firefox_beta(123.0b9)                                        76
# Ubuntu firefox(121)                                                   0
# Ubuntu firefox(122)                                                  27
# Ubuntu firefox(123)                                                  33
# iPadOS chrome(122.0.6261.89)                                        104
# macOS safari(17.3.1)                                                 94
#
#                                                     Ubuntu firefox(122)  \
# Android brave(1.62.165_shield), Android chrome(...                   94
# Android firefox_beta(123.0b9)                                        69
# Ubuntu firefox(121)                                                  27
# Ubuntu firefox(122)                                                   0
# Ubuntu firefox(123)                                                  38
# iPadOS chrome(122.0.6261.89)                                        101
# macOS safari(17.3.1)                                                 97
#
#                                                     Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                   92
# Android firefox_beta(123.0b9)                                        73
# Ubuntu firefox(121)                                                  33
# Ubuntu firefox(122)                                                  38
# Ubuntu firefox(123)                                                   0
# iPadOS chrome(122.0.6261.89)                                         97
# macOS safari(17.3.1)                                                 79
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                            91
# Android firefox_beta(123.0b9)                                                130
# Ubuntu firefox(121)                                                          104
# Ubuntu firefox(122)                                                          101
# Ubuntu firefox(123)                                                           97
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                          42
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                    77
# Android firefox_beta(123.0b9)                                        136
# Ubuntu firefox(121)                                                   94
# Ubuntu firefox(122)                                                   97
# Ubuntu firefox(123)                                                   79
# iPadOS chrome(122.0.6261.89)                                          42
# macOS safari(17.3.1)                                                   0
# subresourceloadingCORP_img
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 57
# iPadOS chrome(122.0.6261.89)                                                                       36
# macOS safari(17.3.1)                                                                               37
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 57
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       45
# macOS safari(17.3.1)                                                                               44
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                            36
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                            45
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                           1
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                    37
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                    44
# iPadOS chrome(122.0.6261.89)                                           1
# macOS safari(17.3.1)                                                   0
# subresourceloadingCORP_object
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 32
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                176
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 32
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                176
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                176
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                176
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# upgradeHSTS_direct
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                   1
# Android firefox_beta(123.0b9)                                                  244
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                               2
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             246
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                              86
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                   1
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9)                                                  245
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                               3
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             247
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                              87
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                                244
# Android chrome(121.0.6167.180)                                                245
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                            246
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              2
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                            284
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                                      2
# Android chrome(121.0.6167.180)                                                                      3
# Android firefox_beta(123.0b9)                                                                     246
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                  0
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                244
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 84
#
#                                                     Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                    246
# Android chrome(121.0.6167.180)                                                                    247
# Android firefox_beta(123.0b9)                                                                       2
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                244
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                282
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                                                     86
# Android chrome(121.0.6167.180)                                                                     87
# Android firefox_beta(123.0b9)                                                                     284
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                 84
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                282
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# upgradeHSTS_subdomain
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 68
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 54
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 68
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 80
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 54
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 80
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0

# %% [markdown]
# ## Analysis
# - Limit df on responsses that have more than one outcome

# %%
# Limit on responses that have more than one outcome!
# This will remove all the branches that are the same in all browsers (and make trees large and confusing)
condition = df.groupby(["test_id"], observed=True)["outcome_str"].transform("nunique") != 1
tree_df = df.loc[condition]
print("Remove tests that are the same in all browsers. Remaining rows:", len(tree_df))
# Out:
# Remove tests that are the same in all browsers. Remaining rows: 53184

# %%
# How many rows exist with more than one outcome
with pd.option_context("display.max_rows", 100):
    display(tree_df[["test_name", "label", "relation_info"]].value_counts())
# Out:
# test_name                      label       relation_info
# fullscreen_iframe              PP          child_allow       5616
#                                            direct            4968
# upgradeHSTS_direct             HSTS        direct            3696
# imgloading_iframe              CSP-IMG     direct            2916
# framing_iframe                 CSP-FA      direct            2628
# script_execution_iframe        CSP-SCRIPT  direct            2592
# subresourceloadingCOEP_img     COEP        direct            2376
# subresourceloadingCORP_object  CORP        direct            2112
# referrer_iframe                RP          iframe            1428
#                                            window.open       1404
# framing_iframe                 CSP-FA      nested            1284
# framing_object                 CSP-FA      direct            1224
# framing_embed                  CSP-FA      direct            1224
# upgradeHSTS_subdomain          HSTS        subdomain         1212
# perfAPI_img                    TAO         direct            1056
# framing_iframe                 XFO         direct             888
# framing_object                 XFO         direct             888
# framing_embed                  XFO         direct             888
# accesswindow_direct            COOP        direct             864
# framing_iframe                 CSPvsXFO    direct             864
# subresourceloadingCORP_img     CORP        direct             828
# framing_object                 CSP-FA      nested             768
#                                            sandbox            768
# framing_embed                  CSP-FA      sandbox            768
#                                            nested             768
#                                XFO         nested             600
# framing_object                 XFO         sandbox            600
# framing_embed                  XFO         sandbox            600
# framing_object                 XFO         nested             600
# framing_iframe                 XFO         nested             444
# fetch_GET                      CORS-ACAO   simple             432
# sniffing_script                XCTO        direct             408
# fetch_TEST                     CORS-ACAO   custom_method      396
# fetch_GET                      CORS-ACAO   custom_headers     396
#                                CORS-ACEH   simple             336
# fetch_TEST                     CORS-ACEH   custom_method      312
# fetch_GET                      CORS-ACEH   custom_headers     312
# fullscreen_iframe              PP          child              276
# fetch_GET                      CORS-ACEH   credentials        264
# script_execution_iframe        CSP-SCRIPT  sandbox            252
# fetch_GET                      CORS-ACAH   custom_headers     240
#                                CORS-ACAO   credentials        240
# fetch_TEST                     CORS-ACAM   custom_method      240
# fetch_GET                      CORS-ACAH   simple             192
#                                            credentials        192
#                                CORS-ACAM   simple             192
#                                            credentials        192
#                                            custom_headers     180
# fetch_TEST                     CORS-ACAH   custom_method      180
# fetch_GET                      CORS-ACAC   credentials        144
# framing_embed                  CSPvsXFO    direct             120
# framing_object                 CSPvsXFO    direct             120
# fetch_GET                      CORS-ACAC   simple              96
# framing_iframe                 CSP-FA      sandbox             96
# fetch_GET                      CORS-ACAC   custom_headers      84
# fetch_TEST                     CORS-ACAC   custom_method       84
# framing_embed                  CSPvsXFO    sandbox             72
#                                            nested              72
# framing_object                 CSPvsXFO    nested              72
#                                            sandbox             72
# subresourceloadingCOEP_img     COEP        sandbox             48
# Name: count, dtype: int64

# %% [markdown]
# # Manual analysis
# - Noise check/Manual confirmation:
#     - Android: http://134.96.225.54:8888/#!/control/emulator-5554

# %% [markdown]
# ## Helpers

# %%
from IPython.display import display, HTML
import os
# Out:
# <a href="http://localhost:8888/files/analysis/trees/2024-05-15T07:41/svg/('accesswindow_direct', 'direct').svg" target="_blank">Open ('accesswindow_direct', 'direct').svg</a>

# %%
def show_overlap(test_name, groupby=True, show_all=True):
    d = df.loc[df["test_name"] == test_name]
    if groupby:
        for name, group in d.groupby("resp_type"):
            display_overlap(group, show_all=show_all, name=name)
    else:
        display_overlap(d, show_all=show_all, name="all")

# %%
from io import StringIO
import ipywidgets as widgets
from utils import clickable
from functools import partial

class DataFrameWidget(widgets.VBox):
    def __init__(self, df, rows_per_page=20):
        self.df = df
        self.rows_per_page = rows_per_page
        self.page_index = 0
        self.total_pages = (len(df) - 1) // rows_per_page + 1
        
        self.output = widgets.Output()
        
        self.prev_button = widgets.Button(description='Prev')
        self.prev_button.on_click(self.prev_page)
        self.next_button = widgets.Button(description='Next')
        self.next_button.on_click(self.next_page)
        
        self.page_label = widgets.Label(value=f'Page: {self.page_index + 1} / {self.total_pages}')
        
        self.update_output()

        super().__init__(children=[self.output, 
                                   widgets.HBox([self.prev_button, self.next_button]),
                                   self.page_label])
    
    def update_output(self):
        start = self.page_index * self.rows_per_page
        end = min((self.page_index + 1) * self.rows_per_page, len(self.df))
        display_df = self.df.iloc[start:end]
        
        with self.output:
            self.output.clear_output()
            with pd.option_context("display.max_colwidth", 500):
                click_func = partial(clickable, "URL")
                display_df = display_df.style.format({'url': click_func})
                display(display_df)
        self.page_label.value = f'Page: {self.page_index + 1} / {self.total_pages}'
    
    def prev_page(self, _):
        if self.page_index > 0:
            self.page_index -= 1
            self.update_output()
    
    def next_page(self, _):
        if self.page_index < self.total_pages - 1:
            self.page_index += 1
            self.update_output()


def show_response_groups(test_name, relation=None):
    splits = {}
    d = tree_df.loc[tree_df["test_name"] == test_name]
    if relation:
        d = d.loc[d["relation_info"] == relation]
    for test_id, group in d.groupby("test_id", observed=True):
        key = group[["browser", "outcome_str"]].drop_duplicates().sort_values("browser")
        key = key.to_csv(index=False)
        try:
            splits[key].append(test_id)
        except (AttributeError, KeyError):
            splits[key] = [test_id]

    tab_contents = []
    
    for i, (key, values) in enumerate(splits.items()):        
        # Prepare content for the tab
        main_output = widgets.Output()
        with main_output:
            print(f"Group {i}")
            display(pd.read_csv(StringIO(key)).groupby("outcome_str")["browser"].unique().apply(sorted).to_dict())
            with pd.option_context("display.max_colwidth", 500):
                cur_data = tree_df.loc[tree_df["test_id"].isin(values)]
                example = cur_data.iloc[0]
                example_url = example["clean_url"]
                example_element_relation = example["test_name"].split("_")[1] + "_" + example["relation_info"]
                example_resp_origin = example["resp_origin"]
                example_resp_id = example["response_id"]
                example_url += f"&t_resp_id={example_resp_id}&t_element_relation={example_element_relation}&t_resp_origin={example_resp_origin}"
                display(example_url)
                
                d_data = cur_data.drop_duplicates(subset=["raw_header", "status_code", "org_origin", "resp_origin", "response_id"]).sort_values(by=["raw_header", "status_code", "org_origin", "resp_origin"])
                d_data["url"] = d_data["clean_url"] + "&t_resp_id=" + d_data["response_id"].astype(str) + "&t_element_relation=" + d_data["test_name"].apply(lambda x: x.split("_")[1]) + "_" + d_data["relation_info"] + "&t_resp_origin=" + d_data["resp_origin"]
                d_data = d_data[["raw_header", "status_code", "org_origin", "resp_origin", "response_id", "test_id", "url"]]

                # Display the DataFrame
                display(DataFrameWidget(d_data))
        
        # Add the content to the tab
        tab_contents.append(main_output)
    
    # Create tabs
    tab = widgets.Tab()
    tab.children = tab_contents

    
    # Set tab titles
    for i in range(len(tab_contents)):
        tab.set_title(i, f"Group {i}")
    
    display(tab)

# %%
def show_outcome_nums(test_name):
    display(pd.concat([df.loc[df["test_name"] == test_name].pivot_table("test_id", "outcome_str", aggfunc="nunique"), tree_df.loc[tree_df["test_name"] == test_name].pivot_table("test_id", "outcome_str", aggfunc="nunique")], axis=1))

def show_response_nums(test_name):
    display(tree_df.loc[tree_df["test_name"] == test_name].groupby("resp_type")["raw_header"].unique().apply(len))
    display(df.loc[df["test_name"] == test_name].groupby("resp_type")["raw_header"].unique().apply(len))

# %% [markdown]
# ## accesswindow_direct/COOP window-references-coop.sub.html
# - Testfile: `window-references-coop.sub.html`
# - Testnames: accesswindow_direct
# - Header: COOP
# - Basic:
#     - Android chrome (121), Ubuntu chrome (120-122), edge (121), brave (121) are identical
#     - Android: Opera + brave sligthly different?
#     - Safari, Firefox (all platforms) are identical
#     - The two groups have 28 differences
# - Parsing:
#     - Ubuntu chrome (120-122), edge (121), brave (121), opera (Android 121) are identical
#     - Android: Brave + chrome identical
#     - Firefox desktop identical
#     - Safari almost identical to Chrome/Brave Android?
#     - ...
# - **Small amount of noise: mostly opera android**
# - **Everything entered into google sheets**

# %%
test_name = 'accesswindow_direct'

# %%
show_overlap(test_name, groupby=True, show_all=True)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 28
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123), iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 28
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# parsing
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                   2
# Android firefox_beta(123.0b9)                                                   29
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                              11
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              39
# iPadOS chrome(122.0.6261.89)                                                     9
# macOS safari(17.3.1)                                                             1
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                   2
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9)                                                   29
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                              11
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              39
# iPadOS chrome(122.0.6261.89)                                                     9
# macOS safari(17.3.1)                                                             1
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                                 29
# Android chrome(121.0.6167.180)                                                 29
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                             40
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             12
# iPadOS chrome(122.0.6261.89)                                                   36
# macOS safari(17.3.1)                                                           28
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                                     11
# Android chrome(121.0.6167.180)                                                                     11
# Android firefox_beta(123.0b9)                                                                      40
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                  0
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                 28
# iPadOS chrome(122.0.6261.89)                                                                       12
# macOS safari(17.3.1)                                                                               12
#
#                                                     Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                     39
# Android chrome(121.0.6167.180)                                                                     39
# Android firefox_beta(123.0b9)                                                                      12
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                 28
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       40
# macOS safari(17.3.1)                                                                               40
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                                 9
# Android chrome(121.0.6167.180)                                                 9
# Android firefox_beta(123.0b9)                                                 36
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                            12
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                            40
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                           8
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                         1
# Android chrome(121.0.6167.180)                                         1
# Android firefox_beta(123.0b9)                                         28
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                    12
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                    40
# iPadOS chrome(122.0.6261.89)                                           8
# macOS safari(17.3.1)                                                   0

# %%
# Noise check/Manual confirmation:
# Android: http://134.96.225.54:8888/#!/control/emulator-5554


# Noise vs edge-case confirmation ?!
# Group 0 opera is in wrong group (noise)

# Group 5: confirmed 204 is handled differently on iPad

# Group 6: confirmed iPad is in the other group; not sure why? probably COOP applies before the download? (the difference between 2 is that \n is at the end, and the difference to 9 is that the COOP value is blocking)

# Group 7 opera is also in the firefox group (recorded result was noisy?)
# Group 8 opera + brave stay the same/no noise; actual difference might be: only chrome applies redirect + COOP!
# Difference between (0,1) and (7,8) is that the latter uses http://sub.headers.websec.saarland; seems like opera + brave do not auto-update this origin (exception?)


# Final Groups:
# 0+1 COOP only active on HTTPS, even though resp_origin is HTTP COOP is active in chromium-based browsers due to HTTPS auto-upgrade; (opera had noise once thus 2 groups)
# 2,9 Varying download behavior: download triggered due to \n in response. Safari (+ Android without Opera?) download pages are treated similarily to about:blank? (brave + chrome had noise once thus 2 groups)
# More info! On Android object Window is the result if the file already exist, for the first file the result is null, this is due to automatic downloads only if the file is not already existing, otherwise there is a popup that needs user confirmation
# 3 \r, \t, or space at the beginning or end of header name allowed in all non-firefox browsers;
# 4 1. Two headers, one empty: COOP active in Firefox, not-active in other browsers (which behavior is correct?), 2. \r at the end of the header name: works in Firefox, does not work in the other browsers!
# 5 Status code 204 + COOP works on iPad; does not work in other browsers (bug?)
# 6 similar to 2, only difference iPad in other group; (\n at the end!)
# 7,8 Similar to 0+1, however brave (Android) does not auto update to https here (due to shields being disabled on sub.headers.websec.saarland!) (opera had noise once thus 2 groups)

show_response_groups(test_name)
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), selected_index=…

# %%
df["denoised_outcome_str"] = df["outcome_str"]

# Crean 1 noisy entry:
l = ["accesswindow_direct_direct_http_sub.headers.websec.saarland_https_headers.webappsec.eu_21640_parsing",
    ]
df.loc[(df["test_id"].isin(l)) & (df["browser_id"].isin([68])), "denoised_outcome_str"] = '{\'window.open.opener\': \'object "[object Window]"\'}'


# Clean 4x2 noisy entries:
l = ["accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_81_basic",
    "accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_73_basic",
    "accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_80_basic",
    "accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_72_basic"]
df.loc[(df["test_id"].isin(l)) & (df["browser_id"].isin([62, 68])), "denoised_outcome_str"] = '{\'window.open.opener\': \'object "[object Window]"\'}'

# Clean 1x2 noisy entries
df.loc[(df["test_id"] == "accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_23242_parsing") & (df["browser_id"].isin([62, 65])), "denoised_outcome_str"] = '{\'window.open.opener\': \'object "[object Window]"\'}'

df.loc[(df["test_id"] == "accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_23242_parsing")]
# Out:
#                                                  test_id  \
# 53016  accesswindow_direct_direct_https_sub.headers.w...
# 53017  accesswindow_direct_direct_https_sub.headers.w...
# 53018  accesswindow_direct_direct_https_sub.headers.w...
# 53019  accesswindow_direct_direct_https_sub.headers.w...
# 53020  accesswindow_direct_direct_https_sub.headers.w...
# 53021  accesswindow_direct_direct_https_sub.headers.w...
# 53022  accesswindow_direct_direct_https_sub.headers.w...
# 53023  accesswindow_direct_direct_https_sub.headers.w...
# 53024  accesswindow_direct_direct_https_sub.headers.w...
# 53025  accesswindow_direct_direct_https_sub.headers.w...
# 53026  accesswindow_direct_direct_https_sub.headers.w...
# 53027  accesswindow_direct_direct_https_sub.headers.w...
#
#                                                  browser  \
# 53016       brave Android 11 1.62.165_shield intent real
# 53017  brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) ...
# 53018       chrome Android 11 121.0.6167.180 intent real
# 53019      chrome Ubuntu 22.04 120 selenium headless-new
# 53020      chrome Ubuntu 22.04 121 selenium headless-new
# 53021      chrome Ubuntu 22.04 122 selenium headless-new
# 53022     chrome iPadOS 17.3.1 122.0.6261.89 intent real
# 53023         firefox Ubuntu 22.04 121 selenium headless
# 53024         firefox Ubuntu 22.04 122 selenium headless
# 53025         firefox Ubuntu 22.04 123 selenium headless
# 53026        firefox_beta Android 11 123.0b9 intent real
# 53027           safari macOS 14.3.1 17.3.1 selenium real
#
#                                              outcome_str        id  \
# 53016  {'window.open.opener': 'object "[object Window...  52378080
# 53017                     {'window.open.opener': 'null'}  40556874
# 53018                     {'window.open.opener': 'null'}  45644562
# 53019                     {'window.open.opener': 'null'}  40345756
# 53020                     {'window.open.opener': 'null'}  40031454
# 53021                     {'window.open.opener': 'null'}  40271158
# 53022  {'window.open.opener': 'object "[object Window...  47879454
# 53023                     {'window.open.opener': 'null'}  40401027
# 53024                     {'window.open.opener': 'null'}  40082891
# 53025                     {'window.open.opener': 'null'}  40479081
# 53026  {'window.open.opener': 'object "[object Window...  47371475
# 53027  {'window.open.opener': 'object "[object Window...  50778111
#
#          outcome_type                                      outcome_value  \
# 53016  <class 'dict'>                     {'window.open.opener': 'null'}
# 53017  <class 'dict'>                     {'window.open.opener': 'null'}
# 53018  <class 'dict'>                     {'window.open.opener': 'null'}
# 53019  <class 'dict'>                     {'window.open.opener': 'null'}
# 53020  <class 'dict'>                     {'window.open.opener': 'null'}
# 53021  <class 'dict'>                     {'window.open.opener': 'null'}
# 53022  <class 'dict'>  {'window.open.opener': 'object "[object Window...
# 53023  <class 'dict'>                     {'window.open.opener': 'null'}
# 53024  <class 'dict'>                     {'window.open.opener': 'null'}
# 53025  <class 'dict'>                     {'window.open.opener': 'null'}
# 53026  <class 'dict'>  {'window.open.opener': 'object "[object Window...
# 53027  <class 'dict'>  {'window.open.opener': 'object "[object Window...
#
#                  test_name  test_status test_message test_stack  ...  \
# 53016  accesswindow_direct            0         None       None  ...
# 53017  accesswindow_direct            0         None       None  ...
# 53018  accesswindow_direct            0         None       None  ...
# 53019  accesswindow_direct            0         None       None  ...
# 53020  accesswindow_direct            0         None       None  ...
# 53021  accesswindow_direct            0         None       None  ...
# 53022  accesswindow_direct            0         None       None  ...
# 53023  accesswindow_direct            0         None       None  ...
# 53024  accesswindow_direct            0         None       None  ...
# 53025  accesswindow_direct            0         None       None  ...
# 53026  accesswindow_direct            0         None       None  ...
# 53027  accesswindow_direct            0         None       None  ...
#
#                   os automation_mode add_info  \
# 53016     Android 11          intent
# 53017   Ubuntu 22.04        selenium
# 53018     Android 11          intent
# 53019   Ubuntu 22.04        selenium
# 53020   Ubuntu 22.04        selenium
# 53021   Ubuntu 22.04        selenium
# 53022  iPadOS 17.3.1          intent
# 53023   Ubuntu 22.04        selenium
# 53024   Ubuntu 22.04        selenium
# 53025   Ubuntu 22.04        selenium
# 53026     Android 11          intent
# 53027   macOS 14.3.1        selenium
#
#                                       outcome_str_ignore  \
# 53016                     {'window.open.opener': 'null'}
# 53017                     {'window.open.opener': 'null'}
# 53018                     {'window.open.opener': 'null'}
# 53019                     {'window.open.opener': 'null'}
# 53020                     {'window.open.opener': 'null'}
# 53021                     {'window.open.opener': 'null'}
# 53022  {'window.open.opener': 'object "[object Window...
# 53023                     {'window.open.opener': 'null'}
# 53024                     {'window.open.opener': 'null'}
# 53025                     {'window.open.opener': 'null'}
# 53026  {'window.open.opener': 'object "[object Window...
# 53027  {'window.open.opener': 'object "[object Window...
#
#                                                clean_url  \
# 53016  https://sub.headers.websec.saarland/_hp/tests/...
# 53017  https://sub.headers.websec.saarland/_hp/tests/...
# 53018  https://sub.headers.websec.saarland/_hp/tests/...
# 53019  https://sub.headers.websec.saarland/_hp/tests/...
# 53020  https://sub.headers.websec.saarland/_hp/tests/...
# 53021  https://sub.headers.websec.saarland/_hp/tests/...
# 53022  https://sub.headers.websec.saarland/_hp/tests/...
# 53023  https://sub.headers.websec.saarland/_hp/tests/...
# 53024  https://sub.headers.websec.saarland/_hp/tests/...
# 53025  https://sub.headers.websec.saarland/_hp/tests/...
# 53026  https://sub.headers.websec.saarland/_hp/tests/...
# 53027  https://sub.headers.websec.saarland/_hp/tests/...
#
#                                 org_origin                   resp_origin  \
# 53016  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53017  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53018  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53019  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53020  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53021  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53022  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53023  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53024  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53025  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53026  https://sub.headers.websec.saarland  https://headers.webappsec.eu
# 53027  https://sub.headers.websec.saarland  https://headers.webappsec.eu
#
#                     file_name                                   b_short  \
# 53016  window-references-coop            Android brave(1.62.165_shield)
# 53017  window-references-coop  Ubuntu brave(v1.62.156 (121.0.6167.139))
# 53018  window-references-coop            Android chrome(121.0.6167.180)
# 53019  window-references-coop                        Ubuntu chrome(120)
# 53020  window-references-coop                        Ubuntu chrome(121)
# 53021  window-references-coop                        Ubuntu chrome(122)
# 53022  window-references-coop              iPadOS chrome(122.0.6261.89)
# 53023  window-references-coop                       Ubuntu firefox(121)
# 53024  window-references-coop                       Ubuntu firefox(122)
# 53025  window-references-coop                       Ubuntu firefox(123)
# 53026  window-references-coop             Android firefox_beta(123.0b9)
# 53027  window-references-coop                      macOS safari(17.3.1)
#
#                                     denoised_outcome_str
# 53016  {'window.open.opener': 'object "[object Window...
# 53017                     {'window.open.opener': 'null'}
# 53018  {'window.open.opener': 'object "[object Window...
# 53019                     {'window.open.opener': 'null'}
# 53020                     {'window.open.opener': 'null'}
# 53021                     {'window.open.opener': 'null'}
# 53022  {'window.open.opener': 'object "[object Window...
# 53023                     {'window.open.opener': 'null'}
# 53024                     {'window.open.opener': 'null'}
# 53025                     {'window.open.opener': 'null'}
# 53026  {'window.open.opener': 'object "[object Window...
# 53027  {'window.open.opener': 'object "[object Window...
#
# [12 rows x 39 columns]

# %% [markdown]
# ## Fetch/CORS
# - Testfile: `fetch-cors.sub.html`
# - Testnames: `fetch_GET_credentials|custom_headers_simple, fetch_TEST_custom_method`
# - Headers: ACAO, ACAM, ACAH, ACAC, ACEH
# - Basic + Parsing, ...
# - **No noise** (anymore)

# %%
test_name = 'fetch_GET' # fetch_TEST

# %%
show_overlap(test_name, groupby=True, show_all=True)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123), iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                291
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 94
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                291
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                197
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 94
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                197
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0

# %%
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
#                                                     test_id  test_id
# outcome_str
# {'error': 'null', 'headers': ''}                          3      3.0
# {'error': 'null', 'headers': 'access-control-al...        1      1.0
# {'error': 'null', 'headers': 'access-control-al...       91     12.0
# {'error': 'null', 'headers': 'access-control-al...        6      NaN
# {'error': 'null', 'headers': 'access-control-al...        6      NaN
# {'error': 'null', 'headers': 'access-control-al...        6      NaN
# {'error': 'null', 'headers': 'access-control-al...        6      NaN
# {'error': 'null', 'headers': 'cache-control,con...       35     10.0
# {'error': 'null', 'headers': 'content-length,'}        4516     49.0
# {'error': 'null', 'headers': 'content-length,te...     9681    139.0
# {'error': 'object "AbortError: Fetch is aborted...      120    120.0
# {'error': 'object "TypeError: Failed to fetch"'...    34462    248.0
# resp_type
# parsing    96
# Name: raw_header, dtype: int64
# resp_type
# basic         6
# parsing    7969
# Name: raw_header, dtype: int64

# %%
# Simple
# 0: 2 differences, Firefox vs All: 1. Firefox allows \r at the end of headers 2. Firefox allows two acao header with '' and with '*'
# 1: Firefox vs All: Firefox times out if \n in a response to fetch
# 2: Firefox vs all: Firefox fails fetch if either starts with \r or ends with space or \t
# 3: Firefox vs all: Only Firefox redirects for status code 300
# 4: Firefox vs all: similar to 1, firefox times out if \n in a response
# 5: Chromium-based vs others: \x00 (header-name) not allowed in Chromium
# 6: Firefox vs all: similar to 3
# 7: similar to 5
# 8: Firefox vs all: Only Firefox allows \r at end of header or at the start of the value
# 9: similar to 2
# 10: similar to 8
# 11: similar to 3
show_response_groups(test_name, relation="simple")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output…

# %%
# credentials
# 0: Firefox vs all: \n timeout
# 1: Only firefox allows double acac + \r at the end of headers
# 2: Firefox does not allow \r at the beginning of headers or \t and space at the end + redirect 300
# 3: Chromium does not allow \x00 (header names)
# 4: same as 3
# 5: same as 2
# 6: Firefox vs all: Only Firefox allows \r at end of header or at the start of the value
# 7: only firefox redirects for 300
show_response_groups(test_name, relation="credentials")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), selected_index=…

# %%
# custom_headers
# 0: Only firefox allows \r and double header
# 1: Firefox + WebKit abort if \n in response?
# 2: Firefox \r, \t and space (\r special case if in other unrelated header e.g., ACAM)
# 3: \x00 in header names
# 4: same as 2
# 5: \x00 in header names
# 6: same as 0
# 7: same as 2
# 8: same as 0
show_response_groups(test_name, relation="custom_headers")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), selec…

# %%
# custom_method
# 0: Firefox \r + double header
# 1: \n in response Firefox + WebKit do not like
# 2: Firefox \r, \t, space (special \r in unrelated headers ignored by other browsers, Firefox errors)
# 3: \x00 in header names
# 4: Firefox \r, \t, space
# 5: \x00 in header names
# 6: Firefox \r in value + end of header
# 7: Firefox \r, \t, space
# 8: Firefox \r in value + end of header
show_response_groups("fetch_TEST", relation="custom_method")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), selec…

# %% [markdown]
# ## Framing
# - Testfile: `framing.sub.html`
# - Testnames: `framing_embed`, `framing_iframe`, `framing_object` all `direct`, `nested`, and `sandbox`
# - Headers: XFO, CSP, XFOvsCSP
# - Mostly Firefox vs the others, sometimes Safari agrees with Firefox and not with Chromium
# - **No noise**
# - **Everything entered into google sheets!**

# %%
test_name = 'framing_iframe' # framing_embed, framing_object (direct, nested, sandbox)

# %%
show_overlap(test_name, groupby=True, show_all=True)

show_outcome_nums(test_name)

# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  8
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)
# Android brave(1.62.165_shield), Android chrome(...                                                  8
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                509
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 95
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                509
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                414
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 95
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                414
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                  test_id  test_id
# outcome_str
# message send       21769      517
# message timeout    15548      517
# resp_type
# basic        1
# parsing    222
# Name: raw_header, dtype: int64
# resp_type
# basic        32
# parsing    8726
# Name: raw_header, dtype: int64

# %%
# 0: Firefox+Safari vs Chromium-based (2 issues): 1. uppercase scheme not allowed in chrome (bug), 2. \x00 not allowed in chrome (unclear?)
# 1: Firefox vs the others (only firefox allows): 
# - 1. Firefox ignores path for FA, Others do not even allow the correct path? (What is the correct behavior according to the specs?)
# - 2. Firefox does not allow \r at the beginning of a header name
# - 3. Firefox does not allow space and \t between header name and colon
# - 4. Firefox does not allow \x0b (vertical tab) at the beginning or end of header value
# 2: Firefox vs the others (only firefox disallows):
# - 1. Firefox allows \r at the beginning of header values
# - 2. Only Firefox redirects for status code 300
# - 3. \x0b (vertical tab) not ignored in Firefox, thus *\x0b != *
# - 4. Only Firefox allows \r at the end of a header name
# - 5. XFO: firefox allows space, \r, \t, \x0c (form feed) anywhere!
# - 6. \x01 - \x08, \x0e, \x0f, \x10 - \x1f, \x7f after * -> *\xNN -> blocked, after 'none'\xNN -> blocked (other browsers declare the full directive as invalid -> allowed?)
# 3: Firefox + Safari vs Chromium based: */ -> blocked in Firefox/Safari, allowed in Chromium?

# Old DuckDuckGo:
# 0: Duckduckgo (Webview 83) does not support various frame-ancestor value misspellings (empty, NoNe, \t, ...)
# 4: Firefox + duckduckgo(Webview 83): \x01 - \x08, \x0e, \x0f, \x10 - \x1f, \x7f after * -> *\xNN -> blocked, after 'none'\xNN -> blocked (other browsers declare the full directive as invalid -> allowed?)
# 5: Duckduckgo (Webview 83): \xa0a, ´, “, ... leads to response being blocked
show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1', 'Group …

# %%
# Nested
# More or less identical to `direct`? Some differences due to the fact that it is nested and the chain does not fullfill everything
show_response_groups(test_name, relation="nested")
# Out:
# Tab(children=(Output(), Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1', 'Group …

# %%
# Sandbox
# 0: Firefox vs the rest: `frame-ancestors *` matches sandboxed frame, does not match in the other browsers (compare https://www.w3.org/TR/CSP3/#match-url-to-source-expression)
# Error message in Chrome is wrong/misleading (Safari as well). However behavior is correct, `sandbox` without `allow-same-origin` is an opaque origin that should not be matched by *

# Old duckduckgo:
# 0: Duckduckgo vs the rest: 1. mixed content blocking not working correctly?, 2. frame-ancestors without a value not working
show_response_groups(test_name, relation="sandbox")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %%
# Embed direct
# 0: WebKit does not allow embeds/postMessages for embeds

# Old Duckduckgo:
# 1: Duckduckgo allows `CSP: frame-ancestors`
show_response_groups("framing_embed", relation="direct")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %%
# Embed nested
# Same as embed direct?
show_response_groups("framing_embed", relation="nested")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %%
# Embed sandbox
# Same as embed nested
show_response_groups("framing_embed", relation="sandbox")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %%
# Object direct
# Same as embed direct (Safari does not allow postMessages on objects?)
show_response_groups("framing_object", relation="direct")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %%
# Object nested
# Same as embed nested
show_response_groups("framing_object", relation="nested")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %%
# Object sandbox
# Same as embed sandbox
show_response_groups("framing_object", relation="sandbox")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %% [markdown]
# ## Fullscreen/PP
# - Testfile: `fullscreen-api-pp.sub.hml`
# - Testnames: `fullscreen_iframe` with `direct`, `child`, `child_allow`, `child_sandbox`
# - Headers: PP/FP
# - Mostly Firefox/Safari vs Chromium, however also a small difference between Firefox and Safari
# - **Everything entered into google sheets!** (nothing new: known FP and PP not supported yet in WebKit/Firefox, general parsing issues \x00, 300; we also found to old FP bugs in duckduckgo, however they were long discovered and fixed, still good to know? )
# - **No noise**

# %%
test_name = 'fullscreen_iframe'

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                278
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123), iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                278
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                627
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                622
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                627
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  9
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                622
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  9
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                           test_id  test_id
# outcome_str
# fullscreenEnabled: false     1181      873
# fullscreenEnabled: true     12061      905
# message timeout              4723       36
# resp_type
# basic       15
# parsing    341
# Name: raw_header, dtype: int64
# resp_type
# basic        24
# parsing    3853
# Name: raw_header, dtype: int64

# %%
with pd.option_context("display.max_rows", 154):
    display(df.loc[(df["test_name"] == test_name)].groupby(["relation_info", "browser"])["outcome_str"].value_counts())
# Out:
# relation_info  browser                                                              outcome_str
# child          brave Android 11 1.62.165_shield intent real                         message timeout              208
#                                                                                     fullscreenEnabled: false     155
#                                                                                     fullscreenEnabled: true       21
#                brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  message timeout              208
#                                                                                     fullscreenEnabled: false     155
#                                                                                     fullscreenEnabled: true       21
#                chrome Android 11 121.0.6167.180 intent real                         message timeout              208
#                                                                                     fullscreenEnabled: false     155
#                                                                                     fullscreenEnabled: true       21
#                chrome Ubuntu 22.04 120 selenium headless-new                        message timeout              208
#                                                                                     fullscreenEnabled: false     155
#                                                                                     fullscreenEnabled: true       21
#                chrome Ubuntu 22.04 121 selenium headless-new                        message timeout              208
#                                                                                     fullscreenEnabled: false     155
#                                                                                     fullscreenEnabled: true       21
#                chrome Ubuntu 22.04 122 selenium headless-new                        message timeout              208
#                                                                                     fullscreenEnabled: false     155
#                                                                                     fullscreenEnabled: true       21
#                chrome iPadOS 17.3.1 122.0.6261.89 intent real                       message timeout              208
#                                                                                     fullscreenEnabled: false     132
#                                                                                     fullscreenEnabled: true       44
#                firefox Ubuntu 22.04 121 selenium headless                           message timeout              208
#                                                                                     fullscreenEnabled: false     132
#                                                                                     fullscreenEnabled: true       44
#                firefox Ubuntu 22.04 122 selenium headless                           message timeout              208
#                                                                                     fullscreenEnabled: false     132
#                                                                                     fullscreenEnabled: true       44
#                firefox Ubuntu 22.04 123 selenium headless                           message timeout              208
#                                                                                     fullscreenEnabled: false     132
#                                                                                     fullscreenEnabled: true       44
#                firefox_beta Android 11 123.0b9 intent real                          message timeout              208
#                                                                                     fullscreenEnabled: false     132
#                                                                                     fullscreenEnabled: true       44
#                safari macOS 14.3.1 17.3.1 selenium real                             message timeout              208
#                                                                                     fullscreenEnabled: false     132
#                                                                                     fullscreenEnabled: true       44
# child_allow    brave Android 11 1.62.165_shield intent real                         message timeout             4118
#                                                                                     fullscreenEnabled: true     3568
#                                                                                     fullscreenEnabled: false     458
#                brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  message timeout             4118
#                                                                                     fullscreenEnabled: true     3568
#                                                                                     fullscreenEnabled: false     458
#                chrome Android 11 121.0.6167.180 intent real                         message timeout             4118
#                                                                                     fullscreenEnabled: true     3568
#                                                                                     fullscreenEnabled: false     458
#                chrome Ubuntu 22.04 120 selenium headless-new                        message timeout             4118
#                                                                                     fullscreenEnabled: true     3568
#                                                                                     fullscreenEnabled: false     458
#                chrome Ubuntu 22.04 121 selenium headless-new                        message timeout             4118
#                                                                                     fullscreenEnabled: true     3568
#                                                                                     fullscreenEnabled: false     458
#                chrome Ubuntu 22.04 122 selenium headless-new                        message timeout             4118
#                                                                                     fullscreenEnabled: true     3568
#                                                                                     fullscreenEnabled: false     458
#                chrome iPadOS 17.3.1 122.0.6261.89 intent real                       message timeout             4109
#                                                                                     fullscreenEnabled: true     4035
#                firefox Ubuntu 22.04 121 selenium headless                           message timeout             4112
#                                                                                     fullscreenEnabled: true     4032
#                firefox Ubuntu 22.04 122 selenium headless                           message timeout             4112
#                                                                                     fullscreenEnabled: true     4032
#                firefox Ubuntu 22.04 123 selenium headless                           message timeout             4112
#                                                                                     fullscreenEnabled: true     4032
#                firefox_beta Android 11 123.0b9 intent real                          message timeout             4112
#                                                                                     fullscreenEnabled: true     4032
#                safari macOS 14.3.1 17.3.1 selenium real                             message timeout             4109
#                                                                                     fullscreenEnabled: true     4035
# child_sandbox  brave Android 11 1.62.165_shield intent real                         message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                chrome Android 11 121.0.6167.180 intent real                         message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                chrome Ubuntu 22.04 120 selenium headless-new                        message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                chrome Ubuntu 22.04 121 selenium headless-new                        message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                chrome Ubuntu 22.04 122 selenium headless-new                        message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                chrome iPadOS 17.3.1 122.0.6261.89 intent real                       message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                firefox Ubuntu 22.04 121 selenium headless                           message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                firefox Ubuntu 22.04 122 selenium headless                           message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                firefox Ubuntu 22.04 123 selenium headless                           message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                firefox_beta Android 11 123.0b9 intent real                          message timeout              208
#                                                                                     fullscreenEnabled: false     176
#                safari macOS 14.3.1 17.3.1 selenium real                             message timeout              208
#                                                                                     fullscreenEnabled: false     176
# direct         brave Android 11 1.62.165_shield intent real                         fullscreenEnabled: true     7572
#                                                                                     fullscreenEnabled: false     392
#                                                                                     message timeout              180
#                brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  fullscreenEnabled: true     7572
#                                                                                     fullscreenEnabled: false     392
#                                                                                     message timeout              180
#                chrome Android 11 121.0.6167.180 intent real                         fullscreenEnabled: true     7572
#                                                                                     fullscreenEnabled: false     392
#                                                                                     message timeout              180
#                chrome Ubuntu 22.04 120 selenium headless-new                        fullscreenEnabled: true     7572
#                                                                                     fullscreenEnabled: false     392
#                                                                                     message timeout              180
#                chrome Ubuntu 22.04 121 selenium headless-new                        fullscreenEnabled: true     7572
#                                                                                     fullscreenEnabled: false     392
#                                                                                     message timeout              180
#                chrome Ubuntu 22.04 122 selenium headless-new                        fullscreenEnabled: true     7572
#                                                                                     fullscreenEnabled: false     392
#                                                                                     message timeout              180
#                chrome iPadOS 17.3.1 122.0.6261.89 intent real                       fullscreenEnabled: true     7982
#                                                                                     message timeout              162
#                firefox Ubuntu 22.04 121 selenium headless                           fullscreenEnabled: true     7976
#                                                                                     message timeout              168
#                firefox Ubuntu 22.04 122 selenium headless                           fullscreenEnabled: true     7976
#                                                                                     message timeout              168
#                firefox Ubuntu 22.04 123 selenium headless                           fullscreenEnabled: true     7976
#                                                                                     message timeout              168
#                firefox_beta Android 11 123.0b9 intent real                          fullscreenEnabled: true     7976
#                                                                                     message timeout              168
#                safari macOS 14.3.1 17.3.1 selenium real                             fullscreenEnabled: true     7982
#                                                                                     message timeout              162
# Name: count, dtype: int64

# %%
df.loc[(df["test_name"] == test_name) & (df["outcome_str"] == "fullscreenEnabled: false")].groupby("browser")["relation_info"].value_counts()
# Out:
# browser                                                              relation_info
# brave Android 11 1.62.165_shield intent real                         child_allow      458
#                                                                      direct           392
#                                                                      child_sandbox    176
#                                                                      child            155
# brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  child_allow      458
#                                                                      direct           392
#                                                                      child_sandbox    176
#                                                                      child            155
# chrome Android 11 121.0.6167.180 intent real                         child_allow      458
#                                                                      direct           392
#                                                                      child_sandbox    176
#                                                                      child            155
# chrome Ubuntu 22.04 120 selenium headless-new                        child_allow      458
#                                                                      direct           392
#                                                                      child_sandbox    176
#                                                                      child            155
# chrome Ubuntu 22.04 121 selenium headless-new                        child_allow      458
#                                                                      direct           392
#                                                                      child_sandbox    176
#                                                                      child            155
# chrome Ubuntu 22.04 122 selenium headless-new                        child_allow      458
#                                                                      direct           392
#                                                                      child_sandbox    176
#                                                                      child            155
# chrome iPadOS 17.3.1 122.0.6261.89 intent real                       child_sandbox    176
#                                                                      child            132
# firefox Ubuntu 22.04 121 selenium headless                           child_sandbox    176
#                                                                      child            132
# firefox Ubuntu 22.04 122 selenium headless                           child_sandbox    176
#                                                                      child            132
# firefox Ubuntu 22.04 123 selenium headless                           child_sandbox    176
#                                                                      child            132
# firefox_beta Android 11 123.0b9 intent real                          child_sandbox    176
#                                                                      child            132
# safari macOS 14.3.1 17.3.1 selenium real                             child_sandbox    176
#                                                                      child            132
# Name: count, dtype: int64

# %%
# Direct
# 0: Permission Policy only supported in Chromium 88+, currently not supported in Safari/WebKit and Firefox, Feature Policy only supported in Chromium 60?+, Safari/WebKit only support the allow attribute?
# 1: \x00 breaks Chromium, response not rendered -> no message send
# 2/3: Status code 300 only redirects in Firefox
show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1', 'Group …

# %%
# Child
# Without the allow attribute only frames from the same origin should be allowed?
# 0: Only Chromium 88+ supports PP header (header blocks same-origin child), Only Chromium 60?+ supports FP header (header blocks same-origin child)

# Old duckduckgo:
# 0: Duckduckgo allows non-same origin responses without the allow tag if FP header allows it?
show_response_groups(test_name, relation="child")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %%
# Child allow
# 0: Only chromium supports FP + PP header, Only chromium supports FP header
# 1: \x00 issue in chrome
# 2/3: 300 only redirects in Firefox
show_response_groups(test_name, relation="child_allow")
# Out:
# Tab(children=(Output(), Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1', 'Group …

# %%
# Child sandbox

# Old duckduckgo
# 0: duckduckgo FP: fullscreen * even allows sandboxed frames (without an allow fullscreen attribute)
show_response_groups(test_name, relation="child_sandbox")
# Out:
# Tab()

# %% [markdown]
# ## Imgloading/CSP-subresources
# - Testfile: `subcresource-loding-csp.sub.html`
# - Testnames: `imgloading_iframe` with `direct`
# - Headers: CSP (default-src, img-src)
# - Mostly Firefox vs Chrome/Webkit, sometimes WebKit behaves similar to Firefox
# - **Everything entered into google sheets**
# - **No noise**

# %%
test_name = 'imgloading_iframe'

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 13
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123), iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 13
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                230
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 28
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                230
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                202
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 28
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                202
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                  test_id  test_id
# outcome_str
# error               1153      223
# load                4610      239
# message timeout      172       24
# resp_type
# basic        4
# parsing    119
# Name: raw_header, dtype: int64
# resp_type
# basic        17
# parsing    2683
# Name: raw_header, dtype: int64

# %%
# Direct
# 0: 
# - Mostly https ugrade in chromium
# 1x: `*/` same as `*` in chromium, does not match anything in Firefox/WebKit?
# however also some differences in *.headers.websec.saarland, Chromium seems to allow both http and https, Firefox/Webkit only allow https?
# Maybe Chromium upgrade resources first, then checks whether they pass the CSP? Firefox/WebKit first check whether they pass the CSP then updates?
# Difference in mixed-content auto upgrade, vs normal HTTP ugrade
# https://echo.sectec.rocks/echo/?ecocnt_css=%3Cimg%20src=%22http://en.wikipedia.org/favicon.ico%22%3E&content-security-policy=default-src%20*.wikipedia.org&content-type=text/html
# https://echo.sectec.rocks/echo/?ecocnt_css=%3Cimg%20src=%22http://en.wikipedia.org/favicon.ico%22%3E&content-security-policy=default-src%20https://en.wikipedia.org&content-type=text/html
# https://echo.sectec.rocks/echo/?ecocnt_css=%3Cimg%20src=%22http://en.wikipedia.org/favicon.ico%22%3E&content-security-policy=default-src%20http://en.wikipedia.org&content-type=text/html

# 1: \x00 in Chromium

# 2: Firefox ignores header names starting with \r, or ending with \t or space, does not "ignore" \x0b (vertical tab) in header value

# 3: Firefox ignores \r at the end of header names, ignores \r at the beginning of header values, \x01, and many more at the end of header values

# 4: Firefox 300

# 5: Firefox 300 

# 6: Chrome scheme is not case insensitive bug!
show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output()), selected_index=0, titles=…

# %% [markdown]
# ## PerformanceAPI
# - Testfile: `perfAPI-tao.sub.html`
# - Testnames: `perfAPI_img` (`direct`)
# - Headers: TAO
# - **Everything entered into google sheets**
# - **No noise**

# %%
test_name = 'perfAPI_img'

# %%
df.loc[df["test_name"] == test_name].groupby("outcome_str")["browser"].value_counts()
# Out:
# outcome_str                   browser
# No load/error event fired!    safari macOS 14.3.1 17.3.1 selenium real                                  8
#                               chrome iPadOS 17.3.1 122.0.6261.89 intent real                            8
# No performance entry          chrome iPadOS 17.3.1 122.0.6261.89 intent real                           62
#                               chrome Ubuntu 22.04 122 selenium headless-new                            52
#                               brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new      52
#                               chrome Ubuntu 22.04 121 selenium headless-new                            52
#                               chrome Android 11 121.0.6167.180 intent real                             52
#                               chrome Ubuntu 22.04 120 selenium headless-new                            52
#                               brave Android 11 1.62.165_shield intent real                             52
#                               safari macOS 14.3.1 17.3.1 selenium real                                 10
# {'requestStart != 0': False}  firefox_beta Android 11 123.0b9 intent real                            3242
#                               firefox Ubuntu 22.04 121 selenium headless                             3242
#                               firefox Ubuntu 22.04 123 selenium headless                             3242
#                               firefox Ubuntu 22.04 122 selenium headless                             3242
#                               safari macOS 14.3.1 17.3.1 selenium real                               3212
#                               chrome Android 11 121.0.6167.180 intent real                           3200
#                               brave Android 11 1.62.165_shield intent real                           3200
#                               brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new    3200
#                               chrome Ubuntu 22.04 121 selenium headless-new                          3200
#                               chrome Ubuntu 22.04 122 selenium headless-new                          3200
#                               chrome Ubuntu 22.04 120 selenium headless-new                          3200
#                               chrome iPadOS 17.3.1 122.0.6261.89 intent real                         3180
# {'requestStart != 0': True}   safari macOS 14.3.1 17.3.1 selenium real                                180
#                               firefox Ubuntu 22.04 122 selenium headless                              168
#                               firefox_beta Android 11 123.0b9 intent real                             168
#                               firefox Ubuntu 22.04 121 selenium headless                              168
#                               firefox Ubuntu 22.04 123 selenium headless                              168
#                               chrome iPadOS 17.3.1 122.0.6261.89 intent real                          160
#                               chrome Ubuntu 22.04 120 selenium headless-new                           158
#                               chrome Android 11 121.0.6167.180 intent real                            158
#                               brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new     158
#                               brave Android 11 1.62.165_shield intent real                            158
#                               chrome Ubuntu 22.04 121 selenium headless-new                           158
#                               chrome Ubuntu 22.04 122 selenium headless-new                           158
# Name: count, dtype: int64

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 52
# iPadOS chrome(122.0.6261.89)                                                                        3
# macOS safari(17.3.1)                                                                               55
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 52
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       55
# macOS safari(17.3.1)                                                                                7
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                             3
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                            55
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                          52
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                    55
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                     7
# iPadOS chrome(122.0.6261.89)                                          52
# macOS safari(17.3.1)                                                   0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 14
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 19
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 14
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 33
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 19
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 33
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                               test_id  test_id
# outcome_str
# No load/error event fired!          8        8
# No performance entry               62       62
# {'requestStart != 0': False}     3246       70
# {'requestStart != 0': True}       186       40
# resp_type
# basic      13
# parsing    16
# Name: raw_header, dtype: int64
# resp_type
# basic        13
# parsing    1583
# Name: raw_header, dtype: int64

# %%
# Direct
# 0: WebKit: \n in response response never loads
# 1: Firefox \r (beginning of header), space, \t (end of header) and 300
# 2: Firefox ignores \r at the end of header name and beginning of header value
# 3: WebKit: \x00 in header value -> no performance entry (failed to load resource: response contained invalid HTTP headers)
# 4: Same as 0 (TAO: *\n -> allow in other browsers)
# 5: Chromium https upgrade (no entry for http URL) (also on chrome iPadOS?)
# 6: See 5
# 7: WebKit (desktop only) use TAO * for 302 (http->https) (on iPad the mixed content is blocked! -> no performance Entry?, on Firefox + Chrome upgrade insecure content)
# More info: mixed content type blocking seems to be configurable by the browser on iPadOS? -> blocked/no-perf entry for Chrome and Brave, allowed/true for Safari + Firefox!
# 8: WebKit (iPad + desktop) use TAO * for 302 (https->https)

# Old duckduckgo:
# 1: \x00 (header name) old chromium (duckduckgo) no performance entry
# 9: Duckduckgo (old chromium) allows TAO null for 302

show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), selec…

# %%
df.loc[df["raw_header"] == "[['Timing-Allow-Origin', 'null']]"].iloc[0]["clean_url"]
# Out:
# 'http://sub.headers.websec.saarland/_hp/tests/perfAPI-tao.sub.html?resp_type=basic&browser_id=1&label=TAO&first_id=208&last_id=208&scheme=http'

# %% [markdown]
# ## Referer/Referrer Policy
# - Testfile: `referrer-access-rp.sub.html`
# - Testnames: `referrer_iframe` with `iframe`, `window.open`
# - Headers: RP
# - Post processing: all http:// to <http-origin> and all https:// to <https-origin>
# - **Some noise (mostly brave only window.open), hard to analyze**
# - **Everything (interesting/confirmed) entered into google sheets**

# %%
test_name = 'referrer_iframe'

# %%
with pd.option_context("display.max_rows", 67):
    display(df.loc[df["test_name"] == test_name].groupby("outcome_str")["browser"].value_counts().reset_index().drop_duplicates(subset=["outcome_str", "count"]).set_index(["outcome_str", "browser"]))
# Out:
#                                                                                       count
# outcome_str                       browser
# document.referrer:                brave Android 11 1.62.165_shield intent real          245
#                                   brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...    243
#                                   chrome Ubuntu 22.04 120 selenium headless-new         218
#                                   chrome Android 11 121.0.6167.180 intent real          217
#                                   safari macOS 14.3.1 17.3.1 selenium real              186
#                                   firefox_beta Android 11 123.0b9 intent real           180
# document.referrer: full_url       chrome Android 11 121.0.6167.180 intent real          170
#                                   chrome Ubuntu 22.04 120 selenium headless-new         164
#                                   chrome Ubuntu 22.04 121 selenium headless-new         163
#                                   firefox_beta Android 11 123.0b9 intent real            90
#                                   safari macOS 14.3.1 17.3.1 selenium real               79
#                                   brave Android 11 1.62.165_shield intent real           50
#                                   brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...     40
# document.referrer: http://origin  chrome iPadOS 17.3.1 122.0.6261.89 intent real        105
#                                   firefox Ubuntu 22.04 122 selenium headless             99
#                                   brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...     57
#                                   brave Android 11 1.62.165_shield intent real           42
#                                   chrome Ubuntu 22.04 121 selenium headless-new          39
#                                   chrome Ubuntu 22.04 120 selenium headless-new          38
#                                   chrome Android 11 121.0.6167.180 intent real           33
# document.referrer: https://origin brave Android 11 1.62.165_shield intent real         2766
#                                   brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...   2763
#                                   safari macOS 14.3.1 17.3.1 selenium real             2742
#                                   firefox Ubuntu 22.04 122 selenium headless           2740
#                                   chrome Ubuntu 22.04 121 selenium headless-new        2683
# message timeout                   chrome Ubuntu 22.04 122 selenium headless-new        3003
#                                   firefox Ubuntu 22.04 122 selenium headless           2997
#                                   chrome iPadOS 17.3.1 122.0.6261.89 intent real       2994

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                  64
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                             119
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                        16
# Ubuntu chrome(120)                                                              70
# Ubuntu chrome(121), Ubuntu chrome(122)                                          71
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                             116
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                  64
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                              73
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                        77
# Ubuntu chrome(120)                                                               6
# Ubuntu chrome(121), Ubuntu chrome(122)                                           7
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                              83
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                    119
# Android chrome(121.0.6167.180)                                                                     73
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                          121
# Ubuntu chrome(120)                                                                                 79
# Ubuntu chrome(121), Ubuntu chrome(122)                                                             80
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 11
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                            16
# Android chrome(121.0.6167.180)                                                            77
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                       121
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                   0
# Ubuntu chrome(120)                                                                        71
# Ubuntu chrome(121), Ubuntu chrome(122)                                                    72
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                       118
#
#                                                     Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                                      70
# Android chrome(121.0.6167.180)                                       6
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                  79
# Ubuntu brave(v1.62.156 (121.0.6167.139))                            71
# Ubuntu chrome(120)                                                   0
# Ubuntu chrome(121), Ubuntu chrome(122)                               1
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                  89
#
#                                                     Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                          71
# Android chrome(121.0.6167.180)                                                           7
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                      80
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                72
# Ubuntu chrome(120)                                                                       1
# Ubuntu chrome(121), Ubuntu chrome(122)                                                   0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                      90
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                                                    116
# Android chrome(121.0.6167.180)                                                                     83
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 11
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                          118
# Ubuntu chrome(120)                                                                                 89
# Ubuntu chrome(121), Ubuntu chrome(122)                                                             90
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield), Ubuntu brave(v1...                                                  0
# Android chrome(121.0.6167.180), Ubuntu chrome(1...                                                 70
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 32
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 17
#
#                                                     Android chrome(121.0.6167.180), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Ubuntu brave(v1...                                                 70
# Android chrome(121.0.6167.180), Ubuntu chrome(1...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                101
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 87
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Ubuntu brave(v1...                                                 32
# Android chrome(121.0.6167.180), Ubuntu chrome(1...                                                101
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 15
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Ubuntu brave(v1...                                                 17
# Android chrome(121.0.6167.180), Ubuntu chrome(1...                                                 87
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 15
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                                    test_id  test_id
# outcome_str
# document.referrer:                     251       76
# document.referrer: full_url            173      140
# document.referrer: http://origin       120       87
# document.referrer: https://origin     2807      172
# message timeout                       3006       12
# resp_type
# basic      13
# parsing    94
# Name: raw_header, dtype: int64
# resp_type
# basic        16
# parsing    2770
# Name: raw_header, dtype: int64

# %%
# Iframe
# 0: no-referrer-when-downgrade, unsafe-url not supported in Firefox/WebKit, brave (desktop) (brave Android shields deactivated!)
# 1: Firefox, MacOS, brave (Android shields deactivated) seem to be using same-site instead of same-origin when falling back to strict-origin-when-cross-origin??
# 2: Similiar to 0 but all HTTPS instead of HTTP, also Chromium allows \t, \x0b, \x0c, \r next to unsafe-url and still parses it as unsafe-url
# 3: Firefox allows \r at the end of header name and beginning of header values
# 4: Firefox does not allow \r at the beginning of header names, or space, and \t at the end of header names
# 5: \x00 in header names (chromium does not allow)
# 6: Only Firefox redirects for code 300
# 7: \x0b and \x0c are not ignored in Firefox and WebKit
# 8: Only Firefox redirects for code 300 (other RP)
# 9: Same as 1: only with https this time

# Old Duckduckgo:
# 0: Duckduckgo, default RP changed in chromium 85
show_response_groups(test_name, relation="iframe")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output…

# %%
# 0: Chromium auto-updates to HTTPS and does not send any referrer when the policy is strict-origin-when-cross-origin? (even though it should when it is an upgrade and not a downgrade?)
# 1: Firefox sends full_urls for no-referrer-when-downgrade for window.open? (should not be supported?)
# 2: Brave no referrer for origin?, Chrome and Firefox/Safari different results due to https upgrade
# 3: Brave desktop noise? -> should be the same as 2?
# 4: Similar/same to 1, Firefox leaks too much information for window.open?
# 5: Opera noise -> should be the same as 0
# 6: Similar to 1, here however WebKit also leaks! (issue with same-site vs same-origin?); also opera Android noise?
# 7: Opera noise -> should be the same as 2
# 8: Brave desktop noise -> should be the same as 2
# 9: Similar to 1, same-site vs same-origin? + unsafe-url in Chromium
# 10: Cannot reproduce/noise? all leak full_url here during manual testing?
# 11: Cannot reroduce/noise? similar to 10
# 12: Cannot reproduce/noise? similar to 10
# 13: Cannot reproduce/noise? similar to 10
# 14: Similar to 1,6,9: both WebKit and Firefox leak here? (same-site vs same-origin?)
# 15: Brave no referrer for origin? (same as 2, only https now)
# 16: Similar to 1? only unsafe-url instead of no-referrer-when-downgrade here (seems to be a major bug in Firefox?) https://blog.mozilla.org/security/2021/10/05/firefox-93-features-an-improved-smartblock-and-new-referrer-tracking-protections/
# 17: HTTPS auto-upgrades? Chromium; noise opera Android
# 18: Similar to 1
# 19: Same as 17 without noise?
# 20: Same as 17, this time brave Ubuntu noise?
# 21: Similar to 1 with some noise (brave Android)
# 22: Similar to 1,6,9 (WebKit also leaks same-site vs same-origin?)
# 23: Similar to 17 (however same-origin here) + noise brave Android
# 24: Noise brave Android
# 25: Noise brave Android (auto-upgrade of same-origin URL seems to have failed quite often)
# 26: Noise brave Android
# 27: Brave does not support origin-when-cross-origin?
# 28: Brave Ubuntu noise?
# 29: Similar to 1

# In general similar to iframe?
# Chromium default (at least of http to https auto upgrade) is no referrer at all?
# Brave quite noisy?, also more secure than the others
# Firefox has some serious issue with unsafe-url, no-referrer-when-downgrade with window.open (and <a>)
# Safari has some same-site vs same-origin issues?
# ...

# %%
# Window.open

# Final groups
# 0, 5, 25 Chromium auto-updates the first window.open to HTTPS but not the second -> thus downgrade and no referrer when the policy is strict-origin-when-cross-origin
# 1, 4, 16, 18, 21, 29 Firefox sends full_urls for no-referrer-when-downgrade, unsafe-url for window.open? (should not be supported?)
# 2, 3, 7, 8, 15, (27) Brave no referrer for origin (and similar)?
# 6, 9, 14, 22 Similar to 1, here however WebKit also leaks! (issue with same-site vs same-origin?)
# 10, 11, 12, 13 Cannot reproduce/Noise: during the tests?: no full URL for Chromium (Desktop) for same-origin
# 17, 19, 20, 23, 26, 28 HTTPS auto-upgrades? Chromium (similar to 0)
# 24 Full noise
show_response_groups(test_name, relation="window.open")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output…

# %%
# Might be possible to remove the noise here as well. Most of the differences with brave are actual real and due to shields being disabled on http://sub.headers.websec.saarland
# However the old 10-13, now 7-10 cannot be reproduced

# %% [markdown]
# ## Script execution/CSP
# - Testfile: `script-execution-csp.sub.html`
# - Testnames: `script_execution_iframe` (`direct`, `sandbox`)
# - Headers: CSP (default-src, script-src, ...)
# - **Everything entered into google sheets**, one potentially critical security bug identified?!
# - **No noise**

# %%
test_name = 'script_execution_iframe'

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 21
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 21
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                216
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 22
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                216
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                194
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 22
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                194
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                  test_id  test_id
# outcome_str
# message send        4835      237
# message timeout     1398      237
# resp_type
# basic        2
# parsing    108
# Name: raw_header, dtype: int64
# resp_type
# basic        17
# parsing    2699
# Name: raw_header, dtype: int64

# %%
# Direct
# 0: \x00 chromium-based + uppercase scheme chromium-base
# 1: \rheader, header<space>, header\t, \x0b<header-value> Firefox
# 2: \r<header-value>, <header-value>\x01, ... + status code 300, <header-name>\r firefox
# 3: */ -> * in chromium-based, */ (unknown) in other browsers
show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1', 'Group …

# %%
# Sandbox
# 0: WebKit: sandboxed iframes match everything with self (bug?!)
# 1: WebKit: for some reason *.headers.websec.saarland does not match https://sub.headers.websec.saarland/_hp/common/frame-script-csp.js Probably a bug in WebKit? might be related to sandbox??
show_response_groups(test_name, relation="sandbox")
# Out:
# Tab(children=(Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1'))

# %%
# Chromium-based treats host-source as case sensitive even though it should not? (URLs and CSP is case-insensitive!)
# Play around: https://observer.sectec.rocks/opg/iframe/?url=https://echo.sectec.rocks/echo/?content-security-policy=img-src%20HTTPS://echo.sectec.rocks&ecocnt_css=%3Cimg%20src=https://echo.sectec.rocks/%3E&content-type=text/html
# Issue is in the scheme match which should be case-insensitive but is in Chromium-based browsers https://w3c.github.io/webappsec-csp/#match-schemes
# host-part matching was fixed here https://issues.chromium.org/issues/41412675, seems like they forgot fixing scheme-sensitivity 
df.loc[df["raw_header"].str.contains("img-src HTTPS://")][["clean_url", "raw_header", "outcome_str", "browser"]].value_counts().to_frame()
# Out:
#                                                                                                                                                                       count
# clean_url                                          raw_header                                         outcome_str browser
# http://sub.headers.websec.saarland/_hp/tests/su... [['content-security-policy', 'img-src HTTPS://S... error       brave Android 11 1.62.165_shield intent real            1
#                                                                                                                   brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      1
#                                                                                                                   chrome Android 11 121.0.6167.180 intent real            1
#                                                                                                                   chrome Ubuntu 22.04 120 selenium headless-new           1
#                                                                                                                   chrome Ubuntu 22.04 121 selenium headless-new           1
#                                                                                                                   chrome Ubuntu 22.04 122 selenium headless-new           1
#                                                                                                                   chrome iPadOS 17.3.1 122.0.6261.89 intent real          1
#                                                                                                                   firefox Ubuntu 22.04 121 selenium headless              1
#                                                                                                                   firefox Ubuntu 22.04 122 selenium headless              1
#                                                                                                                   firefox Ubuntu 22.04 123 selenium headless              1
#                                                                                                                   firefox_beta Android 11 123.0b9 intent real             1
#                                                                                                                   safari macOS 14.3.1 17.3.1 selenium real                1
# https://sub.headers.websec.saarland/_hp/tests/s... [['content-security-policy', 'img-src HTTPS://S... error       brave Android 11 1.62.165_shield intent real            1
#                                                                                                                   brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) s...      1
#                                                                                                                   chrome Android 11 121.0.6167.180 intent real            1
#                                                                                                                   chrome Ubuntu 22.04 120 selenium headless-new           1
#                                                                                                                   chrome Ubuntu 22.04 121 selenium headless-new           1
#                                                                                                                   chrome Ubuntu 22.04 122 selenium headless-new           1
#                                                                                                       load        chrome iPadOS 17.3.1 122.0.6261.89 intent real          1
#                                                                                                                   firefox Ubuntu 22.04 121 selenium headless              1
#                                                                                                                   firefox Ubuntu 22.04 122 selenium headless              1
#                                                                                                                   firefox Ubuntu 22.04 123 selenium headless              1
#                                                                                                                   firefox_beta Android 11 123.0b9 intent real             1
#                                                                                                                   safari macOS 14.3.1 17.3.1 selenium real                1

# %% [markdown]
# ## COEP
# - Testfile: `subresource-loading-coep.sub.html`
# - Testnames: `subresourceloadingCOEP_img` (`direct`, `sandbox`)
# - Headers: COEP
# - **Issues with (known) randomness/undeterministic behavior in Firefox**
# - **Noise/Random Behavior (mostly Firefox, also MacOS), hard to analyze**
# - **Everything entered into google sheets**

# %%
test_name = 'subresourceloadingCOEP_img'

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9)                                                                      66
# Ubuntu firefox(121)                                                                                42
# Ubuntu firefox(122)                                                                                42
# Ubuntu firefox(123)                                                                                43
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 16
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield), Android chrome(...                             66
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu firefox(121)                                                            54
# Ubuntu firefox(122)                                                            54
# Ubuntu firefox(123)                                                            51
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                             79
#
#                                                     Ubuntu firefox(121)  \
# Android brave(1.62.165_shield), Android chrome(...                   42
# Android firefox_beta(123.0b9)                                        54
# Ubuntu firefox(121)                                                   0
# Ubuntu firefox(122)                                                  12
# Ubuntu firefox(123)                                                  15
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                   41
#
#                                                     Ubuntu firefox(122)  \
# Android brave(1.62.165_shield), Android chrome(...                   42
# Android firefox_beta(123.0b9)                                        54
# Ubuntu firefox(121)                                                  12
# Ubuntu firefox(122)                                                   0
# Ubuntu firefox(123)                                                  15
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                   41
#
#                                                     Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                   43
# Android firefox_beta(123.0b9)                                        51
# Ubuntu firefox(121)                                                  15
# Ubuntu firefox(122)                                                  15
# Ubuntu firefox(123)                                                   0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                   42
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 16
# Android firefox_beta(123.0b9)                                                                      79
# Ubuntu firefox(121)                                                                                41
# Ubuntu firefox(122)                                                                                41
# Ubuntu firefox(123)                                                                                42
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9)                                                                      51
# Ubuntu firefox(121)                                                                                55
# Ubuntu firefox(122)                                                                                52
# Ubuntu firefox(123)                                                                                49
# iPadOS chrome(122.0.6261.89)                                                                       75
# macOS safari(17.3.1)                                                                               61
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield), Android chrome(...                             51
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu firefox(121)                                                            22
# Ubuntu firefox(122)                                                            15
# Ubuntu firefox(123)                                                            22
# iPadOS chrome(122.0.6261.89)                                                   51
# macOS safari(17.3.1)                                                           57
#
#                                                     Ubuntu firefox(121)  \
# Android brave(1.62.165_shield), Android chrome(...                   55
# Android firefox_beta(123.0b9)                                        22
# Ubuntu firefox(121)                                                   0
# Ubuntu firefox(122)                                                  15
# Ubuntu firefox(123)                                                  18
# iPadOS chrome(122.0.6261.89)                                         63
# macOS safari(17.3.1)                                                 53
#
#                                                     Ubuntu firefox(122)  \
# Android brave(1.62.165_shield), Android chrome(...                   52
# Android firefox_beta(123.0b9)                                        15
# Ubuntu firefox(121)                                                  15
# Ubuntu firefox(122)                                                   0
# Ubuntu firefox(123)                                                  23
# iPadOS chrome(122.0.6261.89)                                         60
# macOS safari(17.3.1)                                                 56
#
#                                                     Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                   49
# Android firefox_beta(123.0b9)                                        22
# Ubuntu firefox(121)                                                  18
# Ubuntu firefox(122)                                                  23
# Ubuntu firefox(123)                                                   0
# iPadOS chrome(122.0.6261.89)                                         55
# macOS safari(17.3.1)                                                 37
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                            75
# Android firefox_beta(123.0b9)                                                 51
# Ubuntu firefox(121)                                                           63
# Ubuntu firefox(122)                                                           60
# Ubuntu firefox(123)                                                           55
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                          42
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                    61
# Android firefox_beta(123.0b9)                                         57
# Ubuntu firefox(121)                                                   53
# Ubuntu firefox(122)                                                   56
# Ubuntu firefox(123)                                                   37
# iPadOS chrome(122.0.6261.89)                                          42
# macOS safari(17.3.1)                                                   0
#                                                     test_id  test_id
# outcome_str
# message timeout                                         202       24
# {'image-events': {'swag.jpg': 'error', 'swag-sa...      102       94
# {'image-events': {'swag.jpg': 'error', 'swag-sa...        6        6
# {'image-events': {'swag.jpg': 'load', 'swag-sam...     5358      138
# {'image-events': {'swag.jpg': 'load', 'swag-sam...       79       72
# {'image-events': {'swag.jpg': 'load', 'swag-sam...       84       73
# resp_type
# basic       9
# parsing    67
# Name: raw_header, dtype: int64
# resp_type
# basic        11
# parsing    2610
# Name: raw_header, dtype: int64

# %%
# Direct
# 55 groups?!
# Lot's of random/undeterministic behavior in Firefox? (+ maybe noise iPad)?

# 0, 1, 2, 3, 4, 5, 6, 11, 12, 13, 14, 22: Noise Firefox (load for same-site, same-origin or one of them even though cross-site or cross-origin) Cannot reproduce this indeterministic behavior at the moment?
# 7, 8, 9, 10, 27, 29, 30: Noise Firefox (error for same-site, same-origin, or swag.jpg or one of them even though it is same-site, same-origin)
# 15: \x00 in header names Chromium timeout
# 16, 17, 20, 21, 23: same as the thing with sandboxes below
# Wrong hypothesis:
# require-corp parsing differences: e.g., \trequire-corp, or require-corp<SP>, 'require-corp; foo=bar' parsed as require-corp in WebKit, parsed as invalid in other browsers?! 
# maybe the other browsers allow swag.jpg always? even if require-corp is there (e.g., 21, 23) or they do a same-site instead of an same-origin check?
# 'require-corp; foo=bar' also compare to 37, 38, ... where other browsers interpreted it correctly as 'require-corp'!
# New hypothesis: require-corp: Firefox/Chromium allow http/auto-upgraded resources, Safari does not (swag.jpg); real https is not allowed by all browsers!
# (+ also quite some noise in iPadOS and/or MacOS)
# 18, 19, 42: code 300 firefox (also includes 16 group)
# 24, 26: HTTP auto-upgrade chromium
# 25: mix of 16 + 24
# 28, 32, 33, 34, 36, 37, 38, 39, 40, 41, 43, 44, 45, 46, 47, 48, 49, 50, 51, 53, 54, 55: full noise (usually firefox, sometimes safari as well)
# 31, 35: Firefox \r<header>, <header><space>, <header>\t + noise
# -52: Firefox empty header + header with 'require-corp' allowed, other browsers parse this as invalid!
# 

show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output…

# %%
# Sandbox
# 0: require-corp with sandbox: 
# Wrong old hypothesis: Safari says nothing is same-origin to sandbox, Chromium/Firefox say same URL is enough (still fail for CORP header that is same-origin though)
# Correct thing: only Safari disallows http loads without anything with require-corp, the other browsers allow http (even auto-upgraded) ones!

# Old Duckduckgo:
# 0: crossOriginIsolated missing in duckduckgo?
# 2: crossOriginIsolated missing in duckduckgo?
show_response_groups(test_name, relation="sandbox")
# Out:
# Tab(children=(Output(),), selected_index=0, titles=('Group 0',))

# %% [markdown]
# ## CORP
# - Testfile: `subresource-loading-corp.sub.html`
# - Testnames: `subresourceloadingCORP_img` (`direct`), `subresourceloadingCORP_object` (`direct`) (`nested` + `sandbox` have 0 differences between the browsers!)
# - Headers: CORP
# - **Entered everything into google sheets**
# - **No noise**

# %%
test_name = 'subresourceloadingCORP_img'

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  1
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                  1
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 56
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 36
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 56
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 44
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 36
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 44
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                          test_id  test_id
# outcome_str
# error                        301     69.0
# load                        6866     57.0
# message timeout              132      NaN
# timeout: no event fired       12     12.0
# resp_type
# basic       1
# parsing    34
# Name: raw_header, dtype: int64
# resp_type
# basic        11
# parsing    3321
# Name: raw_header, dtype: int64

# %%
# Direct
# 0: \x00 in chromium
# 1: WebKit does not like \n in reponses (timeout!)
# 2: Firefox \r<header-name>, <header-name><space>|<\t>
# 3: 2 CORP headers (one empty) work differently in Firefox and other browsers, Firefox says invalid, other browsers ignore all headers/invalid merged value?! 
# + 300, <header-name>\r
# 4: Chromium-https upgrade (includes iPadOS)
show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1…

# %%
# Object
# 0: WebKit does not support postMessages from objects (without the correct URL/type)
# 1: Only Firefox applies CORP to objects!
# 2: 0 + mixed-content blocking
show_response_groups("subresourceloadingCORP_object", relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1', 'Group 2'))

# %% [markdown]
# ## HSTS
# - Testfile: `upgrade-hsts.sub.html`
# - Testnames: `upgradeHSTS_direct` (`direct`), `upgradeHSTS_subdomain` (`subdomain`)
# - Headers: HSTS
# - **Everything entered into Google sheets**
# - **Small amount of noise on Android: ignored some of the results**

# %%
test_name = 'upgradeHSTS_direct'

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  1
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                  1
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# parsing
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                   1
# Android firefox_beta(123.0b9)                                                  244
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                               2
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             246
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                              85
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                   1
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9)                                                  245
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                               3
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             247
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                              86
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                                244
# Android chrome(121.0.6167.180)                                                245
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                            246
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              2
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                            283
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                                      2
# Android chrome(121.0.6167.180)                                                                      3
# Android firefox_beta(123.0b9)                                                                     246
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                  0
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                244
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 83
#
#                                                     Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                    246
# Android chrome(121.0.6167.180)                                                                    247
# Android firefox_beta(123.0b9)                                                                       2
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                244
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                281
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                                                     85
# Android chrome(121.0.6167.180)                                                                     86
# Android firefox_beta(123.0b9)                                                                     283
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                 83
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                281
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                                 test_id  test_id
# outcome_str
# Fetch timed out                      12       12
# TypeError: Failed to fetch           36       27
# {'response.redirected': False}     6133      304
# {'response.redirected': True}       803      273
# resp_type
# basic        1
# parsing    292
# Name: raw_header, dtype: int64
# resp_type
# basic        14
# parsing    3297
# Name: raw_header, dtype: int64

# %%
# Direct
# 0: \x00 in Chromium header name
# 1: \n in Firefox results in timed out fetch
# 2: WebKit vs all: various things? 
# e.g., WebKit ignores everything after the first ,?
# also ignores invalid directives?
# 3: Cannot reproduce results! Noise brave android :( -> ignore
# 4: Firefox vs all: 
# \r, space, \t; 
# however also Firefox does not ignore errors outside of the valid max-age=60
# 5: Firefox allows <header-name>\r 
# 6: Cannot reproduce: Noise brave android + chrome Android :( -> ignore
# 7: Firefox + WebKit vs Chrome: WebKit stops after the first comma, Firefox says full header is invalid? chrome ignores the invalid part?
# 8: Cannot reproduce: Noise opera Android :( -> ignore
# 9: \x00 in header values fails to fetch in chromium + firefox (works in Webkit)
# 10: Strange android behavior can be reproduced: maybe HSTS does not work with code 300 on Android: caching!
# 11: Firefox times out if fetch ends with \n (same as 1)
# 12: Firefox + WebKit vs Chrome: Chrome does not like incomplete directives? + leading ;
# 13: similar to 9, as \x00 is in includeSubDomains, max-age works in WebKit?
# 14: Cannot reproduce: Noise brave android :( -> ignore
show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output…

# %%
# Denoising!!

l = ["upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_31373_parsing",
"upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_32198_parsing",
"upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_29723_parsing"]

df.loc[(df["test_id"].isin(l)) & (df["browser_id"].isin([65])), "denoised_outcome_str"] = "{'response.redirected': False}"


# upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_30548_parsing chrome, brave android "{'response.redirected': False}"
# upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_33022_parsing brave android "{'response.redirected': True}"
df.loc[(df["test_id"] == "upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_30548_parsing") & (df["browser_id"].isin([62, 65])), "denoised_outcome_str"] = "{'response.redirected': False}"
df.loc[(df["test_id"] == "upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_33022_parsing") & (df["browser_id"].isin([65])), "denoised_outcome_str"] = "{'response.redirected': True}"

df.loc[(df["test_id"] == "upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_33022_parsing") & (df["browser_id"].isin([65]))]
# Out:
# Empty DataFrame
# Columns: [test_id, browser, outcome_str, id, outcome_type, outcome_value, test_name, test_status, test_message, test_stack, org_scheme, org_host, resp_scheme, resp_host, relation_info, browser_id, testcase_id, response_id, status, full_url, created_at, updated_at, raw_header, status_code, label, resp_type, name, version, headless_mode, os, automation_mode, add_info, outcome_str_ignore, clean_url, org_origin, resp_origin, file_name, b_short, denoised_outcome_str]
# Index: []
#
# [0 rows x 39 columns]

# %%
df.loc[(df["test_name"] == test_name) & (df["raw_header"].str.contains(";"))]["raw_header"].unique()
# Out:
# array(["[['Strict-Transport-Security', 'max-age=20; includeSubDomains']]",
#        "[['Strict-Transport-Security', 'max-age=20; includeSubDomains; preload']]",
#        "[['Strict-Transport-Security', 'max-age=20, max-age=20; includeSubDomains, includeSubDomains, , max-age=20; includeSubDomains; preload, max-age=0, max-age=-5']]",
#        ...,
#        "[['strict-transport-security', 'INVALID'], ['strict-transport-security', 'max-age=20; includeSubDomains']]",
#        "[['strict-transport-security', 'max-age=20; includeSubDomains, INVALID']]",
#        "[['strict-transport-security', 'INVALID, max-age=20; includeSubDomains']]"],
#       dtype=object)

# %%
# subdomain
# 0: \x00 in header name chromium
# 1: \n in fetch firefox
# 2: Firefox vs all: several differences
# 3: Firefox ignores = after includeSubDomains?! + <header-name>\r
# 4: Firefox + WebKit vs Chrome: WebKit stops after the first comma, Firefox says full header is invalid? chrome ignores the invalid part?
# 5: WebKit vs all: several differences?
# 6: \x00 in header value
# 7: \n in fetch Firefox (same as 1)
# 8: Chromium-based vs all: leading ;
show_response_groups("upgradeHSTS_subdomain", relation="subdomain")
# Out:
# Tab(children=(Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output(), Output()), selec…

# %% [markdown]
# ## XCTO
# - Testfile: `script-execution-xcto.sub.html`
# - Testnames: `sniffing_script` (`direct`)
# - Headers: XCTO

# %%
test_name = "sniffing_script"

# %%
show_overlap(test_name, groupby=True, show_all=True)
show_outcome_nums(test_name)
# All response headers that (sometimes) result in different outcomes
show_response_nums(test_name)
# Out:
# basic
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123), iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# parsing
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 18
# Ubuntu chrome(120)                                                                                 16
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  6
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 18
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# Ubuntu chrome(120)                                                                                 34
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 12
#
#                                                     Ubuntu chrome(120)  \
# Android brave(1.62.165_shield), Android chrome(...                  16
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                  34
# Ubuntu chrome(120)                                                   0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                  22
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                  6
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 12
# Ubuntu chrome(120)                                                                                 22
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
#                  test_id  test_id
# outcome_str
# message send        1818       34
# message timeout      202       34
# resp_type
# parsing    17
# Name: raw_header, dtype: int64
# resp_type
# basic       13
# parsing    880
# Name: raw_header, dtype: int64

# %%
# Direct
# 0: Chromium \x00
# 1: Firefox \r<header-name> and <header-name>\t:
# 2: Firefox <header-name>\r and <header-name>: \r<value>
# 3: Chrome (120): incorrect parsing: two headers, header with comma, \x0b, \x0c allowed even though it should not

show_response_groups(test_name, relation="direct")
# Out:
# Tab(children=(Output(), Output(), Output(), Output()), selected_index=0, titles=('Group 0', 'Group 1', 'Group …

# %% [markdown]
# ## Browser comparisons
# - One to one browser comparisons
# - E.g., what difference exist between Chrome 121 and Chrome 122
# - "Noise" summary:
#     - More or less matches with the "Stability" results, some are filtered out (wrong result only occured a single time, others remain as the majority vote was wrong?)
#     - No noise/all results could be reproduced/are stable: CORP, CSP-Script, perfAPI, CSP-Subresource, fullscreenPP, Framing, Fetch-CORS
#     - Small amount of noise: COOP (Chromium-based: Android only), HSTS (Chromium-based: Android only)
#     - Medium amount of noise: RP (Chromium-based: All)
#     - High noise: COEP (Firefox: All, WebKit: All)
# - Table only with the stable/non-noisy tests (browser-similarity)

# %%
for name, group in df.groupby("resp_type"):
    display_overlap(group, show_all=True, name=name)

for name, group in df.groupby("test_name"):
    display_overlap(group, show_all=False, name=name)
# Out:
# basic
#                                           Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                         0
# Android chrome(121.0.6167.180)                                        64
# Android firefox_beta(123.0b9)                                        597
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              16
# Ubuntu chrome(120)                                                    70
# Ubuntu chrome(121), Ubuntu chrome(122)                                71
# Ubuntu firefox(121)                                                  573
# Ubuntu firefox(122)                                                  573
# Ubuntu firefox(123)                                                  574
# iPadOS chrome(122.0.6261.89)                                        1504
# macOS safari(17.3.1)                                                1557
#
#                                           Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                        64
# Android chrome(121.0.6167.180)                                         0
# Android firefox_beta(123.0b9)                                        551
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              77
# Ubuntu chrome(120)                                                     6
# Ubuntu chrome(121), Ubuntu chrome(122)                                 7
# Ubuntu firefox(121)                                                  527
# Ubuntu firefox(122)                                                  527
# Ubuntu firefox(123)                                                  528
# iPadOS chrome(122.0.6261.89)                                        1471
# macOS safari(17.3.1)                                                1524
#
#                                           Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                      597
# Android chrome(121.0.6167.180)                                      551
# Android firefox_beta(123.0b9)                                         0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                            599
# Ubuntu chrome(120)                                                  557
# Ubuntu chrome(121), Ubuntu chrome(122)                              558
# Ubuntu firefox(121)                                                  54
# Ubuntu firefox(122)                                                  54
# Ubuntu firefox(123)                                                  51
# iPadOS chrome(122.0.6261.89)                                       1204
# macOS safari(17.3.1)                                               1155
#
#                                           Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                  16
# Android chrome(121.0.6167.180)                                                  77
# Android firefox_beta(123.0b9)                                                  599
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                         0
# Ubuntu chrome(120)                                                              71
# Ubuntu chrome(121), Ubuntu chrome(122)                                          72
# Ubuntu firefox(121)                                                            575
# Ubuntu firefox(122)                                                            575
# Ubuntu firefox(123)                                                            576
# iPadOS chrome(122.0.6261.89)                                                  1506
# macOS safari(17.3.1)                                                          1559
#
#                                           Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                            70
# Android chrome(121.0.6167.180)                             6
# Android firefox_beta(123.0b9)                            557
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  71
# Ubuntu chrome(120)                                         0
# Ubuntu chrome(121), Ubuntu chrome(122)                     1
# Ubuntu firefox(121)                                      533
# Ubuntu firefox(122)                                      533
# Ubuntu firefox(123)                                      534
# iPadOS chrome(122.0.6261.89)                            1477
# macOS safari(17.3.1)                                    1530
#
#                                           Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                71
# Android chrome(121.0.6167.180)                                                 7
# Android firefox_beta(123.0b9)                                                558
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                      72
# Ubuntu chrome(120)                                                             1
# Ubuntu chrome(121), Ubuntu chrome(122)                                         0
# Ubuntu firefox(121)                                                          534
# Ubuntu firefox(122)                                                          534
# Ubuntu firefox(123)                                                          535
# iPadOS chrome(122.0.6261.89)                                                1478
# macOS safari(17.3.1)                                                        1531
#
#                                           Ubuntu firefox(121)  \
# Android brave(1.62.165_shield)                            573
# Android chrome(121.0.6167.180)                            527
# Android firefox_beta(123.0b9)                              54
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  575
# Ubuntu chrome(120)                                        533
# Ubuntu chrome(121), Ubuntu chrome(122)                    534
# Ubuntu firefox(121)                                         0
# Ubuntu firefox(122)                                        12
# Ubuntu firefox(123)                                        15
# iPadOS chrome(122.0.6261.89)                             1166
# macOS safari(17.3.1)                                     1117
#
#                                           Ubuntu firefox(122)  \
# Android brave(1.62.165_shield)                            573
# Android chrome(121.0.6167.180)                            527
# Android firefox_beta(123.0b9)                              54
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  575
# Ubuntu chrome(120)                                        533
# Ubuntu chrome(121), Ubuntu chrome(122)                    534
# Ubuntu firefox(121)                                        12
# Ubuntu firefox(122)                                         0
# Ubuntu firefox(123)                                        15
# iPadOS chrome(122.0.6261.89)                             1166
# macOS safari(17.3.1)                                     1117
#
#                                           Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                            574
# Android chrome(121.0.6167.180)                            528
# Android firefox_beta(123.0b9)                              51
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  576
# Ubuntu chrome(120)                                        534
# Ubuntu chrome(121), Ubuntu chrome(122)                    535
# Ubuntu firefox(121)                                        15
# Ubuntu firefox(122)                                        15
# Ubuntu firefox(123)                                         0
# iPadOS chrome(122.0.6261.89)                             1167
# macOS safari(17.3.1)                                     1118
#
#                                           iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                    1504
# Android chrome(121.0.6167.180)                                    1471
# Android firefox_beta(123.0b9)                                     1204
# Ubuntu brave(v1.62.156 (121.0.6167.139))                          1506
# Ubuntu chrome(120)                                                1477
# Ubuntu chrome(121), Ubuntu chrome(122)                            1478
# Ubuntu firefox(121)                                               1166
# Ubuntu firefox(122)                                               1166
# Ubuntu firefox(123)                                               1167
# iPadOS chrome(122.0.6261.89)                                         0
# macOS safari(17.3.1)                                                53
#
#                                           macOS safari(17.3.1)
# Android brave(1.62.165_shield)                            1557
# Android chrome(121.0.6167.180)                            1524
# Android firefox_beta(123.0b9)                             1155
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  1559
# Ubuntu chrome(120)                                        1530
# Ubuntu chrome(121), Ubuntu chrome(122)                    1531
# Ubuntu firefox(121)                                       1117
# Ubuntu firefox(122)                                       1117
# Ubuntu firefox(123)                                       1118
# iPadOS chrome(122.0.6261.89)                                53
# macOS safari(17.3.1)                                         0
# parsing
#                                           Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                         0
# Android chrome(121.0.6167.180)                                        73
# Android firefox_beta(123.0b9)                                       2486
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              13
# Ubuntu chrome(120)                                                    99
# Ubuntu chrome(121), Ubuntu chrome(122)                                83
# Ubuntu firefox(121)                                                 2502
# Ubuntu firefox(122)                                                 2499
# Ubuntu firefox(123)                                                 2496
# iPadOS chrome(122.0.6261.89)                                        1217
# macOS safari(17.3.1)                                                1195
#
#                                           Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                        73
# Android chrome(121.0.6167.180)                                         0
# Android firefox_beta(123.0b9)                                       2556
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              84
# Ubuntu chrome(120)                                                    30
# Ubuntu chrome(121), Ubuntu chrome(122)                                14
# Ubuntu firefox(121)                                                 2572
# Ubuntu firefox(122)                                                 2569
# Ubuntu firefox(123)                                                 2566
# iPadOS chrome(122.0.6261.89)                                        1288
# macOS safari(17.3.1)                                                1266
#
#                                           Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                     2486
# Android chrome(121.0.6167.180)                                     2556
# Android firefox_beta(123.0b9)                                         0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                           2499
# Ubuntu chrome(120)                                                 2584
# Ubuntu chrome(121), Ubuntu chrome(122)                             2568
# Ubuntu firefox(121)                                                  36
# Ubuntu firefox(122)                                                  29
# Ubuntu firefox(123)                                                  36
# iPadOS chrome(122.0.6261.89)                                       1616
# macOS safari(17.3.1)                                               1614
#
#                                           Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                  13
# Android chrome(121.0.6167.180)                                                  84
# Android firefox_beta(123.0b9)                                                 2499
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                         0
# Ubuntu chrome(120)                                                              86
# Ubuntu chrome(121), Ubuntu chrome(122)                                          70
# Ubuntu firefox(121)                                                           2489
# Ubuntu firefox(122)                                                           2486
# Ubuntu firefox(123)                                                           2483
# iPadOS chrome(122.0.6261.89)                                                  1218
# macOS safari(17.3.1)                                                          1204
#
#                                           Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                            99
# Android chrome(121.0.6167.180)                            30
# Android firefox_beta(123.0b9)                           2584
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  86
# Ubuntu chrome(120)                                         0
# Ubuntu chrome(121), Ubuntu chrome(122)                    16
# Ubuntu firefox(121)                                     2574
# Ubuntu firefox(122)                                     2571
# Ubuntu firefox(123)                                     2568
# iPadOS chrome(122.0.6261.89)                            1304
# macOS safari(17.3.1)                                    1290
#
#                                           Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                83
# Android chrome(121.0.6167.180)                                                14
# Android firefox_beta(123.0b9)                                               2568
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                      70
# Ubuntu chrome(120)                                                            16
# Ubuntu chrome(121), Ubuntu chrome(122)                                         0
# Ubuntu firefox(121)                                                         2558
# Ubuntu firefox(122)                                                         2555
# Ubuntu firefox(123)                                                         2552
# iPadOS chrome(122.0.6261.89)                                                1288
# macOS safari(17.3.1)                                                        1274
#
#                                           Ubuntu firefox(121)  \
# Android brave(1.62.165_shield)                           2502
# Android chrome(121.0.6167.180)                           2572
# Android firefox_beta(123.0b9)                              36
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 2489
# Ubuntu chrome(120)                                       2574
# Ubuntu chrome(121), Ubuntu chrome(122)                   2558
# Ubuntu firefox(121)                                         0
# Ubuntu firefox(122)                                        15
# Ubuntu firefox(123)                                        18
# iPadOS chrome(122.0.6261.89)                             1630
# macOS safari(17.3.1)                                     1620
#
#                                           Ubuntu firefox(122)  \
# Android brave(1.62.165_shield)                           2499
# Android chrome(121.0.6167.180)                           2569
# Android firefox_beta(123.0b9)                              29
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 2486
# Ubuntu chrome(120)                                       2571
# Ubuntu chrome(121), Ubuntu chrome(122)                   2555
# Ubuntu firefox(121)                                        15
# Ubuntu firefox(122)                                         0
# Ubuntu firefox(123)                                        23
# iPadOS chrome(122.0.6261.89)                             1627
# macOS safari(17.3.1)                                     1623
#
#                                           Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                           2496
# Android chrome(121.0.6167.180)                           2566
# Android firefox_beta(123.0b9)                              36
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 2483
# Ubuntu chrome(120)                                       2568
# Ubuntu chrome(121), Ubuntu chrome(122)                   2552
# Ubuntu firefox(121)                                        18
# Ubuntu firefox(122)                                        23
# Ubuntu firefox(123)                                         0
# iPadOS chrome(122.0.6261.89)                             1622
# macOS safari(17.3.1)                                     1604
#
#                                           iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                    1217
# Android chrome(121.0.6167.180)                                    1288
# Android firefox_beta(123.0b9)                                     1616
# Ubuntu brave(v1.62.156 (121.0.6167.139))                          1218
# Ubuntu chrome(120)                                                1304
# Ubuntu chrome(121), Ubuntu chrome(122)                            1288
# Ubuntu firefox(121)                                               1630
# Ubuntu firefox(122)                                               1627
# Ubuntu firefox(123)                                               1622
# iPadOS chrome(122.0.6261.89)                                         0
# macOS safari(17.3.1)                                                50
#
#                                           macOS safari(17.3.1)
# Android brave(1.62.165_shield)                            1195
# Android chrome(121.0.6167.180)                            1266
# Android firefox_beta(123.0b9)                             1614
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  1204
# Ubuntu chrome(120)                                        1290
# Ubuntu chrome(121), Ubuntu chrome(122)                    1274
# Ubuntu firefox(121)                                       1620
# Ubuntu firefox(122)                                       1623
# Ubuntu firefox(123)                                       1604
# iPadOS chrome(122.0.6261.89)                                50
# macOS safari(17.3.1)                                         0
# accesswindow_direct
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                   2
# Android firefox_beta(123.0b9)                                                   57
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                              11
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              67
# iPadOS chrome(122.0.6261.89)                                                    37
# macOS safari(17.3.1)                                                            29
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                   2
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9)                                                   57
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                              11
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              67
# iPadOS chrome(122.0.6261.89)                                                    37
# macOS safari(17.3.1)                                                            29
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                                 57
# Android chrome(121.0.6167.180)                                                 57
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                             68
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             12
# iPadOS chrome(122.0.6261.89)                                                   36
# macOS safari(17.3.1)                                                           28
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                                     11
# Android chrome(121.0.6167.180)                                                                     11
# Android firefox_beta(123.0b9)                                                                      68
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                  0
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                 56
# iPadOS chrome(122.0.6261.89)                                                                       40
# macOS safari(17.3.1)                                                                               40
#
#                                                     Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                     67
# Android chrome(121.0.6167.180)                                                                     67
# Android firefox_beta(123.0b9)                                                                      12
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                 56
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       40
# macOS safari(17.3.1)                                                                               40
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                                37
# Android chrome(121.0.6167.180)                                                37
# Android firefox_beta(123.0b9)                                                 36
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                            40
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                            40
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                           8
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                        29
# Android chrome(121.0.6167.180)                                        29
# Android firefox_beta(123.0b9)                                         28
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                    40
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                    40
# iPadOS chrome(122.0.6261.89)                                           8
# macOS safari(17.3.1)                                                   0
# fetch_GET
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                291
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 94
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                291
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                197
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 94
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                197
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# fetch_TEST
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                101
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 55
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                101
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 46
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 55
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 46
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# framing_embed
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                426
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                426
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# framing_iframe
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                517
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 95
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                517
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                422
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 95
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                422
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# framing_object
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Android firefox_beta(123.0b9), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                426
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                426
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# fullscreen_iframe
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                905
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                900
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                905
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  9
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                900
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  9
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# imgloading_iframe
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                243
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 41
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                243
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                202
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 41
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                202
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# perfAPI_img
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 66
# iPadOS chrome(122.0.6261.89)                                                                       22
# macOS safari(17.3.1)                                                                               74
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 66
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       88
# macOS safari(17.3.1)                                                                               40
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                            22
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                            88
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                          52
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                    74
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                    40
# iPadOS chrome(122.0.6261.89)                                          52
# macOS safari(17.3.1)                                                   0
# referrer_iframe
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                 134
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                             151
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                        16
# Ubuntu chrome(120)                                                             140
# Ubuntu chrome(121), Ubuntu chrome(122)                                         141
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                             133
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                 134
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                             174
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                       147
# Ubuntu chrome(120)                                                               6
# Ubuntu chrome(121), Ubuntu chrome(122)                                           7
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                             170
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                    151
# Android chrome(121.0.6167.180)                                                                    174
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                          153
# Ubuntu chrome(120)                                                                                180
# Ubuntu chrome(121), Ubuntu chrome(122)                                                            181
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 26
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                            16
# Android chrome(121.0.6167.180)                                                           147
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                       153
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                   0
# Ubuntu chrome(120)                                                                       141
# Ubuntu chrome(121), Ubuntu chrome(122)                                                   142
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                       135
#
#                                                     Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                                     140
# Android chrome(121.0.6167.180)                                       6
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                 180
# Ubuntu brave(v1.62.156 (121.0.6167.139))                           141
# Ubuntu chrome(120)                                                   0
# Ubuntu chrome(121), Ubuntu chrome(122)                               1
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                 176
#
#                                                     Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                         141
# Android chrome(121.0.6167.180)                                                           7
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                     181
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                               142
# Ubuntu chrome(120)                                                                       1
# Ubuntu chrome(121), Ubuntu chrome(122)                                                   0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                     177
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                                                    133
# Android chrome(121.0.6167.180)                                                                    170
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 26
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                          135
# Ubuntu chrome(120)                                                                                176
# Ubuntu chrome(121), Ubuntu chrome(122)                                                            177
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# script_execution_iframe
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                216
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 43
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                216
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                215
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 43
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                215
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# sniffing_script
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 18
# Ubuntu chrome(120)                                                                                 16
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  6
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# ...
# Ubuntu firefox(121)                                                                                97
# Ubuntu firefox(122)                                                                                94
# Ubuntu firefox(123)                                                                                92
# iPadOS chrome(122.0.6261.89)                                                                       91
# macOS safari(17.3.1)                                                                               77
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield), Android chrome(...                            117
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu firefox(121)                                                            76
# Ubuntu firefox(122)                                                            69
# Ubuntu firefox(123)                                                            73
# iPadOS chrome(122.0.6261.89)                                                  130
# macOS safari(17.3.1)                                                          136
#
#                                                     Ubuntu firefox(121)  \
# Android brave(1.62.165_shield), Android chrome(...                   97
# Android firefox_beta(123.0b9)                                        76
# Ubuntu firefox(121)                                                   0
# Ubuntu firefox(122)                                                  27
# Ubuntu firefox(123)                                                  33
# iPadOS chrome(122.0.6261.89)                                        104
# macOS safari(17.3.1)                                                 94
#
#                                                     Ubuntu firefox(122)  \
# Android brave(1.62.165_shield), Android chrome(...                   94
# Android firefox_beta(123.0b9)                                        69
# Ubuntu firefox(121)                                                  27
# Ubuntu firefox(122)                                                   0
# Ubuntu firefox(123)                                                  38
# iPadOS chrome(122.0.6261.89)                                        101
# macOS safari(17.3.1)                                                 97
#
#                                                     Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                   92
# Android firefox_beta(123.0b9)                                        73
# Ubuntu firefox(121)                                                  33
# Ubuntu firefox(122)                                                  38
# Ubuntu firefox(123)                                                   0
# iPadOS chrome(122.0.6261.89)                                         97
# macOS safari(17.3.1)                                                 79
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                            91
# Android firefox_beta(123.0b9)                                                130
# Ubuntu firefox(121)                                                          104
# Ubuntu firefox(122)                                                          101
# Ubuntu firefox(123)                                                           97
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                          42
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                    77
# Android firefox_beta(123.0b9)                                        136
# Ubuntu firefox(121)                                                   94
# Ubuntu firefox(122)                                                   97
# Ubuntu firefox(123)                                                   79
# iPadOS chrome(122.0.6261.89)                                          42
# macOS safari(17.3.1)                                                   0
# subresourceloadingCORP_img
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 57
# iPadOS chrome(122.0.6261.89)                                                                       36
# macOS safari(17.3.1)                                                                               37
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 57
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                       45
# macOS safari(17.3.1)                                                                               44
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield), Android chrome(...                            36
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                            45
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                           1
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                    37
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                    44
# iPadOS chrome(122.0.6261.89)                                           1
# macOS safari(17.3.1)                                                   0
# subresourceloadingCORP_object
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 32
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                176
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 32
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                176
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                176
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                176
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# upgradeHSTS_direct
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                   1
# Android firefox_beta(123.0b9)                                                  244
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                               2
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             246
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                              86
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                   1
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9)                                                  245
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                               3
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             247
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                              87
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                                244
# Android chrome(121.0.6167.180)                                                245
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                            246
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                              2
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                            284
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                                      2
# Android chrome(121.0.6167.180)                                                                      3
# Android firefox_beta(123.0b9)                                                                     246
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                  0
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                244
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 84
#
#                                                     Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                    246
# Android chrome(121.0.6167.180)                                                                    247
# Android firefox_beta(123.0b9)                                                                       2
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                244
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                282
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                                                     86
# Android chrome(121.0.6167.180)                                                                     87
# Android firefox_beta(123.0b9)                                                                     284
# Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubunt...                                                 84
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                282
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0
# upgradeHSTS_subdomain
#                                                     Android brave(1.62.165_shield), Android chrome(121.0.6167.180), Ubuntu brave(v1.62.156 (121.0.6167.139)), Ubuntu chrome(120), Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield), Android chrome(...                                                  0
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 68
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 54
#
#                                                     Android firefox_beta(123.0b9), Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield), Android chrome(...                                                 68
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                  0
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                 80
#
#                                                     iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)
# Android brave(1.62.165_shield), Android chrome(...                                                 54
# Android firefox_beta(123.0b9), Ubuntu firefox(1...                                                 80
# iPadOS chrome(122.0.6261.89), macOS safari(17.3.1)                                                  0

# %%
df["test_name"].unique()
# Out:
# array(['accesswindow_direct', 'fetch_GET', 'fetch_TEST', 'framing_embed',
#        'framing_iframe', 'framing_object', 'fullscreen_iframe',
#        'imgloading_iframe', 'perfAPI_img', 'referrer_iframe',
#        'script_execution_iframe', 'sniffing_script',
#        'subresourceloadingCOEP_img', 'subresourceloadingCORP_img',
#        'subresourceloadingCORP_object', 'upgradeHSTS_direct',
#        'upgradeHSTS_subdomain'], dtype=object)

# %%
no_noise = [ 'fetch_GET', 'fetch_TEST', 'framing_embed',
       'framing_iframe', 'framing_object', 'fullscreen_iframe',
       'imgloading_iframe', 'perfAPI_img',
       'script_execution_iframe', 
       'subresourceloadingCORP_img', 'subresourceloadingCORP_object',
         'upgradeHSTS_subdomain', 'sniffing_script']

# Clean(ed) noise for accesswindows, upgradeHSTS
# for referrer only remove window.open, for COEP only remove direct, sandbox is not noisy!
# Noisy remaining: only referrer_iframe_window and COEP_direct

some_noise = [('subresourceloadingCOEP_img', 'direct'), ('referrer_iframe', 'window.open')]

# %%
# Only the ones without noise
nnd = df
for (test_name, relation) in some_noise:
    nnd = nnd.loc[~((nnd["test_name"] == test_name) & (nnd["relation_info"] == relation))]

nnd["outcome_str"] = nnd["denoised_outcome_str"]
no_noise_diff = display_overlap(nnd)
# Out:
# All
#                                                     Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                                   0
# Android chrome(121.0.6167.180)                                                  88
# Android firefox_beta(123.0b9)                                                 2854
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                        18
# Ubuntu chrome(120)                                                             122
# Ubuntu chrome(121), Ubuntu chrome(122)                                         106
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                            2868
# iPadOS chrome(122.0.6261.89)                                                  2525
# macOS safari(17.3.1)                                                          2570
#
#                                                     Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                                  88
# Android chrome(121.0.6167.180)                                                   0
# Android firefox_beta(123.0b9)                                                 2917
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                       106
# Ubuntu chrome(120)                                                              34
# Ubuntu chrome(121), Ubuntu chrome(122)                                          18
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                            2931
# iPadOS chrome(122.0.6261.89)                                                  2589
# macOS safari(17.3.1)                                                          2634
#
#                                                     Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                               2854
# Android chrome(121.0.6167.180)                                               2917
# Android firefox_beta(123.0b9)                                                   0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                     2872
# Ubuntu chrome(120)                                                           2951
# Ubuntu chrome(121), Ubuntu chrome(122)                                       2935
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                             14
# iPadOS chrome(122.0.6261.89)                                                 2683
# macOS safari(17.3.1)                                                         2626
#
#                                                     Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                            18
# Android chrome(121.0.6167.180)                                                           106
# Android firefox_beta(123.0b9)                                                           2872
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                   0
# Ubuntu chrome(120)                                                                       104
# Ubuntu chrome(121), Ubuntu chrome(122)                                                    88
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                      2858
# iPadOS chrome(122.0.6261.89)                                                            2531
# macOS safari(17.3.1)                                                                    2584
#
#                                                     Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                                     122
# Android chrome(121.0.6167.180)                                      34
# Android firefox_beta(123.0b9)                                     2951
# Ubuntu brave(v1.62.156 (121.0.6167.139))                           104
# Ubuntu chrome(120)                                                   0
# Ubuntu chrome(121), Ubuntu chrome(122)                              16
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                2937
# iPadOS chrome(122.0.6261.89)                                      2611
# macOS safari(17.3.1)                                              2664
#
#                                                     Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                                         106
# Android chrome(121.0.6167.180)                                                          18
# Android firefox_beta(123.0b9)                                                         2935
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                88
# Ubuntu chrome(120)                                                                      16
# Ubuntu chrome(121), Ubuntu chrome(122)                                                   0
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                    2921
# iPadOS chrome(122.0.6261.89)                                                          2595
# macOS safari(17.3.1)                                                                  2648
#
#                                                     Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                                                                   2868
# Android chrome(121.0.6167.180)                                                                   2931
# Android firefox_beta(123.0b9)                                                                      14
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                                         2858
# Ubuntu chrome(120)                                                                               2937
# Ubuntu chrome(121), Ubuntu chrome(122)                                                           2921
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                                                  0
# iPadOS chrome(122.0.6261.89)                                                                     2685
# macOS safari(17.3.1)                                                                             2636
#
#                                                     iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                              2525
# Android chrome(121.0.6167.180)                                              2589
# Android firefox_beta(123.0b9)                                               2683
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                    2531
# Ubuntu chrome(120)                                                          2611
# Ubuntu chrome(121), Ubuntu chrome(122)                                      2595
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                          2685
# iPadOS chrome(122.0.6261.89)                                                   0
# macOS safari(17.3.1)                                                          61
#
#                                                     macOS safari(17.3.1)
# Android brave(1.62.165_shield)                                      2570
# Android chrome(121.0.6167.180)                                      2634
# Android firefox_beta(123.0b9)                                       2626
# Ubuntu brave(v1.62.156 (121.0.6167.139))                            2584
# Ubuntu chrome(120)                                                  2664
# Ubuntu chrome(121), Ubuntu chrome(122)                              2648
# Ubuntu firefox(121), Ubuntu firefox(122), Ubunt...                  2636
# iPadOS chrome(122.0.6261.89)                                          61
# macOS safari(17.3.1)                                                   0

# %%
len(df[["test_name", "relation_info"]].drop_duplicates()), len(nnd[["test_name", "relation_info"]].drop_duplicates())
# Out:
# (33, 31)

# %%
nnd.groupby("test_id", observed=True)["denoised_outcome_str"].nunique().value_counts()
# Out:
# denoised_outcome_str
# 1    167324
# 2      4075
# 3        41
# Name: count, dtype: int64

# %%
df.groupby("test_id", observed=True)["denoised_outcome_str"].nunique().value_counts()
# Out:
# denoised_outcome_str
# 1    172715
# 2      4373
# 3        58
# Name: count, dtype: int64

# %%
4373+58
# Out:
# 4431

# %%
print(no_noise_diff.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrrr}
# \toprule
#  & Android brave(1.62.165_shield) & Android chrome(121.0.6167.180) & Android firefox_beta(123.0b9) & Ubuntu brave(v1.62.156 (121.0.6167.139)) & Ubuntu chrome(120) & Ubuntu chrome(121), Ubuntu chrome(122) & Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123) & iPadOS chrome(122.0.6261.89) & macOS safari(17.3.1) \\
# \midrule
# Android brave(1.62.165_shield) & 0 & 88 & 2854 & 18 & 122 & 106 & 2868 & 2525 & 2570 \\
# Android chrome(121.0.6167.180) & 88 & 0 & 2917 & 106 & 34 & 18 & 2931 & 2589 & 2634 \\
# Android firefox_beta(123.0b9) & 2854 & 2917 & 0 & 2872 & 2951 & 2935 & 14 & 2683 & 2626 \\
# Ubuntu brave(v1.62.156 (121.0.6167.139)) & 18 & 106 & 2872 & 0 & 104 & 88 & 2858 & 2531 & 2584 \\
# Ubuntu chrome(120) & 122 & 34 & 2951 & 104 & 0 & 16 & 2937 & 2611 & 2664 \\
# Ubuntu chrome(121), Ubuntu chrome(122) & 106 & 18 & 2935 & 88 & 16 & 0 & 2921 & 2595 & 2648 \\
# Ubuntu firefox(121), Ubuntu firefox(122), Ubuntu firefox(123) & 2868 & 2931 & 14 & 2858 & 2937 & 2921 & 0 & 2685 & 2636 \\
# iPadOS chrome(122.0.6261.89) & 2525 & 2589 & 2683 & 2531 & 2611 & 2595 & 2685 & 0 & 61 \\
# macOS safari(17.3.1) & 2570 & 2634 & 2626 & 2584 & 2664 & 2648 & 2636 & 61 & 0 \\
# \bottomrule
# \end{tabular}

# %%
all_diff = display_overlap(df)
# Out:
# All
#                                           Android brave(1.62.165_shield)  \
# Android brave(1.62.165_shield)                                         0
# Android chrome(121.0.6167.180)                                       137
# Android firefox_beta(123.0b9)                                       3083
# Ubuntu brave(v1.62.156 (121.0.6167.139))                              29
# Ubuntu chrome(120)                                                   169
# Ubuntu chrome(121), Ubuntu chrome(122)                               154
# Ubuntu firefox(121)                                                 3075
# Ubuntu firefox(122)                                                 3072
# Ubuntu firefox(123)                                                 3070
# iPadOS chrome(122.0.6261.89)                                        2721
# macOS safari(17.3.1)                                                2752
#
#                                           Android chrome(121.0.6167.180)  \
# Android brave(1.62.165_shield)                                       137
# Android chrome(121.0.6167.180)                                         0
# Android firefox_beta(123.0b9)                                       3107
# Ubuntu brave(v1.62.156 (121.0.6167.139))                             161
# Ubuntu chrome(120)                                                    36
# Ubuntu chrome(121), Ubuntu chrome(122)                                21
# Ubuntu firefox(121)                                                 3099
# Ubuntu firefox(122)                                                 3096
# Ubuntu firefox(123)                                                 3094
# iPadOS chrome(122.0.6261.89)                                        2759
# macOS safari(17.3.1)                                                2790
#
#                                           Android firefox_beta(123.0b9)  \
# Android brave(1.62.165_shield)                                     3083
# Android chrome(121.0.6167.180)                                     3107
# Android firefox_beta(123.0b9)                                         0
# Ubuntu brave(v1.62.156 (121.0.6167.139))                           3098
# Ubuntu chrome(120)                                                 3141
# Ubuntu chrome(121), Ubuntu chrome(122)                             3126
# Ubuntu firefox(121)                                                  90
# Ubuntu firefox(122)                                                  83
# Ubuntu firefox(123)                                                  87
# iPadOS chrome(122.0.6261.89)                                       2820
# macOS safari(17.3.1)                                               2769
#
#                                           Ubuntu brave(v1.62.156 (121.0.6167.139))  \
# Android brave(1.62.165_shield)                                                  29
# Android chrome(121.0.6167.180)                                                 161
# Android firefox_beta(123.0b9)                                                 3098
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                         0
# Ubuntu chrome(120)                                                             157
# Ubuntu chrome(121), Ubuntu chrome(122)                                         142
# Ubuntu firefox(121)                                                           3064
# Ubuntu firefox(122)                                                           3061
# Ubuntu firefox(123)                                                           3059
# iPadOS chrome(122.0.6261.89)                                                  2724
# macOS safari(17.3.1)                                                          2763
#
#                                           Ubuntu chrome(120)  \
# Android brave(1.62.165_shield)                           169
# Android chrome(121.0.6167.180)                            36
# Android firefox_beta(123.0b9)                           3141
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 157
# Ubuntu chrome(120)                                         0
# Ubuntu chrome(121), Ubuntu chrome(122)                    17
# Ubuntu firefox(121)                                     3107
# Ubuntu firefox(122)                                     3104
# Ubuntu firefox(123)                                     3102
# iPadOS chrome(122.0.6261.89)                            2781
# macOS safari(17.3.1)                                    2820
#
#                                           Ubuntu chrome(121), Ubuntu chrome(122)  \
# Android brave(1.62.165_shield)                                               154
# Android chrome(121.0.6167.180)                                                21
# Android firefox_beta(123.0b9)                                               3126
# Ubuntu brave(v1.62.156 (121.0.6167.139))                                     142
# Ubuntu chrome(120)                                                            17
# Ubuntu chrome(121), Ubuntu chrome(122)                                         0
# Ubuntu firefox(121)                                                         3092
# Ubuntu firefox(122)                                                         3089
# Ubuntu firefox(123)                                                         3087
# iPadOS chrome(122.0.6261.89)                                                2766
# macOS safari(17.3.1)                                                        2805
#
#                                           Ubuntu firefox(121)  \
# Android brave(1.62.165_shield)                           3075
# Android chrome(121.0.6167.180)                           3099
# Android firefox_beta(123.0b9)                              90
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 3064
# Ubuntu chrome(120)                                       3107
# Ubuntu chrome(121), Ubuntu chrome(122)                   3092
# Ubuntu firefox(121)                                         0
# Ubuntu firefox(122)                                        27
# Ubuntu firefox(123)                                        33
# iPadOS chrome(122.0.6261.89)                             2796
# macOS safari(17.3.1)                                     2737
#
#                                           Ubuntu firefox(122)  \
# Android brave(1.62.165_shield)                           3072
# Android chrome(121.0.6167.180)                           3096
# Android firefox_beta(123.0b9)                              83
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 3061
# Ubuntu chrome(120)                                       3104
# Ubuntu chrome(121), Ubuntu chrome(122)                   3089
# Ubuntu firefox(121)                                        27
# Ubuntu firefox(122)                                         0
# Ubuntu firefox(123)                                        38
# iPadOS chrome(122.0.6261.89)                             2793
# macOS safari(17.3.1)                                     2740
#
#                                           Ubuntu firefox(123)  \
# Android brave(1.62.165_shield)                           3070
# Android chrome(121.0.6167.180)                           3094
# Android firefox_beta(123.0b9)                              87
# Ubuntu brave(v1.62.156 (121.0.6167.139))                 3059
# Ubuntu chrome(120)                                       3102
# Ubuntu chrome(121), Ubuntu chrome(122)                   3087
# Ubuntu firefox(121)                                        33
# Ubuntu firefox(122)                                        38
# Ubuntu firefox(123)                                         0
# iPadOS chrome(122.0.6261.89)                             2789
# macOS safari(17.3.1)                                     2722
#
#                                           iPadOS chrome(122.0.6261.89)  \
# Android brave(1.62.165_shield)                                    2721
# Android chrome(121.0.6167.180)                                    2759
# Android firefox_beta(123.0b9)                                     2820
# Ubuntu brave(v1.62.156 (121.0.6167.139))                          2724
# Ubuntu chrome(120)                                                2781
# Ubuntu chrome(121), Ubuntu chrome(122)                            2766
# Ubuntu firefox(121)                                               2796
# Ubuntu firefox(122)                                               2793
# Ubuntu firefox(123)                                               2789
# iPadOS chrome(122.0.6261.89)                                         0
# macOS safari(17.3.1)                                               103
#
#                                           macOS safari(17.3.1)
# Android brave(1.62.165_shield)                            2752
# Android chrome(121.0.6167.180)                            2790
# Android firefox_beta(123.0b9)                             2769
# Ubuntu brave(v1.62.156 (121.0.6167.139))                  2763
# Ubuntu chrome(120)                                        2820
# Ubuntu chrome(121), Ubuntu chrome(122)                    2805
# Ubuntu firefox(121)                                       2737
# Ubuntu firefox(122)                                       2740
# Ubuntu firefox(123)                                       2722
# iPadOS chrome(122.0.6261.89)                               103
# macOS safari(17.3.1)                                         0

# %%
print(all_diff.to_latex())
# Out:
# \begin{tabular}{lrrrrrrrrrrr}
# \toprule
#  & Android brave(1.62.165_shield) & Android chrome(121.0.6167.180) & Android firefox_beta(123.0b9) & Ubuntu brave(v1.62.156 (121.0.6167.139)) & Ubuntu chrome(120) & Ubuntu chrome(121), Ubuntu chrome(122) & Ubuntu firefox(121) & Ubuntu firefox(122) & Ubuntu firefox(123) & iPadOS chrome(122.0.6261.89) & macOS safari(17.3.1) \\
# \midrule
# Android brave(1.62.165_shield) & 0 & 137 & 3083 & 29 & 169 & 154 & 3075 & 3072 & 3070 & 2721 & 2752 \\
# Android chrome(121.0.6167.180) & 137 & 0 & 3107 & 161 & 36 & 21 & 3099 & 3096 & 3094 & 2759 & 2790 \\
# Android firefox_beta(123.0b9) & 3083 & 3107 & 0 & 3098 & 3141 & 3126 & 90 & 83 & 87 & 2820 & 2769 \\
# Ubuntu brave(v1.62.156 (121.0.6167.139)) & 29 & 161 & 3098 & 0 & 157 & 142 & 3064 & 3061 & 3059 & 2724 & 2763 \\
# Ubuntu chrome(120) & 169 & 36 & 3141 & 157 & 0 & 17 & 3107 & 3104 & 3102 & 2781 & 2820 \\
# Ubuntu chrome(121), Ubuntu chrome(122) & 154 & 21 & 3126 & 142 & 17 & 0 & 3092 & 3089 & 3087 & 2766 & 2805 \\
# Ubuntu firefox(121) & 3075 & 3099 & 90 & 3064 & 3107 & 3092 & 0 & 27 & 33 & 2796 & 2737 \\
# Ubuntu firefox(122) & 3072 & 3096 & 83 & 3061 & 3104 & 3089 & 27 & 0 & 38 & 2793 & 2740 \\
# Ubuntu firefox(123) & 3070 & 3094 & 87 & 3059 & 3102 & 3087 & 33 & 38 & 0 & 2789 & 2722 \\
# iPadOS chrome(122.0.6261.89) & 2721 & 2759 & 2820 & 2724 & 2781 & 2766 & 2796 & 2793 & 2789 & 0 & 103 \\
# macOS safari(17.3.1) & 2752 & 2790 & 2769 & 2763 & 2820 & 2805 & 2737 & 2740 & 2722 & 103 & 0 \\
# \bottomrule
# \end{tabular}

# %%
# Add single repeat URL to each test
df["url"] = df["clean_url"] + "&t_resp_id=" + df["response_id"].astype(str) + "&t_element_relation=" + df["test_name"].apply(lambda x: x.split("_")[1]) + "_" + df["relation_info"] + "&t_resp_origin=" + df["resp_origin"]

# %%
bf = df.set_index(["test_id", "browser"])["denoised_outcome_str"].unstack().astype("str")
# bf = df.set_index(["test_id", "browser"])["outcome_str"].unstack().astype("str")


# bf = nnd.set_index(["test_id", "browser"])["outcome_str"].unstack().astype("str")


def com_browsers(bf, b1, b2):
    bf["diff"] = bf[b1] != bf[b2]
    r = bf.loc[bf["diff"]][[b1, b2]].reset_index()
    return r

# %% [markdown]
# ### Chromium 121-122 vs 120 (desktop linux)
# - **RP the same: noise, cannot reproduce difference!**
# - **16 Differences for sniffing script!**
# - Basic RP test: referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_196_basic
# - 'Referrer-Policy', 'origin-when-cross-origin'
# - 120 has full URL, 121 - 121 report `document.referrer: http://sub.headers.websec.saarland/`

# %%
r = com_browsers(bf, "chrome Ubuntu 22.04 120 selenium headless-new", "chrome Ubuntu 22.04 121 selenium headless-new")
display(r)
display(df.loc[df["response_id"] == 196]["raw_header"].iloc[0])
display(df.loc[df["test_id"] == r["test_id"].iloc[0]]["url"].iloc[0])
# Out:
# browser                                            test_id  \
# 0        referrer_iframe_window.open_http_sub.headers.w...
# 1        sniffing_script_direct_http_sub.headers.websec...
# 2        sniffing_script_direct_http_sub.headers.websec...
# 3        sniffing_script_direct_http_sub.headers.websec...
# 4        sniffing_script_direct_http_sub.headers.websec...
# 5        sniffing_script_direct_http_sub.headers.websec...
# 6        sniffing_script_direct_http_sub.headers.websec...
# 7        sniffing_script_direct_http_sub.headers.websec...
# 8        sniffing_script_direct_http_sub.headers.websec...
# 9        sniffing_script_direct_https_sub.headers.webse...
# 10       sniffing_script_direct_https_sub.headers.webse...
# 11       sniffing_script_direct_https_sub.headers.webse...
# 12       sniffing_script_direct_https_sub.headers.webse...
# 13       sniffing_script_direct_https_sub.headers.webse...
# 14       sniffing_script_direct_https_sub.headers.webse...
# 15       sniffing_script_direct_https_sub.headers.webse...
# 16       sniffing_script_direct_https_sub.headers.webse...
#
# browser chrome Ubuntu 22.04 120 selenium headless-new  \
# 0                         document.referrer: full_url
# 1                                     message timeout
# 2                                     message timeout
# 3                                     message timeout
# 4                                     message timeout
# 5                                     message timeout
# 6                                     message timeout
# 7                                     message timeout
# 8                                     message timeout
# 9                                     message timeout
# 10                                    message timeout
# 11                                    message timeout
# 12                                    message timeout
# 13                                    message timeout
# 14                                    message timeout
# 15                                    message timeout
# 16                                    message timeout
#
# browser chrome Ubuntu 22.04 121 selenium headless-new
# 0                    document.referrer: http://origin
# 1                                        message send
# 2                                        message send
# 3                                        message send
# 4                                        message send
# 5                                        message send
# 6                                        message send
# 7                                        message send
# 8                                        message send
# 9                                        message send
# 10                                       message send
# 11                                       message send
# 12                                       message send
# 13                                       message send
# 14                                       message send
# 15                                       message send
# 16                                       message send
# "[['Referrer-Policy', 'origin-when-cross-origin']]"
# 'http://sub.headers.websec.saarland/_hp/tests/referrer-access-rp.sub.html?resp_type=basic&browser_id=1&label=RP&first_id=196&last_id=196&scheme=http&t_resp_id=196&t_element_relation=iframe_window.open&t_resp_origin=http://sub.headers.websec.saarland'

# %% [markdown]
# ### Chromium 121 desktop vs android
# - **Differences: accesswindow_direct (different download behavior), upgradeHSTS (caching behavior)**
# - RP: noise/cannot reproduce

# %%
r = com_browsers(bf, "chrome Ubuntu 22.04 121 selenium headless-new", "chrome Android 11 121.0.6167.180 intent real")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
display(r)
# Out:
# test_id
# accesswindow    16
# referrer         7
# upgradeHSTS      2
# Name: count, dtype: int64
# browser                                            test_id  \
# 0        accesswindow_direct_direct_http_sub.headers.we...
# 1        accesswindow_direct_direct_http_sub.headers.we...
# 2        accesswindow_direct_direct_http_sub.headers.we...
# 3        accesswindow_direct_direct_http_sub.headers.we...
# 4        accesswindow_direct_direct_http_sub.headers.we...
# 5        accesswindow_direct_direct_http_sub.headers.we...
# 6        accesswindow_direct_direct_https_sub.headers.w...
# 7        accesswindow_direct_direct_https_sub.headers.w...
# 8        accesswindow_direct_direct_https_sub.headers.w...
# 9        accesswindow_direct_direct_https_sub.headers.w...
# 10       accesswindow_direct_direct_https_sub.headers.w...
# 11       accesswindow_direct_direct_https_sub.headers.w...
# 12       accesswindow_direct_direct_https_sub.headers.w...
# 13       accesswindow_direct_direct_https_sub.headers.w...
# 14       accesswindow_direct_direct_https_sub.headers.w...
# 15       accesswindow_direct_direct_https_sub.headers.w...
# 16       referrer_iframe_window.open_http_sub.headers.w...
# 17       referrer_iframe_window.open_http_sub.headers.w...
# 18       referrer_iframe_window.open_http_sub.headers.w...
# 19       referrer_iframe_window.open_http_sub.headers.w...
# 20       referrer_iframe_window.open_http_sub.headers.w...
# 21       referrer_iframe_window.open_http_sub.headers.w...
# 22       referrer_iframe_window.open_http_sub.headers.w...
# 23       upgradeHSTS_direct_direct_http_sub.headers.web...
# 24       upgradeHSTS_direct_direct_http_sub.headers.web...
#
# browser chrome Ubuntu 22.04 121 selenium headless-new  \
# 0                      {'window.open.opener': 'null'}
# 1                      {'window.open.opener': 'null'}
# 2                      {'window.open.opener': 'null'}
# 3                      {'window.open.opener': 'null'}
# 4                      {'window.open.opener': 'null'}
# 5                      {'window.open.opener': 'null'}
# 6                      {'window.open.opener': 'null'}
# 7                      {'window.open.opener': 'null'}
# 8                      {'window.open.opener': 'null'}
# 9                      {'window.open.opener': 'null'}
# 10                     {'window.open.opener': 'null'}
# 11                     {'window.open.opener': 'null'}
# 12                     {'window.open.opener': 'null'}
# 13                     {'window.open.opener': 'null'}
# 14                     {'window.open.opener': 'null'}
# 15                     {'window.open.opener': 'null'}
# 16                   document.referrer: http://origin
# 17                   document.referrer: http://origin
# 18                   document.referrer: http://origin
# 19                                document.referrer:
# 20                   document.referrer: http://origin
# 21                   document.referrer: http://origin
# 22                   document.referrer: http://origin
# 23                      {'response.redirected': True}
# 24                      {'response.redirected': True}
#
# browser       chrome Android 11 121.0.6167.180 intent real
# 0        {'window.open.opener': 'object "[object Window...
# 1        {'window.open.opener': 'object "[object Window...
# 2        {'window.open.opener': 'object "[object Window...
# 3        {'window.open.opener': 'object "[object Window...
# 4        {'window.open.opener': 'object "[object Window...
# 5        {'window.open.opener': 'object "[object Window...
# 6        {'window.open.opener': 'object "[object Window...
# 7        {'window.open.opener': 'object "[object Window...
# 8        {'window.open.opener': 'object "[object Window...
# 9        {'window.open.opener': 'object "[object Window...
# 10       {'window.open.opener': 'object "[object Window...
# 11       {'window.open.opener': 'object "[object Window...
# 12       {'window.open.opener': 'object "[object Window...
# 13       {'window.open.opener': 'object "[object Window...
# 14       {'window.open.opener': 'object "[object Window...
# 15       {'window.open.opener': 'object "[object Window...
# 16                             document.referrer: full_url
# 17                             document.referrer: full_url
# 18                             document.referrer: full_url
# 19                             document.referrer: full_url
# 20                             document.referrer: full_url
# 21                             document.referrer: full_url
# 22                             document.referrer: full_url
# 23                          {'response.redirected': False}
# 24                          {'response.redirected': False}

# %% [markdown]
# ### Brave 121 (desktop) vs Chrome 121 (desktop)
# - **Differences only in referrer/RP**
# - Most of the time brave has less info in the referrer (e.g., does not support unsafe-url)
# - `referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_196_basic` here Brave leaks the full_url whereas chrome only has the origin?!
# - 196: `'Referrer-Policy', 'origin-when-cross-origin'`

# %%
r = com_browsers(bf, "brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new", "chrome Ubuntu 22.04 121 selenium headless-new")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
display(r.head())
# Out:
# test_id
# referrer    142
# Name: count, dtype: int64
# browser                                            test_id  \
# 0        referrer_iframe_iframe_http_sub.headers.websec...
# 1        referrer_iframe_iframe_http_sub.headers.websec...
# 2        referrer_iframe_iframe_http_sub.headers.websec...
# 3        referrer_iframe_iframe_http_sub.headers.websec...
# 4        referrer_iframe_iframe_http_sub.headers.websec...
#
# browser brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  \
# 0                         document.referrer: http://origin
# 1                         document.referrer: http://origin
# 2                         document.referrer: http://origin
# 3                         document.referrer: http://origin
# 4                         document.referrer: http://origin
#
# browser chrome Ubuntu 22.04 121 selenium headless-new
# 0                         document.referrer: full_url
# 1                         document.referrer: full_url
# 2                         document.referrer: full_url
# 3                         document.referrer: full_url
# 4                         document.referrer: full_url

# %% [markdown]
# ### Brave 121 (desktop) vs Brave 121 (Android)
# - **Differences: upgradeHSTS (android cache behavior), accesswindow_direct (download behavior, +different autoupgrades), ~~RP (brave android shields deactivated)~~ RP (different autoupgrades)**
# - ~~Also noise: upgradeHSTS (Android), referrerPolicy~~

# %%
r = com_browsers(bf, "chrome Android 11 121.0.6167.180 intent real", "brave Android 11 1.62.165_shield intent real")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
display(r)
# Out:
# test_id
# referrer    134
# Name: count, dtype: int64
# browser                                            test_id  \
# 0        referrer_iframe_iframe_http_sub.headers.websec...
# 1        referrer_iframe_iframe_http_sub.headers.websec...
# 2        referrer_iframe_iframe_http_sub.headers.websec...
# 3        referrer_iframe_iframe_http_sub.headers.websec...
# 4        referrer_iframe_iframe_http_sub.headers.websec...
# ..                                                     ...
# 129      referrer_iframe_window.open_https_sub.headers....
# 130      referrer_iframe_window.open_https_sub.headers....
# 131      referrer_iframe_window.open_https_sub.headers....
# 132      referrer_iframe_window.open_https_sub.headers....
# 133      referrer_iframe_window.open_https_sub.headers....
#
# browser chrome Android 11 121.0.6167.180 intent real  \
# 0                        document.referrer: full_url
# 1                        document.referrer: full_url
# 2                        document.referrer: full_url
# 3                        document.referrer: full_url
# 4                        document.referrer: full_url
# ..                                               ...
# 129                      document.referrer: full_url
# 130                      document.referrer: full_url
# 131                      document.referrer: full_url
# 132                      document.referrer: full_url
# 133                      document.referrer: full_url
#
# browser brave Android 11 1.62.165_shield intent real
# 0                   document.referrer: http://origin
# 1                   document.referrer: http://origin
# 2                   document.referrer: http://origin
# 3                   document.referrer: http://origin
# 4                   document.referrer: http://origin
# ..                                               ...
# 129                document.referrer: https://origin
# 130                document.referrer: https://origin
# 131                document.referrer: https://origin
# 132                document.referrer: https://origin
# 133                document.referrer: https://origin
#
# [134 rows x 3 columns]

# %%
# r = com_browsers(bf, "brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new", "brave Android 11 1.62.165 intent real")
# display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
# display(r)

# %%
# brave android shields vs brave desktop!
# (brave android shields vs no-shields)
with pd.option_context("display.max_colwidth", None):
    with pd.option_context("display.max_rows", 200):

        r = com_browsers(bf, "brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new", "brave Android 11 1.62.165_shield intent real")
        display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
        display(r)

        # r = com_browsers(bf, "brave Android 11 1.62.165 intent real", "brave Android 11 1.62.165_shield intent real")
        # display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
        # display(r)
# Out:
# test_id
# accesswindow    16
# referrer        16
# upgradeHSTS      2
# Name: count, dtype: int64
# browser                                                                                                       test_id  \
# 0                accesswindow_direct_direct_http_sub.headers.websec.saarland_https_headers.webappsec.eu_21640_parsing
# 1                accesswindow_direct_direct_http_sub.headers.websec.saarland_https_headers.webappsec.eu_22059_parsing
# 2                accesswindow_direct_direct_http_sub.headers.websec.saarland_https_headers.webappsec.eu_22478_parsing
# 3                accesswindow_direct_direct_http_sub.headers.websec.saarland_https_headers.webappsec.eu_23242_parsing
# 4                accesswindow_direct_direct_http_sub.headers.websec.saarland_https_headers.webappsec.eu_23606_parsing
# 5                accesswindow_direct_direct_http_sub.headers.websec.saarland_https_headers.webappsec.eu_23990_parsing
# 6              accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_72_basic
# 7              accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_73_basic
# 8              accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_80_basic
# 9              accesswindow_direct_direct_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_81_basic
# 10              accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_21640_parsing
# 11              accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_22059_parsing
# 12              accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_22478_parsing
# 13              accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_23242_parsing
# 14              accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_23606_parsing
# 15              accesswindow_direct_direct_https_sub.headers.websec.saarland_https_headers.webappsec.eu_23990_parsing
# 16                   referrer_iframe_window.open_http_sub.headers.websec.saarland_http_headers.webappsec.eu_196_basic
# 17                referrer_iframe_window.open_http_sub.headers.websec.saarland_http_headers.websec.saarland_196_basic
# 18            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_188_basic
# 19            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_189_basic
# 20            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_190_basic
# 21            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_192_basic
# 22            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_193_basic
# 23            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_197_basic
# 24            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_198_basic
# 25            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_199_basic
# 26            referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.headers.websec.saarland_200_basic
# 27        referrer_iframe_window.open_http_sub.headers.websec.saarland_http_sub.sub.headers.websec.saarland_196_basic
# 28                  referrer_iframe_window.open_https_sub.headers.websec.saarland_http_headers.webappsec.eu_196_basic
# 29               referrer_iframe_window.open_https_sub.headers.websec.saarland_http_headers.websec.saarland_196_basic
# 30           referrer_iframe_window.open_https_sub.headers.websec.saarland_http_sub.headers.websec.saarland_196_basic
# 31       referrer_iframe_window.open_https_sub.headers.websec.saarland_http_sub.sub.headers.websec.saarland_196_basic
# 32         upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_32042_parsing
# 33         upgradeHSTS_direct_direct_http_sub.headers.websec.saarland_https_sub.headers.websec.saarland_32481_parsing
#
# browser brave Ubuntu 22.04 v1.62.156 (121.0.6167.139) selenium headless-new  \
# 0                                            {'window.open.opener': 'null'}
# 1                                            {'window.open.opener': 'null'}
# 2                                            {'window.open.opener': 'null'}
# 3                                            {'window.open.opener': 'null'}
# 4                                            {'window.open.opener': 'null'}
# 5                                            {'window.open.opener': 'null'}
# 6                                            {'window.open.opener': 'null'}
# 7                                            {'window.open.opener': 'null'}
# 8                                            {'window.open.opener': 'null'}
# 9                                            {'window.open.opener': 'null'}
# 10                                           {'window.open.opener': 'null'}
# 11                                           {'window.open.opener': 'null'}
# 12                                           {'window.open.opener': 'null'}
# 13                                           {'window.open.opener': 'null'}
# 14                                           {'window.open.opener': 'null'}
# 15                                           {'window.open.opener': 'null'}
# 16                                         document.referrer: http://origin
# 17                                         document.referrer: http://origin
# 18                                         document.referrer: http://origin
# 19                                         document.referrer: http://origin
# 20                                         document.referrer: http://origin
# 21                                         document.referrer: http://origin
# 22                                                      document.referrer:
# 23                                         document.referrer: http://origin
# 24                                         document.referrer: http://origin
# 25                                         document.referrer: http://origin
# 26                                         document.referrer: http://origin
# 27                                         document.referrer: http://origin
# 28                                         document.referrer: http://origin
# 29                                         document.referrer: http://origin
# 30                                         document.referrer: http://origin
# 31                                         document.referrer: http://origin
# 32                                            {'response.redirected': True}
# 33                                            {'response.redirected': True}
#
# browser        brave Android 11 1.62.165_shield intent real
# 0        {'window.open.opener': 'object "[object Window]"'}
# 1        {'window.open.opener': 'object "[object Window]"'}
# 2        {'window.open.opener': 'object "[object Window]"'}
# 3        {'window.open.opener': 'object "[object Window]"'}
# 4        {'window.open.opener': 'object "[object Window]"'}
# 5        {'window.open.opener': 'object "[object Window]"'}
# 6        {'window.open.opener': 'object "[object Window]"'}
# 7        {'window.open.opener': 'object "[object Window]"'}
# 8        {'window.open.opener': 'object "[object Window]"'}
# 9        {'window.open.opener': 'object "[object Window]"'}
# 10       {'window.open.opener': 'object "[object Window]"'}
# 11       {'window.open.opener': 'object "[object Window]"'}
# 12       {'window.open.opener': 'object "[object Window]"'}
# 13       {'window.open.opener': 'object "[object Window]"'}
# 14       {'window.open.opener': 'object "[object Window]"'}
# 15       {'window.open.opener': 'object "[object Window]"'}
# 16                                      document.referrer:
# 17                                      document.referrer:
# 18                              document.referrer: full_url
# 19                              document.referrer: full_url
# 20                              document.referrer: full_url
# 21                              document.referrer: full_url
# 22                              document.referrer: full_url
# 23                              document.referrer: full_url
# 24                              document.referrer: full_url
# 25                              document.referrer: full_url
# 26                              document.referrer: full_url
# 27                                      document.referrer:
# 28                        document.referrer: https://origin
# 29                        document.referrer: https://origin
# 30                              document.referrer: full_url
# 31                        document.referrer: https://origin
# 32                           {'response.redirected': False}
# 33                           {'response.redirected': False}

# %% [markdown]
# ### Firefox 121 vs 122 vs 123 (desktop linux)
# - subresourceloadingCOEP_img_direct both basic and parsing
# - **random behavior: no actual difference?**

# %%
r = com_browsers(bf, "firefox Ubuntu 22.04 121 selenium headless", "firefox Ubuntu 22.04 122 selenium headless")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())

r = com_browsers(bf, "firefox Ubuntu 22.04 121 selenium headless", "firefox Ubuntu 22.04 123 selenium headless")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())

r = com_browsers(bf, "firefox Ubuntu 22.04 122 selenium headless", "firefox Ubuntu 22.04 123 selenium headless")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
# Out:
# test_id
# subresourceloadingCOEP    27
# Name: count, dtype: int64
# test_id
# subresourceloadingCOEP    33
# Name: count, dtype: int64
# test_id
# subresourceloadingCOEP    38
# Name: count, dtype: int64

# %% [markdown]
# ### Firefox 123 Desktop vs Android
# - subresourceloadingCOEP_img_direct both basic and parsing
# - lots of random behavior for subresourceloadingCOEP_img
# - **actual differences: accesswindow_direct (different download behavior), upgradeHSTS (cache android vs fresh desktop behavior)**

# %%
r = com_browsers(bf, "firefox Ubuntu 22.04 123 selenium headless", "firefox_beta Android 11 123.0b9 intent real")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
display(r.loc[~r["test_id"].str.startswith("subresource")])
# Out:
# test_id
# subresourceloadingCOEP    73
# accesswindow              12
# upgradeHSTS                2
# Name: count, dtype: int64
# browser                                            test_id  \
# 0        accesswindow_direct_direct_http_sub.headers.we...
# 1        accesswindow_direct_direct_http_sub.headers.we...
# 2        accesswindow_direct_direct_http_sub.headers.we...
# 3        accesswindow_direct_direct_http_sub.headers.we...
# 4        accesswindow_direct_direct_http_sub.headers.we...
# 5        accesswindow_direct_direct_http_sub.headers.we...
# 6        accesswindow_direct_direct_https_sub.headers.w...
# 7        accesswindow_direct_direct_https_sub.headers.w...
# 8        accesswindow_direct_direct_https_sub.headers.w...
# 9        accesswindow_direct_direct_https_sub.headers.w...
# 10       accesswindow_direct_direct_https_sub.headers.w...
# 11       accesswindow_direct_direct_https_sub.headers.w...
# 85       upgradeHSTS_direct_direct_http_sub.headers.web...
# 86       upgradeHSTS_direct_direct_http_sub.headers.web...
#
# browser firefox Ubuntu 22.04 123 selenium headless  \
# 0                   {'window.open.opener': 'null'}
# 1                   {'window.open.opener': 'null'}
# 2                   {'window.open.opener': 'null'}
# 3                   {'window.open.opener': 'null'}
# 4                   {'window.open.opener': 'null'}
# 5                   {'window.open.opener': 'null'}
# 6                   {'window.open.opener': 'null'}
# 7                   {'window.open.opener': 'null'}
# 8                   {'window.open.opener': 'null'}
# 9                   {'window.open.opener': 'null'}
# 10                  {'window.open.opener': 'null'}
# 11                  {'window.open.opener': 'null'}
# 85                   {'response.redirected': True}
# 86                   {'response.redirected': True}
#
# browser        firefox_beta Android 11 123.0b9 intent real
# 0        {'window.open.opener': 'object "[object Window...
# 1        {'window.open.opener': 'object "[object Window...
# 2        {'window.open.opener': 'object "[object Window...
# 3        {'window.open.opener': 'object "[object Window...
# 4        {'window.open.opener': 'object "[object Window...
# 5        {'window.open.opener': 'object "[object Window...
# 6        {'window.open.opener': 'object "[object Window...
# 7        {'window.open.opener': 'object "[object Window...
# 8        {'window.open.opener': 'object "[object Window...
# 9        {'window.open.opener': 'object "[object Window...
# 10       {'window.open.opener': 'object "[object Window...
# 11       {'window.open.opener': 'object "[object Window...
# 85                          {'response.redirected': False}
# 86                          {'response.redirected': False}

# %% [markdown]
# ### Safari (MacOS 17.3.1) vs Chrome/WebKit (iPadOS 17.3.1)
# - **Differences: perfAPI (mixed content blocking differences), accesswindow_direct (204 + different download behavior), subresourceloadingCORP (mixed-content/auto-upgrade?)**
# - Noise: subresourceloadingCOEP

# %%
r = com_browsers(bf, "chrome iPadOS 17.3.1 122.0.6261.89 intent real", "safari macOS 14.3.1 17.3.1 selenium real")
display(r["test_id"].apply(lambda x: x.split("_")[0]).value_counts())
display(r)
# Out:
# test_id
# perfAPI                   52
# subresourceloadingCOEP    42
# accesswindow               8
# subresourceloadingCORP     1
# Name: count, dtype: int64
# browser                                            test_id  \
# 0        accesswindow_direct_direct_http_sub.headers.we...
# 1        accesswindow_direct_direct_http_sub.headers.we...
# 2        accesswindow_direct_direct_http_sub.headers.we...
# 3        accesswindow_direct_direct_http_sub.headers.we...
# 4        accesswindow_direct_direct_https_sub.headers.w...
# ..                                                     ...
# 98       subresourceloadingCOEP_img_direct_https_sub.he...
# 99       subresourceloadingCOEP_img_direct_https_sub.he...
# 100      subresourceloadingCOEP_img_direct_https_sub.he...
# 101      subresourceloadingCOEP_img_direct_https_sub.he...
# 102      subresourceloadingCORP_img_direct_https_sub.he...
#
# browser     chrome iPadOS 17.3.1 122.0.6261.89 intent real  \
# 0                           {'window.open.opener': 'null'}
# 1                           {'window.open.opener': 'null'}
# 2                           {'window.open.opener': 'null'}
# 3                           {'window.open.opener': 'null'}
# 4                           {'window.open.opener': 'null'}
# ..                                                     ...
# 98       {'image-events': {'swag.jpg': 'load', 'swag-sa...
# 99       {'image-events': {'swag.jpg': 'load', 'swag-sa...
# 100      {'image-events': {'swag.jpg': 'load', 'swag-sa...
# 101      {'image-events': {'swag.jpg': 'error', 'swag-s...
# 102                                                   load
#
# browser           safari macOS 14.3.1 17.3.1 selenium real
# 0        {'window.open.opener': 'object "[object Window...
# 1        {'window.open.opener': 'object "[object Window...
# 2        {'window.open.opener': 'object "[object Window...
# 3        {'window.open.opener': 'object "[object Window...
# 4        {'window.open.opener': 'object "[object Window...
# ..                                                     ...
# 98       {'image-events': {'swag.jpg': 'error', 'swag-s...
# 99       {'image-events': {'swag.jpg': 'error', 'swag-s...
# 100      {'image-events': {'swag.jpg': 'error', 'swag-s...
# 101      {'image-events': {'swag.jpg': 'load', 'swag-sa...
# 102                                                  error
#
# [103 rows x 3 columns]

# %% [markdown]
# ## Timing estimates

# %%
df_org["created_at"].describe()
# Out:
# count                         11447247
# mean     2024-03-21 09:14:42.165381888
# min         2024-03-07 13:43:13.249687
# 25%      2024-03-14 01:27:39.076239360
# 50%      2024-03-14 13:39:04.032933120
# 75%      2024-03-15 13:06:52.008785920
# max         2024-05-14 15:35:42.349864
# Name: created_at, dtype: object

# %%
df_org.loc[df_org["created_at"] < "2024-03-13"]["browser"].value_counts()
# Out:
# browser
# chrome iPadOS 17.3.1 122.0.6261.89 intent real    868147
# safari macOS 14.3.1 17.3.1 selenium real           47224
# Name: count, dtype: int64

# %%
# Basic + Parsing Chrome
# Add all "took" values from one basic chrome run (all except XCTO) + from one basic chrome run (XCTO only)
# Only one run, does not include repeats but sometimes there were none, in other cases the repeats are quite fast
def calc_time(path_list):
    try:
        total_time = pd.to_timedelta(0)
        for entry in path_list:
            time = pd.read_json(entry, lines=True)
            time = time["message"].str.extract("(\d+:\d+:\d+)").apply(pd.to_timedelta).sum()
            total_time += time.iloc[0]
        print(total_time)
    except (KeyError, ValueError):
        pass

basic = "/home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-chrome-120.json"
basic_xcto = "/home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-chrome-120.json"
calc_time([basic, basic_xcto])


parsing = "/home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-chrome-120.json"
parsing_xcto = "/home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-chrome-120.json"
calc_time([parsing, parsing_xcto])
# Out:
# 0 days 00:43:20
# 1 days 00:53:30

# %%
from glob import glob

for file in sorted(glob("/home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/*.json")):
    print(file)
    calc_time([file])
# Out:
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 16:27:42.927528-chrome-119.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 16:46:34.505944-brave-119.json
# 43 days 17:13:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 16:46:34.505944-edge-119.json
# 55 days 14:41:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 16:46:34.505944-firefox-119.json
# 67 days 10:19:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 21:22:29.397128-brave-119.json
# 4 days 03:45:51
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 21:22:29.397128-chrome-119.json
# 4 days 06:21:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 21:22:29.397128-edge-119.json
# 3 days 19:23:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-29 21:22:29.397128-firefox-119.json
# 5 days 16:29:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 10:00:40.652350-brave-119.json
# 3 days 12:51:33
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 10:00:40.652350-chrome-119.json
# 3 days 10:29:25
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 10:00:40.652350-edge-119.json
# 3 days 15:59:29
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 10:00:40.652350-firefox-119.json
# 3 days 12:12:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 17:13:10.979399-brave-119.json
# 3 days 20:02:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 17:13:10.979399-chrome-119.json
# 4 days 05:22:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 17:13:10.979399-edge-119.json
# 3 days 16:24:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30 17:13:10.979399-firefox-119.json
# 5 days 14:09:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-01-30_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 08:49:50.822686-brave-119.json
# 0 days 04:41:09
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 08:49:50.822686-chrome-119.json
# 0 days 02:55:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 08:49:50.822686-edge-119.json
# 0 days 00:16:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 08:49:50.822686-firefox-119.json
# 0 days 00:09:28
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 10:52:02.220545-brave-119.json
# 0 days 00:00:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 10:52:02.220545-chrome-119.json
# 0 days 00:03:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 10:52:02.220545-edge-119.json
# 0 days 00:00:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01 10:52:02.220545-firefox-119.json
# 0 days 00:08:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-01_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 11:42:56.488751-brave-121.json
# 2 days 18:53:29
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 11:42:56.488751-chrome-121.json
# 2 days 15:50:18
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 11:42:56.488751-edge-121.json
# 2 days 21:05:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 11:42:56.488751-firefox-122.json
# 2 days 13:35:28
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:28:09.952954-brave-121.json
# 0 days 00:32:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:28:09.952954-chrome-121.json
# 0 days 00:31:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:28:09.952954-edge-121.json
# 0 days 00:32:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:28:09.952954-firefox-122.json
# 0 days 00:27:17
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:40:52.084860-brave-121.json
# 0 days 00:31:28
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:40:52.084860-chrome-121.json
# 0 days 00:30:52
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:40:52.084860-edge-121.json
# 0 days 00:32:05
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:40:52.084860-firefox-122.json
# 0 days 00:27:23
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:57:40.474301-brave-121.json
# 2 days 17:36:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:57:40.474301-chrome-121.json
# 2 days 13:36:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:57:40.474301-edge-121.json
# 2 days 18:40:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05 16:57:40.474301-firefox-122.json
# 2 days 13:57:09
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-05_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-06_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 07:58:44.965330-edge-121.json
# 0 days 00:01:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 07:58:44.965330-firefox-122.json
# 0 days 00:00:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 08:19:54.547065-edge-121.json
# 0 days 00:01:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:28:55.420463-brave-121.json
# 0 days 02:10:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:28:55.420463-chrome-121.json
# 0 days 02:14:12
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:28:55.420463-edge-121.json
# 0 days 02:22:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:28:55.420463-firefox-122.json
# 0 days 02:28:51
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:42:58.730537-brave-121.json
# 0 days 02:07:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:42:58.730537-chrome-121.json
# 0 days 02:01:12
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:42:58.730537-edge-121.json
# 0 days 02:19:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12 15:42:58.730537-firefox-122.json
# 0 days 02:28:08
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-12_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:29:37.822634-chrome-121.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:52:15.839836-brave-121.json
# 0 days 21:35:22
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:52:15.839836-chrome-120.json
# 0 days 22:09:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:52:15.839836-chrome-121.json
# 0 days 22:04:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:52:15.839836-chrome-122.json
# 0 days 22:28:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:52:15.839836-edge-121.json
# 0 days 22:19:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:52:15.839836-firefox-121.json
# 0 days 17:30:17
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15 16:52:15.839836-firefox-122.json
# 0 days 19:40:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-15_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 13:45:26.164750-chrome-120.json
# 0 days 02:00:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 13:45:26.164750-chrome-122.json
# 0 days 03:12:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 13:45:26.164750-firefox-121.json
# 1 days 05:50:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 17:39:27.632486-brave-121.json
# 0 days 21:56:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 17:39:27.632486-chrome-120.json
# 0 days 21:20:52
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 17:39:27.632486-chrome-121.json
# 0 days 21:36:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 17:39:27.632486-chrome-122.json
# 0 days 21:09:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 17:39:27.632486-edge-121.json
# 0 days 22:35:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 17:39:27.632486-firefox-121.json
# 0 days 20:06:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16 17:39:27.632486-firefox-122.json
# 0 days 19:42:09
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-16_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:31:53.242902-brave-121.json
# 0 days 00:32:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:31:53.242902-chrome-120.json
# 0 days 00:32:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:31:53.242902-chrome-121.json
# 0 days 00:32:23
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:31:53.242902-chrome-122.json
# 0 days 00:32:18
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:31:53.242902-edge-121.json
# 0 days 00:33:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:31:53.242902-firefox-121.json
# 0 days 00:28:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:31:53.242902-firefox-122.json
# 0 days 00:28:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:41:45.908413-brave-121.json
# 0 days 00:32:58
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:41:45.908413-chrome-120.json
# 0 days 00:31:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:41:45.908413-chrome-121.json
# 0 days 00:31:54
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:41:45.908413-chrome-122.json
# 0 days 00:32:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:41:45.908413-edge-121.json
# 0 days 00:33:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:41:45.908413-firefox-121.json
# 0 days 00:27:58
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:41:45.908413-firefox-122.json
# 0 days 00:27:59
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:51:35.070183-brave-121.json
# 0 days 21:03:18
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:51:35.070183-chrome-120.json
# 0 days 21:04:57
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:51:35.070183-chrome-121.json
# 0 days 21:36:59
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:51:35.070183-chrome-122.json
# 0 days 21:04:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:51:35.070183-edge-121.json
# 0 days 21:33:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:51:35.070183-firefox-121.json
# 0 days 17:52:23
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 09:51:35.070183-firefox-122.json
# 0 days 18:04:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:24:07.711870-brave-121.json
# 0 days 00:31:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:24:07.711870-chrome-120.json
# 0 days 00:30:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:24:07.711870-chrome-121.json
# 0 days 00:30:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:24:07.711870-chrome-122.json
# 0 days 00:30:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:24:07.711870-edge-121.json
# 0 days 00:31:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:24:07.711870-firefox-121.json
# 0 days 00:26:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:24:07.711870-firefox-122.json
# 0 days 00:26:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:33:19.061475-brave-121.json
# 0 days 00:31:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:33:19.061475-chrome-120.json
# 0 days 00:30:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:33:19.061475-chrome-121.json
# 0 days 00:30:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:33:19.061475-chrome-122.json
# 0 days 00:30:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:33:19.061475-edge-121.json
# 0 days 00:31:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:33:19.061475-firefox-121.json
# 0 days 00:26:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:33:19.061475-firefox-122.json
# 0 days 00:26:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:42:28.311398-brave-121.json
# 0 days 21:10:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:42:28.311398-chrome-120.json
# 0 days 20:37:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:42:28.311398-chrome-121.json
# 0 days 21:14:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:42:28.311398-chrome-122.json
# 0 days 20:18:08
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:42:28.311398-edge-121.json
# 0 days 21:13:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:42:28.311398-firefox-121.json
# 0 days 17:52:08
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17 16:42:28.311398-firefox-122.json
# 0 days 17:39:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-17_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:34:13.562989-brave-121.json
# 0 days 00:31:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:34:13.562989-chrome-120.json
# 0 days 00:30:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:34:13.562989-chrome-121.json
# 0 days 00:30:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:34:13.562989-chrome-122.json
# 0 days 00:30:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:34:13.562989-edge-121.json
# 0 days 00:31:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:34:13.562989-firefox-121.json
# 0 days 00:26:46
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:34:13.562989-firefox-122.json
# 0 days 00:26:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:43:25.482431-brave-121.json
# 0 days 00:30:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:43:25.482431-chrome-120.json
# 0 days 00:30:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:43:25.482431-chrome-121.json
# 0 days 00:30:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:43:25.482431-chrome-122.json
# 0 days 00:30:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:43:25.482431-edge-121.json
# 0 days 00:31:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:43:25.482431-firefox-121.json
# 0 days 00:26:42
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:43:25.482431-firefox-122.json
# 0 days 00:26:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:52:37.053367-brave-121.json
# 0 days 00:30:59
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:52:37.053367-chrome-120.json
# 0 days 00:30:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:52:37.053367-chrome-121.json
# 0 days 00:30:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:52:37.053367-chrome-122.json
# 0 days 00:30:45
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:52:37.053367-edge-121.json
# 0 days 00:31:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:52:37.053367-firefox-121.json
# 0 days 00:26:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 12:52:37.053367-firefox-122.json
# 0 days 00:26:30
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:01:44.861276-brave-121.json
# 0 days 00:31:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:01:44.861276-chrome-120.json
# 0 days 00:30:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:01:44.861276-chrome-121.json
# 0 days 00:30:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:01:44.861276-chrome-122.json
# 0 days 00:30:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:01:44.861276-edge-121.json
# 0 days 00:31:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:01:44.861276-firefox-121.json
# 0 days 00:26:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:01:44.861276-firefox-122.json
# 0 days 00:26:28
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:10:55.931849-brave-121.json
# 0 days 00:30:54
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:10:55.931849-chrome-120.json
# 0 days 00:30:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:10:55.931849-chrome-121.json
# 0 days 00:30:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:10:55.931849-chrome-122.json
# 0 days 00:30:51
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:10:55.931849-edge-121.json
# 0 days 00:31:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:10:55.931849-firefox-121.json
# 0 days 00:26:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:10:55.931849-firefox-122.json
# 0 days 00:26:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:20:05.650794-brave-121.json
# 0 days 00:31:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:20:05.650794-chrome-120.json
# 0 days 00:30:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:20:05.650794-chrome-121.json
# 0 days 00:30:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:20:05.650794-chrome-122.json
# 0 days 00:30:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:20:05.650794-edge-121.json
# 0 days 00:31:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:20:05.650794-firefox-121.json
# 0 days 00:26:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:20:05.650794-firefox-122.json
# 0 days 00:26:30
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:29:17.512423-brave-121.json
# 0 days 00:30:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:29:17.512423-chrome-120.json
# 0 days 00:30:33
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:29:17.512423-chrome-121.json
# 0 days 00:30:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:29:17.512423-chrome-122.json
# 0 days 00:30:42
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:29:17.512423-edge-121.json
# 0 days 00:31:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:29:17.512423-firefox-121.json
# 0 days 00:26:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:29:17.512423-firefox-122.json
# 0 days 00:26:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:38:24.873003-brave-121.json
# 0 days 00:31:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:38:24.873003-chrome-120.json
# 0 days 00:30:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:38:24.873003-chrome-121.json
# 0 days 00:30:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:38:24.873003-chrome-122.json
# 0 days 00:30:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:38:24.873003-edge-121.json
# 0 days 00:31:23
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:38:24.873003-firefox-121.json
# 0 days 00:26:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:38:24.873003-firefox-122.json
# 0 days 00:26:22
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:47:35.798555-brave-121.json
# 0 days 00:31:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:47:35.798555-chrome-120.json
# 0 days 00:30:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:47:35.798555-chrome-121.json
# 0 days 00:30:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:47:35.798555-chrome-122.json
# 0 days 00:30:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:47:35.798555-edge-121.json
# 0 days 00:31:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:47:35.798555-firefox-121.json
# 0 days 00:26:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:47:35.798555-firefox-122.json
# 0 days 00:26:30
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:56:46.853457-brave-121.json
# 0 days 00:31:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:56:46.853457-chrome-120.json
# 0 days 00:30:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:56:46.853457-chrome-121.json
# 0 days 00:30:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:56:46.853457-chrome-122.json
# 0 days 00:30:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:56:46.853457-edge-121.json
# 0 days 00:31:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:56:46.853457-firefox-121.json
# 0 days 00:26:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 13:56:46.853457-firefox-122.json
# 0 days 00:26:29
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:05:57.467910-brave-121.json
# 0 days 00:31:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:05:57.467910-chrome-120.json
# 0 days 00:30:33
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:05:57.467910-chrome-121.json
# 0 days 00:30:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:05:57.467910-chrome-122.json
# 0 days 00:30:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:05:57.467910-edge-121.json
# 0 days 00:31:11
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:05:57.467910-firefox-121.json
# 0 days 00:26:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:05:57.467910-firefox-122.json
# 0 days 00:26:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:15:06.868958-brave-121.json
# 0 days 00:31:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:15:06.868958-chrome-120.json
# 0 days 00:30:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:15:06.868958-chrome-121.json
# 0 days 00:30:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:15:06.868958-chrome-122.json
# 0 days 00:30:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:15:06.868958-edge-121.json
# 0 days 00:31:21
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:15:06.868958-firefox-121.json
# 0 days 00:26:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:15:06.868958-firefox-122.json
# 0 days 00:26:30
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:24:16.249191-brave-121.json
# 0 days 00:30:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:24:16.249191-chrome-120.json
# 0 days 00:30:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:24:16.249191-chrome-121.json
# 0 days 00:30:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:24:16.249191-chrome-122.json
# 0 days 00:30:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:24:16.249191-edge-121.json
# 0 days 00:31:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:24:16.249191-firefox-121.json
# 0 days 00:26:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:24:16.249191-firefox-122.json
# 0 days 00:26:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:33:29.545445-brave-121.json
# 0 days 00:31:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:33:29.545445-chrome-120.json
# 0 days 00:30:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:33:29.545445-chrome-121.json
# 0 days 00:30:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:33:29.545445-chrome-122.json
# 0 days 00:23:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:33:29.545445-edge-121.json
# 0 days 00:31:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:33:29.545445-firefox-121.json
# 0 days 00:26:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:33:29.545445-firefox-122.json
# 0 days 00:26:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:42:39.782000-brave-121.json
# 0 days 00:31:10
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:42:39.782000-chrome-120.json
# 0 days 00:30:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:42:39.782000-chrome-121.json
# 0 days 00:30:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:42:39.782000-chrome-122.json
# 0 days 00:30:52
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:42:39.782000-edge-121.json
# 0 days 00:31:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:42:39.782000-firefox-121.json
# 0 days 00:26:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:42:39.782000-firefox-122.json
# 0 days 00:26:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:51:50.700928-brave-121.json
# 0 days 00:30:54
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:51:50.700928-chrome-120.json
# 0 days 00:30:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:51:50.700928-chrome-121.json
# 0 days 00:30:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:51:50.700928-chrome-122.json
# 0 days 00:30:46
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:51:50.700928-edge-121.json
# 0 days 00:31:12
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:51:50.700928-firefox-121.json
# 0 days 00:26:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 14:51:50.700928-firefox-122.json
# 0 days 00:26:29
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:00:58.836731-brave-121.json
# 0 days 00:30:58
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:00:58.836731-chrome-120.json
# 0 days 00:30:33
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:00:58.836731-chrome-121.json
# 0 days 00:30:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:00:58.836731-chrome-122.json
# 0 days 00:30:51
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:00:58.836731-edge-121.json
# 0 days 00:31:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:00:58.836731-firefox-121.json
# 0 days 00:26:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:00:58.836731-firefox-122.json
# 0 days 00:26:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:10:07.066440-brave-121.json
# 0 days 00:31:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:10:07.066440-chrome-120.json
# 0 days 00:30:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:10:07.066440-chrome-121.json
# 0 days 00:30:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:10:07.066440-chrome-122.json
# 0 days 00:30:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:10:07.066440-edge-121.json
# 0 days 00:31:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:10:07.066440-firefox-121.json
# 0 days 00:26:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:10:07.066440-firefox-122.json
# 0 days 00:26:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:19:18.503695-brave-121.json
# 0 days 00:31:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:19:18.503695-chrome-120.json
# 0 days 00:30:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:19:18.503695-chrome-121.json
# 0 days 00:30:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:19:18.503695-chrome-122.json
# 0 days 00:30:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:19:18.503695-edge-121.json
# 0 days 00:31:12
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:19:18.503695-firefox-121.json
# 0 days 00:26:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:19:18.503695-firefox-122.json
# 0 days 00:26:30
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:28:28.887917-brave-121.json
# 0 days 00:31:02
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:28:28.887917-chrome-120.json
# 0 days 00:30:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:28:28.887917-chrome-121.json
# 0 days 00:30:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:28:28.887917-chrome-122.json
# 0 days 00:30:52
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:28:28.887917-edge-121.json
# 0 days 00:31:18
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:28:28.887917-firefox-121.json
# 0 days 00:26:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19 15:28:28.887917-firefox-122.json
# 0 days 00:26:33
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-19_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 10:43:31.453506-brave-121.json
# 0 days 21:51:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 10:43:31.453506-chrome-120.json
# 0 days 21:00:02
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 10:43:31.453506-chrome-121.json
# 0 days 22:06:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 10:43:31.453506-chrome-122.json
# 0 days 20:57:08
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 10:43:31.453506-edge-121.json
# 0 days 22:07:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 10:43:31.453506-firefox-121.json
# 0 days 20:22:27
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 10:43:31.453506-firefox-122.json
# 0 days 19:42:53
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 15:13:33.286745-brave-121.json
# 0 days 21:21:54
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 15:13:33.286745-chrome-120.json
# 0 days 20:55:05
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 15:13:33.286745-chrome-121.json
# 0 days 20:59:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 15:13:33.286745-chrome-122.json
# 0 days 20:44:11
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 15:13:33.286745-edge-121.json
# 0 days 21:58:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 15:13:33.286745-firefox-121.json
# 0 days 19:55:59
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 15:13:33.286745-firefox-122.json
# 0 days 19:21:53
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 19:39:49.789822-brave-121.json
# 0 days 21:22:53
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 19:39:49.789822-chrome-120.json
# 0 days 20:45:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 19:39:49.789822-chrome-121.json
# 0 days 21:02:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 19:39:49.789822-chrome-122.json
# 0 days 20:32:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 19:39:49.789822-edge-121.json
# 0 days 21:44:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 19:39:49.789822-firefox-121.json
# 0 days 19:49:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22 19:39:49.789822-firefox-122.json
# 0 days 19:21:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-22_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 00:05:09.380773-brave-121.json
# 0 days 21:38:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 00:05:09.380773-chrome-120.json
# 0 days 20:51:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 00:05:09.380773-chrome-121.json
# 0 days 21:00:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 00:05:09.380773-chrome-122.json
# 0 days 20:41:21
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 00:05:09.380773-edge-121.json
# 0 days 21:57:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 00:05:09.380773-firefox-121.json
# 0 days 20:09:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 00:05:09.380773-firefox-122.json
# 0 days 19:39:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 04:32:20.304883-brave-121.json
# 0 days 22:02:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 04:32:20.304883-chrome-120.json
# 0 days 21:00:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 04:32:20.304883-chrome-121.json
# 0 days 21:12:30
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 04:32:20.304883-chrome-122.json
# 0 days 20:53:12
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 04:32:20.304883-edge-121.json
# 0 days 22:28:27
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 04:32:20.304883-firefox-121.json
# 0 days 19:55:09
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23 04:32:20.304883-firefox-122.json
# 0 days 19:47:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-23_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-27_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-02-28_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:26:38.545868-brave-121.json
# 0 days 00:45:29
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:26:38.545868-chrome-120.json
# 0 days 00:44:46
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:26:38.545868-chrome-121.json
# 0 days 00:44:52
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:26:38.545868-chrome-122.json
# 0 days 00:32:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:26:38.545868-edge-121.json
# 0 days 00:45:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:26:38.545868-firefox-121.json
# 0 days 00:40:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:26:38.545868-firefox-122.json
# 0 days 00:40:34
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:41:06.684053-brave-121.json
# 0 days 00:46:51
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:41:06.684053-chrome-120.json
# 0 days 00:46:11
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:41:06.684053-chrome-121.json
# 0 days 00:45:58
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:41:06.684053-chrome-122.json
# 0 days 00:46:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:41:06.684053-edge-121.json
# 0 days 00:47:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:41:06.684053-firefox-121.json
# 0 days 00:41:17
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:41:06.684053-firefox-122.json
# 0 days 00:41:09
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:55:44.863857-brave-121.json
# 0 days 00:48:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:55:44.863857-chrome-120.json
# 0 days 00:47:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:55:44.863857-chrome-121.json
# 0 days 00:47:32
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:55:44.863857-chrome-122.json
# 0 days 00:47:46
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:55:44.863857-edge-121.json
# 0 days 00:48:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:55:44.863857-firefox-121.json
# 0 days 00:41:42
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 10:55:44.863857-firefox-122.json
# 0 days 00:41:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:10:42.610740-brave-121.json
# 0 days 00:46:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:10:42.610740-chrome-120.json
# 0 days 00:45:22
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:10:42.610740-chrome-121.json
# 0 days 00:45:27
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:10:42.610740-chrome-122.json
# 0 days 00:45:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:10:42.610740-edge-121.json
# 0 days 00:46:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:10:42.610740-firefox-121.json
# 0 days 00:41:05
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:10:42.610740-firefox-122.json
# 0 days 00:41:22
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:25:27.338082-brave-121.json
# 0 days 00:46:22
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:25:27.338082-chrome-120.json
# 0 days 00:45:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:25:27.338082-chrome-121.json
# 0 days 00:45:42
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:25:27.338082-chrome-122.json
# 0 days 00:35:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:25:27.338082-edge-121.json
# 0 days 00:46:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:25:27.338082-firefox-121.json
# 0 days 00:41:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 11:25:27.338082-firefox-122.json
# 0 days 00:40:53
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 12:07:02.812214-chrome-120.json
# 0 days 16:32:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 12:07:02.812214-chrome-121.json
# 0 days 18:26:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 12:07:02.812214-chrome-122.json
# 0 days 18:34:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 12:07:02.812214-edge-121.json
# 0 days 18:18:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 12:07:02.812214-firefox-121.json
# 0 days 01:58:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 12:07:02.812214-firefox-122.json
# 0 days 13:30:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 14:56:29.911112-chrome-122.json
# 0 days 00:41:22
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:03:29.261751-chrome-122.json
# 0 days 00:41:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:15:46.155831-brave-121.json
# 0 days 00:02:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:15:46.155831-chrome-120.json
# 0 days 00:03:27
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:15:46.155831-chrome-121.json
# 0 days 00:02:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:15:46.155831-chrome-122.json
# 0 days 00:00:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:15:46.155831-edge-121.json
# 0 days 00:02:59
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:15:46.155831-firefox-121.json
# 0 days 00:00:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:15:46.155831-firefox-122.json
# 0 days 00:00:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:17:45.805917-brave-121.json
# 0 days 00:02:42
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:17:45.805917-chrome-120.json
# 0 days 00:03:27
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:17:45.805917-chrome-121.json
# 0 days 00:02:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:17:45.805917-chrome-122.json
# 0 days 00:00:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:17:45.805917-edge-121.json
# 0 days 00:02:57
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:17:45.805917-firefox-121.json
# 0 days 00:00:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:17:45.805917-firefox-122.json
# 0 days 00:00:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:20:45.497953-brave-121.json
# 1 days 00:53:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:20:45.497953-chrome-120.json
# 1 days 00:45:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:20:45.497953-chrome-121.json
# 1 days 01:00:23
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:20:45.497953-chrome-122.json
# 1 days 01:28:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:20:45.497953-edge-121.json
# 1 days 00:49:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:20:45.497953-firefox-121.json
# 0 days 21:08:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 15:20:45.497953-firefox-122.json
# 0 days 20:53:12
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 19:43:30.260172-brave-121.json
# 1 days 00:47:05
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 19:43:30.260172-chrome-120.json
# 1 days 00:21:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 19:43:30.260172-chrome-121.json
# 1 days 00:58:05
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 19:43:30.260172-chrome-122.json
# 1 days 01:27:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 19:43:30.260172-edge-121.json
# 1 days 05:59:17
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 19:43:30.260172-firefox-121.json
# 0 days 21:03:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04 19:43:30.260172-firefox-122.json
# 0 days 21:37:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-04_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 00:13:37.991141-brave-121.json
# 1 days 00:44:42
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 00:13:37.991141-chrome-120.json
# 1 days 00:40:29
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 00:13:37.991141-chrome-121.json
# 1 days 00:56:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 00:13:37.991141-chrome-122.json
# 1 days 00:56:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 00:13:37.991141-edge-121.json
# 1 days 00:49:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 00:13:37.991141-firefox-121.json
# 0 days 21:02:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 00:13:37.991141-firefox-122.json
# 0 days 20:46:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 04:35:21.106595-brave-121.json
# 1 days 02:20:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 04:35:21.106595-chrome-120.json
# 1 days 05:37:45
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 04:35:21.106595-chrome-121.json
# 1 days 03:06:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 04:35:21.106595-chrome-122.json
# 1 days 01:27:59
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 04:35:21.106595-edge-121.json
# 1 days 01:17:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 04:35:21.106595-firefox-121.json
# 1 days 00:48:27
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 04:35:21.106595-firefox-122.json
# 0 days 22:44:30
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 09:13:03.773050-brave-121.json
# 1 days 04:09:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 09:13:03.773050-chrome-120.json
# 1 days 03:24:28
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 09:13:03.773050-chrome-121.json
# 1 days 02:53:51
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 09:13:03.773050-chrome-122.json
# 1 days 01:31:05
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 09:13:03.773050-edge-121.json
# 1 days 00:58:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 09:13:03.773050-firefox-121.json
# 0 days 22:18:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 09:13:03.773050-firefox-122.json
# 0 days 22:03:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 15:52:45.799472-chrome-120.json
# 0 days 00:55:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 15:52:45.799472-chrome-121.json
# 0 days 00:02:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 15:52:45.799472-chrome-122.json
# 0 days 01:52:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 15:52:45.799472-edge-121.json
# 0 days 00:13:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 15:52:45.799472-firefox-121.json
# 0 days 00:16:17
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 15:52:45.799472-firefox-122.json
# 0 days 00:01:21
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 16:10:13.410084-chrome-120.json
# 0 days 00:55:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 16:10:13.410084-chrome-121.json
# 0 days 00:02:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 16:10:13.410084-chrome-122.json
# 0 days 01:52:23
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 16:10:13.410084-edge-121.json
# 0 days 00:13:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 16:10:13.410084-firefox-121.json
# 0 days 00:16:25
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05 16:10:13.410084-firefox-122.json
# 0 days 00:01:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-05_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-06_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-brave-121.json
# 1 days 00:42:25
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-chrome-120.json
# 1 days 00:41:09
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-chrome-121.json
# 1 days 01:15:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-chrome-122.json
# 1 days 00:22:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-edge-121.json
# 1 days 00:49:02
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-firefox-121.json
# 0 days 21:04:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-firefox-122.json
# 0 days 20:47:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 16:59:49.714472-firefox-123.json
# 0 days 20:51:57
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 22:18:06.856894-brave-121.json
# 1 days 00:37:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 22:18:06.856894-chrome-120.json
# 1 days 00:36:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-13 22:18:06.856894-chrome-121.json
# 1 days 00:58:08
# ...
# 0 days 20:45:27
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-14 14:17:47.289323-firefox-123.json
# 0 days 20:44:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-14_unraisable.json
# 0 days 00:00:00
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-brave-121.json
# 0 days 00:17:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-chrome-120.json
# 0 days 00:01:21
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-chrome-121.json
# 0 days 00:09:25
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-chrome-122.json
# 0 days 13:29:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-edge-121.json
# 0 days 00:24:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-firefox-121.json
# 0 days 00:04:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-firefox-122.json
# 0 days 00:11:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 08:41:50.734655-firefox-123.json
# 0 days 00:00:21
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:19:10.479395-chrome-122.json
# 0 days 00:27:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:23:39.802245-chrome-122.json
# 0 days 00:28:42
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-brave-121.json
# 0 days 00:41:25
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-chrome-120.json
# 0 days 00:40:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-chrome-121.json
# 0 days 00:40:54
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-chrome-122.json
# 0 days 00:41:02
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-edge-121.json
# 0 days 00:41:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-firefox-121.json
# 0 days 00:36:54
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-firefox-122.json
# 0 days 00:36:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:26:09.161760-firefox-123.json
# 0 days 00:36:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-brave-121.json
# 0 days 00:41:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-chrome-120.json
# 0 days 00:41:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-chrome-121.json
# 0 days 00:41:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-chrome-122.json
# 0 days 00:41:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-edge-121.json
# 0 days 00:41:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-firefox-121.json
# 0 days 00:36:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-firefox-122.json
# 0 days 00:36:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:38:59.283136-firefox-123.json
# 0 days 00:36:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-brave-121.json
# 0 days 00:41:28
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-chrome-120.json
# 0 days 00:40:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-chrome-121.json
# 0 days 00:40:53
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-chrome-122.json
# 0 days 00:41:06
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-edge-121.json
# 0 days 00:41:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-firefox-121.json
# 0 days 00:36:52
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-firefox-122.json
# 0 days 00:36:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 09:51:49.267900-firefox-123.json
# 0 days 00:36:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-brave-121.json
# 0 days 00:41:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-chrome-120.json
# 0 days 00:40:54
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-chrome-121.json
# 0 days 00:40:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-chrome-122.json
# 0 days 00:41:05
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-edge-121.json
# 0 days 00:41:41
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-firefox-121.json
# 0 days 00:36:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-firefox-122.json
# 0 days 00:36:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:04:40.547316-firefox-123.json
# 0 days 00:36:36
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-brave-121.json
# 0 days 00:42:07
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-chrome-120.json
# 0 days 00:41:31
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-chrome-121.json
# 0 days 00:41:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-chrome-122.json
# 0 days 00:41:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-edge-121.json
# 0 days 00:34:25
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-firefox-121.json
# 0 days 00:37:11
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-firefox-122.json
# 0 days 00:37:11
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:17:25.875986-firefox-123.json
# 0 days 00:37:21
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:44:03.507415-brave-121.json
# 0 days 00:01:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:44:03.507415-chrome-122.json
# 0 days 00:00:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:44:03.507415-edge-121.json
# 0 days 00:15:51
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:44:03.507415-firefox-121.json
# 0 days 00:00:23
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15 10:44:03.507415-firefox-123.json
# 0 days 00:00:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-03-15_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-04-11_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-04-12_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-03 06:57:54.293914-chrome-126.json
# 0 days 00:00:55
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-03 06:59:08.843319-chrome-126.json
# 0 days 00:00:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-03 07:04:13.323963-chrome-126.json
# 0 days 00:00:02
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-03 07:06:17.078231-chrome-126.json
# 0 days 00:00:58
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-03 07:07:10.206572-chrome-126.json
# 0 days 03:56:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-03_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-10_unraisable.json
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-brave-121.json
# 0 days 00:02:20
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-chrome-120.json
# 0 days 00:02:26
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-chrome-121.json
# 0 days 00:02:28
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-chrome-122.json
# 0 days 00:02:24
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-firefox-121.json
# 0 days 00:02:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-firefox-122.json
# 0 days 00:02:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:17:43.163676-firefox-123.json
# 0 days 00:02:04
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:19:18.862212-brave-121.json
# 0 days 00:02:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:19:18.862212-chrome-120.json
# 0 days 00:02:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:19:18.862212-chrome-121.json
# 0 days 00:02:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:19:18.862212-chrome-122.json
# 0 days 00:02:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:19:18.862212-firefox-121.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:19:18.862212-firefox-122.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:19:18.862212-firefox-123.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:20:50.631199-brave-121.json
# 0 days 00:02:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:20:50.631199-chrome-120.json
# 0 days 00:02:16
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:20:50.631199-chrome-121.json
# 0 days 00:02:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:20:50.631199-chrome-122.json
# 0 days 00:02:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:20:50.631199-firefox-121.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:20:50.631199-firefox-122.json
# 0 days 00:01:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:20:50.631199-firefox-123.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:22:22.007671-brave-121.json
# 0 days 00:01:11
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:22:22.007671-chrome-120.json
# 0 days 00:02:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:22:22.007671-chrome-121.json
# 0 days 00:02:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:22:22.007671-chrome-122.json
# 0 days 00:02:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:22:22.007671-firefox-121.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:22:22.007671-firefox-122.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:22:22.007671-firefox-123.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:23:52.312456-brave-121.json
# 0 days 00:02:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:23:52.312456-chrome-120.json
# 0 days 00:02:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:23:52.312456-chrome-121.json
# 0 days 00:02:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:23:52.312456-chrome-122.json
# 0 days 00:02:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:23:52.312456-firefox-121.json
# 0 days 00:01:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:23:52.312456-firefox-122.json
# 0 days 00:01:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:23:52.312456-firefox-123.json
# 0 days 00:01:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:36:29.668375-brave-121.json
# 0 days 00:12:01
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:36:29.668375-chrome-120.json
# 0 days 00:12:19
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:36:29.668375-chrome-121.json
# 0 days 00:11:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:36:29.668375-chrome-122.json
# 0 days 00:11:46
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:36:29.668375-firefox-121.json
# 0 days 00:12:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:36:29.668375-firefox-122.json
# 0 days 00:12:49
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:36:29.668375-firefox-123.json
# 0 days 00:12:46
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:40:16.841740-brave-121.json
# 0 days 00:12:03
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:40:16.841740-chrome-120.json
# 0 days 00:12:14
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:40:16.841740-chrome-121.json
# 0 days 00:11:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:40:16.841740-chrome-122.json
# 0 days 00:11:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:40:16.841740-firefox-121.json
# 0 days 00:12:47
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:40:16.841740-firefox-122.json
# 0 days 00:12:44
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:40:16.841740-firefox-123.json
# 0 days 00:12:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:44:00.461429-brave-121.json
# 0 days 00:12:02
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:44:00.461429-chrome-120.json
# 0 days 00:12:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:44:00.461429-chrome-121.json
# 0 days 00:11:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:44:00.461429-chrome-122.json
# 0 days 00:11:39
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:44:00.461429-firefox-121.json
# 0 days 00:12:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:44:00.461429-firefox-122.json
# 0 days 00:12:40
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:44:00.461429-firefox-123.json
# 0 days 00:12:37
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:47:48.780274-brave-121.json
# 0 days 00:11:57
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:47:48.780274-chrome-120.json
# 0 days 00:12:13
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:47:48.780274-chrome-121.json
# 0 days 00:11:38
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:47:48.780274-chrome-122.json
# 0 days 00:11:43
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:47:48.780274-firefox-121.json
# 0 days 00:12:45
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:47:48.780274-firefox-122.json
# 0 days 00:12:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:47:48.780274-firefox-123.json
# 0 days 00:12:35
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-brave-121.json
# 0 days 00:12:15
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-chrome-120.json
# 0 days 00:12:21
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-chrome-121.json
# 0 days 00:11:46
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-chrome-122.json
# 0 days 00:11:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-firefox-121.json
# 0 days 00:12:56
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-firefox-122.json
# 0 days 00:12:50
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 09:51:32.620509-firefox-123.json
# 0 days 00:12:48
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13 10:14:24.456714-brave-121.json
# 0 days 00:01:12
# /home/ubuntu/wpt/_hp/tools/crawler/logs/desktop-selenium/2024-05-13_unraisable.json
