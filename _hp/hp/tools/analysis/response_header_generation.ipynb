# %%
import random
import re
import httpx
import glob
import os
import json
from itertools import permutations, product, chain
import sys
sys.path.append('..')

from models import Response, Session

from crawler.utils import get_or_create

# %%
def randomize_casing(input_string, seed=42):
    """Randomize the casing of a string (fixed with a seed)."""
    random.seed(seed)
    return ''.join(random.choice([c.upper(), c.lower()]) for c in input_string)

def insert_char_middle(input_string, char):
    """Insert a char in the middle of a string."""
    middle_index = len(input_string) // 2
    return input_string[:middle_index] + char + input_string[middle_index:]

# %%
# All the mutations we apply on strings such as header names and header values
# Some of them may have no effect and result in duplicates; however such duplicates are not saved in the db

all_upper = lambda x: x.upper()
all_lower = lambda x: x.lower()
random_case = lambda x: randomize_casing(x)
leadtrail_space = lambda x: " " + x + " "
in_double_quotes = lambda x: '"' + x + '"'
in_single_quotes = lambda x: "'" + x + "'"
remove_whitespace = lambda x: x.replace(" ", "")
double_spaces = lambda x: x.replace(" ", "  ")
space_to_tab = lambda x: x.replace(" ", "\t")

lead_seqs = []
trail_seqs = []
middle_seqs = []

# All all ASCII chars as leading, trailing, and middle char
ascii_chars = [char for char in map(chr, range(128))]
# Alternatively use less ones? All/Some control chars? + space, comma, ....
# ascii_chars = [char for char in map(chr, range(32))] + [" ", ",", ";", ":"]
for seq in ascii_chars:
    lead_seqs.append(lambda x, s=seq: s + x)
    trail_seqs.append(lambda x, s=seq: x + s)
    middle_seqs.append(lambda x, s=seq: insert_char_middle(x, s))

# Add other interesting leading, trailing, middle chars: Double space, non-breaking space, full-width comma
# TODO: add more?
other_chars = ["  ", "\u00A0a", "\uFF0C"]
for seq in other_chars:
    lead_seqs.append(lambda x, s=seq: s + x)
    trail_seqs.append(lambda x, s=seq: x + s)
    middle_seqs.append(lambda x, s=seq: insert_char_middle(x, s))

# Replace some chars with others
chars_to_replace = [";", ",", ":", "=", "'", '"', "-", "_"]
# Replace each of the above with all of the below
replace_chars = [
    "", " ", ";", ",", ":", "=", "-", "_",
    "'", '"', "`", "´",
    '\u2018',  # Left Single Quotation Mark
    '\u2019',  # Right Single Quotation Mark
    '\u201A',  # Single Low-9 Quotation Mark
    '\u201B',  # Single High-Reversed-9 Quotation Mark
    '\u201C',  # Left Double Quotation Mark
    '\u201D',  # Right Double Quotation Mark
    '\u201E',  # Double Low-9 Quotation Mark
    '\u201F',  # Double High-Reversed-9 Quotation Mark
]
replace_funcs = []
for char in chars_to_replace:
    for rp in replace_chars:
        if rp == char:
            continue
        replace_funcs.append(lambda x, c1=char, c2=rp: x.replace(c1, c2))



general_mutations = [
    all_upper,
    all_lower,
    random_case,
    leadtrail_space,
    in_double_quotes,
    in_single_quotes,
    remove_whitespace,
    double_spaces,
    space_to_tab,
    *lead_seqs,
    *trail_seqs,
    *middle_seqs,
    *replace_funcs,
]

basic_mutations = [
    #all_upper,
    all_lower,
    random_case,
    leadtrail_space,
]


def mutate_header_name(header_name):
    header_names = set()
    for mutation in general_mutations:
        header_names.add(mutation(header_name))
    return header_names

def mutate_header_value(header_value, mutation_list=general_mutations):
    header_values = set()
    for mutation in mutation_list:
        header_values.add(mutation(header_value))
    return header_values

# %%
l = mutate_header_value("D EN'Y")
print(l)
print(list(l)[0])
# Out:
# {"qD EN'Y", "D E/N'Y", "，D EN'Y", "D EzN'Y", ":D EN'Y", "D E，N'Y", "D EN'Yu", "VD EN'Y", "`D EN'Y", "D EN'Yv", "D E\x10N'Y", "\x16D EN'Y", "D E1N'Y", "\x1eD EN'Y", "D EXN'Y", "D EN'Yj", "D E)N'Y", "D ELN'Y", "D EN'YB", "D EcN'Y", "  D EN'Y", "D EjN'Y", "D E4N'Y", 'D EN“Y', "hD EN'Y", "6D EN'Y", "D EN'YE", "D EN'YN", "\x0bD EN'Y", "D EN'Y\x18", "D EN'Y%", "D eN'Y", "D EN'Y\r", "D EN'Yg", "D E6N'Y", "D EZN'Y", "OD EN'Y", " D EN'Y", "D EN'YG", 'D EN‟Y', "D EN'Y.", "D EN'Yr", "%D EN'Y", "D EN'Y?", "D EN'Y-", "D EN'Yq", "CD EN'Y", "D EN'YI", "D EN'Y\x01", "D EN'Y\x1e", "D EqN'Y", "D E]N'Y", ")D EN'Y", "ID EN'Y", "D EN'Y\x0e", "D EN'Ya", "D EN'Y，", "D EnN'Y", "\x08D EN'Y", 'D EN-Y', "D EN'YH", 'D EN‛Y', "D E:N'Y", "nD EN'Y", 'D EN=Y', "8D EN'Y", "D EN'Y5", "HD EN'Y", "\x0fD EN'Y", "D E$N'Y", "d en'y", "D EN'Y\x15", "D E\x16N'Y", "D EN'Y&", "GD EN'Y", 'D EN"Y', "ZD EN'Y", "D EtN'Y", "D EN'Y#", "\xa0aD EN'Y", "D EN'Y'", "D EN'Y\x0c", "\x17D EN'Y", 'D EN,Y', " D EN'Y ", ".D EN'Y", "D EN'Y6", "D EN'YW", "D EN'Y\x07", "D ECN'Y", ">D EN'Y", "D EN'Y2", "D EaN'Y", "D EeN'Y", "D E\x7fN'Y", "D EN'YS", "2D EN'Y", "sD EN'Y", "D EN'YR", "D EN'Y\x08", "D EN'Y@", "\x1aD EN'Y", "D EN'Y!", "D EN'Y,", "\tD EN'Y", 'D EN’Y', 'D EN`Y', "\\D EN'Y", "D EBN'Y", "D EN'Y\x04", "D EN'Y\x13", "D E\x1eN'Y", 'D EN;Y', "D EyN'Y", "{D EN'Y", "D EN'Y3", "D E\rN'Y", "D EON'Y", "D E5N'Y", "D EWN'Y", "D  EN'Y", 'D ENY', "D EN'Y\t", "D EN'Yc", "D EN'Y;", "D EHN'Y", "D E  N'Y", "\x02D EN'Y", "D EN'Y\x0b", "bD EN'Y", "D EKN'Y", "D E\x08N'Y", "aD EN'Y", "D EN'Y*", "D EbN'Y", "D E\x02N'Y", "D\tEN'Y", "D EFN'Y", "'D EN'Y'", "D EN'Y=", "!D EN'Y", "dD EN'Y", "D EN'Y\x1c", "oD EN'Y", "D EN'Yh", "\x10D EN'Y", "D EpN'Y", "D E\x01N'Y", "\x14D EN'Y", 'D EN:Y', '"D EN\'Y"', "\x01D EN'Y", "D EN'Y\x7f", "D EN'YK", "rD EN'Y", "D EQN'Y", "D EN'YU", "D E2N'Y", "D EN'Y\x19", "D EN'Y4", "\x12D EN'Y", "D EN'Ys", "\x00D EN'Y", "D EN'Yz", "MD EN'Y", "eD EN'Y", "D EN'Y\x10", "D EmN'Y", "D EN'Y\x0f", "PD EN'Y", "ED EN'Y", "\x06D EN'Y", "\x13D EN'Y", "=D EN'Y", "<D EN'Y", "D E9N'Y", "\x0cD EN'Y", "D EN'Yp", "D EdN'Y", 'D EN´Y', "\x18D EN'Y", "D ESN'Y", "\x1fD EN'Y", "D EN'YX", "D EN'Y\x00", "WD EN'Y", "D E\x07N'Y", "D ETN'Y", "D E@N'Y", "D EN'YJ", "D EN'Y<", "D E?N'Y", 'D EN„Y', "gD EN'Y", 'D EN_Y', "D EN'Y\x1d", "D EN'Y9", "|D EN'Y", "D EN'Y[", "D EN'Y$", "#D EN'Y", "D E\x13N'Y", "D EvN'Y", "D EhN'Y", "D EN'YQ", "vD EN'Y", "D EN'Y\\", "iD EN'Y", "D EN'Y|", "D EUN'Y", "ND EN'Y", "tD EN'Y", "D E7N'Y", "LD EN'Y", "\nD EN'Y", "\x07D EN'Y", "D E%N'Y", 'D EN Y', "/D EN'Y", "D EN'Yx", "\x15D EN'Y", "D EN'Y}", "D EN'Y\x16", "UD EN'Y", "yD EN'Y", "lD EN'Y", "D E\x19N'Y", "D E+N'Y", "D EN'Y\n", "D EN'Y\x12", "fD EN'Y", "D E*N'Y", "D EN'Yf", "-D EN'Y", "D EN'Y/", "\x1bD EN'Y", "*D EN'Y", "uD EN'Y", "D ExN'Y", "D E\xa0aN'Y", "D E-N'Y", "D EIN'Y", "D ElN'Y", "D EN'YZ", "D E\x0bN'Y", "jD EN'Y", "D EsN'Y", "D EN'Y)", "D E`N'Y", "(D EN'Y", "D EPN'Y", "D E\x1dN'Y", "7D EN'Y", "D E\x04N'Y", "D EfN'Y", "D E.N'Y", "D EN'Y\xa0a", "D E\x0fN'Y", "D EiN'Y", "XD EN'Y", "D E,N'Y", "D EgN'Y", "D E\x18N'Y", "+D EN'Y", "wD EN'Y", "D EN'Y+", "D EJN'Y", "D EN'Y`", "D EN'Ye", "D EN'Yk", "D EMN'Y", '"D EN\'Y', 'D EN\'Y"', "D EN'YF", "D EN'YC", "D E_N'Y", "1D EN'Y", "_D EN'Y", "D EN'Yo", "$D EN'Y", "D ENN'Y", "D EN'Y~", "D E\x14N'Y", "\x0eD EN'Y", "D EN'Y(", "D EN'YO", "D E'N'Y", "D EN'Y  ", "D EN'Y\x17", "D EN'Y\x05", "pD EN'Y", "3D EN'Y", "D E#N'Y", "@D EN'Y", "mD EN'Y", "\x05D EN'Y", "D E\x00N'Y", "D EuN'Y", "DEN'Y", ";D EN'Y", "D E\x17N'Y", "RD EN'Y", "JD EN'Y", "?D EN'Y", "D EN'Y]", "\x7fD EN'Y", "D EDN'Y", "AD EN'Y", "D EN'Y\x03", "\x03D EN'Y", "D EN'YL", "KD EN'Y", "D E}N'Y", "D E\x1bN'Y", "}D EN'Y", "D E|N'Y", "xD EN'Y", "D EN'Y1", "cD EN'Y", "D EwN'Y", "\x1cD EN'Y", "[D EN'Y", "]D EN'Y", "BD EN'Y", "D EYN'Y", "D E{N'Y", "D E N'Y", "kD EN'Y", "D EN'Y\x06", "D E~N'Y", 'D EN‘Y', "D EN'Y\x11", ",D EN'Y", "D EN'Y\x1f", "D EN'Y7", "\x19D EN'Y", "D EoN'Y", "D E\x12N'Y", "D EVN'Y", "0D EN'Y", "\x11D EN'Y", "D EN'Y\x14", "D EG ...
# qD EN'Y

# %%
class HeaderTests:
    def __init__(self, label: str, header_name: str, alt_names: list[str], block_values: list[str], allow_values: list[str], partial_values: list[str], legacy_values: list[str], other_values: list[str], base_resp: list[tuple[str, str]]=None):
        """"HeaderTests class to create lots of responses
        label (str): Additional information about these responses (e.g., XFO)
        header_name (str): The correct lower-case name of the header
        alt_names (list[str]): Legacy and other (invalid) alternative header names
        block_values (list[str]): Valid values to set the header to "blocking" (e.g., DENY for XFO means always disallow framing)
        allow_values (list[str]): Valid values to set the header to "allowing" (e.g., unsafe-none  for COOP means do not activate COOP/always allow)
        partial_values (list[str]): Valid values to set the header to an intermediate mode (e.g., SAMEORIGIN for XFO means allow framing only for same-origin)
        legacy_values (list[str]): Legacy values that should not work anymore
        other_values (list[str]): Other values we want to test as well (can include valid ones if we do not want to put too many in the other categories)
        base_resp (list[tuple[str, str]] | None): Base response that other stuff is only added to (default None)
        """
        self.label = label
        self.header_name = header_name
        self.alt_names = alt_names
        self.block_values = block_values
        self.allow_values = allow_values
        self.partial_values = partial_values
        self.legacy_values = legacy_values
        self.other_values = other_values
        self.base_resp = base_resp
        self.responses = []

    def create_response(self, header, label, status_code=200, resp_type="parsing"):
        if self.base_resp:
            header = header + self.base_resp
        self.responses.append((header, label, status_code, resp_type))

    def save_responses(self):
        create_count = 0
        with Session() as session:
            for header, label, status_code, resp_type in self.responses:
                r, created = get_or_create(session, Response, raw_header=json.dumps(header).encode("utf-8"), status_code=status_code, label=label, resp_type=resp_type)
                if created:
                    create_count += 1
        print(len(self.responses))
        print(f"Created: {create_count}")
        print(self.responses[:5])

    def header_name_tests(self):
        """Test all block, allow, partial values (correct values)
            with the correct header names, with all alternative/legacy header names, and with mutated versions of the correct header_name
        """
        for value_group in [self.block_values, self.allow_values, self.partial_values]:
            for header_value in value_group:
                # Original header name
                self.create_response([(self.header_name, header_value)], self.label)
                # Alt header names
                for header_name in self.alt_names:
                    self.create_response([(header_name, header_value)], self.label)
                # Mutated header names
                for header_name in mutate_header_name(self.header_name):
                    self.create_response([(header_name, header_value)], self.label)

    def parsing_tests(self):
        """Test all header values + mutated versions.
        """
        # Test all legacy and other values (block, allow, partial do not have to be tested as they are already tests by header_name_tests)
        for value_group in [self.legacy_values, self.other_values]:
            for header_value in value_group:
                self.create_response([(self.header_name, header_value)], self.label)
        
        # Mutate/change header values (block, allow, partial)
        for value_group in [self.block_values, self.allow_values, self.partial_values]:
            for org_header_value in value_group:
                # Other status codes
                for code in [201, 203, 204, 300, 302, 400, 403, 404, 418, 500]:
                    if 300 <= code < 400:
                        self.create_response([(self.header_name, org_header_value), redirect_empty], self.label, status_code=code)
                    else:
                        self.create_response([(self.header_name, org_header_value)], self.label, status_code=code)
                # Mutated header values
                for header_value in mutate_header_value(org_header_value):
                    self.create_response([(self.header_name, header_value)], self.label)

    def mult_headers_tests(self):
        """Test involving multiple headers/values
        """
        all_valid_values = self.block_values + self.allow_values + self.partial_values
        all_orders = list(permutations(all_valid_values))
        # Basic1: all legal values in a list in all possible orders (Comma, space, semicolon-separated)
        for order in all_orders:
            self.create_response([(self.header_name, ", ".join(order))], self.label)
            self.create_response([(self.header_name, "; ".join(order))], self.label)
            self.create_response([(self.header_name, " ".join(order))], self.label)
        
        # Basic2: all legal values in separate headers in all possible orders
        for order in all_orders:
            headers = [(self.header_name, header_value) for header_value in order]
            self.create_response(headers, self.label)
        # Basic3: all legal values in both separate headers and in one header with comma?!
        # Only if at least 3 values; split in first and all others and last and all others
        for order in all_orders:
            if len(order) >= 3:
                first, rest1 = order[0], ", ".join(order[1:])
                rest2, last = ", ".join(order[:-1]), order[-1]
                self.create_response([(self.header_name, first), (self.header_name, rest1)], self.label)
                self.create_response([(self.header_name, rest2), (self.header_name, last)], self.label)

        # Basic4: all legal values duplicated
        for value in all_valid_values:
            self.create_response([(self.header_name, value), (self.header_name, value)], self.label)
            self.create_response([(self.header_name, f"{value}, {value}")], self.label)
            
            # Could be extended with mutated versions once, e.g., X-Frame-Options: ALLOWALL, allowall;
            # Browsers should first lowercase and then put each value in a set https://html.spec.whatwg.org/multipage/document-lifecycle.html#the-x-frame-options-header
            # Which means no blocking should occur, if they forget the lowercasing part, the set size would be two and it would be blocked
            # Other extensions possible as well
            self.create_response([(self.header_name, value), (self.header_name, value.lower())], self.label)
            self.create_response([(self.header_name, value), (self.header_name, value.upper())], self.label)
        
        # Advanced1: use different header names (e.g., if a browser accepts both x-frame-options and X-FRAME-OPTIONS which takes precedence?; might be neither if the browser first lower-cases or something like that)
        # Currently only either uppercase the first header or all except the first header (other mutations and header duplication strategies could be added in the future)
        # Could be extended with clearly invalid headers (e.g., leading or trailing space, ...)
        for order in all_orders:
            for (header1, header2) in [(self.header_name, self.header_name.upper()), (self.header_name.upper(), self.header_name)]:
                # headers = [(self.header_name, header_value) for header_value in order]
                headers = []
                for i, header_value in enumerate(order):
                    if i == 0:
                        headers.append((header1, header_value))
                    else:
                        headers.append((header2, header_value))
                self.create_response(headers, self.label)
    
        # Advanced2: use invalid values as well (e.g., a browser might always take the first header while another browser takes the first valid header?)
        for valid_value in all_valid_values:
            # Only use the first two invalid values (should be empty and a clearly invalid value ("INVALID")
            # Could be extended with more complex approaches
            for invalid_value in self.other_values[:2]:
                self.create_response([(self.header_name, valid_value), (self.header_name, invalid_value)], self.label)
                self.create_response([(self.header_name, invalid_value), (self.header_name, valid_value)], self.label)
                self.create_response([(self.header_name, f"{valid_value}, {invalid_value}")], self.label)
                self.create_response([(self.header_name, f"{invalid_value}, {valid_value}")], self.label)
                
    def create_all_tests(self):
        self.header_name_tests()
        self.parsing_tests()
        self.mult_headers_tests()
        self.save_responses()

# %%
class HeaderTestsMultHeader(HeaderTests):
    def __init__(self, header_names, values, label, base_resp=None):
        """
        header_names (list[str]): List of header names
        values (dict[str:str]): List of list of values 
        label (str): Label of the response
        """
        assert len(header_names) == len(values)
        self.header_names = header_names
        self.values = values
        self.label = label
        self.responses = []
        self.base_resp = base_resp
        
    def create_all_tests(self):
        # Test all values in all orders of headers
        all_header_orders = list(permutations(self.header_names))
        all_header_orders = [tuple(zip(pair, pair)) for pair in all_header_orders]
        
        # Mutate the header names (basic mutations only)
        mutated_headers = []
        for org_header in self.header_names:
            mutated_headers.append([(org_header, header) for header in mutate_header_value(org_header, mutation_list=basic_mutations)])
        # All possible orders of the mutated headers
        mutated_order = [
            tuple(product(*(mutated_headers[n] for n in list_order)))
            for list_order in permutations(range(len(mutated_headers)))
        ]
        mutated_order = [item for sublist in mutated_order for item in sublist]
        # For each header choose each value
        for headers in mutated_order:
        #for headers in all_header_orders: # No mutations, only the original headers
            # Do not use all combinations of values (too many) but instead cycle through available value (pairs)
            for i in range(len(max(self.values.values(), key=len, default=0))):
                resp = []
                for (org_header, header) in headers:      
                    index = i % len(self.values[org_header]) # Safe index (cycle the list if some have more values than others)
                    resp.append((header, self.values[org_header][index]))
                
                self.create_response(resp, self.label)
        self.save_responses()

# %%
redirect_empty = ("location", "https://sub.headers.websec.saarland/_hp/common/empty.html")
site = "sub.headers.websec.saarland"
origin_s = "https://sub.headers.websec.saarland"
origin_s_upper = "HTTPS://SUB.HEADERS.WEBSEC.SAARLAND"
origin_s_path = f"{origin_s}/abc/"
origin_s_query = f"{origin_s}/?a=a"
origin = "http://sub.headers.websec.saarland"
origin_sp = f"{origin_s}:443"
home = f"{origin_s}/"
home_p = f"{origin_sp}/"
parent = "https://headers.websec.saarland"
child = "https://sub.sub.headers.websec.saarland"
parent_childs = "*.headers.websec.saarland"
self_childs = "*.sub.headers.websec.saarland"
self_childs_https = "https://*.sub.headers.websec.saarland"
cross_site_origin = "https://headers.webappsec.eu"
all_replacements = [site, origin_s, origin_s_upper, origin_s_path, origin_s_query, origin, origin_sp, home, home_p, parent, child, parent_childs, self_childs, self_childs_https, cross_site_origin]
URL_REP = "<!URL!>"

# %%
def expand_urls(other_values):
    """Use different URL, origins, sites variations if the value should allow some sites"""
    return_values = []
    for value in other_values:
        if not URL_REP in value:
            return_values.append(value)
        else:
            # TODO: use combinations if more than one URL in value!
            # Only if less than 2 occurrences? Else chose a random value for each?

            # Currently: replace all occurrences of URL_REP with the same url_like
            for url_like in all_replacements:
                return_values.append(value.replace(URL_REP, url_like))
    return return_values

# %%
label = ""
header_name = ""
alt_names = []
block_values = []
allow_values = []
partial_values = []
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
other_values = ["", "INVALID"]
other_values = expand_urls(other_values)

# %%
def get_values(url, pattern):
    content = httpx.get(url).text
    content = content.replace("TESTURI", URL_REP)
    content = content.replace("http://randomorigin.com/", URL_REP)
    content = content.replace("http://randomorigin.com", URL_REP)
    content = content.replace("http://much.ninja", URL_REP)
    content = content.replace("http://random.ninja", URL_REP)
    content = content.replace("https://much.ninja", URL_REP)
    content = content.replace("http://*.ninja", URL_REP)
    content = content.replace("*.ninja", URL_REP)
    content = content.replace("much.ninja", URL_REP)
    matches = list(set(re.findall(pattern, content)))
    return matches

siewert_xfo = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'X-Frame-Options: (.*?)\'")
print(siewert_xfo)
print()
siewert_csp = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'Content-Security-Policy: (.*?)\'")
print(siewert_csp)
# Out:
# ['deny, deny', 'allow-from <!URL!>; allow-from <!URL!>', 'deny, sameorigin', 'deny, allow-from <!URL!>', 'RANDOMDIRECTIVE', 'deny; deny', 'deny; allow-from <!URL!>', 'allowall', 'allow-from <!URL!>, allow-from <!URL!>', 'deny; sameorigin', 'sameorigin, allow-from <!URL!>', 'allow-from <!URL!>', 'allow-from <!URL!>, deny', 'sameorigin', 'sameorigin, deny', 'deny', 'sameorigin, sameorigin', 'sameorigin; deny', 'allow-from <!URL!>, sameorigin', 'sameorigin; sameorigin', 'allow-from <!URL!>; deny']
#
# ['frame-ancestors https:;', 'frame-ancestors http:;', 'frame-ancestors <!URL!> <!URL!>;', 'frame-ancestors <!URL!>;']

# %%
def get_wpt_values(dir_path, pattern=r'headerValue: `(.*)`|headerValue2: `(.*)`'):
    # Initialize a list to store matching strings
    values = set()
    # Use glob to find all files with the specified extension recursively
    file_paths = glob.glob(os.path.join(dir_path, '*.html'), recursive=False)
    # Iterate through the list of file paths
    for file_path in file_paths:
        with open(file_path, 'r') as f:
            content = f.read()
            content = content.replace("https://example.com/", URL_REP)
            matches = re.findall(pattern, content)
            for match1, match2 in matches:
                values.add(match1)
                values.add(match2)
    return list(values)

wpt_xfo = get_wpt_values('../../../x-frame-options/')
wpt_xfo
# Out:
# ['',
#  'SAMEORIGIN',
#  '  SAMEORIGIN ',
#  '"SAMEORIGIN,DENY"',
#  '  SAMEORIGIN,    DENY',
#  '  DENY ',
#  'ALLOWALL',
#  '"DENY"',
#  'ALLOW-FROM <!URL!>',
#  'denY',
#  '"SAMEORIGIN"',
#  'sameOriGin',
#  'DENY',
#  ',SAMEORIGIN,,DENY,',
#  'INVALID',
#  'allowAll',
#  'sameOrigin',
#  'ALLOW-FROM=<!URL!>']

# %%
def limit_url_occurrences(input_string, max_occurrences):
    # Define the pattern to match <!URL!>
    url_pattern = re.compile(rf'{URL_REP}(?:(\s|,)*(ALLOW-FROM )?(allow-from )?{URL_REP})+')
    #url_pattern = re.compile(rf'{URL_REP}(?:(\s|,)*{URL_REP})+')

    # Find all consecutive occurrences of <!URL!>
    consecutive_url_matches = url_pattern.findall(input_string)

    # Calculate the number of replacements needed
    replacements_needed = max(0, len(consecutive_url_matches) - max_occurrences)

    # Replace excess consecutive occurrences with <!URL!>
    replaced_string = url_pattern.sub('', input_string, count=replacements_needed)

    return replaced_string


def replace_multiple_urls(input_string):
    # Define the pattern to match three or more consecutive <!URL!>
    url_pattern = re.compile(r'((<!URL!>\s*){3,})')

    # Replace three or more consecutive <!URL!> with a single <!URL!>
    replaced_string = re.sub(url_pattern, '<!URL!> ', input_string)

    return replaced_string


def run_replacements(input_string):
    input_string = replace_multiple_urls(input_string)
    input_string = limit_url_occurrences(input_string, 4)
    input_string = re.sub("sha256-\S+", "sha256-default", input_string)
    # Replace 4 digit numbers and higher with 60 (for HSTS; should not affect other headers?)
    input_string = re.sub("\d{4,}", "60", input_string)
    return input_string

def get_crawler_values(url, min_count=0):
    content = httpx.get(url).text
    content = re.sub(r"(http(s)?|HTTP(S)?)://[\w.*/\-:?=]*|([\w*\-/]+\.)+[\w*\-:/?=]+", URL_REP, content)
    rows = [row.rsplit(" ", maxsplit=1) for row in content.split("\r\n")[1:] if " " in row]
    # Only use values occuring more than once? Otherwise we have to many possible values?
    rows = [row[0] for row in rows if int(row[1].replace(",","")) >= min_count]
    return list(set([run_replacements(row) for row in rows]))

crawler_ninja_xfo = get_crawler_values("https://crawler.ninja/files/xfo-values.txt")
print(len(crawler_ninja_xfo))
#display(crawler_ninja_xfo)
crawler_ninja_csp = get_crawler_values("https://crawler.ninja/files/csp-values.txt", min_count=2)
print(len(crawler_ninja_csp))
crawler_ninja_csp
# Out:
# 217
# 1437
# ['connect-src *',
#  "default-src data: 'unsafe-inline' 'unsafe-eval' https: http:;script-src data: 'unsafe-inline' 'unsafe-eval' https: http: blob:;style-src data: 'unsafe-inline' https: http: blob:;img-src data: https: http: blob:;font-src data: https: http:;connect-src https: wss: ws: http: blob:;media-src https: blob: http:;object-src https: http:;child-src https: data: blob: http:;form-action https: http:;block-all-mixed-content;",
#  "default-src * data: blob: filesystem: 'unsafe-inline' 'unsafe-eval'; script-src * 'unsafe-inline' 'unsafe-eval'; connect-src * 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; frame-src *; style-src * 'unsafe-inline';",
#  "default-src 'self'; base-uri 'self'; connect-src *; font-src * data:; frame-src *; img-src * data:; media-src *; object-src *; script-src * 'unsafe-inline' 'unsafe-eval'; worker-src 'self' blob:; style-src * 'unsafe-inline'",
#  "default-src 'self' data: blob: <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> blob: data: blob:; connect-src 'self' data: blob: <!URL!> wss:<!URL!> wss:<!URL!> ; img-src 'self' blob: data: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' data: <!URL!> ; media-src 'self' <!URL!> data: blob:;",
#  "default-src 'self'; script-src * 'unsafe-eval' 'unsafe-inline'; object-src *; style-src * 'unsafe-inline'; img-src * data:;frame-src *;font-src * data:;connect-src * blob:;media-src * blob:;worker-src * blob:;",
#  "default-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; script-src 'self' blob: 'unsafe-inline' 'unsafe-eval'; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> ; script-src-elem 'self' 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> wss:; form-action 'self' <!URL!>; frame-ancestors 'self'; upgrade-insecure-requests; block-all-mixed-content;",
#  "default-src 'self' data: blob: <!URL!> 'unsafe-inline' 'unsafe-eval';",
#  "default-src * 'unsafe-inline' 'unsafe-eval'; img-src * 'unsafe-inline' 'unsafe-eval' 'self' data: https:; report-uri /report-csp-violation",
#  "default-src * 'unsafe-inline' 'unsafe-eval' blob:; frame-ancestors ; img-src * data:; font-src * data:; media-src * blob:; report-uri <!URL!>",
#  "frame-ancestors <!URL!> 'self'",
#  "frame-src <!URL!> ; font-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; form-action 'self' <!URL!>; script-src 'self' 'unsafe-inline' <!URL!> ;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' data: https: blob: ws:; frame-ancestors 'self'; upgrade-insecure-requests; base-uri 'self';",
#  "default-src * 'unsafe-inline' 'unsafe-eval'; script-src * 'unsafe-inline' 'unsafe-eval'; connect-src * 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; frame-src *; style-src * 'unsafe-inline'",
#  "default-src * blob:; img-src * data: blob: resource: ; connect-src * wss: blob: resource:; frame-src 'self' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: <!URL!> ; style-src 'self' 'unsafe-inline'  resource:; frame-ancestors <!URL!>;",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' * blob: <!URL!> ; object-src 'none' ; style-src 'self' 'unsafe-inline' *; img-src 'self' data: * blob:; media-src 'self' <!URL!> blob:; frame-src 'self' <!URL!> blob: <!URL!> ; child-src 'self' <!URL!> blob: <!URL!> ; font-src 'self' <!URL!> data:; connect-src 'self' * blob: <!URL!>; base-uri 'self'; report-uri /report-csp-violation",
#  "default-src 'self' ; child-src blob: <!URL!>; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:; font-src 'self' data: <!URL!> ; form-action 'self' <!URL!> ; frame-ancestors 'self' <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' data: blob: https: *; media-src 'self' 'unsafe-inline' data: <!URL!> ; script-src-elem 'self' 'unsafe-inline' blob: <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' blob: <!URL!> data: <!URL!> ; style-src-elem 'self' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; manifest-src 'self'; worker-src blob: 'self'; object-src <!URL!>; report-to report-uri-amnh-csp-endpoint; report-uri <!URL!>",
#  "default-src 'self';media-src 'self' <!URL!>;script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;connect-src 'self' wss: <!URL!> ;img-src 'self' data: <!URL!> ;font-src 'self' <!URL!> ;style-src 'self' 'unsafe-inline' <!URL!>;frame-src 'self' <!URL!> ;child-src 'self' blob:;object-src 'none'",
#  "frame-ancestors 'self'; script-src 'unsafe-inline' 'unsafe-eval' blob: data: localhost localhost:60 <!URL!> ",
#  "frame-ancestors 'self' https:",
#  "default-src *  data: blob: filesystem: about: ws: wss: 'unsafe-inline' 'unsafe-eval'; script-src * data: blob: 'unsafe-inline' 'unsafe-eval'; connect-src * data: blob: 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; frame-src * data: blob: ; style-src * data: blob: 'unsafe-inline'; font-src * data: blob: 'unsafe-inline'; frame-ancestors * data: blob:;",
#  "default-src * 'unsafe-inline' 'unsafe-eval'; img-src * 'unsafe-inline' 'unsafe-eval' data:; frame-ancestors 'self' <!URL!>;",
#  "base-uri 'self'; font-src 'self' https: data: <!URL!>; form-action 'self'; frame-ancestors *; img-src 'self' https: data: <!URL!> ; object-src 'self'; script-src-attr 'unsafe-inline'; style-src https: 'unsafe-inline' 'self' <!URL!> ; script-src 'unsafe-inline' 'unsafe-eval' https: *; upgrade-insecure-requests; connect-src *; default-src 'self' https:; frame-src *; media-src 'self' https: data:; worker-src * blob:;",
#  "upgrade-insecure-requests; frame-ancestors 'self' ",
#  "default-src https:; script-src https: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline'; img-src https: data: cid:; connect-src https: wss:; worker-src 'self' blob: ; child-src 'self' https: blob: ;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; img-src 'self' <!URL!> data:; style-src 'self' 'unsafe-inline' <!URL!> ; child-src 'self' ; font-src <!URL!> data:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; connect-src 'self' <!URL!> ; frame-src 'self' <!URL!> ",
#  "frame-ancestors 'self' <!URL!> ; form-action https:; script-src https: 'unsafe-inline' 'unsafe-eval'",
#  "frame-ancestors 'self' <!URL!> ; default-src https: blob: 'unsafe-inline' 'unsafe-eval' data:; font-src https: blob: data:; img-src https: data: android-webview-video-poster: blob:; form-action https:; block-all-mixed-content; media-src https: blob: data:;",
#  'frame-ancestors <!URL!> ',
#  "default-src * 'unsafe-inline' 'unsafe-eval'; script-src * 'unsafe-inline' 'unsafe-eval'; connect-src * 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; frame-src *; font-src * data: blob: 'unsafe-inline'; style-src * 'unsafe-inline';",
#  "script-src blob: <!URL!> 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline'; img-src * 'self' data: https:; frame-ancestors <!URL!> ; object-src <!URL!>;",
#  "default-src 'self' blob: <!URL!> ; script-src 'unsafe-eval' 'unsafe-inline' 'self' *; style-src 'unsafe-inline' 'self' blob: *; child-src 'self' blob: *; frame-src 'self' *; object-src 'self' *; img-src 'self' data: blob: *; media-src 'self' data: blob: *; font-src 'self' data: *; connect-src 'self' data: *; frame-ancestors 'self' <!URL!> ;",
#  "default-src *; script-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' http: https: data: mediastream:; style-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' http: https: data: mediastream:; img-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' http: https: data: mediastream:; connect-src *; font-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' http: https: data: mediastream:; media-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' http: https: data: mediastream:; report-uri *; child-src *; form-action *; frame-ancestors *; object-src *; frame-src *; worker-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' http: https: data: mediastream: blob:; manifest-src *; navigate-to *; base-uri *; upgrade-insecure-requests",
#  "default-src https:; child-src blob: https:; connect-src blob: https: wss:; form-action https:; frame-ancestors https: <!URL!>; media-src blob: https:; object-src https:; img-src https: data: blob:; script-src https: data: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline'; font-src https: data:",
#  "default-src * 'self' 'unsafe-inline' 'unsafe-eval' blob:;script-src * 'self' 'unsafe-inline' 'unsafe-eval'; style-src * 'self' 'unsafe-inline';img-src * 'self' data:;frame-ancestors 'self' <!URL!> ;worker-src * 'self' blob:;connect-src * 'self' blob:;font-src * 'self' data:;frame-src * 'self';media-src * 'self' blob:;object-src * 'self';",
#  "object-src 'none'; frame-src *; frame-ancestors 'self' X-Frame-Options: SAMEORIGIN",
#  "default-src 'self' <!URL!>; connect-src *; font-src * data:; frame-src *; img-src * data: blob: https:; worker-src blob:; media-src *; object-src *; script-src * 'unsafe-inline' 'unsafe-eval'; style-src * 'unsafe-inline';",
#  "default-src https: http: wss: 'self' data: 'unsafe-inline' 'unsafe-eval' blob:;",
#  "default-src  'self' <!URL!> ;  script-src  'self'  'sha256-default # Script for GTM tag blob:  <!URL!> wss:<!URL!> wss:<!URL!> @@<!URL!> ;  object-src  'self' ;  style-src  'self'  'unsafe-inline' <!URL!> @<!URL!> ;  img-src  * ;  media-src  * ;  frame-src  <!URL!> ;  frame-ancestors  'none' ;  font-src  *  data: ;  connect-src  'self'  <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ;",
#  "base-uri 'self'; connect-src 'self'  <!URL!> wss:<!URL!> ; default-src 'self'; font-src 'self'  data:; frame-src 'self' <!URL!> ; img-src 'self' <!URL!> data:; manifest-src 'self'; media-src 'self'; object-src 'none'; script-src 'self' 'wasm-unsafe-eval' 'nonce-dubi13asf985gfGDlmsnIot' 'sha256-default <!URL!> ; style-src 'self' 'unsafe-inline' ; worker-src ;",
#  "default-src https: data: blob: 'unsafe-eval' 'unsafe-inline' <!URL!> wss:<!URL!> wss:<!URL!> 'self'; upgrade-insecure-requests; frame-ancestors 'self' <!URL!> ;",
#  "default-src *; style-src 'self' <!URL!> 'unsafe-inline'; font-src 'self' data: <!URL!> 'unsafe-inline' 'unsafe-eval'; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; img-src 'self' <!URL!> data:;",
#  "frame-ancestors 'none', frame-ancestors 'none'",
#  "frame-ancestors 'none'; object-src 'none'; upgrade-insecure-requests",
#  "default-src 'self'; font-src *;img-src * data:; script-src *; style-src *;",
#  "default-src 'self' blob: wss: data: https:; script-src 'self' 'unsafe-eval' 'unsafe-inline' blob: data: https:; style-src 'self' 'unsafe-inline' data: https:;",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval';object-src 'self';style-src 'self' 'unsafe-inline';",
#  "worker-src 'self' blob: <!URL!> https: 'unsafe-inline' 'unsafe-eval';<!URL!>;default-src  https: blob: data: 'unsafe-inline' 'unsafe-eval';object-src *;script-src  https: 'unsafe-inline' 'unsafe-eval';frame-ancestors 'self' ;img-src * 'self' data: https:;font-src * 'self' data: https:;worker-src 'self' blob:;",
#  "default-src 'self' blob: data: <!URL!> ;img-src 'self' blob: data: <!URL!> ;script-src 'self' blob: 'unsafe-inline' 'unsafe-eval' <!URL!> inline: <!URL!> @@<!URL!> ;style-src  'unsafe-inline' 'self' <!URL!> @<!URL!> @<!URL!> ;connect-src 'self' <!URL!> wss:<!URL!> ;frame-src <!URL!> 'self' <!URL!> ;frame-ancestors <!URL!> 'self';",
#  "frame-ancestors  'self' <!URL!> ",
#  "upgrade-insecure-requests; frame-ancestors 'self' ; report-uri <!URL!>",
#  "frame-src  'self' <!URL!> ; worker-src 'self' blob: ; child-src 'self' ",
#  "default-src 'self' <!URL!> wss:<!URL!> localhost:* chrome-extension://*;script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> wss:<!URL!> localhost:* chrome-extension://*;child-src <!URL!> wss:<!URL!> localhost:* chrome-extension://*;style-src 'self' 'unsafe-inline' <!URL!> wss:<!URL!> localhost:* chrome-extension://*;img-src * blob: data:;media-src 'self' <!URL!> blob: data: <!URL!> wss:<!URL!> localhost:* chrome-extension://*;connect-src data: *;font-src 'self' <!URL!> ;worker-src 'self' <!URL!> blob:",
#  "frame-ancestors 'self' <!URL!> wss:",
#  "manifest-src 'self' 'unsafe-inline'; child-src <!URL!> http: https: blob: 'self' 'unsafe-inline'; upgrade-insecure-requests; frame-ancestors 'self' <!URL!> ; form-action 'self' <!URL!> * 'self' 'unsafe-inline'; style-src 'self' 'unsafe-inline' <!URL!> unsafe-inline <!URL!> 'self' 'unsafe-inline'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; object-src 'none'; media-src ; img-src 'self' data: <!URL!> 'self' data: <!URL!> data: 'self' 'unsafe-inline'; frame-src 'self' <!URL!> * 'self' 'unsafe-inline'; font-src 'self' data: <!URL!> 'self' data: <!URL!> data: 'self' 'unsafe-inline'; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> 'self' data: <!URL!> 'self' 'unsafe-inline'; default-src 'self' <!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; worker-src 'self' <!URL!> ;",
#  "default-src * 'unsafe-inline' 'unsafe-eval' data: blob: <!URL!> ; connect-src 'self' <!URL!> ; font-src 'self' <!URL!> data: <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; media-src data:; script-src 'self' 'unsafe-hashes' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ",
#  "block-all-mixed-content; object-src 'none'; base-uri 'none'; frame-ancestors 'self';",
#  "frame-ancestors 'none', upgrade-insecure-requests",
#  "default-src 'self'; img-src 'self'  data:; frame-ancestors 'self'; font-src 'self' <!URL!>; upgrade-insecure-requests; frame-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; script-src 'self' <!URL!> ",
#  "default-src blob: 'unsafe-eval' 'unsafe-inline' https: wss:<!URL!>; img-src data: https:; font-src data: https:",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> @<!URL!> ; img-src * data:; media-src * data:; font-src 'self' <!URL!> @ data:; worker-src 'self' blob:",
#  "script-src 'self' <!URL!> ; connect-src *",
#  'frame-ancestors *',
#  "script-src 'unsafe-eval' <!URL!> ; frame-src <!URL!> bytedance: ; worker-src https: blob:; frame-ancestors ; report-to csp-endpoint; upgrade-insecure-requests ; default-src 'self' 'unsafe-eval' 'unsafe-inline' blob: bytedance: data: wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ; report-uri <!URL!>&revision=3ed08dc1-de79-48ef-bb0b-f0c28ac60",
#  'frame-ancestors self <!URL!>',
#  "default-src 'self' https:; img-src 'self' https: data:; media-src 'self' https: data:; style-src 'self' 'unsafe-inline' https:; font-src 'self' https: data:; script-src 'self' 'unsafe-inline' https: 'unsafe-eval'; script-src-elem 'self' https: 'unsafe-inline'; frame-ancestors <!URL!>;",
#  'sandbox allow-same-origin allow-scripts allow-orientation-lock allow-pointer-lock allow-forms allow-popups allow-top-navigation-by-user-activation;',
#  "default-src *; script-src * 'unsafe-eval' 'self' 'unsafe-inline' https:; style-src * 'unsafe-inline'; object-src 'self' ; img-src * data:; frame-src * blob:; font-src * data:; connect-src *; media-src * blob:; worker-src 'self' blob:; frame-ancestors 'self' ;",
#  'frame-ancestors *;',
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!>; img-src *; media-src *",
#  "default-src 'self' blob: <!URL!> ; img-src 'self' 'unsafe-inline' data: <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' https: blob: <!URL!> ; style-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; font-src 'self' data: <!URL!> ; connect-src 'self' blob: <!URL!> wss:<!URL!> wss: wss:<!URL!> $self_user/events <!URL!>$self_user/props <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss: wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss: wss:<!URL!> wss:<!URL!>; frame-ancestors 'self' <!URL!> ;",
#  "default-src * data: blob: 'unsafe-inline' 'unsafe-eval';",
#  "default-src https: data: 'unsafe-eval' 'unsafe-inline' blob:",
#  "object-src 'none'; base-uri 'none'; default-src ; style-src <!URL!> <!URL!>; font-src <!URL!> <!URL!>; script-src <!URL!> <!URL!>; img-src <!URL!> ; connect-src <!URL!> <!URL!>; frame-ancestors 'none'; report-uri /default/csp;",
#  "frame-ancestors 'self' <!URL!> ; form-action <!URL!> 'self' <!URL!>",
#  "default-src 'self'; base-uri 'self'; style-src 'self' 'unsafe-inline' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'self' ; media-src 'self' <!URL!> ;child-src <!URL!> ; img-src 'self' data: <!URL!> ; frame-ancestors 'self';",
#  "default-src 'self'; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; connect-src *; img-src 'self' data: <!URL!> ; frame-src 'self' <!URL!> ; frame-ancestors ; font-src 'self' data: <!URL!> ; media-src 'self' data: ",
#  "frame-ancestors 'none'; default-src *; script-src 'self' 'unsafe-eval' <!URL!> ; style-src * 'unsafe-inline'; img-src * data: blob:; font-src * data:;",
#  "object-src 'none'; base-uri 'none'",
#  "default-src https: data: wss: 'unsafe-inline'; script-src https: 'unsafe-inline' 'unsafe-eval'; object-src 'self'",
#  "default-src 'self' data: blob:;",
#  'frame-ancestors *; report-uri /report-csp-violation',
#  "default-src data: 'unsafe-inline' 'unsafe-eval' https: http:;script-src data: 'unsafe-inline' 'unsafe-eval' https: http: blob:;style-src data: 'unsafe-inline' https: http: blob:;style-src-elem data: 'unsafe-inline' https: http: blob:;img-src data: https: http: blob:;font-src data: https: http:;connect-src https: wss: ws: http: blob:;media-src https: blob: http:;object-src https: http:;child-src https: data: blob: http:;form-action https: http:;block-all-mixed-content;",
#  "default-src * self blob: data: gap:; style-src * self 'unsafe-inline' blob: data: gap:; script-src * 'self' 'unsafe-eval' 'unsafe-inline' blob: data: gap:; object-src * 'self' blob: data: gap:; img-src * self 'unsafe-inline' blob: data: gap:; connect-src self * 'unsafe-inline' blob: data: gap:; frame-src * self blob: data: gap:;",
#  "frame-ancestors 'self'; base-uri 'self'",
#  'frame-ancestors <!URL!> ;',
#  "default-src 'self'  wss:<!URL!> 'unsafe-inline'; object-src 'self'; style-src 'self' 'unsafe-inline' ; script-src 'self' 'unsafe-inline'  'unsafe-eval' <!URL!> ; img-src * data: blob: ; connect-src *; frame-src *; font-src 'self' <!URL!> data:",
#  "connect-src 'self' <!URL!> wss:<!URL!> ; default-src 'self' ; font-src 'self' data: <!URL!> ; form-action 'self' ; frame-ancestors 'self' ; img-src 'self' <!URL!> ; media-src 'self' <!URL!> ; object-src 'none' ; script-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!>",
#  'child-src * blob:',
#  "default-src 'self' blob: <!URL!> ; img-src 'self' 'unsafe-inline' * data: <!URL!> ; frame-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; font-src 'self' 'unsafe-inline' * data: <!URL!> ; script-src 'self' 'unsafe-inline' <!URL!> 'unsafe-eval' blob: <!URL!> ;connect-src 'self' <!URL!> ;base-uri 'self'; form-action 'self'",
#  "require-trusted-types-for 'script';report-uri /_/PlayStoreUi/cspreport",
#  '*',
#  "default-src 'self' ;style-src 'self' 'unsafe-inline' <!URL!> ;connect-src 'self' <!URL!> *;script-src 'unsafe-eval' 'unsafe-inline' <!URL!> 'self' <!URL!> ;font-src 'self' data: <!URL!> ;img-src <!URL!> 'self' data: <!URL!> ;frame-src <!URL!> ;object-src 'none';upgrade-insecure-requests;base-uri 'self';form-action 'self';frame-ancestors 'self';script-src-attr 'none'",
#  "frame-ancestors 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'none'; style-src 'self' 'unsafe-inline' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; font-src 'self' <!URL!>;",
#  "frame-ancestors 'self' *, object-src 'none', font-src 'self' , frame-src 'self' <!URL!> , img-src 'self' data: <!URL!> ",
#  "default-src 'none';         script-src 'self' 'unsafe-inline' 'unsafe-eval'         <!URL!> ;         style-src 'self' 'unsafe-inline'         <!URL!> ;         font-src 'self'         data:         <!URL!> ;         img-src 'self'         data:         <!URL!> ;         frame-src 'self'         <!URL!> ;         connect-src 'self'         <!URL!> ;         object-src 'self';         media-src 'self';         worker-src 'self'         blob:         <!URL!> ;",
#  "default-src 'self' <!URL!>;    script-src  'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;    style-src   'self' 'unsafe-inline' <!URL!> ;    font-src data: *;    img-src  data: *;    frame-ancestors 'self' <!URL!> ;    worker-src  'self' <!URL!> ;    frame-src   'self' <!URL!> ;    object-src  'self';    connect-src 'self' ;    media-src *; upgrade-insecure-requests;",
#  "default-src https: data: 'unsafe-inline' 'unsafe-eval'",
#  "connect-src 'self' <!URL!> ; font-src 'self' <!URL!> data:; img-src 'self'  data: <!URL!> ; media-src 'self' <!URL!>; object-src 'self' <!URL!>; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; script-src-attr 'self' 'unsafe-inline'; style-src 'self' 'unsafe-inline' <!URL!> ; style-src-attr 'self' 'unsafe-inline'; frame-ancestors 'self' <!URL!>; report-uri <!URL!>; report-to csp",
#  "report-uri <!URL!>; frame-ancestors 'self'; default-src 'self' 'unsafe-inline' 'unsafe-eval' wss: https: data: blob: android-webview-video-poster:; upgrade-insecure-requests;",
#  "default-src self *  ;style-src  https: data: 'unsafe-inline';img-src  https: blob: data:;child-src data:;object-src none;worker-src blob: <!URL!>  ;frame-src  https: blob:;script-src  https: 'unsafe-inline' 'unsafe-eval';font-src data: self https: ;connect-src self * blob:",
#  "script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> wss:<!URL!> wss:<!URL!> ;  connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ;  img-src 'self' data: <!URL!> ;  font-src 'self' data: <!URL!> ;  style-src 'self' 'unsafe-inline' <!URL!> ;  worker-src blob: ;",
#  "default-src 'none';  script-src 'unsafe-inline' 'unsafe-eval' 'self' <!URL!> ;  style-src 'self' 'unsafe-inline' <!URL!>;  connect-src 'self' <!URL!> ;  img-src data: 'self' 'unsafe-inline' <!URL!> ;  media-src <!URL!> ;  frame-src data: 'self' <!URL!> ;  font-src 'self' ;  object-src 'self';  manifest-src 'self';  worker-src 'self' blob:;",
#  "default-src https: wss:; script-src 'unsafe-inline' 'unsafe-eval' https:; style-src 'unsafe-inline' https: blob:; img-src * blob: data:; frame-ancestors 'self' <!URL!> ; worker-src blob: data: https:; font-src https: data:; script-src-elem 'unsafe-inline' 'unsafe-eval' * blob:",
#  "upgrade-insecure-requests; frame-ancestors 'self' <!URL!>; default-src 'self'; object-src 'none'; worker-src 'self'; frame-src 'self' https:; form-action 'self' <!URL!>; font-src 'self' data: <!URL!> ; img-src 'self' data: https: blob:; script-src 'report-sample' 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'report-sample' 'self' 'unsafe-inline' ; connect-src 'self' <!URL!> ; media-src 'self' <!URL!>",
#  "default-src 'self'; font-src data: <!URL!>; script-src 'self' <!URL!> ; worker-src 'self' blob:; connect-src  'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; form-action 'self' <!URL!> ; img-src 'self' blob: data: <!URL!> ; frame-ancestors 'self' <!URL!> ; frame-src 'self' <!URL!> ; base-uri 'self' <!URL!> ; child-src 'self' blob:; manifest-src 'self'; report-uri /__csp-reports__; upgrade-insecure-requests;",
#  "default-src 'self'; img-src * data: 'unsafe-inline' blob:; style-src * 'unsafe-inline' blob:; font-src * data:; script-src * 'unsafe-inline' 'unsafe-eval'; connect-src *; form-action *; media-src <!URL!> 'self' blob:; frame-src *; frame-ancestors 'self'; worker-src * 'unsafe-inline' blob:;",
#  "default-src 'none'; connect-src 'self' <!URL!> ; font-src 'self'; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; manifest-src 'self'; media-src 'self'; script-src 'self' <!URL!> 'unsafe-inline' <!URL!>; style-src 'self' 'unsafe-inline'; worker-src 'self'; base-uri 'self'; frame-ancestors 'self'",
#  "frame-ancestors 'self'; default-src * data: 'unsafe-eval' 'unsafe-inline' blob:; style-src 'self' <!URL!> 'unsafe-inline'; script-src 'self' blob: <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ",
#  "default-src https: data: blob: 'unsafe-inline' 'unsafe-eval'; connect-src *;",
#  "script-src 'unsafe-inline' 'unsafe-eval' 'self' <!URL!> blob:;report-uri /_/MeetingsUi/cspreport/allowlist",
#  "base-uri 'self'; default-src 'self' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> ; form-action 'self' <!URL!> ; frame-src 'self' <!URL!> ; img-src * data: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; media-src 'self' 'unsafe-inline' <!URL!> false; font-src 'self' data: <!URL!> ; child-src 'self' <!URL!>;",
#  "default-src 'self'; script-src 'self' 'unsafe-inline' ; style-src 'self' 'unsafe-inline' ; object-src 'none'; connect-src 'self' <!URL!> ; font-src 'self' <!URL!>; frame-src 'self'; img-src 'self' data: <!URL!> ; manifest-src 'self'; worker-src 'none';",
#  "default-src 'self' ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> @elbwalker  <!URL!> ; style-src 'self' 'unsafe-inline'  <!URL!> ; font-src 'self' <!URL!> data:; img-src 'self'  data: blob:  <!URL!> ; media-src 'self' data: <!URL!>; frame-src 'self' <!URL!> ; frame-ancestors 'self' ; child-src 'self' <!URL!>  blob: <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> data:;",
#  'Content-Security-Policy-Report-Only',
#  "base-uri 'self'; worker-src 'self' blob:; img-src 'self' data: <!URL!> ; style-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; connect-src 'self' <!URL!> ; object-src 'none'; report-to csp-endpoint; report-uri <!URL!>;",
#  "img-src 'self' <!URL!> data:;connect-src 'self' ;object-src 'none';media-src 'self' <!URL!> data:;child-src 'self';frame-src 'self' <!URL!> ;form-action <!URL!> 'self';frame-ancestors 'self' <!URL!> ;upgrade-insecure-requests;worker-src 'self' <!URL!>",
#  "default-src * 'unsafe-eval' 'unsafe-inline'; img-src * data: unsafe-inline",
#  'form-action https:; upgrade-insecure-requests',
#  "default-src 'self'  ; media-src <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> * ; img-src * 'self' data: https: blob: <!URL!> ; script-src * data: <!URL!> blob: 'unsafe-inline' 'unsafe-eval' ; connect-src * data: blob: 'unsafe-inline' ; font-src * data: blob: 'unsafe-inline' ; frame-src * ;",
#  "frame-src 'self' *",
#  "frame-ancestors 'self' <!URL!> ; frame-src 'self' <!URL!> ; report-uri <!URL!>",
#  'frame-ancestors "none"',
#  'block-all-mixed-content;frame-ancestors <!URL!>',
#  "frame-ancestors 'self'; report-uri /report-csp-violation",
#  "default-src 'none'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; img-src data: 'self' <!URL!> blob:; style-src 'self' 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> ; font-src <!URL!> ; frame-src <!URL!> ; frame-ancestors 'self' ; base-uri 'self'; form-action 'self';",
#  "frame-ancestors 'self' ; child-src * blob:; worker-src * blob:; img-src * <!URL!> blob: data:; connect-src * <!URL!> blob:; script-src 'self' * 'unsafe-inline' 'unsafe-eval' blob:  blob:",
#  "default-src 'self' <!URL!> ; img-src 'self' data: *; script-src 'unsafe-eval' 'unsafe-inline' 'self' *; style-src 'unsafe-inline' 'self' *; font-src 'self' data: *; object-src 'none'; media-src * blob:; worker-src blob: 'self'; frame-ancestors 'self';",
#  "default-src * 'unsafe-inline' 'unsafe-eval'; img-src * data: blob: 'unsafe-inline';",
#  "script-src  'self' 'unsafe-inline' <!URL!> ; style-src 'unsafe-inline' <!URL!> ; frame-src 'unsafe-inline' <!URL!> report-uri <!URL!>",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;connect-src 'self' data: blob: <!URL!> wss: wss:<!URL!> ws://localhost:* ws:<!URL!> wss:<!URL!> notion:<!URL!> ;font-src 'self' data: ;img-src 'self' data: blob: https: <!URL!> notion:<!URL!> ;style-src 'self' 'unsafe-inline' <!URL!> ;frame-ancestors 'self';worker-src 'self' blob:;child-src 'self' blob:;media-src blob: https: http: <!URL!> notion:;frame-src https: http: <!URL!> ",
#  "connect-src  'self' <!URL!> ; img-src <!URL!> data:  'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src-attr 'unsafe-inline'; base-uri 'self'; frame-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data: <!URL!> ; font-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data: <!URL!> ",
#  "manifest-src 'self'; upgrade-insecure-requests; block-all-mixed-content;, report-uri <!URL!>;, frame-ancestors 'self';",
#  "object-src 'self' data:",
#  "default-src 'self' 'unsafe-inline' <!URL!> https:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> https:; img-src 'self' <!URL!> data:  https:; style-src 'self' 'unsafe-inline' <!URL!> https:; font-src 'self' <!URL!> data:; object-src  https:; media-src  'self'  https:; frame-ancestors 'self'; frame-src 'self' https:; ",
#  "default-src 'none';child-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> data: blob:;connect-src 'self' <!URL!> wss: wss:<!URL!> wss:<!URL!> wss:<!URL!> ;script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> wss:<!URL!> ;img-src 'self' data: <!URL!> ;media-src 'self' blob: data:;style-src 'self' 'unsafe-inline' <!URL!> ;font-src 'self' data: <!URL!> ;frame-src 'self' <!URL!> wss:<!URL!> ",
#  "default-src 'self';base-uri 'self';font-src 'self' https: data:;form-action 'self';frame-ancestors 'self';img-src 'self' data:;object-src 'none';script-src 'self';script-src-attr 'none';style-src 'self' https: 'unsafe-inline';upgrade-insecure-requests",
#  "script-src 'self' 'unsafe-inline' <!URL!> blob: http: https:; object-src 'none'; base-uri 'none'; report-uri <!URL!>;",
#  "frame-ancestors 'self' <!URL!> ; frame-src <!URL!> ",
#  'frame-ancestors',
#  "default-src 'self' <!URL!>; font-src 'self' <!URL!>; style-src 'self' 'unsafe-inline' <!URL!>; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; img-src 'self' data: <!URL!>; frame-src <!URL!> ",
#  "base-uri 'none';child-src 'none';connect-src 'self' <!URL!> ;default-src 'self';font-src 'self';form-action 'self';frame-ancestors self;frame-src 'none';img-src 'self' data: <!URL!> ;manifest-src 'self';media-src 'self';object-src 'none';prefetch-src 'self';script-src 'self' 'unsafe-inline' https:;style-src 'self' 'unsafe-inline';worker-src 'self';report-uri <!URL!>;report-to <!URL!>;",
#  "script-src 'self' 'unsafe-eval' 'unsafe-inline' 'report-sample' blob: data: <!URL!> ; connect-src 'self' 'report-sample' data: blob:  wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss: wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss: wss:<!URL!> <!URL!> wss:<!URL!> <!URL!> wss:<!URL!> <!URL!> wss:<!URL!> <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!>; frame-src 'self' 'report-sample' blob: data: <!URL!> ; frame-ancestors 'self' <!URL!> ; report-uri <!URL!>;",
#  "default-src <!URL!> wss:<!URL!> 'self' 'unsafe-inline' 'unsafe-eval' data: https: <!URL!> ; frame-ancestors 'self' <!URL!>; frame-src <!URL!> ; object-src 'none';",
#  "frame-ancestors 'self'; object-src ; plugin-types application/x-shockwave-flash application/pdf",
#  "default-src 'self'; connect-src 'self' <!URL!> wss:<!URL!>; font-src 'self' <!URL!> ; frame-src 'unsafe-inline' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; media-src 'none'; object-src 'none'; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline'",
#  "default-src * data: blob: filesystem: about: ws: wss: 'unsafe-inline' 'unsafe-eval'; script-src * data: blob: 'unsafe-inline' 'unsafe-eval';frame-src * data: blob: ; style-src * data: blob: 'unsafe-inline'; connect-src * data: blob: 'unsafe-inline';",
#  "default-src https: 'unsafe-inline' 'unsafe-eval' data:",
#  "upgrade-insecure-requests; frame-ancestors 'none'; object-src 'none'",
#  'block-all-mixed-content',
#  "default-src https: data: blob: 'self' 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self' <!URL!> data: blob:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data: blob:; style-src 'self' 'unsafe-inline' <!URL!>  data: blob:; frame-src 'self' <!URL!>; frame-ancestors 'self';img-src 'self' <!URL!> data: blob: ;media-src 'self' <!URL!> data: blob: ;font-src 'self' <!URL!> data: blob:",
#  "default-src 'self' <!URL!> blob:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; img-src <!URL!> 'self' data: blob: <!URL!> ;style-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; font-src  data: ; object-src 'self' <!URL!>; frame-src <!URL!> 'self' data: blob:; media-src <!URL!> blob:; worker-src <!URL!> blob:; connect-src wss: <!URL!> blob:; frame-ancestors 'self';",
#  "default-src http: data: 'unsafe-inline' 'unsafe-eval'",
#  "font-src 'self' ;",
#  "default-src 'self' <!URL!> ; script-src 'self' <!URL!> 'report-sample' 'unsafe-inline' 'unsafe-eval'; style-src 'self' <!URL!> 'unsafe-inline'; img-src * data:; font-src 'self' data: <!URL!> ; connect-src 'self' <!URL!> ; frame-src https: sberpay: sbolpay: <!URL!> ; report-uri <!URL!>",
#  "style-src 'self' blob: 'unsafe-inline' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: <!URL!> ; font-src 'self' <!URL!> data:  ; img-src * 'self' data: https: blob: <!URL!> ; default-src 'self' data: wss: <!URL!> ;",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; child-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ",
#  "default-src 'self' data: http: https: ws: wss:; script-src 'unsafe-inline' 'unsafe-eval' http: https: ; style-src 'unsafe-inline' 'unsafe-eval' http: https:;",
#  "default-src 'self' wss: https: data: 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self' ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; img-src 'self' data: <!URL!> ; frame-src 'self' <!URL!> ; frame-ancestors 'self' <!URL!> capacitor:<!URL!> capacitor:<!URL!>; font-src 'self' <!URL!> ; connect-src 'self' <!URL!> ;",
#  "default-src 'none'; script-src <!URL!> 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ; connect-src <!URL!> 'self' <!URL!> ; img-src data: <!URL!> 'self' <!URL!> ; style-src  'self' <!URL!> 'unsafe-inline' <!URL!> ; font-src data:  'self'; frame-ancestors <!URL!> 'self' <!URL!>; frame-src https: *; report-uri <!URL!>;",
#  "default-src 'self' 'unsafe-inline' <!URL!> wss:<!URL!> ; font-src 'self' data: ; object-src 'none'; style-src 'unsafe-inline' https:; base-uri 'self'; form-action 'self' ; frame-ancestors 'none'; upgrade-insecure-requests; frame-src 'self' data: <!URL!> ; img-src http: https: data:;",
#  "default-srd 'self';",
#  "object-src 'none'; form-action 'self'; frame-ancestors 'none'",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval'     <!URL!> blob: data:;",
#  "script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; connect-src 'self' data: <!URL!> wss:<!URL!> ws:<!URL!> ; style-src 'self' 'unsafe-inline' data: <!URL!> ; font-src 'self' data: <!URL!> ; prefetch-src 'self'; img-src 'self' blob: data: <!URL!> ; media-src 'self' <!URL!>; manifest-src 'self'",
#  "default-src 'self' 'unsafe-inline';frame-src 'self' 'unsafe-inline' mailto: tel: <!URL!> ;img-src 'self' 'unsafe-inline' blob: <!URL!> data:;style-src 'self' 'unsafe-inline'  ;font-src 'self' 'unsafe-inline' data: ; upgrade-insecure-requests; block-all-mixed-content;script-src-elem 'self' 'unsafe-inline' <!URL!> ;connect-src 'self' 'unsafe-inline' data: <!URL!> ;script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; child-src blob:; worker-src blob:;",
#  "upgrade-insecure-requests; block-all-mixed-content; default-src 'self'; connect-src 'self' <!URL!> wss://localhost:* <!URL!>; font-src 'self' <!URL!> data: <!URL!>; object-src 'none'; img-src 'self' * data:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> 'report-sample'; style-src 'self' 'unsafe-inline' <!URL!> ; media-src 'self' blob: <!URL!>; frame-ancestors 'self' <!URL!>; base-uri 'self'; frame-src 'self' <!URL!> ",
#  "report-uri /csp-report?p=; block-all-mixed-content; default-src 'none'; base-uri 'none'; img-src 'self' <!URL!> data:; style-src 'unsafe-inline' 'self' <!URL!>; connect-src 'self' <!URL!> blob: <!URL!> ; font-src 'self' <!URL!>; form-action 'self' ; frame-src 'self' <!URL!> ; media-src 'self' <!URL!> ; script-src 'self' <!URL!> 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default  'report-sample'; frame-ancestors 'self' <!URL!>",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'self'; worker-src blob 'self'; frame-ancestors 'self';",
#  "style-src 'self' 'unsafe-inline' <!URL!> ;",
#  "default-src * blob: data: cid:; img-src * data: blob: cid: 'unsafe-inline'; media-src * data: blob:; script-src * data: blob: 'unsafe-inline' 'unsafe-eval'; style-src * blob: data: 'unsafe-inline'; style-src-elem * blob: data: 'unsafe-inline', font-src * data:",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' data: *",
#  "script-src 'self' 'unsafe-eval' 'unsafe-inline'       <!URL!> ;            frame-ancestors 'self'       <!URL!> ;",
#  "default-src 'self' ; connect-src * data: https: <!URL!> ; script-src * 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data: https:; img-src * 'self' data: https: <!URL!> ; media-src * 'self' data: blob: https: <!URL!> ; style-src * 'self' 'unsafe-inline' 'unsafe-eval' data: https: <!URL!>;font-src * data: https:; frame-src * data: https: ; child-src blob:; worker-src 'self' blob:;",
#  "default-src 'self'; script-src <!URL!> @<!URL!> 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; style-src <!URL!> 'self' <!URL!> 'unsafe-inline'; img-src <!URL!> data: blob: <!URL!> 'self' <!URL!> ; font-src 'self' <!URL!> data:; frame-src <!URL!> 'self' <!URL!>; connect-src data: <!URL!> 'self' ; media-src 'self' data: blob:; child-src <!URL!> 'self' <!URL!>",
#  "frame-ancestors 'self'; form-action 'self'",
#  "img-src 'self' data:; default-src 'self' 'unsafe-inline'",
#  "default-src 'self'",
#  "base-uri 'self'; connect-src 'self' data: <!URL!> wss:<!URL!> ; default-src 'none'; manifest-src 'self'; font-src 'self' data: ; form-action 'self'; frame-ancestors 'self' <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; media-src <!URL!> ; object-src 'none'; script-src 'self' 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' ; upgrade-insecure-requests",
#  "connect-src https: 'self'; img-src 'self' data: <!URL!>; default-src blob: https: 'unsafe-inline' 'unsafe-eval'",
#  "style-src 'self' 'unsafe-inline' ;connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> ;script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;frame-src  'self' <!URL!> ;frame-ancestors 'self';font-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ",
#  "frame-ancestors <!URL!>; default-src 'none'; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ;  font-src 'self' <!URL!> ; object-src 'none'; style-src 'self' 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> ; img-src 'self' data: image/svg+xml <!URL!> ; frame-src 'self' <!URL!>; worker-src 'self'",
#  "default-src * 'unsafe-eval' 'unsafe-inline' data: filesystem: about: blob: ws: wss:; base-uri 'self'; frame-ancestors 'self';",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data: blob:;",
#  "default-src * blob: data: 'unsafe-inline' 'unsafe-eval'",
#  "default-src * 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;       script-src 'report-sample' 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;    style-src 'report-sample' 'self' 'unsafe-inline' 'unsafe-eval' blob: <!URL!> ;    object-src 'self' <!URL!> ;    base-uri 'self' <!URL!> ;    connect-src * 'self' data:  <!URL!> ;    font-src 'self' <!URL!> ;    frame-src * 'self' <!URL!> ;    img-src 'self' <!URL!> data: <!URL!> ;    manifest-src 'self' <!URL!> ;    media-src * 'self'",
#  "frame-ancestors 'self' ; default-src 'unsafe-inline' 'self' <!URL!> ; script-src 'self' blob: 'unsafe-inline' 'wasm-unsafe-eval' 'unsafe-eval' <!URL!> ; img-src 'self' blob: <!URL!> data:; connect-src 'self' blob: <!URL!> data:; font-src 'self' <!URL!> data:; frame-src 'self' <!URL!> ; child-src blob:",
#  "default-src https: <!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; font-src https: <!URL!> data: 'self' 'unsafe-inline' 'unsafe-eval'; img-src https: <!URL!> data: 'self' 'unsafe-inline' 'unsafe-eval'; script-src blob: https: 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; connect-src https: <!URL!> wss:<!URL!> wss:<!URL!>; frame-src https: 'self' blob: <!URL!> ; style-src blob: https: 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; media-src * blob: data: https:  'self' 'unsafe-inline' 'unsafe-eval';",
#  "default-src 'none';media-src 'self';style-src 'self' https: 'unsafe-inline' ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;  img-src 'self' data: <!URL!> ; ;connect-src 'self'  ;manifest-src 'self' <!URL!>; report-uri /csp_report_parser;",
#  "default-src 'self' https:; font-src 'self' https: data: <!URL!>; img-src 'self' https: data: blob: ; object-src 'none'; script-src 'self' https: 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' https: 'unsafe-inline'  data:; connect-src 'self' https: data: blob: <!URL!>",
#  "object-src 'none'; report-uri /report-csp-violation; upgrade-insecure-requests",
#  "img-src * data:; script-src * 'unsafe-inline' 'unsafe-eval';worker-src blob:;",
#  "default-src 'self'; script-src 'self' 'unsafe-inline' <!URL!> ; object-src 'self'; style-src 'self' 'unsafe-inline' <!URL!>; img-src 'self' <!URL!> data:; media-src 'self'; frame-src 'self' <!URL!>; frame-ancestors 'self'; child-src 'self'; font-src 'self' <!URL!>; connect-src 'self' <!URL!> ; report-uri /report-csp-violation; upgrade-insecure-requests",
#  "default-src 'none'; script-src 'self'  'unsafe-inline' <!URL!> 'unsafe-inline' 'unsafe-eval' ; worker-src 'self' blob: ; frame-src <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> data: <!URL!> ; media-src 'self' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> blob: * ; frame-ancestors 'self' ; manifest-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; upgrade-insecure-requests; block-all-mixed-content; report-uri <!URL!>; base-uri 'self'",
#  "default-src 'self' https:;                                              connect-src 'self' https:;                                              font-src 'self' https: data:;                                              frame-src 'self' https:;                                              img-src 'self' https: data:; media-src 'self' https:;                                              object-src 'self' https:;                                              script-src 'self' 'unsafe-inline' 'unsafe-eval' https:;                                              style-src 'self' 'unsafe-inline' https:;",
#  "default-src 'self' ;script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: <!URL!> ;style-src 'self' 'unsafe-inline' <!URL!> ;img-src 'self' data:  <!URL!> ;font-src 'self'   data:;connect-src 'self' <!URL!> ;frame-src <!URL!> ;media-src 'self' blob: <!URL!> ;worker-src blob:;report-uri <!URL!>",
#  "default-src 'self' ; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' <!URL!> 'unsafe-inline' <!URL!> ; img-src 'self' <!URL!> data: blob: <!URL!> ; font-src 'self' <!URL!> data:; frame-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; media-src 'self' data: blob: ; child-src 'self' <!URL!> ; object-src <!URL!> 'self'",
#  "default-src 'self' https:; connect-src https: wss:; font-src 'self' https: data:; frame-src 'self' https: data:; img-src 'self' https: data:; media-src 'self' https: blob:; object-src 'none'; script-src https: 'unsafe-inline' 'unsafe-eval'; style-src 'self' https: 'unsafe-inline'",
#  "default-src 'self'; script-src 'self' 'report-sample' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'none'; style-src 'self' 'report-sample' 'unsafe-inline' <!URL!> ; img-src 'self' data: <!URL!> ; media-src 'self' data:; frame-src 'self' <!URL!> ; frame-ancestors 'self'; child-src 'self' <!URL!> 'self' <!URL!> ; font-src 'self' data: ; connect-src 'self' <!URL!> ; report-uri <!URL!>; upgrade-insecure-requests; base-uri 'self'; form-action 'self'; manifest-src 'self'; worker-src 'self'",
#  "default-src 'self' <!URL!> ;base-uri 'self';font-src 'self' <!URL!> https: data:;form-action 'self';frame-ancestors 'self';img-src 'self' data: <!URL!> ;connect-src 'self'  wss:<!URL!> ;script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ;script-src-attr 'none';style-src 'self' <!URL!> https: 'unsafe-inline';upgrade-insecure-requests",
#  "frame-ancestors <!URL!>; base-uri 'self'; object-src 'self'; media-src 'self' <!URL!>; font-src 'self'; frame-src 'self' <!URL!> ; form-action 'self'; img-src 'self' data: <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> ",
#  "frame-ancestors 'self' <!URL!> ;object-src 'none';",
#  "script-src 'self' <!URL!> ;style-src 'self' <!URL!> 'unsafe-inline';",
#  "default-src 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> ; font-src 'self' data: <!URL!> ; img-src 'self' data: blob: <!URL!> ; media-src 'self' <!URL!>; object-src 'none'; upgrade-insecure-requests; block-all-mixed-content; frame-src 'self' <!URL!> ;",
#  "object-src 'self'; frame-ancestors 'self'",
#  "default-src 'self' <!URL!> ; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; style-src http: https: data: 'unsafe-inline'; img-src blob: http: https: data:; frame-src http: https:; font-src http: https: data:; connect-src 'self' <!URL!> wss:<!URL!> ; report-uri <!URL!>; report-to livejournal; media-src http: https: data: <!URL!>; frame-ancestors 'self'; worker-src 'self' blob:; object-src 'self' blob: ; child-src 'self' blob:;",
#  "default-src 'self' 'unsafe-inline' ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; img-src 'self' 'unsafe-inline' <!URL!> data: <!URL!> ; media-src 'self' <!URL!> blob:; frame-src <!URL!> ; frame-ancestors 'self' <!URL!> ; child-src <!URL!> ; font-src 'self' <!URL!> data: <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ; upgrade-insecure-requests",
#  "upgrade-insecure-requests; report-to endpoint; report-uri <!URL!>; default-src 'self' ;base-uri 'self';form-action 'self' <!URL!> ;frame-ancestors 'self';connect-src *;font-src 'self' <!URL!> data:;frame-src 'self' <!URL!> ;child-src 'self' <!URL!> ;img-src 'self' <!URL!> data:;object-src 'none';script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' data:;style-src 'self' <!URL!> 'unsafe-inline';worker-src 'self' blob:;",
#  "default-src <!URL!> 'unsafe-inline' 'unsafe-eval' blob: data: 'self' <!URL!> ;",
#  "base-uri 'self'; report-uri <!URL!>; script-src 'unsafe-inline' 'unsafe-eval' 'self' <!URL!> ; object-src 'none';",
#  'frame-ancestors <!URL!>',
#  "upgrade-insecure-requests; frame-ancestors 'self' <!URL!>",
#  "default-src *; style-src * 'unsafe-inline'; script-src * 'unsafe-inline' 'unsafe-eval'; img-src * data: 'unsafe-inline'; connect-src * 'unsafe-inline'; frame-src *;",
#  "font-src 'self' data: <!URL!> ; style-src-elem 'self' 'unsafe-inline' <!URL!> ; style-src 'unsafe-inline' <!URL!> ; script-src-elem 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src-attr 'unsafe-inline'; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!>; default-src 'self' 'unsafe-eval' <!URL!> ; form-action 'self'; script-src-attr 'unsafe-eval';",
#  "upgrade-insecure-requests; block-all-mixed-content; default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data: blob: <!URL!> wss:<!URL!> ; child-src 'self' <!URL!> blob: <!URL!> ; connect-src 'self' blob: <!URL!> wss:<!URL!> wss:<!URL!> ; object-src none;",
# ...
#  "default-src https:; script-src https: data: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline'; img-src https: data: blob:; media-src https: data: blob:; font-src https: data:; connect-src https: wss:; worker-src 'self' blob:",
#  "default-src https: 'unsafe-eval' 'unsafe-inline'; object-src https: ; child-src https: <!URL!>; img-src https: data:; ",
#  "img-src 'self' <!URL!> data: <!URL!> ;connect-src 'self' <!URL!> ;object-src 'none';media-src 'self' <!URL!> data:;child-src *;frame-src *;form-action <!URL!> 'self';frame-ancestors 'self' <!URL!> ;upgrade-insecure-requests;worker-src 'self' <!URL!>",
#  "default-src 'self' <!URL!> ; script-src 'self' 'unsafe-inline' blob: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; object-src 'none'; base-uri 'self'; connect-src 'self' <!URL!> wss:<!URL!>; font-src 'self' data: <!URL!> ; frame-src 'self' <!URL!> ; frame-ancestors 'self' ; img-src 'self' data: <!URL!> blob: content: <!URL!> ; manifest-src 'self'; media-src 'self' <!URL!>; worker-src 'self' blob:; child-src blob:;",
#  'same-origin',
#  "default-src 'none'; base-uri 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!>; object-src 'none'; style-src 'self' data: 'unsafe-inline' <!URL!>; img-src 'self' blob: data: <!URL!>; media-src 'self' data: <!URL!>; frame-src *; font-src *; form-action 'self' <!URL!>; connect-src 'self' <!URL!>; prefetch-src 'self' <!URL!>; manifest-src 'self' <!URL!>; frame-ancestors 'self'; report-uri <!URL!>",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> data: <!URL!> ; img-src https: data:; report-uri /api/six/cspreport; report-to csp-endpoint;",
#  "default-src 'self' ;img-src https: data:;style-src 'self' <!URL!> 'unsafe-inline';connect-src 'self' ;frame-src 'self' <!URL!> data:;script-src 'self' <!URL!> ;font-src https: data:",
#  "frame-src 'self' <!URL!> ",
#  "base-uri 'self'; default-src wss: <!URL!> 'self' blob: data: <!URL!> ; frame-src <!URL!> 'self' blob: <!URL!> ; img-src <!URL!> 'self' blob: data: <!URL!> ; script-src 'unsafe-eval' <!URL!> 'self' 'unsafe-inline' blob: <!URL!> ; style-src <!URL!> 'self' blob: 'unsafe-inline' <!URL!> data:; object-src ; script-src-elem <!URL!> 'unsafe-inline';",
#  "default-src 'self' <!URL!> ; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; style-src 'self' <!URL!> 'unsafe-inline'; frame-ancestors 'self' ; frame-src <!URL!> ; object-src 'none'; base-uri 'self'; form-action 'self' <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> ; font-src 'self' data: <!URL!> ; media-src <!URL!> ; img-src https: data:; report-uri <!URL!>",
#  "frame-ancestors 'self'; report-uri /report-csp-violation; upgrade-insecure-requests",
#  "default-src * blob: data:; script-src * 'unsafe-inline' 'unsafe-eval'; style-src * 'unsafe-inline'; worker-src 'self' blob:;",
#  "default-src 'self' https: data: 'unsafe-inline' 'unsafe-eval', script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> , img-src 'self' data: <!URL!> , style-src 'self' 'unsafe-inline' <!URL!>, base-uri 'self', form-action 'self'",
#  "upgrade-insecure-requests; frame-ancestors 'self'",
#  "base-uri 'self'; object-src 'none'; frame-ancestors 'self';",
#  "default-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!>;    script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ;    connect-src 'self' <!URL!> wss: wss:<!URL!>;    style-src 'self' 'unsafe-inline' <!URL!>;    img-src 'self'  blob: data:;    media-src 'self' <!URL!>;    font-src 'self'  data:;    object-src 'none';    base-uri 'self';    form-action 'self';    frame-ancestors 'none';    frame-src <!URL!>;    upgrade-insecure-requests;",
#  "default-src 'self' 'unsafe-inline' https:",
#  "default-src 'self'; frame-src 'self' ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; img-src 'self' <!URL!> data:; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; form-action 'self'; frame-ancestors 'self'; base-uri 'self' <!URL!>;",
#  "default-src 'self'; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' <!URL!> 'unsafe-inline' <!URL!> ; img-src 'self' <!URL!> data: blob: <!URL!> * <!URL!> ; font-src 'self' <!URL!> data: <!URL!> ; frame-src 'self' <!URL!> * <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:; media-src 'self' data: blob: <!URL!>; child-src 'self' blob: <!URL!> ; frame-ancestors 'self' <!URL!> ",
#  "upgrade-insecure-requests; frame-ancestors 'self' ;",
#  "frame-ancestors 'self'; object-src 'none';",
#  "default-src * 'self' data: 'unsafe-inline' 'unsafe-hashes' 'unsafe-eval'",
#  "default-src https: data: 'unsafe-inline' 'unsafe-eval';frame-ancestors 'self'",
#  "default-src 'self'  'unsafe-inline' 'unsafe-eval' data:;",
#  "default-src 'self' ; worker-src 'self' blob:; object-src 'self'; frame-ancestors 'self' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' data: <!URL!> ; connect-src 'self' data: <!URL!> ; img-src 'self' data: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> data:; frame-src 'self' <!URL!> *;",
#  "default-src 'self'; font-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; object-src 'none'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; child-src 'self' <!URL!> ; connect-src 'self' <!URL!> ;",
#  "default-src *; script-src * 'unsafe-eval' 'unsafe-inline' data: 'self'; style-src * 'unsafe-inline' 'self'; img-src * data:; font-src * data:; connect-src *; object-src *; frame-ancestors 'self' <!URL!> ; style-src-attr 'unsafe-inline'; style-src-elem * 'unsafe-inline'; script-src-elem * 'unsafe-inline'; report-uri <!URL!>",
#  "upgrade-insecure-requests; form-action 'self'; frame-ancestors 'self'; object-src 'none'; base-uri 'none'; prefetch-src 'self'",
#  'upgrade-insecure-requests',
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' https:",
#  "default-src 'self' <!URL!> ; script-src 'self' <!URL!> ; style-src 'self'  'unsafe-inline'; object-src 'none'; base-uri 'none'; connect-src 'self' https:; media-src 'self' https:; img-src 'self' http: https: data:;",
#  "img-src: 'self'; style-src: 'self'; script-src: 'self' <!URL!> ; font-src: 'self' <!URL!>;",
#  "default-src https: data: 'unsafe-inline' 'unsafe-eval'; frame-ancestors 'self'",
#  "default-src 'self' <!URL!> ; script-src 'self' <!URL!> ; style-src 'self' <!URL!> 'unsafe-inline'; base-uri 'self'; frame-ancestors 'self' <!URL!> ; upgrade-insecure-requests",
#  "default-src 'none'; img-src 'self' https: data:; script-src 'self' 'unsafe-inline' 'unsafe-eval' https:; style-src 'self' 'unsafe-inline' https:; font-src 'self' https:; connect-src 'self' https:; media-src <!URL!> blob:; worker-src blob:",
#  "default-src *; img-src * 'self' data: https: blob:; script-src 'self' 'unsafe-inline' 'unsafe-eval' *; style-src  'self' 'unsafe-inline' *; font-src * 'self' data:; worker-src 'self' blob:; child-src blob:; frame-src *; frame-ancestors 'self' <!URL!>",
#  "require-trusted-types-for 'script'",
#  "frame-ancestors 'self' <!URL!>;default-src 'self' 'unsafe-eval' 'unsafe-inline' blob: <!URL!> data:;",
#  "default-src 'self' <!URL!> https: wss: data: blob:; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' blob:; style-src 'self' data: blob: <!URL!> 'unsafe-inline'; worker-src 'self' blob:; frame-ancestors 'self' <!URL!> ;",
#  "default-src * data: blob: 'unsafe-eval' 'unsafe-inline'",
#  "frame-ancestors 'self' base-uri 'self' font-src 'self' default-src 'self'; script-src 'self'; style-src 'self' 'unsafe-inline'; child-src 'self'; img-src 'self'; frame-src 'self'; connect-src 'self'; object-src 'self'; media-src 'self'; form-action 'self'; report-to 'self';",
#  "upgrade-insecure-requests;frame-ancestors 'self' <!URL!>",
#  'upgrade-insecure-requests; frame-ancestors <!URL!> ',
#  "base-uri 'self';default-src 'self';object-src 'self';frame-ancestors 'self';style-src 'self' 'unsafe-inline' <!URL!> ;font-src 'self' data:;img-src 'self' data: blob: https:;script-src 'self' <!URL!> 'nonce-d-1ea172e8-60-4e2e-81ce-dc196d99f802' 'nonce-g-4e91d30a-038f-482f-a761-b60' 'nonce-h-f60d8-60-4a89-b43e-60f60d0' 'nonce-b-d60a2-a0e0-4d3e-b43b-ce60f2bf58';child-src 'self' data: https:;frame-src 'self' data: https:;connect-src 'self' <!URL!> wss:<!URL!> ;",
#  "default-src 'self'; connect-src *; font-src 'self' data:; frame-src *; img-src data: *; media-src *; object-src *; script-src 'self' 'unsafe-eval' 'unsafe-inline' *; style-src 'self' 'unsafe-inline';",
#  'always',
#  "default-src data: wss: blob: 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ",
#  "default-src * data: 'unsafe-eval' 'unsafe-inline';",
#  "default-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> wss:<!URL!> ; img-src * data:; font-src 'self' data: <!URL!>;",
#  "object-src 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src * 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self' https: data: blob: <!URL!> ; object-src 'none'; connect-src 'self' https: data: blob: <!URL!> wss:<!URL!> ; script-src 'unsafe-inline' 'unsafe-eval' 'self' https: data: blob: <!URL!> ; img-src 'self' https: data: blob: <!URL!> ; style-src 'unsafe-inline' 'self' https: data: blob: <!URL!> ; frame-src https: <!URL!> ",
#  'object-src * ; report-uri <!URL!>',
#  "default-src https: data: 'unsafe-inline' 'unsafe-eval';connect-src 'self'  ws: wss: <!URL!> ;",
#  "default-src 'self'; child-src 'self' ; connect-src 'self' <!URL!> ; font-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' @<!URL!> ; script-src-attr 'unsafe-inline'; script-src-elem 'self' 'unsafe-inline' <!URL!> @@<!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; style-src-elem 'self' 'unsafe-inline' <!URL!> ;;",
#  "default-src 'self' 'unsafe-eval' http: https: data: blob: 'unsafe-inline'",
#  "default-src 'self' 'unsafe-inline' ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self'  data: ; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; connect-src 'self' 'unsafe-inline' <!URL!> ; media-src 'self' 'unsafe-inline' <!URL!> ; frame-ancestors 'self' <!URL!>",
#  'upgrade-insecure-requests; block-all-mixed-content',
#  "frame-ancestors 'self' <!URL!> cmsp <!URL!> ",
#  "default-src 'self' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!>; img-src 'self' <!URL!> data:; connect-src 'self' <!URL!> ; font-src 'self' <!URL!>; script-src 'self' <!URL!> 'unsafe-eval' 'unsafe-inline'; frame-src 'self' ;",
#  "default-src * https: data: blob: wss: 'unsafe-inline'",
#  "font-src https: data: blob:; frame-ancestors 'self' <!URL!> ; img-src https: data: blob:; default-src https: data: blob: wss:; script-src https: blob: 'unsafe-inline' 'unsafe-eval'; style-src https: blob: 'unsafe-inline';",
#  "frame-ancestors 'self', object-src 'none', base-uri 'self'",
#  "default-src 'self' <!URL!> ; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; script-src-elem 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; style-src 'self' <!URL!> 'unsafe-inline'; style-src-elem 'self' <!URL!> 'unsafe-inline'; connect-src 'self' <!URL!> data:; font-src 'self' <!URL!> data:; img-src 'self' <!URL!> data:; child-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; base-uri 'self'; report-uri <!URL!>",
#  "frame-ancestors 'none'",
#  "frame-src 'self' ; frame-ancestors 'self' <!URL!> ; object-src 'none';",
#  "default-src *; font-src * data:;img-src * data:;frame-src * data:; script-src * 'unsafe-inline'; style-src * 'unsafe-inline';",
#  "script-src * 'self' 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self' <!URL!>; style-src 'self' 'unsafe-inline' <!URL!> ; object-src 'none'; base-uri 'self'; connect-src 'self' <!URL!> ; font-src 'self' data: <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; manifest-src 'self' <!URL!> ; media-src 'self' <!URL!>; frame-ancestors 'self' <!URL!>; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;",
#  "report-uri /csp; child-src 'self'; connect-src *; default-src 'self'; img-src 'self' data: <!URL!> ; font-src 'self' data: ; object-src 'self'; media-src 'self' <!URL!>; manifest-src 'self' 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' 'self' <!URL!> ; style-src 'self' 'unsafe-inline' blob: ; frame-ancestors 'self' <!URL!> ; frame-src <!URL!> ",
#  "default-src data: blob: 'unsafe-inline' 'self' ",
#  "default-src 'self' <!URL!>; connect-src 'self'  <!URL!> ws:<!URL!> ws:<!URL!> ws://localhost:60/ ws:<!URL!> ws:<!URL!> ; font-src 'self' <!URL!> data://* data: <!URL!> ; form-action 'self' <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; media-src 'self' blob: <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval'  <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; worker-src 'self' blob: <!URL!>; report-uri ;",
#  '"unsafe-inline";',
#  "script-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' ; font-src <!URL!>;",
#  "default-src  * 'unsafe-inline' 'unsafe-eval' ; img-src * blob: data: 'unsafe-inline' ; font-src * data: 'unsafe-inline' ; media-src * blob: 'unsafe-inline' ; frame-src * data: 'unsafe-inline' 'unsafe-eval' ;",
#  "default-src 'self' http: https: ws: wss: data: blob: 'unsafe-inline'; frame-ancestors 'self';",
#  "frame-ancestors 'self';",
#  "default-src 'none'; base-uri 'self'; child-src ; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!>; font-src <!URL!>; form-action 'self' <!URL!> ; frame-ancestors 'none'; frame-src ; img-src 'self' data: <!URL!> ; manifest-src 'self'; media-src <!URL!> ; script-src <!URL!>; style-src 'unsafe-inline' <!URL!>; upgrade-insecure-requests; worker-src ",
#  "report-uri <!URL!>; upgrade-insecure-requests;  script-src 'self' 'unsafe-inline' <!URL!> ;  img-src 'self' data: <!URL!> ;  connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ;",
#  "frame-ancestors 'self'; upgrade-insecure-requests; frame-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; img-src 'self' <!URL!> data:; script-src <!URL!> 'self' 'unsafe-eval' 'unsafe-inline';",
#  "default-src https: data: wss: blob: 'unsafe-inline' 'unsafe-eval' ;  object-src 'none' ;  frame-ancestors 'self' ;  base-uri 'self' ;  prefetch-src 'self' ;  img-src https: data: ;",
#  "default-src https:; script-src https: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline'; img-src https: data:;",
#  "default-src 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; img-src * 'self' data: <!URL!> ; media-src blob: data: <!URL!>; frame-src 'self'  data: <!URL!> ; frame-ancestors 'self'; child-src 'self' blob:; font-src 'self' <!URL!> data: ; connect-src 'self' <!URL!> ; report-uri /report-csp-violation; upgrade-insecure-requests",
#  "'self' ;",
#  "default-src <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' blob: asset: <!URL!> 'report-sample'; img-src 'self' data: blob: <!URL!> blob: <!URL!> 'report-sample'; style-src 'self' blob: 'unsafe-inline' ; object-src 'self' ; connect-src 'self' wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss: blob: <!URL!> ; form-action 'self' <!URL!> 'report-sample'; child-src 'self' blob: <!URL!> ; font-src 'self' data: blob: <!URL!> ; frame-src 'self' <!URL!> ; worker-src 'self' blob:; media-src 'self' data: blob: <!URL!>; frame-ancestors 'self' <!URL!> ; base-uri 'self' <!URL!> ; manifest-src blob: 'self' <!URL!> ; report-uri /gd/rest/jslog/csp",
#  "default-src * data: blob: 'unsafe-inline' 'unsafe-eval'; frame-ancestors 'self' <!URL!>;",
#  "default-src 'unsafe-inline' 'unsafe-eval' https: data:; block-all-mixed-content; upgrade-insecure-requests",
#  "default-src * 'unsafe-inline' 'unsafe-eval' data: blob:; report-uri <!URL!>;",
#  "frame-ancestors 'self' <!URL!> ; upgrade-insecure-requests",
#  ...]

# %%
label = "XFO"
header_name = "x-frame-options"
alt_names = ["frame-options", "x-frame-option", "x-frames-options", "content-security-policy", "x_frame_options", "xframeoptions"]
block_values = ["DENY"]
allow_values = ["ALLOWALL"] # This value does not really exist but has some special meaning for processing multiple values (https://html.spec.whatwg.org/multipage/document-lifecycle.html#the-x-frame-options-header)
partial_values = ["SAMEORIGIN"]
legacy_values = [f"ALLOW-FROM {origin_s}"]

# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/x-frame-options?label=master&label=experimental&aligned&q=x-frame
wpt_values = get_wpt_values('../../../x-frame-options/')
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'X-Frame-Options: (.*?)\'")
# https://crawler.ninja/files/xfo-values.txt
crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/xfo-values.txt")
own_values = []
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
xfo_all = block_values + allow_values + partial_values + legacy_values + other_values
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 4705
# Created: 4596
# [([('x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-option', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frames-options', 'DENY')], 'XFO', 200, 'parsing'), ([('content-security-policy', 'DENY')], 'XFO', 200, 'parsing')]

# %%
label = "CSP-FA"
header_name = "content-security-policy"
alt_names = ["x-content-security-policy", "x-webkit-csp", "x-webkit-content-security-policy"]
block_values = ["frame-ancestors 'none'"]
allow_values = ["frame-ancestors *"]
partial_values = ["frame-ancestors 'self'"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/content-security-policy/frame-ancestors?label=master&label=experimental&aligned&q=frame
wpt_values = ["frame-ancestors 'none'", "frame-ancestors 'self'", "frame-ancestors *", f"frame-ancestors {URL_REP}"]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'Content-Security-Policy: (.*?)\'")
# https://crawler.ninja/files/csp-values.txt
crawler_ninja_values = []
# Note: add crawler_ninja_values, Problem: Too many? Many are very similar and URL replacement results in a massive number of values
# crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/csp-values.txt", min_count=2)
own_values = ["default-src 'none'", "self", "*", "frame-ancestors self", "frame-ancestors", "frame-ancestors none", "frame-src none", "frame-ancestors 'null'", "frame-ancestors null"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
csp_fa_all = block_values + allow_values + partial_values + legacy_values + other_values
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 2759
# Created: 2744
# [([('content-security-policy', "frame-ancestors 'none'")], 'CSP-FA', 200, 'parsing'), ([('x-content-security-policy', "frame-ancestors 'none'")], 'CSP-FA', 200, 'parsing'), ([('x-webkit-csp', "frame-ancestors 'none'")], 'CSP-FA', 200, 'parsing'), ([('x-webkit-content-security-policy', "frame-ancestors 'none'")], 'CSP-FA', 200, 'parsing'), ([('content-sec\x12urity-policy', "frame-ancestors 'none'")], 'CSP-FA', 200, 'parsing')]

# %%
# CORS: fix all header except one, only mutate/rotate this one header

# https://wpt.fyi/results/cors?label=master&label=experimental&aligned&q=cors
wpt_values = [] # Nothing parsing related?
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # Difficult to extract
# https://crawler.ninja/files/acao-values.txt
crawler_ninja_values = [] # Only ACAO and mostly different origins

label = "CORS"
alt_names = []
full_base_resp = [("Test", "Test"), ("access-control-allow-origin", origin_s), ("access-control-allow-credentials", "true"), ("access-control-allow-methods", "TEST"), ("access-control-allow-headers", "Test"), ("access-control-expose-headers", "Test")]


# ACAO
label = "CORS-ACAO"
header_name = "access-control-allow-origin"
base_resp = [tup for tup in full_base_resp if tup[0] != header_name]
block_values = ["null"]
allow_values = ["*"] 
partial_values = [origin_s]
legacy_values = []
basic_values = ["", "INVALID", "null", "*", "Test", "true", "?1", "?0", "TEST", "test", "false", "https://", "//", URL_REP]
other_values = expand_urls(basic_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values, base_resp)
ht.create_all_tests()

# ACAC
label = "CORS-ACAC"
header_name = "access-control-allow-credentials"
base_resp = [tup for tup in full_base_resp if tup[0] != header_name]
block_values = []
allow_values = ["true"] 
partial_values = []
legacy_values = []
basic_values = ["", "INVALID", "null", "*", "Test", "true", "?1", "?0", "TEST", "test", "false", "https://", "//", URL_REP]
other_values = expand_urls(basic_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values, base_resp)
ht.create_all_tests()

# ACAM, ACAH, ACEH
for header_name in ["access-control-allow-methods", "access-control-allow-headers", "access-control-expose-headers"]:
    label = f"CORS-{''.join([h[0].upper() for h in header_name.split('-')])}"
    base_resp = [tup for tup in full_base_resp if tup[0] != header_name]
    block_values = []
    allow_values = ["*"] 
    if "methods" in header_name:
        partial_values = ["TEST"]
    else:
        partial_values = ["Test"]
    legacy_values = []
    basic_values = ["", "INVALID", "null", "*", "Test", "true", "?1", "?0", "TEST", "test", "false", "https://", "//", URL_REP]
    other_values = expand_urls(basic_values)
    ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values, base_resp)
    ht.create_all_tests()
# Out:
# 2480
# Created: 2465
# [([('access-control-allow-origin', 'null'), ('Test', 'Test'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAO', 200, 'parsing'), ([('access-control-allow-origino', 'null'), ('Test', 'Test'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAO', 200, 'parsing'), ([('iaccess-control-allow-origin', 'null'), ('Test', 'Test'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAO', 200, 'parsing'), ([('access-control-allow-originM', 'null'), ('Test', 'Test'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAO', 200, 'parsing'), ([('access-control-allow-originG', 'null'), ('Test', 'Test'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAO', 200, 'parsing')]
# 874
# Created: 864
# [([('access-control-allow-credentials', 'true'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAC', 200, 'parsing'), ([('access-control-allow-credentials`', 'true'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAC', 200, 'parsing'), ([('access-control-allow-credentials\x1a', 'true'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAC', 200, 'parsing'), ([('access-control-allow-credentialsH', 'true'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAC', 200, 'parsing'), ([('access-control-allow-credentialsd', 'true'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAC', 200, 'parsing')]
# 1586
# Created: 1576
# [([('access-control-allow-methods', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAM', 200, 'parsing'), ([('Naccess-control-allow-methods', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAM', 200, 'parsing'), ([('access-control~-allow-methods', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAM', 200, 'parsing'), ([('access-control-allow-methods\x01', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAM', 200, 'parsing'), ([('access-control-allow-methodsT', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-headers', 'Test'), ('access-control-expose-headers', 'Test')], 'CORS-ACAM', 200, 'parsing')]
# 1587
# Created: 1577
# [([('access-control-allow-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-expose-headers', 'Test')], 'CORS-ACAH', 200, 'parsing'), ([('zaccess-control-allow-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-expose-headers', 'Test')], 'CORS-ACAH', 200, 'parsing'), ([('access-control\xa0a-allow-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-expose-headers', 'Test')], 'CORS-ACAH', 200, 'parsing'), ([(' access-control-allow-headers ', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-expose-headers', 'Test')], 'CORS-ACAH', 200, 'parsing'), ([('\taccess-control-allow-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-expose-headers', 'Test')], 'CORS-ACAH', 200, 'parsing')]
# 1587
# Created: 1577
# [([('access-control-expose-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test')], 'CORS-ACEH', 200, 'parsing'), ([('\x18access-control-expose-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test')], 'CORS-ACEH', 200, 'parsing'), ([('access-control-expose-headers<', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test')], 'CORS-ACEH', 200, 'parsing'), ([('access-control\x11-expose-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test')], 'CORS-ACEH', 200, 'parsing'), ([('Daccess-control-expose-headers', '*'), ('Test', 'Test'), ('access-control-allow-origin', 'https://sub.headers.websec.saarland'), ('access-control-allow-credentials', 'true'), ('access-control-allow-methods', 'TEST'), ('access-control-allow-headers', 'Test')], 'CORS-ACEH', 200, 'parsing')]

# %%
label = "CORP"
header_name = "cross-origin-resource-policy"
alt_names = ["from-origin", "x-cross-origin-resource-policy"]
block_values = [""]
allow_values = ["cross-origin"]
partial_values = ["same-site", "same-origin"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/fetch/cross-origin-resource-policy?label=master&label=experimental&aligned&q=cross-origin-resource-policy
wpt_values = ["same", "same, same-origin", "SAME-ORIGIN", "Same-Origin", "same-origin, <>", "same-origin, same-origin", URL_REP]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # No CORP tested
# https://crawler.ninja/files
crawler_ninja_values = [] # No CORP tested
own_values = ["unsafe-none"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 3393
# Created: 3357
# [([('cross-origin-resource-policy', '')], 'CORP', 200, 'parsing'), ([('from-origin', '')], 'CORP', 200, 'parsing'), ([('x-cross-origin-resource-policy', '')], 'CORP', 200, 'parsing'), ([('cross`origin`resource`policy', '')], 'CORP', 200, 'parsing'), ([('cross-origin-resource-policyf', '')], 'CORP', 200, 'parsing')]

# %%
label = "COEP"
header_name = "cross-origin-embedder-policy"
alt_names = ["x-cross-origin-embedder-policy"]
block_values = ["require-corp"]
allow_values = ["unsafe-none"]
partial_values = ["credentialless"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/html/cross-origin-embedder-policy?label=master&label=experimental&aligned&q=cross-origin-embedder-policy
wpt_values =   ['jibberish', 'require%FFcorp', 'require-corp;', '\u000brequire-corp\u000b', '\u000crequire-corp\u000c', '\u000drequire-corp\u000d', 'Require-corp', '"require-corp"', ':cmVxdWlyZS1jb3Jw:', 'require-corp;\tfoo=bar', 'require-corp require-corp', 'require-corp,require-corp', 'require-corp', ' require-corp ', '\trequire-corp\t', ' \trequire-corp', 'require-corp\t ', 'require-corp; foo=bar', 'require-corp;require-corp', 'require-corp; report-to="data:']
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # No COEP tested
# https://crawler.ninja/files
crawler_ninja_values = [] # No COEP tested
own_values = ["cross-origin", "same-origin"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 2650
# Created: 2637
# [([('cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('x-cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-elmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policyW', 'require-corp')], 'COEP', 200, 'parsing'), ([('  cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing')]

# %%
label = "COOP"
header_name = "cross-origin-opener-policy"
alt_names = ["x-cross-origin-opener-policy"]
block_values = []
allow_values = ["unsafe-none"]
partial_values = ["same-origin", "same-origin-allow-popups"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/html/cross-origin-opener-policy?label=master&label=experimental&aligned&q=cross-origin-opener-policy
wpt_values =   ["same-origin;", "\u000bsame-origin\u000b", "\u000csame-origin\u000c", "\u000dsame-origin\u000d", "Same-origin", "same-origin;\tfoo=bar", "same-origin ;foo=bar", "same-origin; foo=bar;", "\"same-origin\"", ":c2FtZS1vcmlnaW4=:", "?1", "1", "$same-origin",  "same-origin same-origin", "same-origin\\,same-origin", "*same-origin ", "same%FForigin", " same-origin", "same-origin ", "\tsame-origin", "same-origin\t", "same-origin;same-origin", "same-origin; foo=bar"]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # No COOP tested
# https://crawler.ninja/files
crawler_ninja_values = [] # No COOP tested
own_values = ["cross-origin", "same-origin", "same-origin-plus-COEP"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 2673
# Created: 2656
# [([('cross-origin-opener-policy', 'unsafe-none')], 'COOP', 200, 'parsing'), ([('x-cross-origin-opener-policy', 'unsafe-none')], 'COOP', 200, 'parsing'), ([('cross-origin-yopener-policy', 'unsafe-none')], 'COOP', 200, 'parsing'), ([('cross-origin-opener-policy ', 'unsafe-none')], 'COOP', 200, 'parsing'), ([('cross-origin-opener-policyw', 'unsafe-none')], 'COOP', 200, 'parsing')]

# %%
label = "CSP-SCRIPT"
header_name = "content-security-policy"
alt_names = ["x-content-security-policy", "x-webkit-csp", "x-webkit-content-security-policy"]
block_values = ["script-src 'none'"]
allow_values = ["script-src *"]
partial_values = ["script-src 'self'"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/content-security-policy?label=master&label=experimental&aligned&q=script-src
wpt_values = [] # Tests are more related to correct ordering and co and not parsing?
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # not tested
# https://crawler.ninja/files/csp-values.txt
crawler_ninja_values = []
# NOTE: maybe add crawler_ninja_values, Problem: Too many? Many are very similar and URL replacement results in a massive number of values
# crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/csp-values.txt")
own_values = ["default-src 'none'", "self", "*", "script-src self", "script-src", "script-src none", "script-src none", "script-src 'null'", "script-src null", f"script-src-elem {URL_REP}", f"script-src-attr {URL_REP}"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 2739
# Created: 2726
# [([('content-security-policy', "script-src 'none'")], 'CSP-SCRIPT', 200, 'parsing'), ([('x-content-security-policy', "script-src 'none'")], 'CSP-SCRIPT', 200, 'parsing'), ([('x-webkit-csp', "script-src 'none'")], 'CSP-SCRIPT', 200, 'parsing'), ([('x-webkit-content-security-policy', "script-src 'none'")], 'CSP-SCRIPT', 200, 'parsing'), ([('content-sec\x12urity-policy', "script-src 'none'")], 'CSP-SCRIPT', 200, 'parsing')]

# %%
label = "CSP-IMG"
header_name = "content-security-policy"
alt_names = ["x-content-security-policy", "x-webkit-csp", "x-webkit-content-security-policy"]
block_values = ["img-src 'none'"]
allow_values = ["img-src *"]
partial_values = ["img-src 'self'"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/content-security-policy?label=master&label=experimental&aligned&q=img-src
wpt_values = ["img-src 'none'", "img-src 'self'", "img-src *", f"img-src {URL_REP}"]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # Not tested
# https://crawler.ninja/files/csp-values.txt
crawler_ninja_values = []
# NOTE: maybe add crawler_ninja_values, Problem: Too many? Many are very similar and URL replacement results in a massive number of values
# crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/csp-values.txt")
own_values = ["default-src 'none'", "self", "*", "img-src self", "img-src", "img-src none", "frame-src none", "img-src 'null'", "img-src null"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 2725
# Created: 2710
# [([('content-security-policy', "img-src 'none'")], 'CSP-IMG', 200, 'parsing'), ([('x-content-security-policy', "img-src 'none'")], 'CSP-IMG', 200, 'parsing'), ([('x-webkit-csp', "img-src 'none'")], 'CSP-IMG', 200, 'parsing'), ([('x-webkit-content-security-policy', "img-src 'none'")], 'CSP-IMG', 200, 'parsing'), ([('content-sec\x12urity-policy', "img-src 'none'")], 'CSP-IMG', 200, 'parsing')]

# %%
label = "HSTS"
header_name = "strict-transport-security"
alt_names = ["x-strict-transport-security", "hsts"]
block_values = ["max-age=0"]
allow_values = []
partial_values = ["max-age=60", "max-age=20; includeSubDomains"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# Not in WPT
wpt_values = []
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'Strict-Transport-Security: (.*?)\'")
# https://crawler.ninja/files/sts-values.txt
crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/sts-values.txt")
own_values = ["includeSubDomains", "max-age=-5", "max-age=60; includeSubDomains; preload"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 3355
# Created: 3324
# [([('strict-transport-security', 'max-age=0')], 'HSTS', 200, 'parsing'), ([('x-strict-transport-security', 'max-age=0')], 'HSTS', 200, 'parsing'), ([('hsts', 'max-age=0')], 'HSTS', 200, 'parsing'), ([('strict-transZport-security', 'max-age=0')], 'HSTS', 200, 'parsing'), ([('strict-transport-security\x13', 'max-age=0')], 'HSTS', 200, 'parsing')]

# %%
label = "OAC"
header_name = "origin-agent-cluster"
alt_names = ["x-origin-agent-cluster"]
block_values = ["?1"]
allow_values = ["?0"]
partial_values = []
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/html/browsers/origin/origin-keyed-agent-clusters?label=master&label=experimental&aligned&q=origin-agent-cluster
wpt_values = ["?1", "?0"]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # OAC not tested
crawler_ninja_values = [] # OAC not tested
own_values = ["1", "0", "true", "false"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 1711
# Created: 1699
# [([('origin-agent-cluster', '?1')], 'OAC', 200, 'parsing'), ([('x-origin-agent-cluster', '?1')], 'OAC', 200, 'parsing'), ([('origin-agent-clusterK', '?1')], 'OAC', 200, 'parsing'), ([('origin-agent-cluster@', '?1')], 'OAC', 200, 'parsing'), ([('origin agent cluster', '?1')], 'OAC', 200, 'parsing')]

# %%
label = "PP"
header_name = "permissions-policy"
alt_names = ["x-permissions-policy", "feature-policy"]
block_values = ["fullscreen=()"]
allow_values = ["fullscreen=(*)"]
partial_values = ["fullscreen=(self)"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/permissions-policy/reporting?label=master&label=experimental&aligned&q=fullscreen
wpt_values = [] # Nothing useful?
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # Not tested
# https://crawler.ninja/files/fp-values.txt, https://crawler.ninja/files/pp-values.txt
crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/fp-values.txt", min_count=4) + get_crawler_values("https://crawler.ninja/files/pp-values.txt", min_count=4)
own_values = ["fullscreen=", "fullscreen=*", "fullscreen=()", "fullscreen=(self)", f"fullscreen=({URL_REP})", "fullscreen=(self none)", "fullscreen=(self,none)", "fullscreen=(src)"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 3909
# Created: 3880
# [([('permissions-policy', 'fullscreen=()')], 'PP', 200, 'parsing'), ([('x-permissions-policy', 'fullscreen=()')], 'PP', 200, 'parsing'), ([('feature-policy', 'fullscreen=()')], 'PP', 200, 'parsing'), ([('Apermissions-policy', 'fullscreen=()')], 'PP', 200, 'parsing'), ([('permissions-policy\x17', 'fullscreen=()')], 'PP', 200, 'parsing')]

# %%
label = "RP"
header_name = "referrer-policy"
alt_names = ["x-referrer-policy", "referer-policy"]
block_values = ["no-referrer"]
allow_values = ["unsafe-url"]
partial_values = ["same-origin"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/referrer-policy?label=master&label=experimental&aligned&q=referrer-policy
wpt_values = [] # Too many?
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # Not tested
# https://crawler.ninja/files/rp-values.txt
crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/rp-values.txt")
own_values = ["no-referrer-when-downgrade", "origin", "strict-origin", "origin-when-cross-origin", "strict-origin-when-cross-origin"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 2837
# Created: 2797
# [([('referrer-policy', 'no-referrer')], 'RP', 200, 'parsing'), ([('x-referrer-policy', 'no-referrer')], 'RP', 200, 'parsing'), ([('referer-policy', 'no-referrer')], 'RP', 200, 'parsing'), ([('referrer-policy*', 'no-referrer')], 'RP', 200, 'parsing'), ([('referrer-policy0', 'no-referrer')], 'RP', 200, 'parsing')]

# %%
label = "TAO"
header_name = "timing-allow-origin"
alt_names = ["x-timing-allow-origin"]
block_values = ["null"]
allow_values = ["*"]
partial_values = []
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/resource-timing?label=master&label=experimental&aligned&q=tao
wpt_values = [] # Nothing crazy?
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # Not tested
crawler_ninja_values = [] # Not tested
own_values = ["self", "'self'", f"{URL_REP} {URL_REP}", f"{URL_REP},{URL_REP}"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 1610
# Created: 1601
# [([('timing-allow-origin', 'null')], 'TAO', 200, 'parsing'), ([('x-timing-allow-origin', 'null')], 'TAO', 200, 'parsing'), ([('timing-allow-origin7', 'null')], 'TAO', 200, 'parsing'), ([('timing-allow-originF', 'null')], 'TAO', 200, 'parsing'), ([('timing-allow-origin\x12', 'null')], 'TAO', 200, 'parsing')]

# %%
label = "XCTO"
header_name = "x-content-type-options"
alt_names = ["content-type-options"]
block_values = ["nosniff"]
allow_values = []
partial_values = []
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "nosniff", "no-sniff"]
# https://github.com/web-platform-tests/wpt/blob/master/fetch/nosniff/resources/x-content-type-options.json
wpt_values = ["NOSNIFF", "nosniff,,@#$#%%&^&^*()()11!", "@#$#%%&^&^*()()11!,nosniff", "no", "", ",nosniff", "nosniff\u000C", "nosniff\u000B,nosniff", "'NosniFF'", '"nosniFF"'] 
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # Not tested
crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/xcto-values.txt")
own_values = ["SNIFF", "no", "always", "maybe"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
# Out:
# 915
# Created: 889
# [([('x-content-type-options', 'nosniff')], 'XCTO', 200, 'parsing'), ([('content-type-options', 'nosniff')], 'XCTO', 200, 'parsing'), ([('x-content-tsype-options', 'nosniff')], 'XCTO', 200, 'parsing'), ([('x-content-tyype-options', 'nosniff')], 'XCTO', 200, 'parsing'), ([('x-content-type-options{', 'nosniff')], 'XCTO', 200, 'parsing')]

# %%
label = "CSPvsXFO"
header_names = ["content-security-policy", "x-frame-options"]
values = {
    "content-security-policy": csp_fa_all,
    "x-frame-options": ["DENY", "", "INVALID", "SAMEORIGIN"]
}
ht = HeaderTestsMultHeader(header_names, values, label)
ht.create_all_tests()
# Out:
# 1458
# Created: 0
# [([('COnTENT-sECURITY-PolICy', "frame-ancestors 'none'"), (' x-frame-options ', 'DENY')], 'CSPvsXFO', 200, 'parsing'), ([('COnTENT-sECURITY-PolICy', 'frame-ancestors *'), (' x-frame-options ', '')], 'CSPvsXFO', 200, 'parsing'), ([('COnTENT-sECURITY-PolICy', "frame-ancestors 'self'"), (' x-frame-options ', 'INVALID')], 'CSPvsXFO', 200, 'parsing'), ([('COnTENT-sECURITY-PolICy', ''), (' x-frame-options ', 'SAMEORIGIN')], 'CSPvsXFO', 200, 'parsing'), ([('COnTENT-sECURITY-PolICy', 'INVALID'), (' x-frame-options ', 'DENY')], 'CSPvsXFO', 200, 'parsing')]

# %% [markdown]
# ## Old/alternative ideas

# %%
# Other (old) CORS idea, use all header at the same time, choose some subsets, ... (problem combinatorial explosion)

import numpy as np
def generate_subsets(input_list):
    # Get all subsets of the list
    all_subsets = list(chain.from_iterable(permutations(input_list, r) for r in range(len(input_list) + 1)))
    return all_subsets

# Example usage
input_list = ["access-control-allow-origin", "access-control-allow-credentials", "access-control-allow-methods", "access-control-allow-headers", "access-control-expose-headers"]
header_lists = generate_subsets(input_list)

print(len(header_lists))
for header_list in header_lists:
    if not len(header_list):
        continue
    random.seed(42)
    shuffled_others = [random.sample(other_values, len(other_values)) for _ in range(len(header_list))]
    # Basic: each header gets one random value
    for val_i in range(len(other_values)):
        base_resp = [("Test", "Test")]
        for list_i, header in enumerate(header_list):  
            base_resp.append((header, shuffled_others[list_i][val_i]))
        # print(base_resp) Add resp!
    # Advanced1: the first header gets one random mutated value
    for ...
    
    # Advanced2: the first header is duplicated (with different values?)

    # Advanced3: the first header name is mutated

values = set()
for value in other_values:
    if value in basic_values:
        for mut_value in mutate_header_value(value):        
            values.add(mut_value)
    else:
        values.add(value)
len(values)

label = "CORS"
base_resp = [("Test", "Test")]
header_names = ["access-control-allow-origin", "access-control-allow-credentials", "access-control-allow-methods", "access-control-allow-headers", "access-control-expose-headers"]


basic_values = ["", "null", "*", "Test"]
# https://wpt.fyi/results/cors?label=master&label=experimental&aligned&q=cors
wpt_values = [] # Nothing parsing related?
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # Difficult to extract
# https://crawler.ninja/files/acao-values.txt
crawler_ninja_values = [] # Only ACAO and mostly different origins
own_values = ["true", "?1", "?0", "TEST", "Test", "test", "false", "https://", "//", "//",  "INVALID", URL_REP]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)




#ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
#ht.create_all_tests()
print(len(other_values), other_values)
