# %%
import glob
import json
from anytree.importer import JsonImporter
from anytree.exporter import UniqueDotExporter
from anytree import RenderTree, PreOrderIter
import pandas as pd

# %%
# TODO: Only paths with name/browser_id in them are interesting?
# Trees that are the same do not have to be analyzed
# ...

# %%
base_dir = "trees/2023-11-23T13:48"

tree_files = []
svg_files = []
channel_files = []
for base_dir in [base_dir]:
    tree_files += glob.glob(f"{base_dir}/anytree/*")
    svg_files += glob.glob(f"{base_dir}/svg/*")
    channel_files += glob.glob(f"{base_dir}/obs/*")
    print(len(svg_files))

tree_list = []
for tree_file in tree_files:
    with open(tree_file, "r") as f:
        tree_txt = f.read().replace('"path":', '"path2":')
        tree_name = tree_file.split("anytree/")[1]
        tree_list.append((tree_name, JsonImporter().import_(tree_txt)))
# Out:
# 35

# %%
def create_path(leaf):
    path_dict = {}
    pred = leaf.pred
    for node in leaf.path:
        prop, value = node.path2.split(":", maxsplit=1)
        if prop == "root":
            continue
        old_value = path_dict.get(prop, None)
        if old_value is not None:
            if len(value) < len(old_value):
                path_dict[prop] = value
        else:
            path_dict[prop] = value
    return sorted(list(path_dict.items())), pred

# %%
paths_dict = {}
trees_dict = {}
nodes_dict = {}
all_paths = 0
for tree_name, tree in tree_list:
    paths = [create_path(leaf) for leaf in tree.leaves]
    nodes = set([node.path2 for node in PreOrderIter(tree)])
    for node in nodes:
        vals = nodes_dict.get(node, {"tree_names": []})
        vals["tree_names"].append(tree_name)
        nodes_dict[node] = vals
    # Have a more relaxed fingerprint? (Ignore some of the paths or something like that?)
    # ...
    path_fingerprint = sorted([path for path, pred in paths])
    vals = trees_dict.get(json.dumps(path_fingerprint), {"tree_names": [], "org_paths": [], "tree": tree})
    vals["tree_names"].append(tree_name)
    vals["org_paths"].append(paths)
    trees_dict[json.dumps(path_fingerprint)] = vals
    all_paths += len(paths)
    for path, pred in paths:
        path_string = json.dumps(path)
        vals = paths_dict.get(path_string, {"tree_names": [], "preds": [], "org_path": path})
        vals["tree_names"].append(tree_name)
        vals["preds"].append(pred)
        paths_dict[path_string] = vals


df = pd.DataFrame(columns=["test", "obs_num", "tree_num"])

# Sort paths by most occuring ones, second sorting key length of path
class reversor:
    def __init__(self, obj):
        self.obj = obj

    def __eq__(self, other):
        return other.obj == self.obj

    def __lt__(self, other):
        return other.obj < self.obj
paths_dict = {k: v for k, v in sorted(paths_dict.items(), key=lambda item: (reversor(len(item[1]["preds"])), len(item[1]["org_path"])))}
trees_dict = {k: v for k, v in sorted(trees_dict.items(), key=lambda item: reversor(len(item[1]["tree_names"])))}

enum_trees_dict = list(enumerate(trees_dict.items()))
for num, (fp, vals) in enum_trees_dict:
    for tmp in vals["tree_names"]:
        test, obs_num = tmp.split(")")
        df.loc[len(df)] = [test + ")", obs_num.split(".json")[0], num]
        
print(f"All paths: {all_paths}, all unique paths: {len(paths_dict.keys())}")
print(f"All trees: {len(tree_list)}, all unique trees: {len(trees_dict.keys())}, all svg trees: {len(svg_files)}, all channels: {len(channel_files)}")
print(f"All unique nodes: {len(nodes_dict.keys())}")

print("Keep in mind that binary outcomes result in one tree, and non-binary outcomes result in num-outcomes trees. So, there should be more trees than svg trees.")
# Out:
# All paths: 924, all unique paths: 641
# All trees: 127, all unique trees: 95, all svg trees: 35, all channels: 35
# All unique nodes: 221
# Keep in mind that binary outcomes result in one tree, and non-binary outcomes result in num-outcomes trees. So, there should be more trees than svg trees.

# %%
def to_list(string):
    return string[1:-1].split()

with pd.option_context("display.max_rows", 137):
    with pd.option_context("display.max_colwidth", None):
        groups = df.groupby("test")["tree_num"].unique().to_frame().reset_index()
        display(groups)
        groups["tree_num_str"] = groups["tree_num"].apply(str)
        groups = groups.groupby("tree_num_str")["test"].unique().to_frame().reset_index()
        groups["tree_num"] = groups["tree_num_str"].apply(to_list)
        groups["len"] = groups["tree_num"].str.len()
        groups["tree_num_str_len"] = groups["tree_num_str"].str.len()
        groups = groups.sort_values(["len", "tree_num_str_len", "tree_num_str"])[["tree_num", "test"]].reset_index(drop=True)
        display(groups)
# Out:
#                                            test  \
# 0             ('accesswindow_direct', 'direct')
# 1                  ('fetch_GET', 'credendials')
# 2               ('fetch_GET', 'custom_headers')
# 3                       ('fetch_GET', 'simple')
# 4               ('fetch_TEST', 'custom_method')
# 5                   ('framing_embed', 'direct')
# 6                   ('framing_embed', 'nested')
# 7                  ('framing_embed', 'sandbox')
# 8                  ('framing_iframe', 'direct')
# 9                  ('framing_iframe', 'nested')
# 10                ('framing_iframe', 'sandbox')
# 11                 ('framing_object', 'direct')
# 12                 ('framing_object', 'nested')
# 13                ('framing_object', 'sandbox')
# 14               ('fullscreen_iframe', 'child')
# 15         ('fullscreen_iframe', 'child_allow')
# 16       ('fullscreen_iframe', 'child_sandbox')
# 17              ('fullscreen_iframe', 'direct')
# 18              ('imgloading_iframe', 'direct')
# 19                     ('oac_iframe', 'direct')
# 20                    ('oac_iframe', 'sandbox')
# 21           ('oac_window.open', 'window.open')
# 22                    ('perfAPI_img', 'direct')
# 23                ('referrer_iframe', 'iframe')
# 24           ('referrer_iframe', 'window.open')
# 25        ('script_execution_iframe', 'direct')
# 26       ('script_execution_iframe', 'sandbox')
# 27     ('subresourceloadingCOEP_img', 'direct')
# 28    ('subresourceloadingCOEP_img', 'sandbox')
# 29     ('subresourceloadingCORP_img', 'direct')
# 30     ('subresourceloadingCORP_img', 'nested')
# 31    ('subresourceloadingCORP_img', 'sandbox')
# 32  ('subresourceloadingCORP_object', 'direct')
# 33             ('upgradeHSTS_direct', 'direct')
# 34       ('upgradeHSTS_subdomain', 'subdomain')
#
#                                                                                                tree_num
# 0                                                                                                  [15]
# 1                                                                                    [2, 3, 5, 6, 7, 8]
# 2                                                                                    [2, 3, 5, 6, 7, 8]
# 3                                                                               [2, 3, 5, 6, 7, 50, 67]
# 4                                                                                    [2, 3, 5, 6, 7, 8]
# 5                                                                                                   [9]
# 6                                                                                                   [1]
# 7                                                                                                   [1]
# 8                                                                                                  [44]
# 9                                                                                                  [48]
# 10                                                                                                 [57]
# 11                                                                                                  [9]
# 12                                                                                                  [1]
# 13                                                                                                  [1]
# 14                                                                                          [0, 35, 38]
# 15                                                                                          [0, 62, 65]
# 16                                                                                                  [0]
# 17                                                                                         [12, 18, 88]
# 18                                                                                         [13, 47, 84]
# 19                                                                                      [4, 10, 17, 86]
# 20                                                                                          [4, 10, 16]
# 21                                                                                      [0, 26, 42, 56]
# 22                                                                                         [53, 58, 73]
# 23                                  [0, 14, 27, 31, 32, 36, 37, 41, 43, 46, 52, 66, 68, 74, 83, 87, 90]
# 24  [0, 24, 25, 28, 29, 30, 33, 34, 39, 45, 49, 54, 60, 61, 63, 70, 71, 72, 75, 77, 80, 82, 85, 91, 93]
# 25                                                                                                 [81]
# 26                                                                                                 [19]
# 27                                                                              [4, 11, 20, 40, 64, 79]
# 28                                                                                          [4, 55, 94]
# 29                                                                                                 [92]
# 30                                                                                              [0, 89]
# 31                                                                                         [22, 23, 59]
# 32                                                                                         [51, 76, 78]
# 33                                                                                                 [69]
# 34                                                                                                 [21]
#                                                                                                tree_num  \
# 0                                                                                                   [0]
# 1                                                                                                   [1]
# 2                                                                                                   [9]
# 3                                                                                                  [15]
# 4                                                                                                  [19]
# 5                                                                                                  [21]
# 6                                                                                                  [44]
# 7                                                                                                  [48]
# 8                                                                                                  [57]
# 9                                                                                                  [69]
# 10                                                                                                 [81]
# 11                                                                                                 [92]
# 12                                                                                              [0, 89]
# 13                                                                                          [0, 35, 38]
# 14                                                                                          [0, 62, 65]
# 15                                                                                          [4, 10, 16]
# 16                                                                                          [4, 55, 94]
# 17                                                                                         [12, 18, 88]
# 18                                                                                         [13, 47, 84]
# 19                                                                                         [22, 23, 59]
# 20                                                                                         [51, 76, 78]
# 21                                                                                         [53, 58, 73]
# 22                                                                                      [0, 26, 42, 56]
# 23                                                                                      [4, 10, 17, 86]
# 24                                                                                   [2, 3, 5, 6, 7, 8]
# 25                                                                              [4, 11, 20, 40, 64, 79]
# 26                                                                              [2, 3, 5, 6, 7, 50, 67]
# 27                                  [0, 14, 27, 31, 32, 36, 37, 41, 43, 46, 52, 66, 68, 74, 83, 87, 90]
# 28  [0, 24, 25, 28, 29, 30, 33, 34, 39, 45, 49, 54, 60, 61, 63, 70, 71, 72, 75, 77, 80, 82, 85, 91, 93]
#
#                                                                                                                         test
# 0                                                                                   [('fullscreen_iframe', 'child_sandbox')]
# 1   [('framing_embed', 'nested'), ('framing_embed', 'sandbox'), ('framing_object', 'nested'), ('framing_object', 'sandbox')]
# 2                                                                [('framing_embed', 'direct'), ('framing_object', 'direct')]
# 3                                                                                        [('accesswindow_direct', 'direct')]
# 4                                                                                   [('script_execution_iframe', 'sandbox')]
# 5                                                                                   [('upgradeHSTS_subdomain', 'subdomain')]
# 6                                                                                             [('framing_iframe', 'direct')]
# 7                                                                                             [('framing_iframe', 'nested')]
# 8                                                                                            [('framing_iframe', 'sandbox')]
# 9                                                                                         [('upgradeHSTS_direct', 'direct')]
# 10                                                                                   [('script_execution_iframe', 'direct')]
# 11                                                                                [('subresourceloadingCORP_img', 'direct')]
# 12                                                                                [('subresourceloadingCORP_img', 'nested')]
# 13                                                                                          [('fullscreen_iframe', 'child')]
# 14                                                                                    [('fullscreen_iframe', 'child_allow')]
# 15                                                                                               [('oac_iframe', 'sandbox')]
# 16                                                                               [('subresourceloadingCOEP_img', 'sandbox')]
# 17                                                                                         [('fullscreen_iframe', 'direct')]
# 18                                                                                         [('imgloading_iframe', 'direct')]
# 19                                                                               [('subresourceloadingCORP_img', 'sandbox')]
# 20                                                                             [('subresourceloadingCORP_object', 'direct')]
# 21                                                                                               [('perfAPI_img', 'direct')]
# 22                                                                                      [('oac_window.open', 'window.open')]
# 23                                                                                                [('oac_iframe', 'direct')]
# 24                          [('fetch_GET', 'credendials'), ('fetch_GET', 'custom_headers'), ('fetch_TEST', 'custom_method')]
# 25                                                                                [('subresourceloadingCOEP_img', 'direct')]
# 26                                                                                                 [('fetch_GET', 'simple')]
# 27                                                                                           [('referrer_iframe', 'iframe')]
# 28                                                                                      [('referrer_iframe', 'window.open')]

# %%
def render(node):
    if node.is_leaf:
        if node.pred < 0.5:
            return f"\x1b[31m{node.pred}\x1b[0m-{node.path2}"
        else:
            return f"\x1b[32m{node.pred}\x1b[0m-{node.path2}"
    return node.path2

last_trees = []
for _, row in groups.iterrows():
    current_trees = row["tree_num"]
    tests = row["test"]
    print(f"Current Tests: {tests}, current trees: {current_trees}")
    unique_trees = sorted(set(current_trees) - set(last_trees))
    for tree_num in unique_trees:
        tree_num = int(tree_num)
        print(RenderTree(enum_trees_dict[tree_num][1][1]["tree"]).by_attr(render))
    example_tree = tests[0]
    last_trees = current_trees
    print("\n")
# Out:
# Current Tests: ["('fullscreen_iframe', 'child_sandbox')"], current trees: ['0']
# root:root
# ├── 0.0-status_code:['302']
# └── 0.5-status_code:['200']
#
#
# Current Tests: ["('framing_embed', 'nested')" "('framing_embed', 'sandbox')"
#  "('framing_object', 'nested')" "('framing_object', 'sandbox')"], current trees: ['1']
# root:root
# ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │   ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]"]
# │   │   ├── 0.0-raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]"]
# │   │   └── raw_header:["[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]"]
# │   │       ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │   │       └── resp_origin:['https://sub.headers.websec.saarland']
# │   │           ├── 0.0-org_origin:['http://sub.headers.websec.saarland']
# │   │           └── org_origin:['https://sub.headers.websec.saarland']
# │   │               ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
# │   │               └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
# │   └── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │       ├── resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │       │   ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland']
# │       │   └── resp_origin:['http://sub.sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │       │       ├── 0.0-raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │       │       └── raw_header:["[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]"]
# │       │           ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
# │       │           └── 0.5-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
# │       └── resp_origin:['http://sub.headers.websec.saarland', 'https://sub.headers.websec.saarland']
# │           ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
# │           └── 0.5-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
# └── raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'frame-ancestors *']]", "[['Content-Security-Policy', 'frame-ancestors http:']]", "[['Content-Security-Policy', 'frame-ancestors=*']]", "[['Content-Security-Policy', 'null']]", "[['x-frame-options', '']]", "[['x-frame-options', '*']]", "[['x-frame-options', 'ALLOWALL']]", "[['x-frame-options', 'INVALID']]", "[['x-frame-options', 'null']]", '[]']
#     ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
#     └── 0.5-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
#
#
# Current Tests: ["('framing_embed', 'direct')" "('framing_object', 'direct')"], current trees: ['9']
# root:root
# ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │   ├── 0.0-raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]"]
# │   └── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │       ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
# │       └── resp_origin:['http://sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │           ├── org_origin:['http://sub.headers.websec.saarland']
# │           │   ├── 0.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │           │   └── resp_origin:['http://sub.headers.websec.saarland']
# │           │       ├── 0.0-raw_header:["[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]"]
# │           │       └── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │           │           ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
# │           │           └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
# │           └── org_origin:['https://sub.headers.websec.saarland']
# │               ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │               │   ├── 0.0-resp_origin:['http://sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │               │   └── resp_origin:['https://sub.headers.websec.saarland']
# │               │       ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
# │               │       └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
# │               └── raw_header:["[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]"]
# │                   ├── 0.0-resp_origin:['http://sub.headers.websec.saarland']
# │                   └── resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │                       ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
# │                       └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
# └── raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'frame-ancestors *']]", "[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors http:']]", "[['Content-Security-Policy', 'frame-ancestors=*']]", "[['Content-Security-Policy', 'null']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['x-frame-options', '']]", "[['x-frame-options', '*']]", "[['x-frame-options', 'ALLOWALL']]", "[['x-frame-options', 'INVALID']]", "[['x-frame-options', 'null']]", '[]']
#     ├── org_origin:['https://sub.headers.websec.saarland']
#     │   ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
#     │   └── resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#     │       ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
#     │       └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
#     └── org_origin:['http://sub.headers.websec.saarland']
#         ├── 0.0-browser:['safari macOS 14.0 17.0 selenium real']
#         └── browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
#             ├── raw_header:["[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]"]
#             │   ├── 0.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#             │   └── 1.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
#             └── 1.0-raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'frame-ancestors *']]", "[['Content-Security-Policy', 'frame-ancestors http:']]", "[['Content-Security-Policy', 'frame-ancestors=*']]", "[['Content-Security-Policy', 'null']]", "[['x-frame-options', '']]", "[['x-frame-options', '*']]", "[['x-frame-options', 'ALLOWALL']]", "[['x-frame-options', 'INVALID']]", "[['x-frame-options', 'null']]", '[]']
#
#
# Current Tests: ["('accesswindow_direct', 'direct')"], current trees: ['15']
# root:root
# ├── 0.0-raw_header:["[['Cross-Origin-Opener-Policy', '']]", "[['Cross-Origin-Opener-Policy', '*']]", "[['Cross-Origin-Opener-Policy', 'null']]", "[['Cross-Origin-Opener-Policy', 'same-origin-plus-COEP']]", "[['Cross-Origin-Opener-Policy', 'unsafe-none']]", "[['Cross-Origin-Opener-Policy', 'unsafe-none, same-origin, same-origin-plus-COEP']]", '[]']
# └── raw_header:["[['Cross-Origin-Opener-Policy', 'same-origin'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Cross-Origin-Opener-Policy', 'same-origin']]", "[['Cross-Origin-Opener-Policy', 'same-origin-allow-popups'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Cross-Origin-Opener-Policy', 'same-origin-allow-popups']]"]
#     ├── resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
#     │   ├── 0.0-browser:['chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']
#     │   └── browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']
#     │       ├── resp_origin:['http://sub.headers.websec.saarland']
#     │       │   ├── 0.0-org_origin:['http://sub.headers.websec.saarland']
#     │       │   └── 1.0-org_origin:['https://sub.headers.websec.saarland']
#     │       └── 1.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
#     └── 1.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#
#
# Current Tests: ["('script_execution_iframe', 'sandbox')"], current trees: ['19']
# root:root
# ├── raw_header:['[[\'Content-Security-Policy\', "script-src \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "script-src \'none\'"]]', '[[\'Content-Security-Policy\', "script-src \'none\', script-src *, script-src \'self\'"]]', '[[\'Content-Security-Policy\', "script-src \'self\'"]]', "[['Content-Security-Policy', 'script-src *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'script-src']]"]
# │   ├── 0.0-raw_header:['[[\'Content-Security-Policy\', "script-src \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "script-src \'none\'"]]', '[[\'Content-Security-Policy\', "script-src \'none\', script-src *, script-src \'self\'"]]', "[['Content-Security-Policy', 'script-src *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'script-src']]"]
# │   └── raw_header:['[[\'Content-Security-Policy\', "script-src \'self\'"]]']
# │       ├── resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │       │   ├── 0.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
# │       │   └── browser:['safari macOS 14.0 17.0 selenium real']
# │       │       ├── org_origin:['https://sub.headers.websec.saarland']
# │       │       │   ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
# │       │       │   └── 1.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │       │       └── 1.0-org_origin:['http://sub.headers.websec.saarland']
# │       └── resp_origin:['http://sub.headers.websec.saarland', 'https://sub.headers.websec.saarland']
# │           ├── org_origin:['https://sub.headers.websec.saarland']
# │           │   ├── 0.0-resp_origin:['http://sub.headers.websec.saarland']
# │           │   └── 1.0-resp_origin:['https://sub.headers.websec.saarland']
# │           └── 1.0-org_origin:['http://sub.headers.websec.saarland']
# └── raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'null']]", "[['Content-Security-Policy', 'script-src *']]", "[['Content-Security-Policy', 'script-src *.headers.websec.saarland']]", "[['Content-Security-Policy', 'script-src http:']]", "[['Content-Security-Policy', 'script-src https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'script-src https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'script-src=*']]", '[]']
#     ├── org_origin:['https://sub.headers.websec.saarland']
#     │   ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
#     │   └── resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#     │       ├── browser:['safari macOS 14.0 17.0 selenium real']
#     │       │   ├── 0.0-raw_header:["[['Content-Security-Policy', 'script-src *.headers.websec.saarland']]"]
#     │       │   └── 1.0-raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'null']]", "[['Content-Security-Policy', 'script-src *']]", "[['Content-Security-Policy', 'script-src http:']]", "[['Content-Security-Policy', 'script-src https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'script-src https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'script-src=*']]", '[]']
#     │       └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
#     └── org_origin:['http://sub.headers.websec.saarland']
#         ├── browser:['safari macOS 14.0 17.0 selenium real']
#         │   ├── 0.0-raw_header:["[['Content-Security-Policy', 'script-src *.headers.websec.saarland']]"]
#         │   └── 1.0-raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'null']]", "[['Content-Security-Policy', 'script-src *']]", "[['Content-Security-Policy', 'script-src http:']]", "[['Content-Security-Policy', 'script-src https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'script-src https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'script-src=*']]", '[]']
#         └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']
#
#
# Current Tests: ["('upgradeHSTS_subdomain', 'subdomain')"], current trees: ['21']
# root:root
# ├── raw_header:["[['Strict-Transport-Security', 'max-age=20; includeSubDomains'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Strict-Transport-Security', 'max-age=20; includeSubDomains']]", "[['Strict-Transport-Security', 'max-age=20; includeSubDomains; preload']]"]
# │   ├── 0.0-resp_origin:['https://sub.headers.websec.saarland']
# │   └── 1.0-resp_origin:['http://sub.headers.websec.saarland']
# └── 1.0-raw_header:["[['Strict-Transport-Security', '']]", "[['Strict-Transport-Security', '*']]", "[['Strict-Transport-Security', 'abc, max-age=20']]", "[['Strict-Transport-Security', 'includeSubDomains']]", "[['Strict-Transport-Security', 'max-age=-5']]", "[['Strict-Transport-Security', 'max-age=0']]", "[['Strict-Transport-Security', 'max-age=20'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Strict-Transport-Security', 'max-age=20']]", "[['Strict-Transport-Security', 'max-age=20, max-age=20; includeSubDomains, includeSubDomains, , max-age=20; includeSubDomains; preload, max-age=0, max-age=-5']]", "[['Strict-Transport-Security', 'null']]", '[]']
#
#
# Current Tests: ["('framing_iframe', 'direct')"], current trees: ['44']
# root:root
# ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │   ├── 0.0-raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]"]
# │   └── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │       ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
# │       └── resp_origin:['http://sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │           ├── org_origin:['http://sub.headers.websec.saarland']
# │           │   ├── 0.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │           │   └── resp_origin:['http://sub.headers.websec.saarland']
# │           │       ├── 0.0-raw_header:["[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]"]
# │           │       └── 1.0-raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │           └── org_origin:['https://sub.headers.websec.saarland']
# │               ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │               │   ├── 0.0-resp_origin:['http://sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │               │   └── 1.0-resp_origin:['https://sub.headers.websec.saarland']
# │               └── raw_header:["[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]"]
# │                   ├── 0.0-resp_origin:['http://sub.headers.websec.saarland']
# │                   └── 1.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# └── raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'frame-ancestors *']]", "[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors http:']]", "[['Content-Security-Policy', 'frame-ancestors=*']]", "[['Content-Security-Policy', 'null']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['x-frame-options', '']]", "[['x-frame-options', '*']]", "[['x-frame-options', 'ALLOWALL']]", "[['x-frame-options', 'INVALID']]", "[['x-frame-options', 'null']]", '[]']
#     ├── org_origin:['https://sub.headers.websec.saarland']
#     │   ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
#     │   └── 1.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#     └── org_origin:['http://sub.headers.websec.saarland']
#         ├── raw_header:["[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]"]
#         │   ├── 0.0-resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#         │   └── 1.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']
#         └── 1.0-raw_header:["[['Content-Security-Policy', '']]", "[['Content-Security-Policy', '*']]", "[['Content-Security-Policy', 'frame-ancestors *']]", "[['Content-Security-Policy', 'frame-ancestors http:']]", "[['Content-Security-Policy', 'frame-ancestors=*']]", "[['Content-Security-Policy', 'null']]", "[['x-frame-options', '']]", "[['x-frame-options', '*']]", "[['x-frame-options', 'ALLOWALL']]", "[['x-frame-options', 'INVALID']]", "[['x-frame-options', 'null']]", '[]']
#
#
# Current Tests: ["('framing_iframe', 'nested')"], current trees: ['48']
# root:root
# ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │   ├── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]"]
# │   │   ├── 0.0-raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'INVALID\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'X-Frame-Options\', \'SAMEORIGIN\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\'"]]', '[[\'Content-Security-Policy\', "frame-ancestors \'none\', frame-ancestors *, frame-ancestors \'self\'"]]', "[['Content-Security-Policy', 'default-src *']]", "[['Content-Security-Policy', 'frame-ancestors *'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Content-Security-Policy', 'frame-ancestors']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', '*']]", "[['x-frame-options', 'DENY']]", "[['x-frame-options', 'DENY, INVALID, ALLOWALL']]", "[['x-frame-options', 'INVALID'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['x-frame-options', 'SAMEORIGIN'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]"]
# │   │   └── raw_header:["[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland']]", "[['Content-Security-Policy', 'frame-ancestors https://sub.headers.websec.saarland/']]"]
# │   │       ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │   │       └── resp_origin:['https://sub.headers.websec.saarland']
# │   │           ├── 0.0-org_origin:['http://sub.headers.websec.saarland']
# │   │           └── 1.0-org_origin:['https://sub.headers.websec.saarland']
# │   └── raw_header:['[[\'Content-Security-Policy\', "frame-ancestors \'self\'"]]', "[['Content-Security-Policy', '*'], ['X-Frame-Options', 'SAMEORIGIN']]", "[['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['X-Frame-Options', 'DENY'], ['Content-Security-Policy', 'frame-ancestors *.headers.websec.saarland']]", "[['x-frame-options', 'SAMEORIGIN']]"]
# │       ├── resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# ...
#     │   └── browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real']
#     │       ├── 0.0-raw_header:["[['Referrer-Policy', 'no-referrer'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Referrer-Policy', 'no-referrer']]", "[['Referrer-Policy', 'same-origin']]", "[['Referrer-Policy', 'unsafe-url'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]"]
#     │       └── raw_header:["[['Referrer-Policy', 'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url']]", "[['Referrer-Policy', 'no-referrer-when-downgrade']]", "[['Referrer-Policy', 'unsafe-url']]"]
#     │           ├── 0.0-org_origin:['https://sub.headers.websec.saarland']
#     │           └── org_origin:['http://sub.headers.websec.saarland']
#     │               ├── browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real']
#     │               │   ├── 0.0-raw_header:["[['Referrer-Policy', 'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url']]"]
#     │               │   └── 1.0-raw_header:["[['Referrer-Policy', 'no-referrer-when-downgrade']]", "[['Referrer-Policy', 'unsafe-url']]"]
#     │               └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb']
#     └── raw_header:["[['Referrer-Policy', '']]", "[['Referrer-Policy', '*']]", "[['Referrer-Policy', 'abc, strict-origin']]", "[['Referrer-Policy', 'null']]", "[['Referrer-Policy', 'origin']]", "[['Referrer-Policy', 'origin-when-cross-origin']]", "[['Referrer-Policy', 'strict-origin']]", "[['Referrer-Policy', 'strict-origin-when-cross-origin']]", '[]']
#         ├── raw_header:["[['Referrer-Policy', '']]", "[['Referrer-Policy', '*']]", "[['Referrer-Policy', 'null']]", "[['Referrer-Policy', 'origin-when-cross-origin']]", "[['Referrer-Policy', 'strict-origin-when-cross-origin']]", '[]']
#         │   ├── org_origin:['http://sub.headers.websec.saarland']
#         │   │   ├── 0.0-browser:['chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']
#         │   │   └── browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']
#         │   │       ├── browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real']
#         │   │       │   ├── raw_header:["[['Referrer-Policy', '']]", "[['Referrer-Policy', '*']]"]
#         │   │       │   │   ├── 0.0-browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real']
#         │   │       │   │   └── browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new']
#         │   │       │   │       ├── 0.0-raw_header:["[['Referrer-Policy', '*']]"]
#         │   │       │   │       └── 1.0-raw_header:["[['Referrer-Policy', '']]"]
#         │   │       │   └── 1.0-raw_header:["[['Referrer-Policy', 'null']]", "[['Referrer-Policy', 'origin-when-cross-origin']]", "[['Referrer-Policy', 'strict-origin-when-cross-origin']]", '[]']
#         │   │       └── 1.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']
#         │   └── org_origin:['https://sub.headers.websec.saarland']
#         │       ├── 0.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']
#         │       └── 1.0-browser:['chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']
#         └── raw_header:["[['Referrer-Policy', 'abc, strict-origin']]", "[['Referrer-Policy', 'origin']]", "[['Referrer-Policy', 'strict-origin']]"]
#             ├── browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']
#             │   ├── 0.0-org_origin:['https://sub.headers.websec.saarland']
#             │   └── 1.0-org_origin:['http://sub.headers.websec.saarland']
#             └── 1.0-browser:['chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']
# root:root
# ├── resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │   ├── 0.0-resp_origin:['http://headers.webappsec.eu', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
# │   └── resp_origin:['http://headers.websec.saarland']
# │       ├── 0.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']
# │       └── browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']
# │           ├── 0.0-raw_header:["[['Referrer-Policy', '']]", "[['Referrer-Policy', '*']]", "[['Referrer-Policy', 'abc, strict-origin']]", "[['Referrer-Policy', 'no-referrer'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Referrer-Policy', 'no-referrer']]", "[['Referrer-Policy', 'null']]", "[['Referrer-Policy', 'origin']]", "[['Referrer-Policy', 'origin-when-cross-origin']]", "[['Referrer-Policy', 'same-origin']]", "[['Referrer-Policy', 'strict-origin']]", "[['Referrer-Policy', 'strict-origin-when-cross-origin']]", "[['Referrer-Policy', 'unsafe-url'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", '[]']
# │           └── raw_header:["[['Referrer-Policy', 'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url']]", "[['Referrer-Policy', 'no-referrer-when-downgrade']]", "[['Referrer-Policy', 'unsafe-url']]"]
# │               ├── 0.0-org_origin:['http://sub.headers.websec.saarland']
# │               └── 1.0-org_origin:['https://sub.headers.websec.saarland']
# └── resp_origin:['https://headers.websec.saarland']
#     ├── 0.0-raw_header:["[['Referrer-Policy', '']]", "[['Referrer-Policy', '*']]", "[['Referrer-Policy', 'abc, strict-origin']]", "[['Referrer-Policy', 'no-referrer'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Referrer-Policy', 'no-referrer']]", "[['Referrer-Policy', 'null']]", "[['Referrer-Policy', 'origin']]", "[['Referrer-Policy', 'origin-when-cross-origin']]", "[['Referrer-Policy', 'same-origin']]", "[['Referrer-Policy', 'strict-origin']]", "[['Referrer-Policy', 'strict-origin-when-cross-origin']]", "[['Referrer-Policy', 'unsafe-url'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", '[]']
#     └── raw_header:["[['Referrer-Policy', 'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url']]", "[['Referrer-Policy', 'no-referrer-when-downgrade']]", "[['Referrer-Policy', 'unsafe-url']]"]
#         ├── 0.0-org_origin:['http://sub.headers.websec.saarland']
#         └── org_origin:['https://sub.headers.websec.saarland']
#             ├── 0.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real']
#             └── 1.0-browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']
# root:root
# ├── 0.0-raw_header:["[['Referrer-Policy', '']]", "[['Referrer-Policy', '*']]", "[['Referrer-Policy', 'abc, strict-origin']]", "[['Referrer-Policy', 'no-referrer'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", "[['Referrer-Policy', 'no-referrer']]", "[['Referrer-Policy', 'null']]", "[['Referrer-Policy', 'origin']]", "[['Referrer-Policy', 'origin-when-cross-origin']]", "[['Referrer-Policy', 'same-origin']]", "[['Referrer-Policy', 'strict-origin']]", "[['Referrer-Policy', 'strict-origin-when-cross-origin']]", "[['Referrer-Policy', 'unsafe-url'], ['location', 'https://sub.headers.websec.saarland/_hp/common/empty.html']]", '[]']
# └── raw_header:["[['Referrer-Policy', 'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url']]", "[['Referrer-Policy', 'no-referrer-when-downgrade']]", "[['Referrer-Policy', 'unsafe-url']]"]
#     ├── resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#     │   ├── 0.0-resp_origin:['http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']
#     │   └── resp_origin:['http://headers.webappsec.eu']
#     │       ├── 0.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']
#     │       └── browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']
#     │           ├── 0.0-org_origin:['http://sub.headers.websec.saarland']
#     │           └── 1.0-org_origin:['https://sub.headers.websec.saarland']
#     └── resp_origin:['https://headers.webappsec.eu']
#         ├── 0.0-org_origin:['http://sub.headers.websec.saarland']
#         └── org_origin:['https://sub.headers.websec.saarland']
#             ├── 0.0-browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'safari macOS 14.0 17.0 selenium real']
#             └── 1.0-browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']

# %%
import asyncio

import ipywidgets as widgets
from IPython.display import SVG



out = widgets.Output()
out.layout.width='1800px'


def wait_for_click(btn):
    future = asyncio.Future()
    
    def on_button_clicked(btn):
        future.set_result(btn.description)
    
    btn.on_click(on_button_clicked)
    
    return future

btn = widgets.Button(description="Next Test")


global example_tree

async def f():
    global example_tree
    last_trees = []
    all_trees = set()
    for i, row in groups.iterrows():
        current_trees = row["tree_num"]
        tests = row["test"]
        out.append_stdout(f"{i+1}/{len(groups)}; Current tests: {tests}, \n current trees: {current_trees}\n")
        unique_trees = sorted(set(current_trees) - set(all_trees))
        out.append_stdout(f"Trees different to any previous test: {unique_trees}\n")
        for tree_num in unique_trees:
            tree_num = int(tree_num)
            out.append_stdout(RenderTree(enum_trees_dict[tree_num][1][1]["tree"]).by_attr(render))
            out.append_stdout("\n")
        example_tree = tests[0]
        out.append_stdout("\n")
        tree_name = f"{base_dir}/svg/{example_tree}.svg"
        out.append_stdout(tree_name)
        out.append_display_data(SVG(tree_name))
        for tree in current_trees:
            all_trees.add(tree)
        await wait_for_click(btn)
        out.outputs = ()
        
asyncio.ensure_future(f())

display(btn, out)
# Out:
# Button(description='Next Test', style=ButtonStyle())
# Output(layout=Layout(width='1800px'))

# %% [markdown]
# ## Path analysis?!

# %%
len(paths_dict)
# Out:
# 641

# %%
paths_with_browser = {}
for path in paths_dict:
    if not "browser" in path:
        continue
    paths_with_browser[path] = paths_dict[path]
len(paths_with_browser)
# Out:
# 419

# %%
len(trees_dict)
# Out:
# 95

# %%
trees_with_browser = {}
for path in trees_dict:
    if "browser" in path:
        trees_with_browser[path] = trees_dict[path]
        
len(trees_with_browser)
# Out:
# 71

# %%
for path in trees_with_browser:
    print(RenderTree(trees_with_browser[path]["tree"]))
    print("\n\n\n\n")
# Out:
# AnyNode(path2='root:root', split='raw_header')
# ├── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'INVALID\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'SAMEORIGIN\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'location\\\', \\\'https://sub.headers.websec.saarland/_hp/common/empty.html\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"]]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\', frame-ancestors *, frame-ancestors \\\'self\\\'"]]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'*\'], [\'X-Frame-Options\', \'SAMEORIGIN\']]", "[[\'Content-Security-Policy\', \'default-src *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland/\']]", "[[\'Content-Security-Policy\', \'frame-ancestors\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'*\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'x-frame-options\', \'DENY\']]", "[[\'x-frame-options\', \'DENY, INVALID, ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'x-frame-options\', \'SAMEORIGIN\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'x-frame-options\', \'SAMEORIGIN\']]"]', split='raw_header')
# │   ├── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'INVALID\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'SAMEORIGIN\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'location\\\', \\\'https://sub.headers.websec.saarland/_hp/common/empty.html\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"]]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\', frame-ancestors *, frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'default-src *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland/\']]", "[[\'Content-Security-Policy\', \'frame-ancestors\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'*\']]", "[[\'x-frame-options\', \'DENY\']]", "[[\'x-frame-options\', \'DENY, INVALID, ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'x-frame-options\', \'SAMEORIGIN\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]"]', split='raw_header')
# │   │   ├── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'INVALID\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'SAMEORIGIN\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'location\\\', \\\'https://sub.headers.websec.saarland/_hp/common/empty.html\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"]]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\', frame-ancestors *, frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'default-src *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Content-Security-Policy\', \'frame-ancestors\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'*\']]", "[[\'x-frame-options\', \'DENY\']]", "[[\'x-frame-options\', \'DENY, INVALID, ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'x-frame-options\', \'SAMEORIGIN\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]"]', pred=0.0)
# │   │   └── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland/\']]"]', split='resp_origin')
# │   │       ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
# │   │       └── AnyNode(path2="resp_origin:['https://sub.headers.websec.saarland']", split='org_origin')
# │   │           ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=0.0)
# │   │           └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='browser')
# │   │               ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
# │   │               └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=1.0)
# │   └── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'*\'], [\'X-Frame-Options\', \'SAMEORIGIN\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'x-frame-options\', \'SAMEORIGIN\']]"]', split='resp_origin')
# │       ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='resp_origin')
# │       │   ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland']", pred=0.0)
# │       │   └── AnyNode(path2="resp_origin:['http://sub.sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='raw_header')
# │       │       ├── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'*\'], [\'X-Frame-Options\', \'SAMEORIGIN\']]", "[[\'x-frame-options\', \'SAMEORIGIN\']]"]', pred=0.0)
# │       │       └── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]"]', split='browser')
# │       │           ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
# │       │           └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=0.5)
# │       └── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland', 'https://sub.headers.websec.saarland']", split='browser')
# │           ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
# │           └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=0.5)
# └── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'\']]", "[[\'Content-Security-Policy\', \'*\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors http:\']]", "[[\'Content-Security-Policy\', \'frame-ancestors=*\']]", "[[\'Content-Security-Policy\', \'null\']]", "[[\'x-frame-options\', \'\']]", "[[\'x-frame-options\', \'*\']]", "[[\'x-frame-options\', \'ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\']]", "[[\'x-frame-options\', \'null\']]", \'[]\']', split='browser')
#     ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
#     └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=0.5)
#
#
#
#
#
# AnyNode(path2='root:root', split='raw_header')
# ├── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'INVALID\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'SAMEORIGIN\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'location\\\', \\\'https://sub.headers.websec.saarland/_hp/common/empty.html\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"]]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\', frame-ancestors *, frame-ancestors \\\'self\\\'"]]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'*\'], [\'X-Frame-Options\', \'SAMEORIGIN\']]", "[[\'Content-Security-Policy\', \'default-src *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland/\']]", "[[\'Content-Security-Policy\', \'frame-ancestors\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'*\']]", "[[\'x-frame-options\', \'DENY\']]", "[[\'x-frame-options\', \'DENY, INVALID, ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'x-frame-options\', \'SAMEORIGIN\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'x-frame-options\', \'SAMEORIGIN\']]"]', split='raw_header')
# │   ├── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'INVALID\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'X-Frame-Options\\\', \\\'SAMEORIGIN\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"], [\\\'location\\\', \\\'https://sub.headers.websec.saarland/_hp/common/empty.html\\\']]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\'"]]\', \'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'none\\\', frame-ancestors *, frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'default-src *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Content-Security-Policy\', \'frame-ancestors\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'*\']]", "[[\'x-frame-options\', \'DENY\']]", "[[\'x-frame-options\', \'DENY, INVALID, ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'x-frame-options\', \'SAMEORIGIN\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]"]', pred=0.0)
# │   └── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'*\'], [\'X-Frame-Options\', \'SAMEORIGIN\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland/\']]", "[[\'x-frame-options\', \'SAMEORIGIN\']]"]', split='resp_origin')
# │       ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
# │       └── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='org_origin')
# │           ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", split='resp_origin')
# │           │   ├── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
# │           │   └── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland']", split='raw_header')
# │           │       ├── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland/\']]"]', pred=0.0)
# │           │       └── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'*\'], [\'X-Frame-Options\', \'SAMEORIGIN\']]", "[[\'x-frame-options\', \'SAMEORIGIN\']]"]', split='browser')
# │           │           ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
# │           │           └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=1.0)
# │           └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='raw_header')
# │               ├── AnyNode(path2='raw_header:[\'[[\\\'Content-Security-Policy\\\', "frame-ancestors \\\'self\\\'"]]\', "[[\'Content-Security-Policy\', \'*\'], [\'X-Frame-Options\', \'SAMEORIGIN\']]", "[[\'x-frame-options\', \'SAMEORIGIN\']]"]', split='resp_origin')
# │               │   ├── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
# │               │   └── AnyNode(path2="resp_origin:['https://sub.headers.websec.saarland']", split='browser')
# │               │       ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
# │               │       └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=1.0)
# │               └── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors https://sub.headers.websec.saarland/\']]"]', split='resp_origin')
# │                   ├── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland']", pred=0.0)
# │                   └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='browser')
# │                       ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
# │                       └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=1.0)
# └── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'\']]", "[[\'Content-Security-Policy\', \'*\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'Content-Security-Policy\', \'frame-ancestors http:\']]", "[[\'Content-Security-Policy\', \'frame-ancestors=*\']]", "[[\'Content-Security-Policy\', \'null\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'x-frame-options\', \'\']]", "[[\'x-frame-options\', \'*\']]", "[[\'x-frame-options\', \'ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\']]", "[[\'x-frame-options\', \'null\']]", \'[]\']', split='org_origin')
#     ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='resp_origin')
#     │   ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
#     │   └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='browser')
#     │       ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
#     │       └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=1.0)
#     └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", split='browser')
#         ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=0.0)
#         └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", split='raw_header')
#             ├── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]", "[[\'X-Frame-Options\', \'DENY\'], [\'Content-Security-Policy\', \'frame-ancestors *.headers.websec.saarland\']]"]', split='resp_origin')
#             │   ├── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
#             │   └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=1.0)
#             └── AnyNode(path2='raw_header:["[[\'Content-Security-Policy\', \'\']]", "[[\'Content-Security-Policy\', \'*\']]", "[[\'Content-Security-Policy\', \'frame-ancestors *\']]", "[[\'Content-Security-Policy\', \'frame-ancestors http:\']]", "[[\'Content-Security-Policy\', \'frame-ancestors=*\']]", "[[\'Content-Security-Policy\', \'null\']]", "[[\'x-frame-options\', \'\']]", "[[\'x-frame-options\', \'*\']]", "[[\'x-frame-options\', \'ALLOWALL\']]", "[[\'x-frame-options\', \'INVALID\']]", "[[\'x-frame-options\', \'null\']]", \'[]\']', pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='browser')
# ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real']", pred=0.0)
# └── AnyNode(path2="browser:['firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", split='status_code')
#     ├── AnyNode(path2="status_code:['302']", pred=0.0)
#     └── AnyNode(path2="status_code:['200']", split='org_origin')
#         ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='resp_origin')
#         │   ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
#         │   └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=1.0)
#         └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='resp_origin')
# ├── AnyNode(path2="resp_origin:['http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
# └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'https://headers.webappsec.eu']", split='status_code')
#     ├── AnyNode(path2="status_code:['302']", pred=0.0)
#     └── AnyNode(path2="status_code:['200']", split='org_origin')
#         ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='resp_origin')
#         │   ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu']", pred=0.0)
#         │   └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu']", split='raw_header')
#         │       ├── AnyNode(path2='raw_header:["[[\'Cross-Origin-Embedder-Policy\', \'require-corp\']]"]', pred=0.0)
#         │       └── AnyNode(path2='raw_header:["[[\'Cross-Origin-Embedder-Policy\', \'\']]", "[[\'Cross-Origin-Embedder-Policy\', \'*\']]", "[[\'Cross-Origin-Embedder-Policy\', \'credentialless\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Embedder-Policy\', \'credentialless\']]", "[[\'Cross-Origin-Embedder-Policy\', \'cross-origin\']]", "[[\'Cross-Origin-Embedder-Policy\', \'null\']]", "[[\'Cross-Origin-Embedder-Policy\', \'require-corp\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Embedder-Policy\', \'unsafe-none\']]", "[[\'Cross-Origin-Embedder-Policy\', \'unsafe-none, credentialless, cross-origin\']]", \'[]\']', pred=1.0)
#         └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", split='browser')
#             ├── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", split='raw_header')
#             │   ├── AnyNode(path2='raw_header:["[[\'Cross-Origin-Embedder-Policy\', \'require-corp\']]"]', split='resp_origin')
#             │   │   ├── AnyNode(path2="resp_origin:['https://headers.webappsec.eu']", pred=0.0)
#             │   │   └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu']", pred=1.0)
#             │   └── AnyNode(path2='raw_header:["[[\'Cross-Origin-Embedder-Policy\', \'\']]", "[[\'Cross-Origin-Embedder-Policy\', \'*\']]", "[[\'Cross-Origin-Embedder-Policy\', \'credentialless\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Embedder-Policy\', \'credentialless\']]", "[[\'Cross-Origin-Embedder-Policy\', \'cross-origin\']]", "[[\'Cross-Origin-Embedder-Policy\', \'null\']]", "[[\'Cross-Origin-Embedder-Policy\', \'require-corp\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Embedder-Policy\', \'unsafe-none\']]", "[[\'Cross-Origin-Embedder-Policy\', \'unsafe-none, credentialless, cross-origin\']]", \'[]\']', pred=1.0)
#             └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='raw_header')
# ├── AnyNode(path2='raw_header:[\'[[\\\'Feature-Policy\\\', "fullscreen \\\'self\\\'"]]\', "[[\'Feature-Policy\', \'fullscreen *\']]", "[[\'Permissions-Policy\', \'*\']]", "[[\'Permissions-Policy\', \'fullscreen=\']]", "[[\'Permissions-Policy\', \'fullscreen=()\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Permissions-Policy\', \'fullscreen=(*)\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Permissions-Policy\', \'fullscreen=(self none)\']]", "[[\'Permissions-Policy\', \'fullscreen=(self)\']]", "[[\'Permissions-Policy\', \'fullscreen=(self,none)\']]", "[[\'Permissions-Policy\', \'fullscreen=*\']]", "[[\'Permissions-Policy\', \'null\']]", \'[]\']', pred=0.0)
# └── AnyNode(path2='raw_header:[\'[[\\\'Feature-Policy\\\', "fullscreen \\\'none\\\'"]]\', \'[[\\\'Feature-Policy\\\', "fullscreen \\\'src\\\'"]]\', "[[\'Feature-Policy\', \'fullscreen *.headers.websec.saarland\']]", "[[\'Feature-Policy\', \'fullscreen *.sub.headers.websec.saarland\']]", "[[\'Feature-Policy\', \'fullscreen https://sub.headers.websec.saarland\']]", "[[\'Permissions-Policy\', \'fullscreen=()\']]", "[[\'Permissions-Policy\', \'fullscreen=(*.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(*.sub.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland/)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland:443/)\']]", "[[\'Permissions-Policy\', \'fullscreen=(src)\']]"]', split='browser')
#     ├── AnyNode(path2="browser:['firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=0.0)
#     └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real']", split='org_origin')
#         ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='resp_origin')
#         │   ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
#         │   └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='raw_header')
#         │       ├── AnyNode(path2='raw_header:["[[\'Feature-Policy\', \'fullscreen https://sub.headers.websec.saarland\']]"]', split='resp_origin')
#         │       │   ├── AnyNode(path2="resp_origin:['https://sub.headers.websec.saarland']", pred=0.0)
#         │       │   └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=1.0)
#         │       └── AnyNode(path2='raw_header:[\'[[\\\'Feature-Policy\\\', "fullscreen \\\'none\\\'"]]\', \'[[\\\'Feature-Policy\\\', "fullscreen \\\'src\\\'"]]\', "[[\'Feature-Policy\', \'fullscreen *.headers.websec.saarland\']]", "[[\'Feature-Policy\', \'fullscreen *.sub.headers.websec.saarland\']]", "[[\'Permissions-Policy\', \'fullscreen=()\']]", "[[\'Permissions-Policy\', \'fullscreen=(*.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(*.sub.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland/)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland:443/)\']]", "[[\'Permissions-Policy\', \'fullscreen=(src)\']]"]', pred=1.0)
#         └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", split='raw_header')
#             ├── AnyNode(path2='raw_header:["[[\'Feature-Policy\', \'fullscreen https://sub.headers.websec.saarland\']]"]', split='resp_origin')
#             │   ├── AnyNode(path2="resp_origin:['https://sub.headers.websec.saarland']", pred=0.0)
#             │   └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=1.0)
#             └── AnyNode(path2='raw_header:[\'[[\\\'Feature-Policy\\\', "fullscreen \\\'none\\\'"]]\', \'[[\\\'Feature-Policy\\\', "fullscreen \\\'src\\\'"]]\', "[[\'Feature-Policy\', \'fullscreen *.headers.websec.saarland\']]", "[[\'Feature-Policy\', \'fullscreen *.sub.headers.websec.saarland\']]", "[[\'Permissions-Policy\', \'fullscreen=()\']]", "[[\'Permissions-Policy\', \'fullscreen=(*.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(*.sub.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland/)\']]", "[[\'Permissions-Policy\', \'fullscreen=(https://sub.headers.websec.saarland:443/)\']]", "[[\'Permissions-Policy\', \'fullscreen=(src)\']]"]', pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='resp_origin')
# ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
# └── AnyNode(path2="resp_origin:['http://headers.websec.saarland']", split='raw_header')
#     ├── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'\']]", "[[\'Referrer-Policy\', \'*\']]", "[[\'Referrer-Policy\', \'abc, strict-origin\']]", "[[\'Referrer-Policy\', \'no-referrer\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Referrer-Policy\', \'no-referrer\']]", "[[\'Referrer-Policy\', \'null\']]", "[[\'Referrer-Policy\', \'origin\']]", "[[\'Referrer-Policy\', \'origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'same-origin\']]", "[[\'Referrer-Policy\', \'strict-origin\']]", "[[\'Referrer-Policy\', \'strict-origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'unsafe-url\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", \'[]\']', pred=0.0)
#     └── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url\']]", "[[\'Referrer-Policy\', \'no-referrer-when-downgrade\']]", "[[\'Referrer-Policy\', \'unsafe-url\']]"]', split='org_origin')
#         ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", pred=0.0)
#         └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", split='browser')
#             ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real']", pred=0.0)
#             └── AnyNode(path2="browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='raw_header')
# ├── AnyNode(path2='raw_header:["[[\'Cross-Origin-Opener-Policy\', \'\']]", "[[\'Cross-Origin-Opener-Policy\', \'*\']]", "[[\'Cross-Origin-Opener-Policy\', \'null\']]", "[[\'Cross-Origin-Opener-Policy\', \'same-origin-plus-COEP\']]", "[[\'Cross-Origin-Opener-Policy\', \'unsafe-none\']]", "[[\'Cross-Origin-Opener-Policy\', \'unsafe-none, same-origin, same-origin-plus-COEP\']]", \'[]\']', pred=0.0)
# └── AnyNode(path2='raw_header:["[[\'Cross-Origin-Opener-Policy\', \'same-origin\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Opener-Policy\', \'same-origin\']]", "[[\'Cross-Origin-Opener-Policy\', \'same-origin-allow-popups\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Opener-Policy\', \'same-origin-allow-popups\']]"]', split='resp_origin')
#     ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", split='browser')
#     │   ├── AnyNode(path2="browser:['chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=0.0)
#     │   └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']", split='resp_origin')
#     │       ├── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland']", split='org_origin')
#     │       │   ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=0.0)
#     │       │   └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", pred=1.0)
#     │       └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=1.0)
#     └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='browser')
# ├── AnyNode(path2="browser:['firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=0.0)
# └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real']", split='status_code')
#     ├── AnyNode(path2="status_code:['302']", pred=0.0)
#     └── AnyNode(path2="status_code:['200']", split='org_origin')
#         ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='resp_origin')
#         │   ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
#         │   └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=1.0)
#         └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='resp_origin')
# ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
# └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='browser')
#     ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", split='raw_header')
#     │   ├── AnyNode(path2='raw_header:["[[\'origin-agent-cluster\', \'\']]", "[[\'origin-agent-cluster\', \'*\']]", "[[\'origin-agent-cluster\', \'0\']]", "[[\'origin-agent-cluster\', \'1\']]", "[[\'origin-agent-cluster\', \'?0\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'origin-agent-cluster\', \'?0\']]", "[[\'origin-agent-cluster\', \'?1\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'origin-agent-cluster\', \'?1, ?0, , 1, 0, true, false\']]", "[[\'origin-agent-cluster\', \'abc, ?1\']]", "[[\'origin-agent-cluster\', \'false\']]", "[[\'origin-agent-cluster\', \'null\']]", "[[\'origin-agent-cluster\', \'true\']]", \'[]\']', pred=0.0)
#     │   └── AnyNode(path2='raw_header:["[[\'origin-agent-cluster\', \'?1\']]"]', split='browser')
#     │       ├── AnyNode(path2="browser:['firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=0.0)
#     │       └── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb']", split='resp_origin')
#     │           ├── AnyNode(path2="resp_origin:['https://sub.headers.websec.saarland']", split='org_origin')
#     │           │   ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", pred=0.0)
#     │           │   └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=1.0)
#     │           └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=1.0)
# ...
# │       └── AnyNode(path2="browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']", split='raw_header')
# │           ├── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'\']]", "[[\'Referrer-Policy\', \'*\']]", "[[\'Referrer-Policy\', \'abc, strict-origin\']]", "[[\'Referrer-Policy\', \'no-referrer\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Referrer-Policy\', \'no-referrer\']]", "[[\'Referrer-Policy\', \'null\']]", "[[\'Referrer-Policy\', \'origin\']]", "[[\'Referrer-Policy\', \'origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'same-origin\']]", "[[\'Referrer-Policy\', \'strict-origin\']]", "[[\'Referrer-Policy\', \'strict-origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'unsafe-url\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", \'[]\']', pred=0.0)
# │           └── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url\']]", "[[\'Referrer-Policy\', \'no-referrer-when-downgrade\']]", "[[\'Referrer-Policy\', \'unsafe-url\']]"]', split='org_origin')
# │               ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=0.0)
# │               └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", pred=1.0)
# └── AnyNode(path2="resp_origin:['https://headers.websec.saarland']", split='raw_header')
#     ├── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'\']]", "[[\'Referrer-Policy\', \'*\']]", "[[\'Referrer-Policy\', \'abc, strict-origin\']]", "[[\'Referrer-Policy\', \'no-referrer\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Referrer-Policy\', \'no-referrer\']]", "[[\'Referrer-Policy\', \'null\']]", "[[\'Referrer-Policy\', \'origin\']]", "[[\'Referrer-Policy\', \'origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'same-origin\']]", "[[\'Referrer-Policy\', \'strict-origin\']]", "[[\'Referrer-Policy\', \'strict-origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'unsafe-url\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", \'[]\']', pred=0.0)
#     └── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url\']]", "[[\'Referrer-Policy\', \'no-referrer-when-downgrade\']]", "[[\'Referrer-Policy\', \'unsafe-url\']]"]', split='org_origin')
#         ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=0.0)
#         └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='browser')
#             ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real']", pred=0.0)
#             └── AnyNode(path2="browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='raw_header')
# ├── AnyNode(path2='raw_header:["[[\'Cross-Origin-Resource-Policy\', \'\']]", "[[\'Cross-Origin-Resource-Policy\', \'*\']]", "[[\'Cross-Origin-Resource-Policy\', \'cross-origin\']]", "[[\'Cross-Origin-Resource-Policy\', \'null\']]", "[[\'Cross-Origin-Resource-Policy\', \'same-site\']]", "[[\'Cross-Origin-Resource-Policy\', \'unsafe-none\']]", "[[\'Cross-Origin-Resource-Policy\', \'unsafe-none, same-site, cross-origin\']]", \'[]\']', split='raw_header')
# │   ├── AnyNode(path2='raw_header:["[[\'Cross-Origin-Resource-Policy\', \'\']]", "[[\'Cross-Origin-Resource-Policy\', \'*\']]", "[[\'Cross-Origin-Resource-Policy\', \'cross-origin\']]", "[[\'Cross-Origin-Resource-Policy\', \'null\']]", "[[\'Cross-Origin-Resource-Policy\', \'unsafe-none\']]", "[[\'Cross-Origin-Resource-Policy\', \'unsafe-none, same-site, cross-origin\']]", \'[]\']', pred=0.0)
# │   └── AnyNode(path2='raw_header:["[[\'Cross-Origin-Resource-Policy\', \'same-site\']]"]', split='resp_origin')
# │       ├── AnyNode(path2="resp_origin:['http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
# │       └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='org_origin')
# │           ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='resp_origin')
# │           │   ├── AnyNode(path2="resp_origin:['https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
# │           │   └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'https://headers.webappsec.eu']", pred=1.0)
# │           └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=1.0)
# └── AnyNode(path2='raw_header:["[[\'Cross-Origin-Resource-Policy\', \'same-origin\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Resource-Policy\', \'same-origin\']]", "[[\'Cross-Origin-Resource-Policy\', \'same-site\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]"]', split='resp_origin')
#     ├── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland', 'https://sub.headers.websec.saarland']", split='status_code')
#     │   ├── AnyNode(path2="status_code:['200']", split='org_origin')
#     │   │   ├── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='browser')
#     │   │   │   ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real']", pred=0.0)
#     │   │   │   └── AnyNode(path2="browser:['firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", split='resp_origin')
#     │   │   │       ├── AnyNode(path2="resp_origin:['https://sub.headers.websec.saarland']", pred=0.0)
#     │   │   │       └── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland']", pred=1.0)
#     │   │   └── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", split='resp_origin')
#     │   │       ├── AnyNode(path2="resp_origin:['http://sub.headers.websec.saarland']", pred=0.0)
#     │   │       └── AnyNode(path2="resp_origin:['https://sub.headers.websec.saarland']", pred=1.0)
#     │   └── AnyNode(path2="status_code:['302']", pred=1.0)
#     └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='raw_header')
# ├── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'\']]", "[[\'Referrer-Policy\', \'*\']]", "[[\'Referrer-Policy\', \'abc, strict-origin\']]", "[[\'Referrer-Policy\', \'no-referrer\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Referrer-Policy\', \'no-referrer\']]", "[[\'Referrer-Policy\', \'null\']]", "[[\'Referrer-Policy\', \'origin\']]", "[[\'Referrer-Policy\', \'origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'same-origin\']]", "[[\'Referrer-Policy\', \'strict-origin\']]", "[[\'Referrer-Policy\', \'strict-origin-when-cross-origin\']]", "[[\'Referrer-Policy\', \'unsafe-url\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", \'[]\']', pred=0.0)
# └── AnyNode(path2='raw_header:["[[\'Referrer-Policy\', \'no-referrer, no-referrer-when-downgrade, same-origin, origin, strict-origin, origin-when-cross-origin, strict-origin-when-cross-origin, unsafe-url\']]", "[[\'Referrer-Policy\', \'no-referrer-when-downgrade\']]", "[[\'Referrer-Policy\', \'unsafe-url\']]"]', split='resp_origin')
#     ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='resp_origin')
#     │   ├── AnyNode(path2="resp_origin:['http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", pred=0.0)
#     │   └── AnyNode(path2="resp_origin:['http://headers.webappsec.eu']", split='browser')
#     │       ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=0.0)
#     │       └── AnyNode(path2="browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb']", split='org_origin')
#     │           ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=0.0)
#     │           └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", pred=1.0)
#     └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu']", split='org_origin')
#         ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", pred=0.0)
#         └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", split='browser')
#             ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'safari macOS 14.0 17.0 selenium real']", pred=0.0)
#             └── AnyNode(path2="browser:['brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=1.0)
#
#
#
#
#
# AnyNode(path2='root:root', split='raw_header')
# ├── AnyNode(path2='raw_header:["[[\'Cross-Origin-Embedder-Policy\', \'\']]", "[[\'Cross-Origin-Embedder-Policy\', \'*\']]", "[[\'Cross-Origin-Embedder-Policy\', \'credentialless\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Embedder-Policy\', \'credentialless\']]", "[[\'Cross-Origin-Embedder-Policy\', \'cross-origin\']]", "[[\'Cross-Origin-Embedder-Policy\', \'null\']]", "[[\'Cross-Origin-Embedder-Policy\', \'require-corp\'], [\'location\', \'https://sub.headers.websec.saarland/_hp/common/empty.html\']]", "[[\'Cross-Origin-Embedder-Policy\', \'unsafe-none\']]", "[[\'Cross-Origin-Embedder-Policy\', \'unsafe-none, credentialless, cross-origin\']]", \'[]\']', pred=0.0)
# └── AnyNode(path2='raw_header:["[[\'Cross-Origin-Embedder-Policy\', \'require-corp\']]"]', split='resp_origin')
#     ├── AnyNode(path2="resp_origin:['http://headers.webappsec.eu', 'http://headers.websec.saarland', 'http://sub.headers.websec.saarland', 'http://sub.sub.headers.websec.saarland']", pred=0.0)
#     └── AnyNode(path2="resp_origin:['https://headers.webappsec.eu', 'https://headers.websec.saarland', 'https://sub.headers.websec.saarland', 'https://sub.sub.headers.websec.saarland']", split='org_origin')
#         ├── AnyNode(path2="org_origin:['http://sub.headers.websec.saarland']", split='browser')
#         │   ├── AnyNode(path2="browser:['brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium headless-new', 'brave Ubuntu 22.04 1.59.120 (118.0.5993.88) selenium xvfb', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium headless-new', 'brave Ubuntu 22.04 1.60.114 (119.0.6045.124) selenium xvfb', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium headless-new', 'brave macOS 14.0 1.60.118 (119.0.6045.163) selenium real', 'chrome Ubuntu 22.04 119 selenium headless-new', 'chrome Ubuntu 22.04 119 selenium xvfb', 'chrome macOS 14.0 119 selenium headless-new', 'chrome macOS 14.0 119 selenium real', 'edge Ubuntu 22.04 119 selenium headless-new', 'edge Ubuntu 22.04 119 selenium xvfb', 'edge macOS 14.0 119 selenium headless-new', 'edge macOS 14.0 119 selenium real', 'firefox Ubuntu 22.04 119 selenium headless', 'firefox Ubuntu 22.04 119 selenium xvfb', 'firefox macOS 14.0 119 selenium headless', 'firefox macOS 14.0 119 selenium real']", pred=0.0)
#         │   └── AnyNode(path2="browser:['safari macOS 14.0 17.0 selenium real']", pred=1.0)
#         └── AnyNode(path2="org_origin:['https://sub.headers.websec.saarland']", pred=1.0)
