# %%
import random
import re
import httpx
import glob
import os
from itertools import permutations, product

# %%
def randomize_casing(input_string, seed=42):
    """Randomize the casing of a string (fixed with a seed)."""
    random.seed(seed)
    return ''.join(random.choice([c.upper(), c.lower()]) for c in input_string)

def insert_char_middle(input_string, char):
    """Insert a char in the middle of a string."""
    middle_index = len(input_string) // 2
    return input_string[:middle_index] + char + input_string[middle_index:]

# %%
# All the mutations we apply on strings such as header names and header values
# Some of them may have no effect and result in duplicates; however such duplicates are not saved in the db

all_upper = lambda x: x.upper()
all_lower = lambda x: x.lower()
random_case = lambda x: randomize_casing(x)
leadtrail_space = lambda x: " " + x + " "
in_double_quotes = lambda x: '"' + x + '"'
in_single_quotes = lambda x: "'" + x + "'"
remove_whitespace = lambda x: x.replace(" ", "")
double_spaces = lambda x: x.replace(" ", "  ")
space_to_tab = lambda x: x.replace(" ", "\t")

lead_seqs = []
trail_seqs = []
middle_seqs = []

# All all ASCII chars as leading, trailing, and middle char
ascii_chars = [char for char in map(chr, range(128))]
# Alternatively use less ones? All/Some control chars? + space, comma, ....
# ascii_chars = [char for char in map(chr, range(32))] + [" ", ",", ";", ":"]
for seq in ascii_chars:
    lead_seqs.append(lambda x, s=seq: s + x)
    trail_seqs.append(lambda x, s=seq: x + s)
    middle_seqs.append(lambda x, s=seq: insert_char_middle(x, s))

# Add other interesting leading, trailing, middle chars: Double space, non-breaking space, full-width comma
# TODO: add more?
other_chars = ["  ", "\u00A0a", "\uFF0C"]
for seq in other_chars:
    lead_seqs.append(lambda x, s=seq: s + x)
    trail_seqs.append(lambda x, s=seq: x + s)
    middle_seqs.append(lambda x, s=seq: insert_char_middle(x, s))

# Replace some chars with others
chars_to_replace = [";", ",", ":", "=", "'", '"', "-", "_"]
# Replace each of the above with all of the below
replace_chars = [
    "", " ", ";", ",", ":", "=", "-", "_",
    "'", '"', "`", "´",
    '\u2018',  # Left Single Quotation Mark
    '\u2019',  # Right Single Quotation Mark
    '\u201A',  # Single Low-9 Quotation Mark
    '\u201B',  # Single High-Reversed-9 Quotation Mark
    '\u201C',  # Left Double Quotation Mark
    '\u201D',  # Right Double Quotation Mark
    '\u201E',  # Double Low-9 Quotation Mark
    '\u201F',  # Double High-Reversed-9 Quotation Mark
]
replace_funcs = []
for char in chars_to_replace:
    for rp in replace_chars:
        if rp == char:
            continue
        replace_funcs.append(lambda x, c1=char, c2=rp: x.replace(c1, c2))



general_mutations = [
    all_upper,
    all_lower,
    random_case,
    leadtrail_space,
    in_double_quotes,
    in_single_quotes,
    remove_whitespace,
    double_spaces,
    space_to_tab,
    *lead_seqs,
    *trail_seqs,
    *middle_seqs,
    *replace_funcs,
]


def mutate_header_name(header_name):
    header_names = set()
    for mutation in general_mutations:
        header_names.add(mutation(header_name))
    return header_names

def mutate_header_value(header_value):
    header_values = set()
    for mutation in general_mutations:
        header_values.add(mutation(header_value))
    return header_values

# %%
l = mutate_header_value("D EN'Y")
print(l)
print(list(l)[0])
# Out:
# {"D E~N'Y", "D ERN'Y", "<D EN'Y", "D E\\N'Y", "D EN'Y|", "D EN'Y\x0c", 'D EN’Y', "D E\x1bN'Y", "D E\x13N'Y", " D EN'Y ", ">D EN'Y", "D EWN'Y", "D EkN'Y", "sD EN'Y", "xD EN'Y", "D E  N'Y", "OD EN'Y", "D ErN'Y", "aD EN'Y", "D E\x0cN'Y", "D EUN'Y", "d en'y", "\x7fD EN'Y", "D EVN'Y", "2D EN'Y", "D E\x12N'Y", "5D EN'Y", "\x08D EN'Y", "D EN'YK", 'D EN‘Y', "D\tEN'Y", "D EN'Y\x1c", "KD EN'Y", "\x12D EN'Y", "~D EN'Y", "D E\x1cN'Y", "D ESN'Y", "D EiN'Y", "!D EN'Y", "\x10D EN'Y", 'D EN”Y', "VD EN'Y", "\x0bD EN'Y", "，D EN'Y", "D E)N'Y", "/D EN'Y", "lD EN'Y", "D EN'Y\x11", "QD EN'Y", "D EN'Y\x15", "D E>N'Y", "D ENN'Y", "D E\x04N'Y", "D EN'Y\x01", "D E\x15N'Y", 'D EN‚Y', "D E5N'Y", "\x15D EN'Y", "D EaN'Y", "D EN'Y\x19", "D EN'Y\x0f", "\x17D EN'Y", "D EN'Yr", "D EN'Yx", "D EDN'Y", "D EN'Y\x05", "D E\x10N'Y", "'D EN'Y", "D EhN'Y", "D EN'Y\x14", "D E#N'Y", "D EN'Yh", "D EN'Y[", "D E'N'Y", "D EN'YJ", "D E=N'Y", "yD EN'Y", '"D EN\'Y', "-D EN'Y", "D EcN'Y", "D EN'Yi", "ZD EN'Y", "D EQN'Y", "D EyN'Y", "D EN'Y)", "D EN'Yl", "D EN'Y@", "#D EN'Y", "D EN'Y\t", "D EN'Y*", "\\D EN'Y", 'D EN,Y', "1D EN'Y", "D eN'Y", "D EN'Y\x13", "D EAN'Y", "^D EN'Y", "CD EN'Y", "D EN'Yf", "BD EN'Y", "D EN'Y\x1b", "\x1dD EN'Y", "bD EN'Y", "D E\x0fN'Y", "D EN'Y\x17", "D E{N'Y", "D EN'YL", "\x1bD EN'Y", "DD EN'Y", "D EN'Y%", "D EN'Y ", "MD EN'Y", "D EzN'Y", "D EN'YW", "D E\xa0aN'Y", "D E1N'Y", "]D EN'Y", "D E@N'Y", "D EON'Y", "D E6N'Y", "D E\x1fN'Y", "3D EN'Y", "D EN'Y\n", "D EN'Y\x12", 'D EN‛Y', " D EN'Y", "D E2N'Y", "D EN'Y$", "D EoN'Y", "\x16D EN'Y", "FD EN'Y", "D E\x0bN'Y", "D EN'Yj", "D EN'Y  ", "D E0N'Y", "D E\x0eN'Y", "\x06D EN'Y", "D E\x06N'Y", "D EN'YQ", "D ExN'Y", "D E\x7fN'Y", "\x13D EN'Y", "D E\x08N'Y", "D EN'YM", "D EKN'Y", "D EN'Y\x08", "D EN'Y<", "D EN'Ys", "D EN'Ym", "D EN'Yt", "D E(N'Y", "D EN'Y,", "JD EN'Y", 'D EN„Y', "D E\x14N'Y", "D E*N'Y", "D E N'Y", "D EN'Yd", "D EN'Yb", ";D EN'Y", "YD EN'Y", "D EN'Y\x04", "D EN'YF", "RD EN'Y", "D ECN'Y", "\x01D EN'Y", "jD EN'Y", "D EN'Y5", "{D EN'Y", "D E9N'Y", "D EN'Y\x03", "D EJN'Y", ",D EN'Y", "D EN'Yo", "0D EN'Y", "D EgN'Y", "D E|N'Y", "\rD EN'Y", "HD EN'Y", "gD EN'Y", "D E/N'Y", "\x1eD EN'Y", "D E\x1dN'Y", "iD EN'Y", "D EN'YY", "D EN'Y6", 'D EN‟Y', "D EMN'Y", "D EN'Y+", "D EN'Yp", "D EEN'Y", "D E\x05N'Y", "D EN'Y`", "D EfN'Y", "ID EN'Y", "D EN'YO", "D EGN'Y", "D EN'Yc", "wD EN'Y", "D E;N'Y", "D EN'Y\x16", "\x04D EN'Y", "*D EN'Y", "D EN'Y\x0b", "D EN'Y8", "D EwN'Y", "D EN'YE", "=D EN'Y", "\x1aD EN'Y", "D EN'YZ", "D EN'Y~", "D ETN'Y", "cD EN'Y", "dD EN'Y", "D EN'Yk", "D EnN'Y", "'D EN'Y'", "D EpN'Y", "qD EN'Y", "D EN'Yy", "GD EN'Y", "D EN'Y^", "D E$N'Y", "D EIN'Y", "D EN'Y7", "D EN'Y&", "D EN'YD", "D EN'Y#", "D EN'Y0", "pD EN'Y", "kD EN'Y", "D EN'YC", "uD EN'Y", "D EN'YS", "D E?N'Y", "D EN'Y_", "_D EN'Y", "@D EN'Y", "D EN'YP", "9D EN'Y", "}D EN'Y", "D EtN'Y", "D E4N'Y", "D EN'Yw", "D EN'Y9", "D EN'Y(", "\tD EN'Y", 'D ENY', "D EN'Y\x1f", "D E\x03N'Y", "D ELN'Y", "D EHN'Y", "D E<N'Y", "D EN'Y}", "D E\x00N'Y", "`D EN'Y", "D EFN'Y", "?D EN'Y", "[D EN'Y", "mD EN'Y", "D EPN'Y", "D EN'Y\x18", "D EN'YT", "D EqN'Y", "vD EN'Y", "4D EN'Y", "\x19D EN'Y", "D E+N'Y", "D E:N'Y", "D E&N'Y", "7D EN'Y", "D E\x18N'Y", "D EN'Y\x1a", "TD EN'Y", "D E\nN'Y", "D EmN'Y", 'D EN`Y', ":D EN'Y", "LD EN'Y", "\x05D EN'Y", "D EN'Y\x02", "D EN'Y-", 'D EN\'Y"', "D EN'Ye", "D EN'YX", "D EN'YG", "D E.N'Y", "D EN'Y\x0e", "D EN'Y:", "D EjN'Y", "D EBN'Y", 'D EN-Y', "  D EN'Y", 'D EN Y', "D EN'Yu", "D EN'YN", "D E\x07N'Y", 'D EN=Y', "D EN'Y", "\x14D EN'Y", "D EN'Y\x00", "D EN'YR", "$D EN'Y", "\x0cD EN'Y", 'D EN“Y', "D EN'Y\x1d", "\xa0aD EN'Y", "|D EN'Y", "8D EN'Y", "D EN'Y.", "D EN'Y'", "\x18D EN'Y", "D EYN'Y", "\x03D EN'Y", "D EN'Yz", "\x11D EN'Y", "D EN'Y\r", "D EXN'Y", "&D EN'Y", "ED EN'Y", "SD EN'Y", 'D E"N\'Y', "D EN'Y\x10", "D E7N'Y", 'D EN_Y', ".D EN'Y", "zD EN'Y", "UD EN'Y", "6D EN'Y", "D E[N'Y", "D E_N'Y", "ND EN'Y", "WD EN'Y", "D EN'Y\x1e", "D  EN'Y", "D EN'Yn", "(D EN'Y", "D EeN'Y", "D EN'Yg", "D EN'YV", "D EN'YU", "D E%N'Y", "D EN'Y3", "%D E ...
# D E~N'Y

# %%
class HeaderTests:
    def __init__(self, label: str, header_name: str, alt_names: list[str], block_values: list[str], allow_values: list[str], partial_values: list[str], legacy_values: list[str], other_values: list[str]):
        """"HeaderTests class to create lots of responses
        label (str): Additional information about these responses (e.g., XFO)
        header_name (str): The correct lower-case name of the header
        alt_names (list[str]): Legacy and other (invalid) alternative header names
        block_values (list[str]): Valid values to set the header to "blocking" (e.g., DENY for XFO means always disallow framing)
        allow_values (list[str]): Valid values to set the header to "allowing" (e.g., unsafe-none  for COOP means do not activate COOP/always allow)
        partial_values (list[str]): Valid values to set the header to an intermediate mode (e.g., SAMEORIGIN for XFO means allow framing only for same-origin)
        legacy_values (list[str]): Legacy values that should not work anymore
        other_values (list[str]): Other values we want to test as well (can include valid ones if we do not want to put too many in the other categories)
        """
        self.label = label
        self.header_name = header_name
        self.alt_names = alt_names
        self.block_values = block_values
        self.allow_values = allow_values
        self.partial_values = partial_values
        self.legacy_values = legacy_values
        self.other_values = other_values
        self.responses = []

    def create_response(self, header, label, status_code=200, resp_type="parsing"):
        self.responses.append((header, label, status_code, resp_type))

    def save_responses(self):
        #with Session() as session:
        #for header in header_list:
         #r, created = get_or_create(session, Response, raw_header=header, status_code=status_code, label=label, resp_type=resp_type)
         #if created:
            #print(r)
        print(len(self.responses))
        print(self.responses)

    def header_name_tests(self):
        """Test all block, allow, partial values (correct values)
            with the correct header names, with all alternative/legacy header names, and with mutated versions of the correct header_name
        """
        for value_group in [self.block_values, self.allow_values, self.partial_values]:
            for header_value in value_group:
                # Original header name
                self.create_response([(self.header_name, header_value)], self.label)
                # Alt header names
                for header_name in self.alt_names:
                    self.create_response([(header_name, header_value)], self.label)
                # Mutated header names
                for header_name in mutate_header_name(self.header_name):
                    self.create_response([(header_name, header_value)], self.label)

    def parsing_tests(self):
        """Test all header values + mutated versions.
        """
        # Test all legacy and other values (block, allow, partial do not have to be tested as they are already tests by header_name_tests)
        for value_group in [self.legacy_values, self.other_values]:
            for header_value in value_group:
                self.create_response([(self.header_name, header_value)], self.label)
        
        # Mutate/change header values (block, allow, partial)
        for value_group in [self.block_values, self.allow_values, self.partial_values]:
            for org_header_value in value_group:
                # Other status codes
                for code in [201, 203, 204, 300, 302, 400, 403, 404, 418, 500]:
                    if 300 <= code < 400:
                        self.create_response([(self.header_name, org_header_value), redirect_empty], self.label, status_code=code)
                    else:
                        self.create_response([(self.header_name, org_header_value)], self.label, status_code=code)
                # Mutated header values
                for header_value in mutate_header_value(org_header_value):
                    self.create_response([(self.header_name, header_value)], self.label)

    def mult_headers_tests(self):
        """Test involving multiple headers/values
        """
        all_valid_values = self.block_values + self.allow_values + self.partial_values
        all_orders = list(permutations(all_valid_values))
        # Basic1: all legal values in a list in all possible orders (Comma, space, semicolon-separated)
        for order in all_orders:
            self.create_response([(self.header_name, ", ".join(order))], self.label)
            self.create_response([(self.header_name, "; ".join(order))], self.label)
            self.create_response([(self.header_name, " ".join(order))], self.label)
        
        # Basic2: all legal values in separate headers in all possible orders
        for order in all_orders:
            headers = [(self.header_name, header_value) for header_value in order]
            self.create_response(headers, self.label)
        # Basic3: all legal values in both separate headers and in one header with comma?!
        # Only if at least 3 values; split in first and all others and last and all others
        for order in all_orders:
            if len(order) >= 3:
                first, rest1 = order[0], ", ".join(order[1:])
                rest2, last = ", ".join(order[:-1]), order[-1]
                self.create_response([(self.header_name, first), (self.header_name, rest1)], self.label)
                self.create_response([(self.header_name, rest2), (self.header_name, last)], self.label)

        # Basic4: all legal values duplicated
        for value in all_valid_values:
            self.create_response([(self.header_name, value), (self.header_name, value)], self.label)
            self.create_response([(self.header_name, f"{value}, {value}")], self.label)
            
            # Could be extended with mutated versions once, e.g., X-Frame-Options: ALLOWALL, allowall;
            # Browsers should first lowercase and then put each value in a set https://html.spec.whatwg.org/multipage/document-lifecycle.html#the-x-frame-options-header
            # Which means no blocking should occur, if they forget the lowercasing part, the set size would be two and it would be blocked
            # Other extensions possible as well
            self.create_response([(self.header_name, value), (self.header_name, value.lower())], self.label)
            self.create_response([(self.header_name, value), (self.header_name, value.upper())], self.label)
        
        # Advanced1: use different header names (e.g., if a browser accepts both x-frame-options and X-FRAME-OPTIONS which takes precedence?; might be none if the browser first lower-cases or something like that)
        # Currently only either uppercase the first header or all except the first header (other mutations and header duplication strategies could be added in the future)
        # Could be extended with clearly invalid headers (e.g., leading or trailing space, ...)
        for order in all_orders:
            for (header1, header2) in [(self.header_name, self.header_name.upper()), (self.header_name.upper(), self.header_name)]:
                headers = [(self.header_name, header_value) for header_value in order]
                headers = []
                for i, header_value in enumerate(order):
                    if i == 0:
                        headers.append((header1, header_value))
                    else:
                        headers.append((header2, header_value))
                self.create_response(headers, self.label)
    
        # Advanced2: use invalid values as well (e.g., a browser might always take the first header while another browser takes the first valid header?)
        for valid_value in all_valid_values:
            # Only use the first two invalid values (should be empty and a clearly invalid value ("INVALID")
            # Could be extended with more complex approaches
            for invalid_value in self.other_values[:2]:
                self.create_response([(self.header_name, valid_value), (self.header_name, invalid_value)], self.label)
                self.create_response([(self.header_name, invalid_value), (self.header_name, valid_value)], self.label)
                self.create_response([(self.header_name, f"{valid_value}, {invalid_value}")], self.label)
                self.create_response([(self.header_name, f"{invalid_value}, {valid_value}")], self.label)

        # TODO special: XFO and CSP-FA

                
    def create_all_tests(self):
        self.header_name_tests()
        self.parsing_tests()
        self.mult_headers_tests()
        self.save_responses()

# %%
redirect_empty = ("location", "https://sub.headers.websec.saarland/_hp/common/empty.html")
site = "sub.headers.websec.saarland"
origin_s = "https://sub.headers.websec.saarland"
origin_s_upper = "HTTPS://SUB.HEADERS.WEBSEC.SAARLAND"
origin_s_path = f"{origin_s}/abc/"
origin_s_query = f"{origin_s}/?a=a"
origin = "http://sub.headers.websec.saarland"
origin_sp = f"{origin_s}:443"
home = f"{origin_s}/"
home_p = f"{origin_sp}/"
parent = "https://headers.websec.saarland"
child = "https://sub.sub.headers.websec.saarland"
parent_childs = "*.headers.websec.saarland"
self_childs = "*.sub.headers.websec.saarland"
self_childs_https = "https://*.sub.headers.websec.saarland"
cross_site_origin = "https://headers.webappsec.eu"
all_replacements = [site, origin_s, origin_s_upper, origin_s_path, origin_s_query, origin, origin_sp, home, home_p, parent, child, parent_childs, self_childs, self_childs_https, cross_site_origin]
URL_REP = "<!URL!>"

# %%
def expand_urls(other_values):
    """Use different URL, origins, sites variations if the value should allow some sites"""
    return_values = []
    for value in other_values:
        if not URL_REP in value:
            return_values.append(value)
        else:
            # TODO: use combinations if more than one URL in value!
            # Only if less than 2 occurrences? Else chose a random value for each?

            # Currently: replace all occurrences of URL_REP with the same url_like
            for url_like in all_replacements:
                return_values.append(value.replace(URL_REP, url_like))
    return return_values

# %%
label = ""
header_name = ""
alt_names = []
block_values = []
allow_values = []
partial_values = []
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
other_values = ["", "INVALID"]
other_values = expand_urls(other_values)

# %%
def get_values(url, pattern):
    content = httpx.get(url).text
    content = content.replace("TESTURI", URL_REP)
    content = content.replace("http://randomorigin.com/", URL_REP)
    content = content.replace("http://randomorigin.com", URL_REP)
    content = content.replace("http://much.ninja", URL_REP)
    content = content.replace("http://random.ninja", URL_REP)
    content = content.replace("https://much.ninja", URL_REP)
    content = content.replace("http://*.ninja", URL_REP)
    content = content.replace("*.ninja", URL_REP)
    content = content.replace("much.ninja", URL_REP)
    matches = list(set(re.findall(pattern, content)))
    return matches

siewert_xfo = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'X-Frame-Options: (.*?)\'")
print(siewert_xfo)
print()
siewert_csp = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'Content-Security-Policy: (.*?)\'")
print(siewert_csp)
# Out:
# ['sameorigin, sameorigin', 'sameorigin; sameorigin', 'sameorigin, allow-from <!URL!>', 'allow-from <!URL!>; deny', 'allow-from <!URL!>; allow-from <!URL!>', 'sameorigin', 'deny, sameorigin', 'sameorigin, deny', 'allowall', 'deny; sameorigin', 'deny; deny', 'allow-from <!URL!>, sameorigin', 'RANDOMDIRECTIVE', 'allow-from <!URL!>', 'allow-from <!URL!>, allow-from <!URL!>', 'allow-from <!URL!>, deny', 'deny; allow-from <!URL!>', 'sameorigin; deny', 'deny, allow-from <!URL!>', 'deny', 'deny, deny']
#
# ['frame-ancestors https:;', 'frame-ancestors <!URL!>;', 'frame-ancestors <!URL!> <!URL!>;', 'frame-ancestors http:;']

# %%
def get_wpt_values(dir_path, pattern=r'headerValue: `(.*)`|headerValue2: `(.*)`'):
    # Initialize a list to store matching strings
    values = set()
    # Use glob to find all files with the specified extension recursively
    file_paths = glob.glob(os.path.join(dir_path, '*.html'), recursive=False)
    # Iterate through the list of file paths
    for file_path in file_paths:
        with open(file_path, 'r') as f:
            content = f.read()
            content = content.replace("https://example.com/", URL_REP)
            matches = re.findall(pattern, content)
            for match1, match2 in matches:
                values.add(match1)
                values.add(match2)
    return list(values)

wpt_xfo = get_wpt_values('../../../x-frame-options/')
wpt_xfo
# Out:
# ['',
#  'SAMEORIGIN',
#  '"DENY"',
#  'sameOriGin',
#  'ALLOW-FROM <!URL!>',
#  'sameOrigin',
#  'ALLOW-FROM=<!URL!>',
#  ',SAMEORIGIN,,DENY,',
#  '  DENY ',
#  '  SAMEORIGIN,    DENY',
#  '"SAMEORIGIN"',
#  'ALLOWALL',
#  'INVALID',
#  '  SAMEORIGIN ',
#  'denY',
#  'allowAll',
#  '"SAMEORIGIN,DENY"',
#  'DENY']

# %%
def limit_url_occurrences(input_string, max_occurrences):
    # Define the pattern to match <!URL!>
    url_pattern = re.compile(rf'{URL_REP}(?:(\s|,)*(ALLOW-FROM )?(allow-from )?{URL_REP})+')
    #url_pattern = re.compile(rf'{URL_REP}(?:(\s|,)*{URL_REP})+')

    # Find all consecutive occurrences of <!URL!>
    consecutive_url_matches = url_pattern.findall(input_string)

    # Calculate the number of replacements needed
    replacements_needed = max(0, len(consecutive_url_matches) - max_occurrences)

    # Replace excess consecutive occurrences with <!URL!>
    replaced_string = url_pattern.sub('', input_string, count=replacements_needed)

    return replaced_string


def replace_multiple_urls(input_string):
    # Define the pattern to match three or more consecutive <!URL!>
    url_pattern = re.compile(r'((<!URL!>\s*){3,})')

    # Replace three or more consecutive <!URL!> with a single <!URL!>
    replaced_string = re.sub(url_pattern, '<!URL!> ', input_string)

    return replaced_string


def run_replacements(input_string):
    input_string = replace_multiple_urls(input_string)
    input_string = limit_url_occurrences(input_string, 4)
    input_string = re.sub("sha256-\S+", "sha256-default", input_string)
    return input_string

def get_crawler_values(url, min_count=0):
    content = httpx.get(url).text
    content = re.sub(r"(http(s)?|HTTP(S)?)://[\w.*/\-:?=]*|([\w*\-/]+\.)+[\w*\-:/?=]+", URL_REP, content)
    rows = [row.rsplit(" ", maxsplit=1) for row in content.split("\r\n")[1:] if " " in row]
    # Only use values occuring more than once? Otherwise we have to many possible values?
    rows = [row[0] for row in rows if int(row[1].replace(",","")) >= min_count]
    return list(set([run_replacements(row) for row in rows]))

crawler_ninja_xfo = get_crawler_values("https://crawler.ninja/files/xfo-values.txt")
print(len(crawler_ninja_xfo))
#display(crawler_ninja_xfo)
crawler_ninja_csp = get_crawler_values("https://crawler.ninja/files/csp-values.txt", min_count=2)
print(len(crawler_ninja_csp))
crawler_ninja_csp
# Out:
# 300
# 2971
# ['',
#  "style-src 'unsafe-inline' 'self' *; font-src 'self' * data:; script-src 'unsafe-inline' 'unsafe-eval' 'self' blob: *; object-src 'self' *; frame-src 'self' *; connect-src 'unsafe-inline' 'unsafe-eval' 'self' blob: *;",
#  "frame-ancestors <!URL!>; base-uri 'self'; default-src data: 'unsafe-inline' 'unsafe-eval' https:; script-src 'unsafe-inline' https:; style-src data: 'unsafe-inline' https:; img-src data: https: blob:; font-src data: https:; connect-src https: wss: blob:; media-src https: blob:; object-src ; child-src https: data: blob:; form-action 'self' https:; block-all-mixed-content",
#  "default-src https:  wss:; script-src https: 'unsafe-inline' 'unsafe-eval' <!URL!>; style-src https: 'unsafe-inline' <!URL!>; img-src https: data: <!URL!>; font-src data: https:; connect-src https: wss:; media-src blob: https:; object-src https:; frame-src http: https: <!URL!>; worker-src blob: https:; frame-ancestors 'self' <!URL!> ; form-action 'self' <!URL!> ; upgrade-insecure-requests; block-all-mixed-content; manifest-src https: ; ",
#  "default-src 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline'; font-src 'self'; img-src 'self' data: <!URL!> ; child-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; object-src 'none'; connect-src 'self' <!URL!> ; worker-src 'none'; form-action 'self'; frame-ancestors 'self'; base-uri 'self'; upgrade-insecure-requests; block-all-mixed-content;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' data: blob: *; report-uri /report-csp-violation; upgrade-insecure-requests",
#  "default-src 'self' <!URL!>; script-src <!URL!> 'self' 'unsafe-inline' 'unsafe-eval' http: https:; img-src <!URL!> * data:; style-src <!URL!> 'self' 'unsafe-inline' *; font-src * data:; connect-src <!URL!> *; frame-src <!URL!> * data:; worker-src 'blob:' *",
#  "default-src 'none'; script-src 'self' 'unsafe-inline' 'unsafe-eval'  https:; manifest-src 'self'; child-src 'self'; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> ; img-src 'self'  https: data: <!URL!> ; media-src 'self' data: <!URL!>; object-src 'self' data:; connect-src 'self' data: <!URL!> wss:<!URL!> https: wss:; frame-src <!URL!> https:; frame-ancestors 'self'; form-action <!URL!>",
#  "default-src 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: data:  ; style-src 'self' 'unsafe-inline' data: <!URL!> ; object-src 'none'; base-uri 'self'; connect-src 'self' wss: data: <!URL!> ; font-src 'self' data: blob: <!URL!> ; frame-ancestors 'self'; frame-src 'self' about: <!URL!> ; img-src 'self' blob: data: about: <!URL!> ; manifest-src 'self' data:; media-src 'self';",
#  "default-src 'self' ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'none' ; style-src 'self' 'unsafe-inline' <!URL!> ; img-src 'self' data: <!URL!> ; media-src 'none'; frame-src <!URL!> ; connect-src 'self' ; font-src 'self' <!URL!>",
#  "frame-ancestors 'self'; default-src 'unsafe-inline' 'unsafe-eval' 'self' blob: data: <!URL!> ;",
#  "img-src 'self' <!URL!> data: <!URL!> ;connect-src 'self' ;object-src 'none';media-src 'self' <!URL!> data:;child-src *;frame-src *;form-action <!URL!> 'self';frame-ancestors 'self' <!URL!> ;upgrade-insecure-requests;worker-src 'self' <!URL!> data:",
#  "default-src http: https: 'self' wss: ws:; script-src http: https: blob: 'unsafe-inline' 'unsafe-eval' 'self' <!URL!> ; style-src http: https: 'unsafe-inline'; img-src http: https: 'unsafe-inline' data:; font-src http: https: 'unsafe-inline' data:;",
#  "base-uri 'none'; object-src 'none';             style-src 'self' 'unsafe-inline' <!URL!> ;             script-src 'nonce-c/1rZ+z+a/hKTm4avOPqew==' 'strict-dynamic' 'unsafe-eval'; frame-ancestors <!URL!> ;             frame-src <!URL!> ;",
#  "default-src 'self'; connect-src *; font-src * data:; frame-src *; img-src * data:; media-src *; object-src *; script-src * 'unsafe-inline' 'unsafe-eval'; style-src * 'unsafe-inline'; manifest-src <!URL!>;",
#  "default-src https: data: blob:; script-src 'unsafe-inline' 'unsafe-eval' https: data:; style-src 'unsafe-inline' https: data:; img-src data: https: blob: android-webview android-webview-video-poster:; font-src data: https:; connect-src *; media-src https: data: blob:; worker-src https: blob:; frame-src 'self' https:; frame-ancestors 'self'; upgrade-insecure-requests",
#  'self',
#  "default-src 'self' data:;script-src 'self' 'unsafe-eval' 'unsafe-inline' data: <!URL!> ;style-src 'self' 'unsafe-inline' data: <!URL!> 'unsafe-eval' <!URL!> ;connect-src blob: <!URL!> ;font-src data: <!URL!> ;img-src 'self' blob: data: <!URL!> ;media-src blob: data: <!URL!> ;child-src blob: data: <!URL!>;frame-src data: <!URL!> ;worker-src blob: data: <!URL!>;block-all-mixed-content;upgrade-insecure-requests;report-uri <!URL!>;",
#  '"unsafe-inline";',
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' https: <!URL!> ; frame-ancestors 'none'",
#  "upgrade-insecure-requests;connect-src * data: blob: 'unsafe-inline';",
#  "default-src <!URL!> wss:<!URL!> data: ws: wss: eval: inline: 'unsafe-eval' 'unsafe-inline' ; connect-src <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> data: ws: wss: eval: inline: 'unsafe-eval' 'unsafe-inline'; font-src http: https: data:; img-src http: https: data: blob:; worker-src http: https: data: blob:; child-src http: https: data: blob:; frame-ancestors 'self' <!URL!> ",
#  'img-src https:',
#  "default-src * 'unsafe-inline' 'unsafe-eval' https: http: data: blob:; worker-src blob: 'self';",
#  "upgrade-insecure-requests; base-uri 'self'",
#  "default-src 'self' <!URL!>;script-src * 'unsafe-inline' 'unsafe-eval';img-src * data:;style-src 'self' 'unsafe-inline' <!URL!> ;connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ;form-action 'self';frame-ancestors 'self';frame-src 'self' <!URL!> ;child-src 'self';font-src * data:;object-src 'none';manifest-src 'self' 'unsafe-inline' data:;upgrade-insecure-requests",
#  "default-src 'self' https: http: bankid:; connect-src 'self' ws: wss: <!URL!> wss:<!URL!> ; font-src 'self' data: <!URL!> wss:; frame-src 'self' bankid://* <!URL!> wss:<!URL!> ; img-src 'self' https: http: data: blob: <!URL!> ; script-src 'self' 'unsafe-eval' <!URL!> wss:<!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> wss:<!URL!> ; worker-src 'self' blob:; report-uri <!URL!>",
#  "default-src 'self' blob: ; script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: @lottiefiles/lottie-player@@dotlottie/player-component@<!URL!> @reactivex/ <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; object-src 'none'; base-uri 'self'; connect-src 'self' <!URL!>@reactivex/* <!URL!> wss: wss:<!URL!> ; font-src data: 'self' <!URL!> ; frame-src 'self' data: 'unsafe-inline' 'unsafe-eval' <!URL!> ; img-src 'self' data: <!URL!> ; manifest-src 'self'; media-src 'self' ;",
#  "default-src 'unsafe-inline' 'unsafe-eval' ; script-src 'unsafe-eval' 'unsafe-inline' 'self' <!URL!> ; font-src 'self' <!URL!> data:; style-src 'unsafe-inline' 'self' <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> ; frame-src 'self' blob: <!URL!> ; img-src 'self' data: https: <!URL!> ; object-src 'self' blob: <!URL!>",
#  "default-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' data: <!URL!> ",
#  "default-src 'self' <!URL!> 'unsafe-inline'; connect-src 'self' <!URL!> wss:<!URL!> ; font-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; object-src 'self'; manifest-src 'self'",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' blob: data: <!URL!> @<!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; img-src * data: <!URL!> ; font-src * data:; connect-src 'self' <!URL!> ",
#  "frame-src 'self' *; object-src 'self'",
#  "frame-ancestors 'self' blank;object-src 'self' blank;",
#  "upgrade-insecure-requests; frame-ancestors 'self'  <!URL!> ;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' data: 'unsafe-inline' 'unsafe-eval' <!URL!> 'unsafe-inline' 'unsafe-eval' ; script-src 'self' 'unsafe-inline' 'unsafe-eval' 'unsafe-inline' 'unsafe-eval' 'report-sample' <!URL!> blob: <!URL!> ~<!URL!> ; style-src 'self' 'unsafe-inline' data: 'unsafe-inline' 'report-sample' 'unsafe-inline' <!URL!> 'unsafe-inline' <!URL!> ; img-src 'self' data: 'unsafe-inline' data: <!URL!> data: blob: <!URL!> data: blob: <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> about: <!URL!> about: <!URL!> ; font-src 'self' data: data: <!URL!> data: <!URL!> data: ; object-src 'self' ; media-src 'self' ; frame-src 'self' 'unsafe-inline' <!URL!> ; child-src 'self' blob: <!URL!> ; worker-src 'self' blob: <!URL!>; base-uri 'self' ; form-action 'self' <!URL!> ; frame-ancestors 'self' <!URL!> ; upgrade-insecure-requests; report-uri <!URL!>;;",
#  "connect-src 'self' <!URL!> ; default-src 'none'; img-src 'self' data: <!URL!> ; font-src 'self' data: ; style-src 'self' 'unsafe-inline' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'none'; frame-src 'self' data: <!URL!> ; frame-ancestors 'self'",
#  'frame-ancestors <!URL!> ; sandbox allow-top-navigation allow-same-origin allow-scripts allow-popups allow-forms',
#  "default-src https:; font-src https: data:; img-src https: data:; script-src https: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline';",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' * <!URL!> ;  style-src * 'self' 'unsafe-inline' <!URL!>;  img-src * 'self' data: ;  font-src * 'self' data: <!URL!>;   child-src <!URL!>;   worker-src * 'self' blob: <!URL!>;   frame-src * 'self' ;  form-action * 'self' ;  connect-src * 'self' <!URL!> ;",
#  "script-src 'self' <!URL!> ;style-src 'self'  'unsafe-inline';",
#  "default-src https: 'unsafe-eval' 'unsafe-inline'; img-src 'self' https: data:; font-src 'self' https: data:;",
#  "default-src https: data: blob: 'unsafe-eval' 'unsafe-inline'; frame-src 'self' <!URL!>;",
#  "frame-src 'self' <!URL!> ;          default-src 'self';          script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ;         img-src blob: data: 'self' <!URL!> ;          object-src 'self';          plugin-types application/x-shockwave-flash application/pdf;         style-src 'self' 'unsafe-inline' ;          connect-src 'self' <!URL!> ;         form-action 'none';         frame-ancestors 'self';         report-uri /api/sessions/CspViolationLog/ReportViolation/",
#  "frame-ancestors 'self' ; report-uri <!URL!>;",
#  "upgrade-insecure-requests; default-src https: blob: wss: data:; script-src https: 'unsafe-inline' 'unsafe-eval' blob:; style-src https: 'unsafe-inline'; img-src https: data: blob:; media-src https: blob: data:;frame-src https: blob: data:; report-uri /cspreports",
#  "default-src 'none'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; img-src data: 'self' <!URL!> blob:; style-src 'self' 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> ; font-src <!URL!> ; frame-src <!URL!> ; frame-ancestors 'self' <!URL!>; base-uri 'self'; form-action 'self';",
#  "default-src https: data: blob: wss:<!URL!> wss:<!URL!> wss:<!URL!> 'unsafe-inline' 'unsafe-eval'; frame-ancestors 'self' <!URL!>; upgrade-insecure-requests",
#  "frame-ancestors https:; default-src 'self' <!URL!> ; connect-src 'self' blob: * <!URL!> wss:<!URL!> about: <!URL!> wss:<!URL!>; manifest-src 'self'; script-src 'self' 'unsafe-eval' <!URL!> 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; img-src data: * blob: <!URL!> ; font-src <!URL!> *  data: <!URL!> ; child-src 'self' blob: <!URL!> ; worker-src 'self' blob:; frame-src  *; form-action ; media-src <!URL!>;",
#  "upgrade-insecure-requests; default-src data: 'unsafe-inline' 'unsafe-eval' https:; script-src data: 'unsafe-inline' 'unsafe-eval' https: blob: <!URL!> ; style-src data: 'unsafe-inline' https: <!URL!> ; img-src data: https: blob: android-webview-video-poster: <!URL!> ; font-src data: https: <!URL!> ; connect-src https: wss: blob:; media-src data: https: blob:; object-src https:; child-src https: data: blob:; form-action https:; frame-ancestors <!URL!> ",
#  "default-src <!URL!> blob: <!URL!> ; script-src <!URL!> blob: <!URL!> 'unsafe-inline'; connect-src <!URL!> blob: <!URL!> 'unsafe-inline'; style-src <!URL!> 'unsafe-inline'; font-src <!URL!> data: <!URL!> ; img-src <!URL!> data:  <!URL!> 'unsafe-inline' 'unsafe-eval'; frame-src <!URL!> blob: <!URL!> ; object-src <!URL!> blob: <!URL!> ;",
#  "object-src 'self' blob;",
#  "script-src 'unsafe-eval' <!URL!> ;frame-src <!URL!> bytedance: ;worker-src https: blob:",
#  "default-src 'self' data: gap: <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: <!URL!> ; img-src 'self' data: <!URL!> ; object-src 'self' ; style-src 'self' 'unsafe-inline' <!URL!> ; frame-src <!URL!> ; font-src 'self' data: <!URL!> ; connect-src 'self' data: gap: <!URL!> wss:<!URL!> wss:<!URL!>; worker-src 'self' data: gap: <!URL!> blob:;",
#  "default-src 'none'; base-uri 'none'; connect-src 'self' <!URL!> ; font-src 'self' <!URL!> data:; form-action 'self' <!URL!> ; frame-ancestors 'none'; frame-src 'self' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; manifest-src 'none'; media-src <!URL!>; object-src 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; worker-src 'none'",
#  "base-uri 'self'; default-src 'self'; style-src 'self' 'unsafe-inline'; script-src 'self' <!URL!>; connect-src 'self' <!URL!>; frame-src 'self' <!URL!> ",
#  "default-src https: data: wss: 'unsafe-inline' 'unsafe-eval'; worker-src blob: 'self'; frame-ancestors <!URL!>",
#  "default-src 'self' 'unsafe-inline'; frame-ancestors 'none';object-src 'none';",
#  "default-src 'self' data: *; img-src 'self' blob: data: *; script-src 'self' 'unsafe-inline' 'unsafe-eval' *; style-src 'unsafe-inline' *",
#  "upgrade-insecure-requests; frame-ancestors 'self';",
#  "script-src 'self' 'unsafe-inline' <!URL!> ;form-action 'self'; style-src 'self' 'unsafe-inline' <!URL!> ;font-src 'self' <!URL!> ; frame-ancestors 'self'; img-src 'self' <!URL!> ",
#  "object-src 'none'; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self' <!URL!> blob: ; style-src 'self' 'unsafe-inline' <!URL!>; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; connect-src 'self' <!URL!> ; frame-src <!URL!> blob: <!URL!> ; font-src 'self' data:;",
#  "frame-ancestors 'self' ;upgrade-insecure-requests",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' https: data:; connect-src 'self' https: data: wss:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ",
#  "default-src 'self' wss: https: data: 'unsafe-inline' 'unsafe-eval'",
#  "media-src 'self' blob: <!URL!> ;",
#  "frame-ancestors 'self'; upgrade-insecure-requests; style-src 'self' 'unsafe-inline' <!URL!> ; script-src 'self' <!URL!> ",
#  "default-src * 'unsafe-inline' 'unsafe-eval' data: blob:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> @6 <!URL!>@popperjs/core@2 <!URL!> @; img-src * data: blob: 'unsafe-inline'; report-uri /report-csp-violation",
#  "default-src <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' blob: asset: <!URL!> 'report-sample'; img-src 'self' data: blob: <!URL!> blob: <!URL!> 'report-sample'; style-src 'self' blob: 'unsafe-inline' ; object-src 'self' ; connect-src 'self' wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss: blob: <!URL!> ; form-action 'self' <!URL!> 'report-sample'; child-src 'self' blob: <!URL!> ; font-src 'self' data: blob: <!URL!> ; frame-src 'self' <!URL!> ; worker-src 'self' blob:; media-src 'self' data: blob: <!URL!>; frame-ancestors 'self' <!URL!> ; base-uri 'self' <!URL!> ; manifest-src blob: 'self' <!URL!> ; report-uri /gd/rest/jslog/csp",
#  "default-src 'self'; style-src 'self' 'unsafe-inline' <!URL!>; script-src 'self' 'unsafe-inline' 'unsafe-eval'; connect-src 'self'; img-src 'self' data: blob:; font-src 'self' data: <!URL!>; frame-ancestors 'self'; object-src 'none';",
#  "frame-ancestors 'self'; script-src 'unsafe-inline' 'unsafe-eval' blob: data: localhost localhost:3000 <!URL!> ",
#  'report-uri /csp_report_parser',
#  "default-src * data: blob: filesystem: 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' * data:;",
#  "frame-ancestors 'self' <!URL!> ; frame-src 'self' <!URL!> ; report-uri <!URL!>",
#  "default-src 'none'; worker-src 'self' blob: ; media-src <!URL!> 'self' blob: data: ; frame-src <!URL!> ; connect-src <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> 'self' ; font-src 'self'  ; img-src  blob: <!URL!> data: 'self' ; style-src 'unsafe-inline' 'self' <!URL!> ; script-src 'self' <!URL!> 'sha256-default 'sha256-default 'sha256-default <!URL!> ; frame-ancestors 'self' <!URL!>",
#  "default-src 'self' <!URL!>; script-src 'self' 'unsafe-eval' <!URL!> 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> wss:; frame-src 'self' <!URL!> ; frame-ancestors 'self'; style-src 'self' <!URL!> 'unsafe-inline' <!URL!>; font-src 'self' <!URL!> data:; img-src 'self' <!URL!> data:; media-src 'self' <!URL!> ;",
#  "child-src 'self' <!URL!> blob: <!URL!>; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> data: <!URL!> ; default-src 'none'; font-src 'self' data: <!URL!> blob: data: <!URL!> ; form-action 'self' <!URL!> ; img-src 'self' data: <!URL!> https: blob:; manifest-src 'none' 'self'; media-src 'self' <!URL!> blob: ; object-src 'self' ; report-uri <!URL!>; script-src 'self' 'unsafe-eval' 'unsafe-inline' data: <!URL!> blob: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; upgrade-insecure-requests; report-to report-endpoint",
#  "frame-ancestors 'self' chrome-extension://hfdhpmpfpcnbboppkkkblilhbloejijj",
#  "default-src https: data: 'unsafe-inline' 'unsafe-eval'; form-action https:; connect-src https: wss:; object-src 'unsafe-inline' 'unsafe-eval'; upgrade-insecure-requests;  frame-ancestors 'self' <!URL!> ",
#  "frame-ancestors 'none'; report-uri <!URL!>; script-src 'self' <!URL!> 'unsafe-eval' 'unsafe-inline' ",
#  "frame-ancestors 'self' <!URL!> ; form-action https:; script-src https: 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self'; connect-src *; font-src * data:; frame-src *; img-src * data:; media-src *; object-src *; script-src * 'unsafe-inline' 'unsafe-eval' blob: data:; style-src * 'unsafe-inline';",
#  "default-src 'self' http: https: data: blob: 'unsafe-inline'",
#  "default-src 'self' <!URL!> ; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' <!URL!> ; frame-src 'self' <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; font-src 'self' <!URL!> data: <!URL!> ; object-src 'self' <!URL!> ; media-src 'self' <!URL!> ;",
#  "img-src 'self' <!URL!> data:; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> blob:; frame-src 'self' <!URL!> ; connect-src 'self' <!URL!> data: blob:; font-src 'self'; style-src 'self' 'unsafe-inline'; worker-src blob:; form-action 'self'; object-src 'none'; frame-ancestors 'self' localhost <!URL!>;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' https: data:",
#  "default-src https: blob:; connect-src https: wss: blob:; font-src https: data:; frame-src https:; frame-ancestors 'self'; img-src https: blob: data:; media-src https: blob:; object-src https:; script-src 'unsafe-inline' 'unsafe-eval' https: blob:; style-src 'unsafe-inline' https:;",
#  "default-src * data: 'unsafe-inline' 'unsafe-eval'; img-src * 'self' data: https:; style-src 'self' 'unsafe-inline' *; script-src * data: blob: 'unsafe-inline' 'unsafe-eval' ",
#  "default-src 'self' https: data: 'unsafe-inline' 'unsafe-eval';",
#  "upgrade-insecure-requests; default-src https: data: 'unsafe-inline' 'unsafe-eval' https:; script-src data: 'unsafe-inline' 'unsafe-eval' https: blob:; style-src data: 'unsafe-inline' https:; img-src data: https: blob:; font-src data: https:; connect-src https: wss: blob:; media-src data: https: blob:; object-src https:; child-src https: data: blob:; form-action https:;",
#  "default-src 'self' https:; style-src 'self' 'unsafe-inline' <!URL!> ; script-src blob: 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; connect-src blob: 'self' <!URL!> wss:<!URL!> ; img-src data: <!URL!> 'self' <!URL!> ; font-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; frame-ancestors 'self' <!URL!>; report-uri /web-services/web-logger",
#  "script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; img-src 'self' https: data: <!URL!> ; frame-ancestors <!URL!> ",
#  "frame-src <!URL!> ; style-src 'self' 'unsafe-inline'; default-src 'self'; script-src  'self' 'unsafe-inline' ; connect-src  'self' 'unsafe-inline' ; font-src 'self' 'unsafe-inline' data:; img-src 'self'  data:;",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' <!URL!> ; style-src 'self' 'unsafe-inline' 'report-sample' ; object-src 'none'; frame-ancestors 'self'; frame-src 'self' ; report-uri /api/csp-report",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' https: data: blob:; frame-src 'self' https:; connect-src 'self' 'unsafe-inline' 'unsafe-eval' wss: https: data: blob:; frame-ancestors 'self' <!URL!> ; block-all-mixed-content; upgrade-insecure-requests;",
#  "base-uri 'self' 'unsafe-inline'; connect-src 'self' 'unsafe-inline' <!URL!> wss: wss:<!URL!> ",
#  "default-src <!URL!> ; connect-src 'self' <!URL!> ; child-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; frame-ancestors 'self' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> blob: data: <!URL!>; font-src 'self' <!URL!> blob: data: <!URL!>; script-src 'self' <!URL!> 'unsafe-eval' 'unsafe-inline' blob: <!URL!> ; style-src 'self' <!URL!> 'unsafe-inline'",
#  "base-uri 'none'; default-src 'none'; frame-ancestors 'self' ; font-src 'self' <!URL!>; img-src 'self' https: data: blob: <!URL!>; style-src 'self' 'unsafe-inline' <!URL!>; media-src 'self' https: data: <!URL!> blob:; frame-src 'self' https: <!URL!>; manifest-src 'self' <!URL!>; connect-src 'self' blob: <!URL!> wss:; script-src 'self' <!URL!> ",
#  "default-src * data: blob: ; script-src * 'unsafe-inline' 'unsafe-eval' blob: ; style-src * 'unsafe-inline' data: ; frame-ancestors 'none' ;",
#  "default-src * ; script-src * data: 'self' blob blob: 'unsafe-eval' 'unsafe-inline' ; style-src * data: 'self' blob blob: 'unsafe-inline' ; img-src * data: ; font-src * data: ; connect-src * ; media-src * blob: ; object-src * ; child-src * ; frame-src * ; worker-src * blob: ; frame-ancestors * ; report-uri /bdportlet-NemIDLoginPortlet/cspreport;",
#  "object-src 'none'; script-src 'self' <!URL!> ; script-src-attr 'self' 'unsafe-inline'; script-src-elem 'self' 'unsafe-inline' <!URL!> ; frame-ancestors 'self'; report-uri <!URL!>",
#  "script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; img-src * data:; object-src 'none'; base-uri 'none';",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval'; style-src 'self' 'unsafe-inline' ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; object-src 'none'; base-uri 'self'; connect-src *; font-src 'self' <!URL!>; frame-src 'self' <!URL!> ; img-src * data: blob:; media-src 'self';",
#  "base-uri 'self'; child-src * gap:; frame-src * gap:; connect-src *; default-src 'self' 'unsafe-inline' <!URL!> gap: 'unsafe-inline' 'unsafe-eval'; font-src 'self'  data:; img-src * data: blob:; script-src 'unsafe-inline' * 'unsafe-inline' 'unsafe-eval'; style-src 'self' 'unsafe-inline'; frame-ancestors <!URL!> 'self' gap:; report-uri /SecurityUtils/rest/Report/ReportViolations?Params=48RWKh8ZMnbZ4%2BgF%2BlsS92SC5gNnRaHN%2F7vP1AG%2FvHxz1n2dI%2FHcnDKMiRS%2Fam%2FlhdOYejgx4HJZDqDJ3Fpcjg%3D%3D;",
#  "frame-ancestors 'self'  localhost:* <!URL!> ",
#  "frame-ancestors <!URL!> 'self'; report-uri /report-csp-violation; upgrade-insecure-requests",
#  "default-src https: 'unsafe-eval' 'unsafe-inline'; object-src 'none'; frame-ancestors 'self'; upgrade-insecure-requests; img-src https: data: ; worker-src blob: https: ; connect-src https: wss:",
#  "default-src * data: 'unsafe-inline' 'unsafe-eval'; connect-src * javascript: data: 'unsafe-inline' 'unsafe-eval'; img-src * data: blob: 'unsafe-inline'",
#  'upgrade-insecure-requests; block-all-mixed-content; disown-opener',
#  "default-src * data: blob: about: ws: wss: 'unsafe-inline' 'unsafe-eval';",
#  "default-src 'none'; base-uri 'self'; connect-src 'self' <!URL!> ; font-src 'self' ; frame-src 'self' <!URL!> ; img-src <!URL!> 'self' data: <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ;",
#  "script-src 'self' <!URL!> 'unsafe-inline' 'report-sample' <!URL!> @tryghost/; style-src 'self' 'unsafe-inline' 'report-sample' <!URL!> ; img-src 'self' data: <!URL!> ; frame-ancestors 'none'; report-uri <!URL!>; report-to default",
#  "frame-src 'self' <!URL!> ; frame-ancestors http: https: ionic: ; script-src 'unsafe-inline' 'unsafe-eval' *; object-src 'self' <!URL!> ; default-src * data: 'unsafe-eval' 'unsafe-inline';",
#  "object-src 'none'; script-src 'self' 'unsafe-inline' <!URL!> ; script-src-attr 'self'; script-src-elem 'self' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; style-src-attr 'self' 'unsafe-inline'; frame-ancestors 'self'; report-uri <!URL!>",
#  'default-src https:',
#  'upgrade-insecure-requests;report-uri /csp-violation-report-endpoint/',
#  "connect-src 'self' 'unsafe-inline' ; script-src 'self' 'unsafe-inline' <!URL!> ; object-src 'none'; default-src 'self' 'unsafe-inline' ; style-src 'self' 'unsafe-inline' ; img-src 'self' 'unsafe-inline' data: <!URL!> ; font-src 'self' 'unsafe-inline' data: ",
#  "default-src 'self'; connect-src 'self' <!URL!> wss:<!URL!>; font-src 'self' data: <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; manifest-src 'none'; media-src 'self'; object-src 'self'; prefetch-src 'self'; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; worker-src 'self'; report-uri <!URL!>; report-to default;",
#  "default-src 'self' http: https: data: blob: wss: 'unsafe-inline' 'unsafe-eval'",
#  "style-src 'unsafe-inline' 'self' <!URL!> ; script-src 'unsafe-eval' 'unsafe-inline' 'self' <!URL!> blob:; default-src 'self' <!URL!> blob: data:;",
#  "default-src https:; script-src https: data: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline'; img-src https: data: blob:; media-src https: data: blob:; font-src https: data:; connect-src https: wss:; worker-src 'self' blob:",
#  "default-src https: blob: data: 'self'; script-src https: blob: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline' ; img-src https: data: ; media-src https: blob: ; upgrade-insecure-requests; block-all-mixed-content; connect-src https: wss:<!URL!>;",
#  'frame-ancestors ‘self’',
#  "default-src 'self' data: https: wss: 'unsafe-inline' 'unsafe-eval'; font-src data: https:; media-src blob: data: https:",
#  "default-src 'self' <!URL!> ;child-src 'self';connect-src 'self' <!URL!> ;font-src <!URL!> data: ;frame-src 'self' <!URL!> ;img-src <!URL!> data: 'self' <!URL!> ;script-src 'self' 'unsafe-inline' <!URL!> ;style-src 'unsafe-inline' <!URL!> ;media-src <!URL!> ;worker-src blob: 'self' ;report-to worldsvc;upgrade-insecure-requests",
#  "default-src * data: blob: filesystem: 'unsafe-inline' 'unsafe-eval'; script-src * 'unsafe-inline' 'unsafe-eval'; connect-src * 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; frame-src *; style-src * 'unsafe-inline';",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' data: <!URL!> , frame-ancestors 'self'",
#  "frame-ancestors 'self' chrome-extension://hfdhpmpfpcnbboppkkkblilhbloejijj <!URL!>",
#  "default-src 'self' <!URL!> blob:; connect-src 'self' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; img-src 'self' <!URL!> data: blob:; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> data: ; frame-src 'self' bytedance: <!URL!> data: blob:; object-src 'self' <!URL!> data: blob:; frame-ancestors  ;",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;connect-src 'self' data: blob: <!URL!> wss:<!URL!> ws://localhost:* ws:<!URL!> wss:<!URL!> wss:<!URL!> notion:<!URL!> ;font-src 'self' data: <!URL!> ;img-src 'self' data: blob: https: <!URL!> notion:<!URL!> ;style-src 'self' 'unsafe-inline' <!URL!> ;frame-ancestors 'self';worker-src 'self' blob:;child-src 'self' blob:;media-src blob: https: http: <!URL!> notion:;frame-src https: http: <!URL!> ",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval';               img-src 'self' data: <!URL!> ;        style-src 'self' 'unsafe-inline' <!URL!> ;        font-src 'self' 'unsafe-inline' data: <!URL!> ;        frame-src 'self' <!URL!> ;        upgrade-insecure-requests;               block-all-mixed-content;        script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ;        connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> ;        frame-ancestors 'self';                   worker-src blob:;        media-src 'self' data:;",
#  "script-src 'unsafe-eval' 'self' wss:<!URL!> wss:<!URL!> 'self' 'unsafe-inline' <!URL!> data:",
#  "default-src 'self'; script-src 'none'; style-src 'self' 'unsafe-inline'; object-src 'none'; connect-src 'self'; font-src 'self'; frame-src 'self'; img-src 'self'; manifest-src 'self'; media-src 'self'; worker-src 'none';",
#  "script-src 'self'; object-src 'self'; base-uri 'none';",
#  "upgrade-insecure-requests;frame-ancestors 'self' <!URL!> ",
#  "default-src 'self' blob:; script-src 'self' 'unsafe-inline' 'unsafe-eval' data: blob: <!URL!> ; font-src 'self' data: <!URL!> ; img-src 'self' data: blob: about: <!URL!> ; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; frame-src 'self' data: <!URL!> ; frame-ancestors 'self' <!URL!> ; upgrade-insecure-requests; report-uri <!URL!>",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' ; img-src 'self' data: ; object-src 'self' data: ; frame-src 'self' data: ;",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; script-src-attr 'self' 'unsafe-inline'; style-src 'self' 'unsafe-inline'  <!URL!> ; style-src-attr 'self' 'unsafe-inline'; frame-ancestors 'self'",
#  "default-src 'self' https: blob: data: 'unsafe-inline' 'unsafe-eval' script-src: <!URL!> object-src: <!URL!> connect-src:  img-src: ;",
#  "default-src 'self'; script-src https: 'self' 'unsafe-inline' 'unsafe-eval' 'wasm-unsafe-eval' <!URL!> blob:; style-src 'self' 'unsafe-inline' https:; img-src https: data: blob: 'self'; media-src https: 'self'; object-src 'self'; font-src  data: 'self' https:; frame-ancestors <!URL!> 'self'; frame-src https:; connect-src https: ws: wss: <!URL!> 'self'; worker-src blob:; child-src blob:",
#  "default-src https: data: blob: 'unsafe-inline' 'unsafe-eval'; connect-src *;",
#  "script-src <!URL!> 'self' data: 'unsafe-inline' 'unsafe-eval' blob: <!URL!> blob: <!URL!> blob: <!URL!> 'unsafe-eval' 'unsafe-inline' <!URL!> 'unsafe-eval' 'unsafe-inline' <!URL!> 'unsafe-eval' 'unsafe-inline' <!URL!> ; font-src <!URL!> 'self' data: <!URL!> ; img-src <!URL!> 'self' data: <!URL!> ; frame-src <!URL!> 'self' <!URL!> ; default-src 'self'; style-src 'self' 'unsafe-inline' <!URL!> ; connect-src 'self' <!URL!> https: wss:<!URL!> ; object-src 'self'; worker-src 'self'; child-src <!URL!> ; media-src <!URL!>",
#  "default-src * blob:; img-src * data: blob: resource: ; connect-src * wss: blob: resource:; frame-src 'self' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: <!URL!> ; style-src 'self' 'unsafe-inline'  resource:; frame-ancestors <!URL!>;",
#  "default-src * 'unsafe-inline' 'unsafe-eval'; script-src * 'unsafe-inline' 'unsafe-eval'; connect-src * 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; frame-src *; style-src * 'unsafe-inline'; font-src * data:;",
#  'frame-ancestors <!URL!>; upgrade-insecure-requests',
#  "frame-ancestors 'self' <!URL!>;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> wss:<!URL!> data: <!URL!> wss:<!URL!> ",
#  "default-src * data: blob:;script-src 'self' <!URL!> @<!URL!> data: 'unsafe-inline' 'unsafe-eval';style-src 'self' <!URL!> data: 'unsafe-inline';font-src 'self' <!URL!> data:;worker-src * blob:;img-src * data: blob: 'unsafe-inline';frame-ancestors 'self' <!URL!>;report-uri <!URL!>&dd-evp-origin=content-security-policy&ddsource=csp-report&ddtags=service%3Amelhor-envio;",
#  'form-action https:; frame-ancestors <!URL!>',
#  "default-src 'self'; style-src 'self' 'unsafe-inline'; script-src 'self' 'unsafe-inline'; upgrade-insecure-requests",
#  "default-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline'; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' blob: data: https: <!URL!>; form-action 'self'; frame-src 'self' <!URL!> ",
#  "upgrade-insecure-requests;         default-src 'self'             <!URL!>;         connect-src 'self'             <!URL!> ;         script-src 'self' 'unsafe-eval';        script-src-attr 'unsafe-hashes'             'sha256-default         script-src-elem 'self'             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             'sha256-default             <!URL!> ;         style-src 'self' blob: 'unsafe-inline'             <!URL!> ;         img-src 'self' data:             <!URL!> ;         font-src 'self' data:             <!URL!> ;         frame-src 'self'             <!URL!> ;         child-src             <!URL!> ;         object-src 'none';         base-uri 'none';",
#  "base-uri 'self'; frame-ancestors *;frame-src *;child-src 'self';block-all-mixed-content;object-src 'none'; prefetch-src 'self';worker-src 'self'; default-src https: data: ws:; script-src https: 'unsafe-inline' 'unsafe-eval';style-src https: 'unsafe-inline';",
#  "default-src *  data: blob: filesystem: about: ws: wss: 'unsafe-inline' 'unsafe-eval' 'unsafe-dynamic'; script-src * data: blob: 'unsafe-inline' 'unsafe-eval'; connect-src * data: blob: 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; frame-src * data: blob: ; style-src * data: blob: 'unsafe-inline'; font-src * data: blob: 'unsafe-inline'",
#  "default-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; font-src 'self' data: https:; frame-src 'self' <!URL!> ; img-src 'self' about: data: https:  blob:; media-src 'self' <!URL!> ; object-src 'self' <!URL!>; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> blob: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; frame-ancestors 'self'; upgrade-insecure-requests",
#  "object-src 'none'; frame-ancestors 'self' <!URL!> ;",
#  'frame-src *; frame-ancestors *;',
#  "upgrade-insecure-requests;base-uri 'self';form-action 'self';frame-ancestors 'none';default-src 'self';child-src 'self';frame-src <!URL!> ;script-src <!URL!> 'self' 'unsafe-inline' 'unsafe-eval';img-src <!URL!> 'self' data:;style-src <!URL!> 'self' 'unsafe-inline';font-src <!URL!> 'self' data:;connect-src <!URL!> 'self' ws:;object-src 'self'",
#  "default-src 'self' ; child-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; font-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; manifest-src 'self' ; media-src 'self' blob: <!URL!> ; frame-src 'self' <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; report-uri /webhooks/csp-report;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> wss:; img-src * data:; font-src *; style-src * 'unsafe-inline'; media-src * blob:; worker-src * blob:",
#  "form-action https: 'self'; default-src https:; script-src https: 'unsafe-inline'; style-src https: 'unsafe-inline'; img-src data: https:",
#  "default-src 'self'; img-src 'self' 'unsafe-inline' * data: <!URL!>; frame-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; font-src 'self' 'unsafe-inline' data: <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; media-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; base-uri 'none';",
#  "default-src 'self'; base-uri 'self'; frame-src 'self'; frame-ancestors 'self'; form-action 'none'; script-src 'self'; img-src 'self'",
#  "default-src 'none'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ttps:<!URL!> ; base-uri 'none'; form-action 'self' <!URL!> ; object-src 'none'; style-src 'self' 'unsafe-inline' <!URL!> ; img-src 'self' data: <!URL!> ; media-src 'self' <!URL!>; frame-src 'self' <!URL!> ; frame-ancestors 'self'; child-src 'self' <!URL!> blob:; font-src 'self' <!URL!> ; connect-src 'self' wss:<!URL!> ; report-uri /report-csp-violation",
#  "default-src https:; script-src https: 'unsafe-inline'; style-src https: 'unsafe-inline'; img-src https: data:; font-src https: data:; connect-src https: wss:;",
#  "default-src 'self' <!URL!> blob: <!URL!> 'unsafe-eval' 'unsafe-inline';                  style-src 'self' <!URL!> 'unsafe-inline';                  font-src 'self' <!URL!> ;   img-src 'self' <!URL!> ",
#  "default-src https: 'unsafe-inline' 'unsafe-eval'; img-src 'self' data: https:;",
#  "base-uri 'self'; default-src 'self'; script-src 'self' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline'; img-src 'self' data: <!URL!> ; connect-src 'self' <!URL!> ; object-src 'none'; upgrade-insecure-requests;",
#  "child-src 'self' ; connect-src 'self'  'unsafe-inline'  'unsafe-eval' <!URL!> ws: ; default-src 'self' ; font-src 'self' <!URL!> data: ; form-action * 'unsafe-inline' ; frame-src 'self' <!URL!> ; frame-ancestors 'self' ; img-src 'self'  'unsafe-inline'  'unsafe-eval' 'unsafe-hashes' <!URL!> data: ; manifest-src 'self' ; media-src 'self' <!URL!> ; object-src 'self' ; prefetch-src 'self' ; script-src 'self'  'unsafe-inline'  'unsafe-eval' <!URL!> ; script-src-elem 'self'  'unsafe-inline'  'unsafe-eval' <!URL!> ; script-src-attr 'self'  'unsafe-inline'  'unsafe-eval' <!URL!> ; style-src 'self'  'unsafe-inline'  'unsafe-eval' <!URL!> ; style-src-elem 'self'  'unsafe-inline'  'unsafe-eval' <!URL!> ; style-src-attr 'self'  'unsafe-inline'  'unsafe-eval' <!URL!> ; worker-src 'self' ;",
#  "default-src 'self'; script-src 'self' <!URL!> 'unsafe-inline'; img-src data: 'self' ; connect-src 'self'; style-src 'self' 'unsafe-inline'; frame-ancestors 'self'; worker-src 'self'; frame-src 'self' <!URL!> ; form-action 'self'; block-all-mixed-content; upgrade-insecure-requests;",
#  "default-src 'self'; script-src 'self' 'unsafe-inline'; img-src data: 'self'; connect-src 'self'; style-src 'self' 'unsafe-inline'; frame-ancestors 'self'; worker-src 'self'; frame-src 'self' <!URL!> ; form-action 'self'; block-all-mixed-content; upgrade-insecure-requests;",
#  "default-src 'self' <!URL!> ;media-src <!URL!>;script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;connect-src data: 'self' <!URL!> ;img-src 'self' data: <!URL!> ;child-src blob: ;frame-src *;frame-ancestors none;object-src 'self' data: <!URL!>;style-src 'self' 'unsafe-inline' <!URL!> ;font-src 'self' data: <!URL!> ;worker-src blob:;report-uri <!URL!>&dd-evp-origin=content-security-policy&ddsource=csp-report&ddtags=env:production%2Cservice:greenlight-website-next;",
#  "default-src https: data: blob: 'unsafe-eval' 'unsafe-inline' <!URL!> wss:<!URL!> wss:<!URL!> 'self'; upgrade-insecure-requests; frame-ancestors 'self' <!URL!> ;",
#  "img-src 'self' <!URL!> blob: data: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!>; font-src 'self' data: <!URL!>; default-src 'self'; script-src 'self' 'sha256-default 'sha256-default 'sha256-default <!URL!> ; media-src 'self' blob: <!URL!>; frame-src 'self' <!URL!>; connect-src 'self' <!URL!>; worker-src 'self' blob:;",
#  "default-src 'self';connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ;script-src-elem 'self' 'unsafe-inline' <!URL!> ;script-src 'self' 'unsafe-eval';form-action 'self' <!URL!>;style-src 'self' 'unsafe-inline' <!URL!>;img-src 'self' data: *;media-src 'self' blob: <!URL!> ;worker-src 'self' <!URL!> blob:;font-src 'self' data: ;frame-src 'self' <!URL!> ;frame-ancestors 'self' *;base-uri 'self';object-src 'none';script-src-attr 'none';upgrade-insecure-requests",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval'  blob:; block-all-mixed-content; upgrade-insecure-requests;",
#  "base-uri 'self'; frame-ancestors 'self'; upgrade-insecure-requests",
#  "default-src 'unsafe-inline'",
#  "default-src *  data: blob: filesystem: about: ws: wss: 'unsafe-inline' 'unsafe-eval';  script-src * data: blob: 'unsafe-inline' 'unsafe-eval';  connect-src * data: blob: 'unsafe-inline';  img-src * data: blob: 'unsafe-inline';  frame-src * data: blob: ;  style-src * data: blob: 'unsafe-inline'; font-src * data: blob: 'unsafe-inline'; frame-ancestors * data: blob:;",
#  "default-src 'self' ; font-src 'self' data:; img-src 'self' data:; object-src 'none'; script-src 'self'  'nonce-'; style-src 'self'; connect-src 'self' wss:<!URL!> ",
#  "base-uri 'self' https:; block-all-mixed-content; child-src 'self' https:; connect-src 'self' https:; font-src 'self' data: https:; form-action 'self' https:; frame-ancestors 'self'; frame-src 'self' https:; img-src 'self' data: https:; media-src 'self' https:; object-src 'self' https:; prefetch-src 'self' https:; report-to csp_default; report-uri <!URL!>; script-src 'self' 'unsafe-inline' https:; style-src 'self' 'unsafe-inline' https:; worker-src 'self' https:",
#  "frame-src 'self' <!URL!> ; frame-ancestors 'self'; upgrade-insecure-requests;",
#  "default-src 'self' data: https: wss: blob:;script-src 'self' 'unsafe-inline' 'unsafe-eval' data: blob: <!URL!> ;style-src 'self' 'unsafe-inline' data: blob: <!URL!> ",
#  "default-src 'self' data: 'unsafe-inline' 'unsafe-eval' https:; script-src 'unsafe-inline' 'unsafe-eval' https: <!URL!> ; connect-src https: <!URL!> ; style-src 'unsafe-inline' https: blob: <!URL!>; img-src data: https: <!URL!> ; font-src https: <!URL!>; media-src 'self' https: blob:; frame-src <!URL!> ; worker-src 'self' https: blob:; frame-ancestors https: <!URL!>",
#  "frame-ancestors <!URL!> 'self'; frame-src <!URL!> 'self';",
#  "connect-src 'self' <!URL!> ;default-src 'none';img-src * data: <!URL!>;script-src 'self' data: 'unsafe-inline' <!URL!> ;style-src 'self' 'unsafe-inline' ;frame-src <!URL!> ;font-src  ;media-src <!URL!> ",
#  "default-src 'self'; worker-src blob:; child-src blob:; font-src * data: https:; img-src * data:; media-src * data:; script-src * 'unsafe-inline' 'unsafe-eval' https:; style-src * 'unsafe-inline' https:; connect-src * https:; frame-src * https:;",
#  "default-src 'self'; script-src 'self' 'nonce-pub1f79f8ac903a5872ae5f53026d20a77c' 'unsafe-inline' 'unsafe-eval' <!URL!> ; script-src-elem 'unsafe-inline' <!URL!> ; img-src * 'self' data: https:; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' data: <!URL!>; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> ; frame-src <!URL!> ; worker-src blob:; report-uri <!URL!>&dd-evp-origin=content-security-policy&ddsource=csp-report;",
#  "default-src 'self'  blob:  data:  <!URL!> 'unsafe-inline'  <!URL!> ; frame-src 'self'  <!URL!> 'unsafe-inline'  ; img-src 'self'  data:  <!URL!> 'unsafe-inline'  ; object-src 'self'  data:  <!URL!> 'unsafe-eval'; script-src 'self'  blob:  data:  <!URL!> 'unsafe-eval'  'unsafe-inline'  about:  <!URL!> ; style-src 'self'  <!URL!> 'unsafe-inline'; frame-ancestors 'self'  ; report-uri <!URL!>; base-uri 'self'; form-action 'self'  <!URL!> ;",
#  "default-src 'none'; base-uri 'none'; frame-src ; frame-ancestors 'none'; style-src ; script-src <!URL!> 'unsafe-eval'; img-src <!URL!> data:; font-src ; manifest-src ; connect-src <!URL!> ; block-all-mixed-content;",
#  "default-src *  data: blob: filesystem: about: ws: wss: 'unsafe-inline' 'unsafe-eval' 'unsafe-dynamic';  script-src * data: blob: 'unsafe-inline' 'unsafe-eval';  connect-src * data: blob: 'unsafe-inline';  img-src * data: blob: 'unsafe-inline';  frame-src * data: blob: ;  style-src * data: blob: 'unsafe-inline'; font-src * data: blob: 'unsafe-inline'; frame-ancestors * data: blob: 'unsafe-inline';",
#  "default-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; script-src 'self' data: <!URL!> 'unsafe-inline' 'unsafe-eval'; connect-src 'self' <!URL!> wss: <!URL!>; img-src 'self' <!URL!> data:; style-src 'self' <!URL!> 'unsafe-inline'; font-src 'self' data: <!URL!>; base-uri 'self'; form-action 'self'; upgrade-insecure-requests",
#  "manifest-src 'self' 'unsafe-inline'; child-src <!URL!> http: https: blob: 'self' 'unsafe-inline'; upgrade-insecure-requests; frame-ancestors 'self' <!URL!> ; form-action 'self' <!URL!> * 'self' 'unsafe-inline'; style-src 'self' 'unsafe-inline' <!URL!> unsafe-inline <!URL!> 'self' 'unsafe-inline'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; object-src 'none'; media-src ; img-src 'self' data: <!URL!> 'self' data: <!URL!> data: 'self' 'unsafe-inline'; frame-src 'self' <!URL!> * 'self' 'unsafe-inline'; font-src 'self' data: <!URL!> 'self' data: data: 'self' 'unsafe-inline'; connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> 'self' data: <!URL!> 'self' 'unsafe-inline'; default-src 'self' <!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; worker-src 'self' <!URL!> ;",
#  "font-src 'self' <!URL!>; frame-ancestors 'none'; form-action 'self'; base-uri 'self'; upgrade-insecure-requests; object-src 'none'; worker-src 'self'; media-src 'self'; connect-src 'self' <!URL!>; manifest-src 'self'; prefetch-src 'none'; img-src 'self' data: <!URL!>; frame-src 'self'; child-src 'self'; style-src 'self' 'unsafe-inline'; block-all-mixed-content; script-src 'self' <!URL!> 'unsafe-inline'; report-uri /impressum/;",
#  "script-src http: https: 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self'; script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; style-src 'self' <!URL!> 'unsafe-inline'; img-src 'self' <!URL!> data: blob: <!URL!> ; font-src 'self' <!URL!> data:; frame-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; media-src 'self' data: blob: <!URL!>; child-src 'self' <!URL!> blob:",
#  'report-uri /report-csp-violation; upgrade-insecure-requests',
#  "child-src 'self' blob:;connect-src * <!URL!> ;default-src 'self' ;img-src 'self' * data:;font-src 'self' data: <!URL!> ;object-src 'self';media-src 'self';manifest-src 'self';script-src 'self' 'unsafe-eval' 'unsafe-inline' https: <!URL!> ;style-src 'self' 'unsafe-inline' blob: <!URL!> ;frame-src <!URL!> ;base-uri 'self';form-action 'self';frame-ancestors 'self';script-src-attr 'none';upgrade-insecure-requests",
#  "default-src 'self' https: wss:;script-src 'self' https: 'unsafe-inline' 'unsafe-eval';style-src 'self' https: 'unsafe-inline' 'unsafe-eval';img-src 'self' data: https:;font-src 'self' data: https:",
#  "default-src 'self'; connect-src 'self' <!URL!> ; font-src 'self' data: ; frame-src ; img-src 'self' data: blob: <!URL!> ; object-src 'none'; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; report-uri /csp_reports",
#  'frame-ancestors *',
#  "default-src 'self' <!URL!>; worker-src 'self' blob:; object-src 'self'; frame-ancestors 'self' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' data: <!URL!> ; connect-src 'self' data: <!URL!> ; img-src 'self' data: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> data:; frame-src 'self' <!URL!> *;",
#  "default-src 'self' https: data: 'unsafe-inline' 'unsafe-eval'; connect-src 'self' <!URL!> wss: wss: wss: wss:<!URL!>;",
#  "object-src 'unsafe-inline'",
# ...
#  "default-src='self'",
#  "frame-ancestors 'self' <!URL!> ; frame-src 'self' comgooglemaps: gsa: <!URL!> ",
#  "default-src 'self'; connect-src *; font-src 'self' data:; frame-src *; img-src data: 'self' *; media-src *; object-src *; script-src data: 'self' 'unsafe-eval' 'unsafe-inline' *; style-src 'self' 'unsafe-inline';",
#  "default-src * blob: data: 'unsafe-inline' 'unsafe-eval'; script-src * blob: data: 'unsafe-inline' 'unsafe-eval'; connect-src * data: 'unsafe-inline'; img-src * data: blob: 'unsafe-inline'; child-src * blob: data: ; style-src * 'unsafe-inline';",
#  "font-src 'self' <!URL!> data:; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; manifest-src 'self'; object-src 'none'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> wss:; script-src-attr 'self' 'unsafe-inline'; script-src-elem 'self' 'unsafe-inline' ; style-src 'self' 'unsafe-inline' <!URL!>; style-src-attr 'self' 'unsafe-inline'",
#  "default-src 'none'; base-uri 'self'; media-src 'self'; frame-src <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' ; font-src ; img-src 'self' <!URL!> ; connect-src 'self' <!URL!> ; object-src 'self'",
#  "default-src 'none'; base-uri 'self' <!URL!>; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' ; img-src 'self' data: <!URL!> ; font-src 'self' data: <!URL!>; connect-src 'self' wss: <!URL!> ; frame-src 'self' <!URL!> ; frame-ancestors 'self' <!URL!>; form-action 'self' ; child-src 'self' blob:;",
#  'block-all-mixed-content; frame-ancestors *; upgrade-insecure-requests;',
#  "frame-ancestors 'self' <!URL!> ; report-uri <!URL!>",
#  "default-src 'none';  script-src 'unsafe-inline' 'unsafe-eval' 'self' <!URL!> ;  style-src 'self' 'unsafe-inline' <!URL!>;  connect-src 'self' <!URL!> ;  img-src data: 'self' 'unsafe-inline' <!URL!> ;  media-src <!URL!> ;  frame-src data: 'self' <!URL!> ;  font-src <!URL!> ;  object-src 'self';  manifest-src 'self';  worker-src 'self' blob:;",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval'  <!URL!> ; frame-src 'self'  <!URL!> ; object-src 'self'",
#  "default-src https: ws: wss: data: 'unsafe-inline' 'unsafe-eval'",
#  "default-src * data: blob: about: vkcalls:;script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' blob:;style-src <!URL!> 'self' 'unsafe-inline'",
#  "default-src https:; connect-src https: wss: http:; font-src https: data:; img-src https: data: blob:; frame-src https: blob:; frame-ancestors 'self'; worker-src blob: https: data: 'unsafe-inline' 'unsafe-eval'; form-action https: javascript:; script-src https: data: blob: 'unsafe-inline' 'unsafe-eval';style-src https: data: 'unsafe-inline'; base-uri 'self';",
#  "default-src * 'unsafe-inline' 'unsafe-eval' blob: data: ;frame-ancestors 'self'",
#  "default-src 'self';style-src 'self' 'unsafe-inline' <!URL!> ;font-src 'self'  data: <!URL!> ;img-src 'self' data: blob: <!URL!> ;script-src 'self' 'unsafe-inline' blob: <!URL!> ;frame-src <!URL!> ;media-src <!URL!> ;connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> ;worker-src blob:;child-src blob:;frame-ancestors self <!URL!>",
#  "default-src 'none';img-src data: https:;script-src 'unsafe-inline' 'unsafe-eval' blob: https:;style-src 'unsafe-inline' https:;font-src data: https:;frame-ancestors 'self';connect-src https: wss:<!URL!>; media-src blob: https:;frame-src https: data: blob:;child-src https:;worker-src blob: https:;base-uri https:;form-action https:",
#  'form-action https:; upgrade-insecure-requests',
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' blob: <!URL!> ; report-uri /cspreport",
#  "frame-src 'self';                                                      img-src  <!URL!> 'self' data:;                                                     child-src 'self';                                                     object-src 'none';                                                     base-uri 'self';                                                     frame-ancestors 'self';                                                     default-src 'self' <!URL!> ;                                                     style-src 'self' <!URL!> 'unsafe-inline';                                                     script-src 'self'  'unsafe-inline' 'unsafe-eval'",
#  "base-uri 'self';default-src 'none'; connect-src 'self' inline-only: *; font-src 'self' data: *; img-src 'self' *;script-src 'self' 'unsafe-hashes' 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'sha256-default 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> *; script-src-elem 'unsafe-inline' *; style-src-elem 'unsafe-inline' *;frame-src 'unsafe-inline' *;worker-src 'unsafe-inline' blob: *;media-src 'unsafe-inline' blob: *;",
#  "script-src-elem <!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; style-src-elem <!URL!> 'self' 'unsafe-inline'; font-src <!URL!> wss:<!URL!> data: 'self' 'unsafe-inline'; form-action <!URL!> wss:<!URL!> 'self' 'unsafe-inline'; frame-ancestors <!URL!> wss:<!URL!> 'self'; frame-src <!URL!> wss:<!URL!> 'self' 'unsafe-inline'; img-src <!URL!> data: <!URL!> wss:<!URL!> data: 'self' 'unsafe-inline'; script-src <!URL!> wss:<!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; style-src <!URL!> wss: unsafe-inline <!URL!> 'self' 'unsafe-inline'; object-src <!URL!> 'self' 'unsafe-inline'; media-src <!URL!> wss:<!URL!> 'self' 'unsafe-inline'; manifest-src <!URL!> 'self' 'unsafe-inline'; connect-src <!URL!> wss:<!URL!> wss:<!URL!> 'self' 'unsafe-inline'; child-src <!URL!> http: https: blob: 'self' 'unsafe-inline'; default-src <!URL!> 'self' 'unsafe-inline' 'unsafe-eval'; base-uri <!URL!> 'self' 'unsafe-inline'; report-uri <!URL!>;",
#  "frame-ancestors 'self' *;",
#  "default-src 'self' data: 'unsafe-inline' 'unsafe-eval' <!URL!> ; img-src 'self' data: <!URL!> ; font-src 'self' data: <!URL!> ; report-uri <!URL!>;",
#  "script-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval'; frame-ancestors 'self'; object-src 'none';",
#  "default-src 'self' <!URL!> 'unsafe-inline' 'unsafe-eval' data:; img-src * data: blob: about:; report-uri <!URL!>;",
#  'upgrade-insecure-requests ;',
#  "default-src * data: blob: 'unsafe-inline' 'unsafe-eval'; frame-ancestors 'self' <!URL!>;",
#  "script-src 'self'",
#  "default-src https: 'unsafe-inline' 'unsafe-eval' data:;",
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' https: data:;",
#  "script-src * 'self' 'unsafe-inline' 'unsafe-eval'  blob:",
#  "default-src *; script-src * 'self' data: 'unsafe-inline' 'unsafe-hashes' 'unsafe-eval'; script-src-elem * 'self' data: 'unsafe-inline' 'unsafe-hashes' 'unsafe-eval'; script-src-attr * 'self' data: 'unsafe-inline' 'unsafe-hashes' 'unsafe-eval'; style-src * 'self' data: 'unsafe-inline' 'unsafe-hashes'; style-src-elem * 'self' data: 'unsafe-inline' 'unsafe-hashes'; style-src-attr * 'self' data: 'unsafe-inline' 'unsafe-hashes'; img-src * data:; font-src * 'self' data:; connect-src *; media-src *; object-src *; prefetch-src *; child-src *; frame-src *; worker-src *; frame-ancestors *; form-action *; base-uri *",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' '<!URL!>' ''",
#  "default-src 'unsafe-inline' 'unsafe-eval' https:;img-src * data:;",
#  "default-src 'self' <!URL!> data: <!URL!>; base-uri 'none'; connect-src 'self' <!URL!> ; font-src 'self' data: <!URL!> ; frame-ancestors 'self'; frame-src 'self' <!URL!> ; img-src 'self' data: <!URL!> ; object-src 'none'; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ",
#  'upgrade-insecure-requests;block-all-mixed-content;',
#  "default-src 'self' 'unsafe-inline' 'unsafe-eval' data: <!URL!> ",
#  "default-src * data:; script-src https: 'unsafe-inline' 'unsafe-eval'; style-src https: 'unsafe-inline'; object-src 'none'; upgrade-insecure-requests",
#  "frame-ancestors 'self' *; default-src 'self' data: wss: <!URL!> 'unsafe-inline' 'unsafe-eval'; object-src 'none'; script-src 'self' blob: <!URL!> 'unsafe-inline' 'unsafe-eval'; img-src 'self' data: <!URL!> ; font-src 'self' data: <!URL!> 'unsafe-inline'; style-src-elem 'self' data: <!URL!> 'unsafe-inline'; base-uri 'none'; form-action 'self' *; style-src 'self' <!URL!> 'unsafe-inline' ; style-src-attr 'self' <!URL!> 'unsafe-inline';",
#  "default-src https:; font-src https: data:; img-src https: data:; script-src 'unsafe-inline' 'unsafe-eval' https:; style-src 'unsafe-inline' https:; frame-ancestors 'self' <!URL!> ;",
#  "child-src blob:;connect-src 'self' <!URL!> wss:<!URL!> wss:<!URL!> wss:<!URL!> ;default-src 'none';font-src <!URL!> data: <!URL!> ;form-action 'self' <!URL!>;frame-src 'self' <!URL!> ;img-src http: https: blob: data: <!URL!> ;media-src <!URL!>;script-src 'unsafe-inline' <!URL!> ;style-src 'unsafe-inline' <!URL!> ;upgrade-insecure-requests;worker-src 'self' blob:;base-uri 'self';frame-ancestors 'self';object-src 'none';script-src-attr 'none'",
#  "default-src https: data: 'unsafe-inline' 'unsafe-eval'; img-src https: data:; font-src https: data:;",
#  "default-src 'self' <!URL!> ;base-uri 'self';img-src 'self' <!URL!> data: localhost <!URL!> ;font-src 'self' <!URL!> data: <!URL!> ;style-src 'self' <!URL!> 'unsafe-inline' <!URL!>;script-src 'self' <!URL!> 'unsafe-eval' 'unsafe-inline' <!URL!> ;child-src 'self' <!URL!> ;connect-src 'self' <!URL!> wss:<!URL!>;frame-src 'self' <!URL!> ;report-uri <!URL!>",
#  "default-src * 'unsafe-inline' 'unsafe-eval' ; child-src blob: ; worker-src 'self' <!URL!> blob: ; script-src * 'unsafe-inline' 'unsafe-eval' ; connect-src * ; media-src * ; img-src * data: blob: ; frame-src *; style-src * data: 'unsafe-inline'; font-src * data: ;",
#  "frame-ancestors 'self' <!URL!>; default-src 'self' <!URL!> data: blob: 'unsafe-inline' 'unsafe-eval'",
#  "default-src 'self' <!URL!> ;base-uri 'self';font-src 'self' https: data:;form-action 'self';frame-ancestors 'self';img-src 'self' data: https: <!URL!>;object-src 'none';script-src <!URL!> 'unsafe-eval' 'unsafe-inline' 'nonce-OT22mYwcUVPp' <!URL!> 'nonce-tgpRzQu1tQMPXlyDgt1hoRK2GKw=' 'sha256-default 'sha256-default <!URL!> ;script-src-attr 'none';style-src 'self' https: 'unsafe-inline';upgrade-insecure-requests;connect-src wss: <!URL!> ",
#  "script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; img-src 'self' data: <!URL!> ; font-src 'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; frame-src <!URL!> ; object-src 'none'",
#  "default-src * 'unsafe-eval' 'unsafe-inline' data: filesystem: about: blob: ws: wss:",
#  "default-src * data: 'unsafe-inline' 'unsafe-hashes' 'unsafe-eval' blob:; frame-ancestors <!URL!>;",
#  "default-src 'none'; manifest-src 'self'; worker-src 'self' blob:; frame-ancestors 'self' <!URL!>; frame-src 'self' blob: 'self' <!URL!> ; script-src 'self' 'unsafe-inline' 'unsafe-eval' 'report-sample' blob: 'self' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' data: ; img-src 'self' data: <!URL!> blob: 'self' <!URL!> ; connect-src blob: 'self' <!URL!> wss:<!URL!> wss:<!URL!> ",
#  "default-src 'self'; script-src 'self' 'unsafe-inline'; img-src * data:; style-src 'self' 'unsafe-inline';",
#  "default-src 'self' blob: 'unsafe-inline' 'unsafe-eval' <!URL!> fbrpc://* fb-messenger://* <!URL!> ; font-src 'self' data: <!URL!> ; img-src * blob: data:; form-action 'self'; frame-ancestors 'self'",
#  "default-src * 'unsafe-inline' 'unsafe-eval'  data: blob: <!URL!> ;frame-src self  <!URL!> ;",
#  "default-src 'none';media-src ;connect-src 'self' <!URL!> ;frame-src <!URL!> ;form-action 'self';img-src * 'self' data: *;object-src 'none';sandbox allow-downloads allow-forms allow-modals allow-popups allow-popups-to-escape-sandbox allow-presentation allow-same-origin allow-scripts;base-uri 'self';script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;style-src-elem 'self' 'unsafe-inline' <!URL!> ;style-src 'self' 'unsafe-inline' <!URL!> ;font-src 'self' <!URL!> ;",
#  "upgrade-insecure-requests; default-src 'self' 'unsafe-eval' 'unsafe-inline' data: https: wss: android-webview-video-poster: blob:;",
#  "frame-ancestors 'none'; report-uri <!URL!>; report-to csp-endpoint",
#  "default-src https: data: 'unsafe-inline' 'unsafe-eval' always",
#  "base-uri 'self'; style-src 'self' 'unsafe-inline' <!URL!> ; script-src 'self' 'unsafe-eval' 'unsafe-inline' <!URL!> ; frame-src 'self' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; connect-src 'self' <!URL!> ; default-src 'self' <!URL!> ; font-src 'self' <!URL!> data: <!URL!> ;",
#  "default-src *; script-src * 'unsafe-eval' 'self' 'unsafe-inline' https:; style-src * 'unsafe-inline'; object-src 'self' ; img-src * data:; frame-src *; font-src * data:; connect-src *; media-src * blob:; worker-src 'self' blob:;",
#  'report-uri /',
#  "frame-ancestors 'self' ; report-uri <!URL!>",
#  "default-src 'none'; script-src 'self'; style-src 'self' 'unsafe-inline'; img-src 'self' data:; font-src 'self' data:; connect-src 'self'; manifest-src 'self'; media-src 'self' blob: ; child-src 'self' blob:; frame-src 'self'; frame-ancestors 'none'",
#  "script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; report-uri /report-csp-violation",
#  "default-src 'self' https:; script-src 'self' https: 'unsafe-inline' 'unsafe-eval'; style-src 'self' https: 'unsafe-inline'; img-src 'self' https: data:; connect-src 'self' https: <!URL!> wss:<!URL!> wss:<!URL!> wss:; font-src 'self' https:; frame-ancestors 'self' https;",
#  "default-src 'self';script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> ;object-src 'self' <!URL!> ;style-src 'self' 'unsafe-inline' <!URL!> ;img-src 'self' <!URL!> data: <!URL!> ;media-src 'none';frame-src 'self' <!URL!> ;font-src 'self' <!URL!>;connect-src 'self' <!URL!> ;report-uri <!URL!>",
#  "default-src 'self'; script-src 'self' 'unsafe-eval' <!URL!> 'sha256-default ; style-src 'self' 'unsafe-inline' <!URL!> ; img-src 'self' blob: data: <!URL!> ; font-src data: <!URL!> ; connect-src 'self' blob: ws: wss: <!URL!> ; frame-src ; worker-src 'self' blob: ; media-src 'self' blob: <!URL!> ;",
#  "default-src https:; font-src https: data:; img-src https: data: blob:; script-src 'unsafe-inline' 'unsafe-eval' https:; style-src 'unsafe-inline' https:",
#  "frame-ancestors 'self' <!URL!> ; img-src 'self' data: <!URL!> ",
#  'frame-ancestors ',
#  "frame-ancestors 'self' <!URL!>; script-src 'unsafe-inline' 'unsafe-eval' 'self' <!URL!> ",
#  "default-src 'self' data:; script-src 'self' 'unsafe-inline' 'unsafe-eval' data: <!URL!> ; object-src 'self'; style-src 'self' 'unsafe-inline' <!URL!> ; img-src 'self' 'unsafe-inline' data: <!URL!> ; media-src 'self' ; frame-src 'self' <!URL!> ; frame-ancestors 'self'; child-src 'self' <!URL!> ; font-src 'self' data: <!URL!> ; connect-src 'self' <!URL!>; report-uri /report-csp-violation; upgrade-insecure-requests",
#  "default-src 'none'; object-src 'self'; script-src 'self' 'unsafe-inline' 'unsafe-eval' <!URL!> nonce-csp-test <!URL!> ; connect-src 'self' <!URL!> ; img-src 'self' <!URL!> data: <!URL!> ; style-src 'self' 'unsafe-inline' <!URL!> ; font-src 'self' <!URL!> ; frame-src 'self' <!URL!> ; child-src 'self' blob: <!URL!>",
#  "frame-ancestors 'self' <!URL!> ;",
#  "default-src <!URL!> 'unsafe-inline'; img-src <!URL!> ; frame-src <!URL!> ; frame-ancestors 'self'",
#  "upgrade-insecure-requests; script-src 'self' 'unsafe-eval' 'unsafe-inline' blob: <!URL!> ; script-src-elem 'self' 'unsafe-eval' 'unsafe-inline' blob: <!URL!> ; report-uri <!URL!>",
#  "default-src * blob: data: 'unsafe-inline' 'unsafe-eval'; ",
#  "child-src 'self' <!URL!> ; frame-ancestors 'self' <!URL!>; form-action 'self';",
#  ...]

# %%
label = "XFO"
header_name = "x-frame-options"
alt_names = ["frame-options", "x-frame-option", "x-frames-options", "content-security-policy", "x_frame_options", "xframeoptions"]
block_values = ["DENY"]
allow_values = ["ALLOWALL"] # This value does not really exist but has some special meaning for processing multiple values (https://html.spec.whatwg.org/multipage/document-lifecycle.html#the-x-frame-options-header)
partial_values = ["SAMEORIGIN"]
legacy_values = [f"ALLOW-FROM {origin_s}"]

# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/x-frame-options?label=master&label=experimental&aligned&q=x-frame
wpt_values = get_wpt_values('../../../x-frame-options/')
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'X-Frame-Options: (.*?)\'")
# https://crawler.ninja/files/xfo-values.txt
crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/xfo-values.txt")
own_values = []
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)

# %%
label = "CSP-FA"
header_name = "content-security-policy"
alt_names = ["x-content-security-policy", "x-webkit-csp", "x-webkit-content-security-policy"]
block_values = ["frame-ancestors 'none'"]
allow_values = ["frame-ancestors *"]
partial_values = ["frame-ancestors 'self'"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/content-security-policy/frame-ancestors?label=master&label=experimental&aligned&q=frame
wpt_values = ["frame-ancestors 'none'", "frame-ancestors 'self'", "frame-ancestors *", f"frame-ancestors {URL_REP}"]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'Content-Security-Policy: (.*?)\'")
# https://crawler.ninja/files/xfo-values.txt
crawler_ninja_values = []
# TODO: add crawler_ninja_values, Problem: Too many? Many are very similar and URL replacement results in a massive number of values
# crawler_ninja_values = get_crawler_values("https://crawler.ninja/files/csp-values.txt")
own_values = ["default-src 'none'", "self", "*", "frame-ancestors self", "frame-ancestors", "frame-ancestors none", "frame-src none", "frame-ancestors 'null'", "frame-ancestors null"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)

# %%
label = "CORP"
header_name = "cross-origin-resource-policy"
alt_names = ["from-origin", "x-cross-origin-resource-policy"]
block_values = [""]
allow_values = ["cross-origin"]
partial_values = ["same-site", "same-origin"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/fetch/cross-origin-resource-policy?label=master&label=experimental&aligned&q=cross-origin-resource-policy
wpt_values = ["same", "same, same-origin", "SAME-ORIGIN", "Same-Origin", "same-origin, <>", "same-origin, same-origin", URL_REP]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # No CORP tested
# https://crawler.ninja/files
crawler_ninja_values = [] # No CORP tested
own_values = ["unsafe-none"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)

# %%
label = "COEP"
header_name = "cross-origin-embedder-policy"
alt_names = ["x-cross-origin-embedder-policy"]
block_values = ["require-corp"]
allow_values = ["unsafe-none"]
partial_values = ["credentialless"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/html/cross-origin-embedder-policy?label=master&label=experimental&aligned&q=cross-origin-embedder-policy
wpt_values =   ['jibberish', 'require%FFcorp', 'require-corp;', '\u000brequire-corp\u000b', '\u000crequire-corp\u000c', '\u000drequire-corp\u000d', 'Require-corp', '"require-corp"', ':cmVxdWlyZS1jb3Jw:', 'require-corp;\tfoo=bar', 'require-corp require-corp', 'require-corp,require-corp', 'require-corp', ' require-corp ', '\trequire-corp\t', ' \trequire-corp', 'require-corp\t ', 'require-corp; foo=bar', 'require-corp;require-corp', 'require-corp; report-to="data:']
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # No COEP tested
# https://crawler.ninja/files
crawler_ninja_values = [] # No COEP tested
own_values = ["cross-origin", "same-origin"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)

# %%
label = "COOP"
header_name = "cross-origin-opener-policy"
alt_names = ["x-cross-origin-opener-policy"]
block_values = []
allow_values = ["unsafe-none"]
partial_values = ["same-origin", "same-origin-allow-popups"]
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/html/cross-origin-opener-policy?label=master&label=experimental&aligned&q=cross-origin-opener-policy
wpt_values =   ["same-origin;", "\u000bsame-origin\u000b", "\u000csame-origin\u000c", "\u000dsame-origin\u000d", "Same-origin", "same-origin;\tfoo=bar", "same-origin ;foo=bar", "same-origin; foo=bar;", "\"same-origin\"", ":c2FtZS1vcmlnaW4=:", "?1", "1", "$same-origin",  "same-origin same-origin", "same-origin\\,same-origin", "*same-origin ", "same%FForigin", " same-origin", "same-origin ", "\tsame-origin", "same-origin\t", "same-origin;same-origin", "same-origin; foo=bar"]
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = [] # No COOP tested
# https://crawler.ninja/files
crawler_ninja_values = [] # No COOP tested
own_values = ["cross-origin", "same-origin", "same-origin-plus-COEP"]
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)

# %%
len(other_values)
# Out:
# 41

# %%
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
#ht.save_responses()
# Out:
# 2650
# [([('cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-eembedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('jcross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-eymbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e7mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e=mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-ecmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('\tcross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policy)', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policy4', 'require-corp')], 'COEP', 200, 'parsing'), ([('，cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e+mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e\x1ambedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e\x1cmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e6mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('<cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e?mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policy\x02', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-epmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('\x1dcross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-exmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e\x18mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-ehmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-eRmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policy\x07', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policy.', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e  mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e\tmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('Pcross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policyo', 'require-corp')], 'COEP', 200, 'parsing'), ([('\x14cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policyO', 'require-corp')], 'COEP', 200, 'parsing'), ([('\x19cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('%cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policyT', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-elmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policyt', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-egmbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('_cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-e_mbedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('\x1across-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('\\cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross`origin`embedder`policy', 'require-corp')], 'COEP', 200, 'parsing'), ([("'cross-origin-embedder-policy", 'require-corp')], 'COEP', 200, 'parsing'), ([('cross”origin”embedder”policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policyf', 'require-corp')], 'COEP', 200, 'parsing'), ([('6cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('@cross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('Icross-origin-embedder-policy', 'require-corp')], 'COEP', 200, 'parsing'), ([('cross-origin-embedder-policyL', 'require-corp' ...
