# %%
import random
import re
import httpx
import glob
import os
from itertools import permutations

# %%
def randomize_casing(input_string, seed=42):
    """Randomize the casing of a string (fixed with a seed)."""
    random.seed(seed)
    return ''.join(random.choice([c.upper(), c.lower()]) for c in input_string)

def insert_char_middle(input_string, char):
    """Insert a char in the middle of a string."""
    middle_index = len(input_string) // 2
    return input_string[:middle_index] + char + input_string[middle_index:]

# %%
# All the mutations we apply on strings such as header names and header values
# Some of them may have no effect and result in duplicates; however such duplicates are not saved in the db

all_upper = lambda x: x.upper()
all_lower = lambda x: x.lower()
random_case = lambda x: randomize_casing(x)
leadtrail_space = lambda x: " " + x + " "
in_double_quotes = lambda x: '"' + x + '"'
in_single_quotes = lambda x: "'" + x + "'"
remove_whitespace = lambda x: x.replace(" ", "")
double_spaces = lambda x: x.replace(" ", "  ")
space_to_tab = lambda x: x.replace(" ", "\t")

lead_seqs = []
trail_seqs = []
middle_seqs = []

# All all ASCII chars as leading, trailing, and middle char
ascii_chars = [char for char in map(chr, range(128))]
# Alternatively use less ones? All/Some control chars? + space, comma, ....
# ascii_chars = [char for char in map(chr, range(32))] + [" ", ",", ";", ":"]
for seq in ascii_chars:
    lead_seqs.append(lambda x, s=seq: s + x)
    trail_seqs.append(lambda x, s=seq: x + s)
    middle_seqs.append(lambda x, s=seq: insert_char_middle(x, s))

# Add other interesting leading, trailing, middle chars: Double space, non-breaking space, full-width comma
# TODO: add more?
other_chars = ["  ", "\u00A0a", "\uFF0C"]
for seq in other_chars:
    lead_seqs.append(lambda x, s=seq: s + x)
    trail_seqs.append(lambda x, s=seq: x + s)
    middle_seqs.append(lambda x, s=seq: insert_char_middle(x, s))

# Replace some chars with others
replace_chars = [
    "", " ", ";", ",", ":", "=", "-", "_",
    "'", '"', "`", "´",
    '\u2018',  # Left Single Quotation Mark
    '\u2019',  # Right Single Quotation Mark
    '\u201A',  # Single Low-9 Quotation Mark
    '\u201B',  # Single High-Reversed-9 Quotation Mark
    '\u201C',  # Left Double Quotation Mark
    '\u201D',  # Right Double Quotation Mark
    '\u201E',  # Double Low-9 Quotation Mark
    '\u201F',  # Double High-Reversed-9 Quotation Mark
]
chars_to_replace = [";", ",", ":", "=", "'", '"', "-", "_"]
replace_funcs = []
for char in chars_to_replace:
    for rp in replace_chars:
        if rp == char:
            continue
        replace_funcs.append(lambda x, c1=char, c2=rp: x.replace(c1, c2))



general_mutations = [
    all_upper,
    all_lower,
    random_case,
    leadtrail_space,
    in_double_quotes,
    in_single_quotes,
    remove_whitespace,
    double_spaces,
    space_to_tab,
    *lead_seqs,
    *trail_seqs,
    *middle_seqs,
    *replace_funcs,
]


def mutate_header_name(header_name):
    header_names = set()
    for mutation in general_mutations:
        header_names.add(mutation(header_name))
    return header_names

def mutate_header_value(header_value):
    header_values = set()
    for mutation in general_mutations:
        header_values.add(mutation(header_value))
    return header_values

# %%
l = mutate_header_value("D EN'Y")
print(l)
print(list(l)[0])
# Out:
# {"D eN'Y", 'D EN`Y', 'D EN;Y', 'D EN“Y', "D  EN'Y", 'D ENY', 'D EN’Y', 'D EN=Y', 'D EN Y', 'D EN„Y', 'D EN”Y', 'D EN‟Y', 'D EN´Y', 'D EN‘Y', "D EN'Y", "d en'y", "'D EN'Y'", 'D EN‛Y', "D\tEN'Y", '"D EN\'Y"', " D EN'Y ", 'D EN,Y', 'D EN‚Y', 'D EN"Y', "DEN'Y", 'D EN:Y'}
# D eN'Y

# %%
class HeaderTests:
    def __init__(self, label: str, header_name: str, alt_names: list[str], block_values: list[str], allow_values: list[str], partial_values: list[str], legacy_values: list[str], other_values: list[str]):
        """"HeaderTests class to create lots of responses
        label (str): Additional information about these responses (e.g., XFO)
        header_name (str): The correct lower-case name of the header
        alt_names (list[str]): Legacy and other (invalid) alternative header names
        block_values (list[str]): Valid values to set the header to "blocking" (e.g., DENY for XFO means always disallow framing)
        allow_values (list[str]): Valid values to set the header to "allowing" (e.g., unsafe-none  for COOP means do not activate COOP/always allow)
        partial_values (list[str]): Valid values to set the header to an intermediate mode (e.g., SAMEORIGIN for XFO means allow framing only for same-origin)
        legacy_values (list[str]): Legacy values that should not work anymore
        other_values (list[str]): Other values we want to test as well (can include valid ones if we do not want to put too many in the other categories)
        """
        self.label = label
        self.header_name = header_name
        self.alt_names = alt_names
        self.block_values = block_values
        self.allow_values = allow_values
        self.partial_values = partial_values
        self.legacy_values = legacy_values
        self.other_values = other_values
        self.responses = []

    def create_response(self, header, label, status_code=200, resp_type="parsing"):
        self.responses.append((header, label, status_code, resp_type))

    def save_responses(self):
        #with Session() as session:
        #for header in header_list:
         #r, created = get_or_create(session, Response, raw_header=header, status_code=status_code, label=label, resp_type=resp_type)
         #if created:
            #print(r)
        print(len(self.responses))
        print(self.responses)

    def header_name_tests(self):
        """Test all block, allow, partial values (correct values)
            with the correct header names, with all alternative/legacy header names, and with mutated versions of the correct header_name
        """
        for value_group in [self.block_values, self.allow_values, self.partial_values]:
            for header_value in value_group:
                # Original header name
                self.create_response([(self.header_name, header_value)], self.label)
                # Alt header names
                for header_name in self.alt_names:
                    self.create_response([(header_name, header_value)], self.label)
                # Mutated header names
                for header_name in mutate_header_name(self.header_name):
                    self.create_response([(header_name, header_value)], self.label)

    def parsing_tests(self):
        """Test all header values + mutated versions.
        """
        # Test all legacy and other values (block, allow, partial do not have to be tested as they are already tests by header_name_tests)
        for value_group in [self.legacy_values, self.other_values]:
            for header_value in value_group:
                self.create_response([(self.header_name, header_value)], self.label)
        
        # Mutate/change header values (block, allow, partial)
        for value_group in [self.block_values, self.allow_values, self.partial_values]:
            for org_header_value in value_group:
                # Other status codes
                for code in [201, 203, 204, 300, 302, 400, 403, 404, 418, 500]:
                    if 300 <= code < 400:
                        self.create_response([(self.header_name, org_header_value), redirect_empty], self.label, status_code=code)
                    else:
                        self.create_response([(self.header_name, org_header_value)], self.label, status_code=code)
                # Mutated header values
                for header_value in mutate_header_value(org_header_value):
                    self.create_response([(self.header_name, header_value)], self.label)

    def mult_headers_tests(self):
        """Test involving multiple headers/values
        """
        all_valid_values = self.block_values + self.allow_values + self.partial_values
        all_orders = list(permutations(all_valid_values))
        # Basic1: all legal values in a list in all possible orders (Comma, space, semicolon-separated)
        for order in all_orders:
            self.create_response([(self.header_name, ", ".join(order))], self.label)
            self.create_response([(self.header_name, "; ".join(order))], self.label)
            self.create_response([(self.header_name, " ".join(order))], self.label)
        
        # Basic2: all legal values in separate headers in all possible orders
        for order in all_orders:
            headers = [(self.header_name, header_value) for header_value in order]
            self.create_response(headers, self.label)
        # Basic3: all legal values in both separate headers and in one header with comma?!
        # Only if at least 3 values; split in first and all others and last and all others
        for order in all_orders:
            if len(order) >= 3:
                first, rest1 = order[0], ", ".join(order[1:])
                rest2, last = ", ".join(order[:-1]), order[-1]
                self.create_response([(self.header_name, first), (self.header_name, rest1)], self.label)
                self.create_response([(self.header_name, rest2), (self.header_name, last)], self.label)

        # Basic4: all legal values duplicated
        for value in all_valid_values:
            self.create_response([(self.header_name, value), (self.header_name, value)], self.label)
            self.create_response([(self.header_name, f"{value}, {value}")], self.label)
            
            # Could be extended with mutated versions once, e.g., X-Frame-Options: ALLOWALL, allowall;
            # Browsers should first lowercase and then put each value in a set https://html.spec.whatwg.org/multipage/document-lifecycle.html#the-x-frame-options-header
            # Which means no blocking should occur, if they forget the lowercasing part, the set size would be two and it would be blocked
            # Other extensions possible as well
            self.create_response([(self.header_name, value), (self.header_name, value.lower())], self.label)
            self.create_response([(self.header_name, value), (self.header_name, value.upper())], self.label)
        
        # Advanced1: use different header names (e.g., if a browser accepts both x-frame-options and X-FRAME-OPTIONS which takes precedence?; might be none if the browser first lower-cases or something like that)
        # Currently only either uppercase the first header or all except the first header (other mutations and header duplication strategies could be added in the future)
        # Could be extended with clearly invalid headers (e.g., leading or trailing space, ...)
        for order in all_orders:
            for (header1, header2) in [(self.header_name, self.header_name.upper()), (self.header_name.upper(), self.header_name)]:
                headers = [(self.header_name, header_value) for header_value in order]
                headers = []
                for i, header_value in enumerate(order):
                    if i == 0:
                        headers.append((header1, header_value))
                    else:
                        headers.append((header2, header_value))
                self.create_response(headers, self.label)
    
        # Advanced2: use invalid values as well (e.g., a browser might always take the first header while another browser takes the first valid header?)
        for valid_value in all_valid_values:
            # Only use the first two invalid values (should be empty and a clearly invalid value ("INVALID")
            # Could be extended with more complex approaches
            for invalid_value in self.other_values[:2]:
                self.create_response([(self.header_name, valid_value), (self.header_name, invalid_value)], self.label)
                self.create_response([(self.header_name, invalid_value), (self.header_name, valid_value)], self.label)
                self.create_response([(self.header_name, f"{valid_value}, {invalid_value}")], self.label)
                self.create_response([(self.header_name, f"{invalid_value}, {valid_value}")], self.label)

        # TODO special: XFO and CSP-FA

                
    def create_all_tests(self):
        self.header_name_tests()
        self.parsing_tests()
        self.mult_headers_tests()
        self.save_responses()

# %%
redirect_empty = ("location", "https://sub.headers.websec.saarland/_hp/common/empty.html")
site = "sub.headers.websec.saarland"
origin_s = "https://sub.headers.websec.saarland"
origin = "http://sub.headers.websec.saarland"
origin_sp = f"{origin_s}:443"
home = f"{origin_s}/"
home_p = f"{origin_sp}/"
parent = "https://headers.websec.saarland"
child = "https://sub.sub.headers.websec.saarland"
parent_childs = "*.headers.websec.saarland"
self_childs = "*.sub.headers.websec.saarland"
cross_site_origin = "https://headers.webappsec.eu"
URL_REP = "<!URL!>"

# %%
label = ""
header_name = ""
alt_names = []
block_values = []
allow_values = []
partial_values = []
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
other_values = ["", "INVALID"]
other_values = expand_urls(other_values)

# %%
def expand_urls(other_values):
    """Use different URL, origins, sites variations if the value should allow some sites"""
    return_values = []
    for value in other_values:
        if not URL_REP in value:
            return_values.append(value)
        else:
            for url_like in [site, origin_s, origin, origin_sp, home, home_p, parent, child, parent_childs, self_childs, cross_site_origin]:
                return_values.append(value.replace(URL_REP, url_like))
    return return_values

# %%
def get_values(url, pattern):
    content = httpx.get(url).text
    matches = set(re.findall(pattern, content))
    return matches

siewert_xfo = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'X-Frame-Options: (.*?)\'")
print(siewert_xfo)
print()
siewert_csp = get_values("https://raw.githubusercontent.com/hen95/HTTPHeaderBrowserTesting/main/transform_to_testcase.py", r"\'Content-Security-Policy: (.*?)\'")
print(siewert_csp)
# Out:
# {'allow-from TESTURI; deny', 'allow-from TESTURI', 'allow-from http://randomorigin.com/, allow-from TESTURI', 'allow-from http://random.ninja', 'allow-from TESTURI; allow-from http://randomorigin.com/', 'allow-from http://randomorigin.com/', 'sameorigin, deny', 'allow-from https://much.ninja', 'deny, sameorigin', 'sameorigin', 'sameorigin; sameorigin', 'RANDOMDIRECTIVE', 'allow-from http://randomorigin.com/; allow-from http://randomorigin.com/', 'allowall', 'deny; deny', 'allow-from http://much.ninja', 'deny; sameorigin', 'sameorigin, sameorigin', 'sameorigin, allow-from http://randomorigin.com', 'sameorigin; deny', 'allow-from http://randomorigin.com, sameorigin', 'deny; allow-from TESTURI', 'deny, deny', 'allow-from http://randomorigin.com/, allow-from http://randomorigin.com/', 'allow-from TESTURI, allow-from http://randomorigin.com/', 'allow-from TESTURI, deny', 'deny, allow-from TESTURI', 'allow-from http://randomorigin.com/, deny', 'deny'}
#
# {'frame-ancestors much.ninja;', 'frame-ancestors http:;', 'frame-ancestors *.ninja;', 'frame-ancestors https:;', 'frame-ancestors http://randomorigin.com;', 'frame-ancestors http://*.ninja http://randomorigin.com;', 'frame-ancestors http://much.ninja;'}

# %%
def get_wpt_values(dir_path, pattern=r'headerValue: `(.*)`|headerValue2: `(.*)`'):
    # Initialize a list to store matching strings
    values = set()
    # Use glob to find all files with the specified extension recursively
    file_paths = glob.glob(os.path.join(dir_path, '*.html'), recursive=False)
    # Iterate through the list of file paths
    for file_path in file_paths:
        with open(file_path, 'r') as f:
            content = f.read()
            matches = re.findall(pattern, content)
            for match1, match2 in matches:
                values.add(match1)
                values.add(match2)
    return values

wpt_xfo = get_wpt_values('../../../x-frame-options/')
wpt_xfo
# Out:
# {'',
#  '  DENY ',
#  '  SAMEORIGIN ',
#  '  SAMEORIGIN,    DENY',
#  '"DENY"',
#  '"SAMEORIGIN"',
#  '"SAMEORIGIN,DENY"',
#  ',SAMEORIGIN,,DENY,',
#  'ALLOW-FROM https://example.com/',
#  'ALLOW-FROM=https://example.com/',
#  'ALLOWALL',
#  'DENY',
#  'INVALID',
#  'SAMEORIGIN',
#  'allowAll',
#  'denY',
#  'sameOriGin',
#  'sameOrigin'}

# %%
def get_crawler_values(url):
    return [row.split(" ", maxsplit=1)[0] for row in httpx.get(url).text.split("\r\n")[1:]]

crawler_ninja_xfo = get_crawler_values("https://crawler.ninja/files/xfo-values.txt")
crawler_ninja_xfo
# Out:
# [['SAMEORIGIN', '202,669'],
#  ['DENY', '39,481'],
#  ['ALLOW-FROM',
#   '1win-partner.com  ww.1win.run 1win.run www.1win.work 1win.work www.1w.run 1w.run www.1wip.best 1wip.best www.1wint.run 1wint.run www.1winr.run 1winr.run www.1wind.run 1wind.run www.1wins.run 1wins.run www.1w.fan 1w.fan www.1win.team 1win.team www.1win.partners 1win.partners 1wip.best www.1wip.best 1wint.run www.1wint.run 1winr.run www.1winr.run 1wind.run www.1wind.run 1wins.run www.1wins.run 1w.fan www.1w.fan 1,238'],
#  ['ALLOWALL', '750'],
#  ['SAMEORIGIN,', 'SAMEORIGIN 592'],
#  ['175'],
#  ['ALLOW', '157'],
#  ['*', '98'],
#  ['ALLOW-FROM', '* 92'],
#  ['GOFORIT', '90'],
#  ['ALLOW-FROM', 'https://dbwas.service.deutschebahn.com 61'],
#  ['ALLOW-FROM',
#   'https://app.kajabi.com https://app.vibely.io https://communities.kajabi.com 60'],
#  ['“DENY”', '56'],
#  ['same-origin', '50'],
#  ['DENY,', 'SAMEORIGIN 41'],
#  ['SAMEORIGIN,SAMEORIGIN', '41'],
#  ['SAMEORIGIN,', 'deny 39'],
#  ['ALLOW-FROM', "'self' 37"],
#  ['ALLOW-FROM', 'SAMEDOMAIN, * 36'],
#  ['SAMEORIGIN', 'always 31'],
#  ['SAMEORIGIN,', 'SAMEORIGIN, SAMEORIGIN 31'],
#  ['NONE', '28'],
#  ['SAMEORIGIN;', '27'],
#  ['Allow-From', 'awards.ratingruneta.ru 24'],
#  ['ALLOW-FROM', 'http://webvisor.com 23'],
#  ['CROSS-ORIGIN', '22'],
#  ['ALLOW-FROM', '20'],
#  ['ALLOW-FROM', 'SAMEDOMAIN 19'],
#  ['allow-from', 'https://co-browsing.mercury.ai 19'],
#  ['SAMEORGIN', '19'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://omnidoctor.ru/ 19'],
#  ['ALLOW-FROM', 'https://www.facebook.com/ 17'],
#  ['“SAMEORIGIN”', '14'],
#  ['"SAMEORIGIN"', '14'],
#  ['ALLOW-FROM', 'platformdirectads.com 14'],
#  ['SAMEORIGIN', 'gtranslate.io 14'],
#  ['ALLOW-FROM', 'https://admin.govdelivery.com/ 13'],
#  ['ALLOW-FROM', 'http://webvisor.com/ 13'],
#  ['ALLOW-FROM', 'https://newapp.etracker.com 13'],
#  ['ALLOW-FROM', '"sameorigin" https://secure.safecharge.com; 13'],
#  ['ALLOW-FROM', 'https://virtual-tours.msccruises.com 12'],
#  ['SAMEORIGIN', 'https://app.contentful.com 11'],
#  ['allow-from', 'https://www.youtube.com 11'],
#  ['ALLOW_FROM',
#   'http://dc2-staging.holagames.io, ALLOW_FROM https://dc2-staging.holagames.io 11'],
#  ['ALLOW-FROM', 'storyblok.com 11'],
#  ['ALLOW-FROM', 'https://play.workadventu.re 11'],
#  ['ALLOW-FROM', 'https://oa.sheincorp.cn 10'],
#  ['ALLOW-FROM', 'https://www.thomsonreuters.com 10'],
#  ['allow-from', 'https://webvisor.com/ 10'],
#  ['ALLOW-FROM', 'SAMEORIGIN 10'],
#  [':', 'SAMEORIGIN 10'],
#  ['ALLOW-FROM', 'https://www.facebook.com 10'],
#  ['FALSE', '10'],
#  ['nosniff', '10'],
#  ['ALLOW-FROM',
#   'SAMEORIGIN https://*.ziggo.nl https://*.vodafone.nl https://*.vfz-services.nl https://*.prod.aws.ziggo.io https://*.acc.aws.ziggo.io https://*.dev.aws.ziggo.io https://*.hollandsnieuwe.nl https://vodafoneziggo.portal.mobilewater.nl 9'],
#  ['ALLOW-FROM', 'https://spa-dev-dodo.vocus.net 9'],
#  ['ALLOW-FROM', 'https://talent.btv.bg 9'],
#  ['ALLOW-FROM', 'https://login.ringcentral.com 8'],
#  [':', 'SAMEORIGIN 8'],
#  ['ALLOW-FROM', 'static.miraheze.org 8'],
#  ['SAMESITE', '8'],
#  ['NEVER', '8'],
#  ['ALLOW-FROM', '49.40.27.13 8'],
#  ['ALLOW-FROM', 'https://web.telegram.org 8'],
#  ['allow-from', 'https://www.youtube.com/ 7'],
#  ['DENY', 'always 7'],
#  ['SAMEORIGIN,',
#   'ALLOW-FROM https://events1.social27.com, https://tools.jll.com, https://journeys.jll.com, https://qa-journeys.jll.com 7'],
#  ['"SAMEORIGIN"', 'always; 7'],
#  ['Allow-From', 'webvisor.com 7'],
#  ['1;', 'SAMEORIGIN 7'],
#  ['"SAMEORIGIN"', 'always 7'],
#  ['ALLOW-FROM', 'https://hotspot.wiline.cz 7'],
#  ['ALLOW-FROM',
#   'https://shopproxy.p-s-s.de https://home.interzum.com https://home.interzum.de 7'],
#  ['SAMEORIGIN,ALLOW-FROM,ALLOW-FROM,ALLOW-FROM,ALLOW-FROM,ALLOW-FROM,ALLOW-FROM',
#   '7'],
#  ['ALLOW-FROM',
#   'https://crowdstrike.pathfactory.com https://crowdstrike.com 6'],
#  ['SAMEORIGIN', 'always; 6'],
#  ['ALLOW-FROM', 'https://apps.facebook.com 6'],
#  ['SANEORIGIN', '6'],
#  ['ALLOW-FROM',
#   'https://www.technomic.com, https://www.restaurantbusinessonline.com, https://www.foodservicedirector.com, https://www.winsightgrocerybusiness.com, https://www.cspdailynews.com/, https://portal.winsight-labs.com, https://portal.winsightmedia.com, https://www.winsightmedia.com, https://static.iris.informa.com 6'],
#  ['SAMEORIGIN', 'storyblok.com 6'],
#  ['self', '6'],
#  ['ALL', '6'],
#  ['allow-from', 'app.storyblok.com 6'],
#  ['ALLOW-FROM', 'https://webvisor.com 6'],
#  ['ALLOW-FROM', 'https://app.storyblok.com/ 6'],
#  ['ALLOW-FROM', "'sameorigin' https://secure.safecharge.com; 6"],
#  ['allow-from', 'https://app.bookingexperts.nl 6'],
#  ['ALLOW-FROM', 'https://planner.dbcargo.com 6'],
#  ['ALLOW-FROM', 'https://optimize.google.com 6'],
#  ['ALLOW-FROM', 'https://content.servicenow.com 5'],
#  ['allow-from', 'splytech.io 5'],
#  ['ALLOW-FROM', 'https://telenor.psplugin.com 5'],
#  ['allow-from', 'https://now.gg/ 5'],
#  ['SAMEORIGIN', '5'],
#  ['ALLOW-FROM', 'https://pages.hitachivantara.com 5'],
#  ['DENY,SAMEORIGIN', '5'],
#  ['ALLOW-FROM', 'https://verizonconnect.getambassador.com/ 5'],
#  ['ALLOW-FROM', 'https://ny1.com 5'],
#  ['ALLOW-FROM',
#   'https://dev.mwcbarcelona.com/ https://www.mwcbarcelona.com/ https://mwcbarcelona.com/ https://dev.mwc-africa.com/ https://www.mwc-africa.com/ https://mwc-africa.com/ https://dev.mwclasvegas.com/ https://www.mwclasvegas.com/ https://mwclasvegas.com/ https://dev.gsmaevents.com/ https://www.gsmaevents.com/ https://staging.gsmaevents.com/ https://gsma.force.com/ https://gsma.my.site.com/ 5'],
#  ['ALLOW-FROM', 'https://trustseal.enamad.ir 5'],
#  ['ALLOW-FROM',
#   'https://resideo.ziftone.com/,https://proportal.resideo.com/,https://pro.resideo.com/,https://resideostaging.staging.ziftone.com/,https://resideo.netdimensions.com/,https://deploy-preview-437--resideo-pro.netlify.com/,https://fxm/,https://resideo-pro-perks.my-rewardsonline/ 5'],
#  ['ALLOW-FROM', 'https://metrika.yandex.ru/ 5'],
#  ['allow-from', 'http://salesforce.com/ 5'],
#  ['allow-from', 'https://ips02.planetart.com 5'],
#  [':', 'DENY 5'],
#  ['add_header', 'X-Frame-Options "SAMEORIGIN" always; 5'],
#  ['ALLOW-ALL', '5'],
#  ['ALLOW-FROM', 'http://nsfwalbum.com/ 5'],
#  ['(DENY', '|| SAMEORIGIN) 5'],
#  ['vasaloppet.se', '5'],
#  ['ALLOW-FROM', 'https://app.reskyt.com/ 5'],
#  ['allow-from', 'https://walmartisd.experiencecloud.adobe.com/ 5'],
#  ['ALLOW-FROM',
#   'https://vimeo.com/ https://secure.onecallnow.com/ https://onsolve.bamboohr.com/ 5'],
#  ['ALLOW-FROM', 'https://www.mapama.gob.es/ 5'],
#  ['allow-from',
#   "'self' *.facebook.com *.salesforce.com *.convio.net *.google.com *.force.com facebook.com salesforce.com convio.net google.com force.com 5"],
#  ['DENY,', 'DENY 5'],
#  ['ALLOW-FROM', 'https://*.storyblok.com/ 5'],
#  ['SAMEORGINE', '5'],
#  ['ALLOW-FROM', 'https://saint-gobain.wmh-demos.com/ 5'],
#  ['ALLOW-FROM', 'https://www.nimblerx.com 4'],
#  ['allow-from', 'https://frida.main.messefrankfurt.com/ 4'],
#  ['ALLOW-FROM', 'https://www.equans.co.uk 4'],
#  ['ALLOW-FROM', 'shop.avid.com 4'],
#  ['ALLOW-FROM',
#   '*.vtr.com/ https://www.googletagmanager.com/ https://www.youtube.com/ https://www.google.com/ https://tivo.pactsafe.io/ https://lilacservices.demdex.net/ https://8032352.fls.doubleclick.net/ https://vtr-app.quantummetric.com/ https://udc-neb.kampyle.com https://ww2.movistar.cl/ 4'],
#  ['ALLOW-FROM', 'https://accounts.cft.ru 4'],
#  ['ALLOW-FROM', 'https://hermes.telekurier.at 4'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://cedarssinai.marketing.adobe.com/ 4'],
#  ['ALLOW-FROM', 'https://docs.google.com 4'],
#  ['sameorigin,',
#   'allow-from *.isrvr.com, allow-from *.ajginternational.com, allow-from *.penunderwriting.co.uk, allow-from *.gallagherheath.local, allow-from *.siteimprove.com 4'],
#  ['strict-origin-when-cross-origin', '4'],
#  ['SOMEORIGIN', '4'],
#  ['ALLOW-FROM', 'app.reskyt.com 4'],
#  ['ALLOW-FROM', 'https://careerkarma.com 4'],
#  ['SAMEORIGIN', 'allow-from yobingo-statices.casinomodule.com 4'],
#  ['ALLOW-FROM', 'static.wikitide.net 4'],
#  ['"DENY"', '4'],
#  ['ALLOW-FROM', 'https://moderncampus.pathfactory.com 4'],
#  ['ALLOW-FROM', 'https://s-static.ak.facebook.com 4'],
#  ['null', '4'],
#  ['ALLOW-FROM', 'http://dev.elsevier.es 4'],
#  ['SAMEORIGIN', '4'],
#  ['author-aem.hyundai.com', '4'],
#  ['SAMEORIGN', '4'],
#  ['SAME', 'ORIGIN 4'],
#  ['frame-ancestors', 'viewer.ipaper.io 4'],
#  ['ALLOW-FROM=https://www2.cdkglobal.com', '4'],
#  ['ALLOW-FROM', 'https://www.synology.com https://*.facebook.com 3'],
#  ['ALLOW-FROM', 'https://twitter.com/ 3'],
#  ['ALLOW-FROM', 'https://nurture.solarwinds.com/ 3'],
#  ['ALLOW-FROM',
#   'https://www.razer.com/ https://storefront-p1.phoenix.razer.com/ https://backoffice-p1.phoenix.razer.com/ 3'],
#  ['ALLOW-FROM', 'https://transferwiseturkiye.com.tr 3'],
#  ['allow-from', 'http://digital.nstp.com.my/ 3'],
#  ['ALLOW-FROM', 'https://target.my.com/ 3'],
#  ['SAMEORIGIN', 'ALLOW-FROM http://info.barchart.com 3'],
#  ['ALLOW-FROM', 'https://centinelapi.cardinalcommerce.com 3'],
#  [':',
#   'allow-from https://www.youtube.com https://giphy.com https://vimeo.com https://mackeeper.com https://www.slideshare.net 3'],
#  ['SAMEDOMAIN', '3'],
#  ['SAMEORIGIN,', 'SAMEORIGIN, DENY 3'],
#  ['ALLOW-FROM', 'https://corporate.payu.com 3'],
#  ['ALLOW-FROM', 'https://rise.articulate.com 3'],
#  ['ALLOW-FROM', 'https://login.apus.edu/ 3'],
#  ['ALLOW-FROM', 'https://translate.googleusercontent.com 3'],
#  ['SAMEORIGIN,',
#   'ALLOW-FROM https://finanzen.check24.de/, ALLOW-FROM https://www.check24.de/ 3'],
#  ['ALLOW-FROM', 'https://clientcenter.tradestation.com 3'],
#  ['ALLOW-FROM',
#   'https://vimeo.com/ https://www.youtube-nocookie.com https://www.youtube.com 3'],
#  ['ALLOW-FROM', 'https://blaetterkatalog.musicstore.de 3'],
#  ['ALLOW-FROM', 'live.globetrotter.de 3'],
#  ['ALLOW-FROM',
#   'https://randomhouse.scnem.com/ https://penguinrandomhouse.scnem.com/ https://shop.randomhouse.de https://www.sinnliche-seiten.de/ https://sinnliche-seiten.de/ https://www.randomhouse.de/ https://www.penguinrandomhouse.de/  https://www.penguin.de/ https://randomhouse.de/ https://www.buchgeschenkefinder.de/ https://buchgeschenkefinder.de/  http://rhdemobilepreview http://rhdemobilepreview:28080 3'],
#  ['ALLOW-FROM', 'https://bite.blueconic.net/ 3'],
#  ['ALLOW-FROM', 'https://awards.ratingruneta.ru 3'],
#  ['ALLOW-FROM', '*.dynamics.com 3'],
#  ['ALLOW-FROM', 'https://www.flatex.de 3'],
#  ['SAMEORIGIN,',
#   'ALLOW-FROM https://www.endesaclientes.com https://syndication.teleborsa.it https://accounts-coll.enel.com:9443 https://assets.adobedtm.com http://52.144.89.133 https://enel.taleo.net https://reg.enel.it https://aemproddmz.enel.com https://endesa.cogitodesk.com https://www.energiaxxi.com 3'],
#  ['ALLOW-FROM', 'https://www.reliaquest.com/ 3'],
#  ['ALLOW-FROM', 'https://www.goglasi.com/ 3'],
#  ['ANY', '3'],
#  ['ALLOW-FROM', 'https://accruent.seismic.com 3'],
#  ['allow-from', ' *.energiebespaargame.nl *.jointhe2b.com 3'],
#  ['allow-from',
#   'http://workflow-test.tyson.com/, allow-from http://workflow.tyson.com/, allow-from https://tysononline.sharepoint.com 3'],
#  ['ALLOW-FROM', 'uri 3'],
#  ['ALLOW-FROM', 'https://planovac.siko.cz 3'],
#  ['ALLOW-FROM', 'HTTPS://CL.KGMSRV.COM/ 3'],
#  ['sameoriginSAMEORIGIN', '3'],
#  ['persistentcontenthub.enablix.com,', 'SAMEORIGIN 3'],
#  ['DENY,', 'DENY, DENY 3'],
#  ['google.com', '3'],
#  ['ALLOW-FROM', 'https://nttdata-solutions.com 3'],
#  ['ALLOW-FROM', 'http://ecomdisplay.int/ 3'],
#  ['ALLOW-FROM',
#   'https://io.apply.creditkarma.com https://embedded.creditkarma.com 3'],
#  ['ALLOW-FROM', 'g.modivcare.com 3'],
#  ['SMAEORIGIN', '3'],
#  ['ALLOW-FROM', 'https://www.growingio.com 3'],
#  ['ALLOW-FROM', 'http://www.itchotels.com 3'],
#  ['ALLOW-FROM', 'beinmatch.biz 3'],
#  ["'deny'", '3'],
#  ['ALLOW_FROM', 'https://wpp-wdcee.wirecard.com 3'],
#  ['Allow-From', 'file:///android_asset/www/index.html 3'],
#  ['ALLOW-FROM', 'mkt.blog.kenlo.com.br 3'],
#  ['ALLOW-FROM', 'https://sf360.com.au 3'],
#  ['ALLOW-FROM',
#   'http://localhost:3000 https://www.targetmarketing.co.kr https://mktplatform.tason.com https://dev-mktplatform.tason.com 3'],
#  ['ALLOW-FROM', 'METRIKA.YANDEX.RU MC.YANDEX.RU 3'],
#  ['https://www.energiewechsel.de', '3'],
#  ['ALLOW-FROM',
#   'https://www.plansponsor.com/site-header/, https://www.plansponsor.com/site-footer/, https://www.planadviser.com/site-header/, https://www.planadviser.com/site-footer/, https://www.ai-cio.com/site-footer/, https://www.ai-cio.com/site-header/ 3'],
#  ['ALLOW-FROM', 'https://www.panamajackshop.com 3'],
#  ['ALLOW-FROM', 'https://services.economy.ae/ 3'],
#  ['ALLOW-FROM', 'https://open-lms-studio.netlify.app 3'],
#  ['ALLOW-FROM', 'https://*.moody.edu/ 3'],
#  ['allow-from', 'https://cws.digital/ 3'],
#  ['ALLOW-FROM',
#   'https://paghe.passepartout.sm/ https://paghe-testupd.passepartout.sm https://paghe.passstage.cloud/ 3'],
#  ['ALLOW-FROM', 'https://greenhouse.cloversites.com 3'],
#  ['X-Frame-Options:', 'DENY 3'],
#  ['ON', '3'],
#  ['ALLOW-FROM', 'http://storyblok.com 3'],
#  ['ALLOW-FROM', 'checkfront.co.uk 3'],
#  ['ALLOW-FROM', 'https://www.h0874.com 3'],
#  ['ALLOW-FROM',
#   'https://metrika.yandex.ru https://webvisor.com http://webvisor.com 3'],
#  ["''", '3'],
#  ['crossorigin', '3'],
#  ['ALLOW-FROM', 'http://poisoft.com 3'],
#  ['ALLOW-FROM', 'https://*.mintegral.com 2'],
#  ['“SAMEORIGIN“', '2'],
#  ['https://bluecore.lookbookhq.com', '2'],
#  ["'SAMEORIGIN'", '2'],
#  ['ALLOW-FROM', 'https://info.domaintools.com 2'],
#  ['ALLOW-FROM',
#   'https://www.slipcase.com https://marketplace.marsh.com https://www.riskdataobject.com https://dev.pcgcustomer.nprd.aig.com https://dev2.pcgcustomer.nprd.aig.com https://qa.pcgcustomer.nprd.aig.com https://qa2.pcgcustomer.nprd.aig.com https://uat.pcgcustomer.nprd.aig.com https://perf.pcgcustomer.nprd.aig.com https://perf2.pcgcustomer.nprd.aig.com https://pcgcustomer.aig.com/ 2'],
#  ['allow-from', '*.toast.com *.dooray.com dooray.com 2'],
#  ['allow-from', 'https://www.livehindustan.com 2'],
#  ['ALLOW-FROM', 'https://www.ub.edu/ 2'],
#  ['ALLOW-FROM', 'https://www.arabnews.com/alula 2'],
#  ['ALLOW-FROM', 'http://201.149.34.171 2'],
#  ['allow-from',
#   "'self' *.edwardjones.com *.edwardjones.ca accountaccess.devjones.com accountaccess.devjones.ca iaa-api-gateway.apps.devjones.com accountaccess.edwardjones.com accountaccess.edwardjones.ca onlineaccess.edwardjones.com iaaweb.edwardjones.com:9070 2"],
#  ['ALLOW-FROM', 'https://comscore.sharepoint.com 2'],
#  ['ALLOW-FROM', 'https://www.oui.sncf 2'],
#  ['ALLOW-FROM', '*.crestron.com 2'],
#  ['ALLOW-FROM', 'https://hightail.com 2'],
#  ['SAMEORIGIN', 'ALLOW-FROM https://design-use.ci360.sas.com 2'],
#  ['ALLOW-FROM', 'https://www.medscape.com 2'],
#  ['ALLOW-FROM',
#   'https://staging.portal.mythermoking.com, ALLOW-FROM https://login.microsoftonline.com, ALLOW-FROM https://beta.thermoking.com, ALLOW-FROM https://corpextdev.b2clogin.com, ALLOW-FROM https://corpsso.b2clogin.com, https://staging.comfortsite.com, https://nva-av-tkweb1pr, https://igrawsndc012r:10446 2'],
#  ['ALLOW-FROM', 'http://polopoly.verdesmares.com.br 2'],
#  ['ALLOW-FROM',
#   '*.mobistar.be *.orange.be *.optimizely.com mobile.kbc-group.com mobileyoungsterapp.kbc-group.com kbctouch.kbc.be cbctouch.cbc.be touch.kbcbrussels.be 2'],
#  ['ALLOW-FROM',
#   '*.microsoft.com *.sharepoint.com *.tarimorman.gov.tr *.com.tr *.gov.tr *.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox5atlanta.com 2'],
#  ['""', '2'],
#  ['ALLOW-FROM',
#   'http://zqb.cyol.com,http://news.cyol.com,http://www.cyol.com,http://iqingyun.cyol.com 2'],
#  ['allow-from', 'https://application.etracker.com/ 2'],
#  ['ALLOW-FROM', 'https://www.gather.town 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox5dc.com 2'],
#  ['ALLOW-FROM',
#   'https://service.fetnet.net/, ALLOW-FROM http://service.fetnet.net/ 2'],
#  ['allow-from', 'https://amp.ipaddress.com/ 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox13news.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox2detroit.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.foxla.com 2'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://dw.beyondtrustcloud.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox9.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox4news.com 2'],
#  ['ALLOW-FROM', 'https://talkable.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox5ny.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox10phoenix.com 2'],
#  ['ALLOW-FROM', 'https://*.uchealth.org 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox32chicago.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox35orlando.com 2'],
#  ['allow-from', 'https://explore.eyemed.com 2'],
#  ['ALLOW-FROM', 'https://ncs-content-apis.tt.com/ttcom.html 2'],
#  ['ALLOW-FROM', 'https://apps.facebook.com/ 2'],
#  ['ALLOW-FROM', 'https://mspl.tap4fun.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.q13fox.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox29.com 2'],
#  ['ALLOW-FROM',
#   'https://app.storyblok.com https://*.storyblok.com https://*.storyblok.com 2'],
#  ['ALLOW-FROM', 'https://www.ironplanet.com 2'],
#  ['ALLOW-FROM',
#   'https://minio.pathfactory.com https://minio.lookbookhq.com; SAMEORIGIN 2'],
#  ['Allow-From', '/* 2'],
#  ['ALLOW-FROM', 'http://kiosk.usp.org.s207189.gridserver.com 2'],
#  [':', 'ALLOW-FROM https://timesofindia.indiatimes.com 2'],
#  ['SameOrigin', '*.firsthorizon.com 2'],
#  ['allow-from', 'https://app.cux.io/ 2'],
#  ['ALLOW-FROM', 'https://ing.ingdirect.es/ 2'],
#  ['ALLOW-FROM', 'https://storables.com 2'],
#  ['ALLOW-FROM', 'https://layout-cms.fox7austin.com 2'],
#  ['ALLOW-FROM',
#   'https://customerfinancing.directcapital-sit.com https://customerfinancing.directcapital2.com https://www.customerfinancing.com https://customerfinancing.directcapital-test1.com https://customerfinancing.directcapital-test2.com https://customerfinancing.directcapital-test3.com https://customerfinancing.directcapital-test4.com onlineapps-conv.readiness.ibanking-services.com onlineapps.ibanking-services.com ibanking-services.com https://*.fisglobal.com https://*.citbank.com https://citcom-dev.ase1-dev.citnet.cit.com https://*.firstcitizens.com 2'],
#  ['http://baidu.com/,', 'https://d.cn/, http://d.cn/ 2'],
#  ['allow-from', 'https://nthp.maps.arcgis.com 2'],
#  ['ALLOW-FROM', 'https://eppendorf.e-spirit.hosting/ 2'],
#  ['Allow-From', 'https://wehco-nwa-online.preview.zephr.com 2'],
#  ['ALLOW-FROM', 'egym.lightning.force.com 2'],
#  ['ALLOW-FROM', 'https://www.priceless.com 2'],
#  ['ALLOW-FROM', 'HTTPS://DASHBOARD.UNGLEICH.CH/ 2'],
#  ['https://sendpulse.com', '2'],
#  ['SAMEORIGIN,',
#   'allow-from https://specialty-care-pavilion-latest.jefferson.edu, allow-from https://specialty-care-pavilion.jefferson.edu, allow-from https://specialty-care-pavilion-dev.jefferson.edu 2'],
#  ['ALLOW-FROM',
#   'speedtest.pucsp.br www.pucsp.br www5.pucsp.br www.unifai.edu.br unifai.edu.br speedteste.pucsp.br speedtest.fundasp.org.br www.fundasp.org.br fundasp.org.br velocidadedainternet.fundasp.org.br velocidadeinternet.fundasp.org.br www.hospitalsantalucinda.com.br 2'],
#  ['allow-from',
#   'https://amp.bajajfinservmarkets.in/ https://BajajFinserv.in https://www.BajajFinserv.in 2'],
#  ['SAMEORIGINS', '2'],
#  ['ALLOW-FROM', 'https://*.kurz-mal-weg.de 2'],
#  ['ALLOW-FROM=https://www.mygenehistory.com', '2'],
#  ['SAMEORIGIN,', 'ALLOW-FROM=https://baselstadt.piwik.pro 2'],
#  ['ALLOW-FROM', 'https://*.nowaera.pl 2'],
#  ['ALLOW-FROM', 'https://mychart.kennedykrieger.org 2'],
#  ['allow-from', 'http://app.storyblok.com/ 2'],
#  ['ALLOW-FROM', 'www.wakefit.co 2'],
#  ['ALLOW-FROM', 'https://console.forge.timescale.com/ 2'],
#  ['ALLOW-FROM',
#   'https://www.cwtanalytiqs.com, https://int.cwtanalytiqs.com 2'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://journeys.jll.com; 2'],
#  ['https://go.contentools.com/', '2'],
#  ['ALLOW-FROM',
#   'SAMEDOMAIN, *.eduardolosilla.es, *.quinielista.es, *.marca.com, *.mundodeportivo.com 2'],
#  ['allow-from', '*.softnyx.com 2'],
#  ['ALLOW-FROM', 'http://heatmap.brick.tools 2'],
#  ['ALLOW-FROM', 'https://craft.threecreeksmedia.com/ 2'],
#  ['ALLOW-FROM', 'https://metrica.yandex.com/ 2'],
#  ['ALLOW-FROM', 'https://www.neurologylive.com/ 2'],
#  ['ALLOW-FROM',
#   'https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, ALLOW-FROM https://login.secure.investec.com/, SAMEORIGIN 2'],
#  ['ALLOW-FROM', 'test.1edtech.net 2'],
#  ['ALLOW-FROM',
#   'http://thomsonreuterstax.lookbookhq.com, ALLOW-FROM https://thomsonreuterstax.lookbookhq.com, ALLOW-FROM http://answers.legalprof.thomsonreuters.com, ALLOW-FROM https://answers.legalprof.thomsonreuters.com, ALLOW-FROM http://app.accelus.com, ALLOW-FROM https://app.accelus.com 2'],
#  ['https://*.pvrcinemas.com', '2'],
#  ['ALLOW-FROM', 'https://authorize.net/ 2'],
#  ['ALLOW-FROM', 'http://app.reskyt.com/ 2'],
#  ['allow-from', '*.man-es.com 2'],
#  ['ALLOW-FORM', 'https://my.yano.digital 2'],
#  ['ALLOWED-FROM', '*.linklist.fr 2'],
#  ['ALLOW-FROM', 'http://app.storyblok.com 2'],
#  ['Allow-From', 'http://dexcom.eu 2'],
#  ['ALLOW-FROM', 'https://*.nbiserv.de 2'],
#  ['allow-from',
#   'http://eyang.info/ http://promogitartogel.com/ http://klikjayatogel.com/ 2'],
#  ['ALLOW-FROM',
#   'http://www.hxnews.com http://m.hxnews.com http://www.fjsen.com http://www.mnw.cn http://widget.weibo.com 2'],
#  ['ALLOW', 'FROM  2'],
#  ['ALLOW-FROM', '*wp-rocket.me,*agfa.net 2'],
#  ['ALLOW-FROM', 'https://*.ecolines.net 2'],
#  ['ALLOW-FROM',
#   'https://www.p3tips.com/ https://www.p3campus.com/ https://tips.sandyhookpromise.org/ 2'],
#  ['ALLOW-FROM', 'http://localhost:8000 2'],
#  ['ALLOW-FROM', 'https://www.golfgenius.com 2'],
#  ['ALLOW-FROM', 'https://*.austinisd.org 2'],
#  ['ALLOW-FROM', 'http://www.rslcontent.co.uk 2'],
#  ['ALLOW-FROM', 'https://www.kayak.com.mx/ 2'],
#  ['Content-Security-Policy:', "frame-ancestors 'self' https://*.ally.ac; 2"],
#  ['ALLOW-FROM',
#   'https://guahao.com/,https://guahao.cn/,https://wedoctor.com/,https://gh.jsszh.org.cn/,https://56minzu.org.cn/,https://0551.so/,http://guahao.com/,http://guahao.cn/,http://wedoctor.com/,http://gh.jsszh.org.cn/,http://56minzu.org.cn/,http://0551.so/ 2'],
#  ['ALLOW-FROM', 'https://generatorweb.sihot.com/ 2'],
#  ['ALLOW-FROM',
#   'http://thomsonreuterstax.lookbookhq.com, ALLOW-FROM https://thomsonreuterstax.lookbookhq.com, ALLOW-FROM http://thomsonreuterstaxprofessionals.lookbookhq.com, ALLOW-FROM https://thomsonreuterstaxprofessionals.lookbookhq.com 2'],
#  ['allow-from', 'https://*.nsw99.com https://*.nswyun.com 2'],
#  ['ALLOW-FROM', 'http://emprolive:8080 2'],
#  ['ALLOW-FROM', 'https://*.thefabulous.co 2'],
#  ['ALLOW-FROM', 'http://awards.ratingruneta.ru/ 2'],
#  ['ALLOW-FROM', 'https://www.ubt.com 2'],
#  ['"DENY"', 'always; 2'],
#  ['SAMEORIGIN,', 'public 2'],
#  ['ALLOW-FROM', 'HTTP://INPAGE.METRIKA.YANDEX.RU 2'],
#  ['ALLOW-FROM',
#   'https://microapps.google.com https://freshpik.hostx5.de https://fynd.hostx5.de https://*.werafoods.com 2'],
#  ['ALLOW-FROM', 'https://partnership.sjp.co.uk 2'],
#  ['ALLOW-FROM', 'https://highchart.sogosurvey.com/ 2'],
#  ['ALLOW-FROM', 'https://mng.gdtv.cn http://test-mp-gdtv.itouchtv.cn 2'],
#  ['allow-from', 'https://digitalportfolio.bertelsmann.com 2'],
#  ['youtube-nocookie.com', '2'],
#  ['ALLOW-FROM', 'https://marelli.com/ 2'],
#  ['ALLOW-FROM', 'static.wikiforge.net 2'],
#  ['ALLOW-FROM', 'https://app.projuris.com.br 2'],
#  ['ALLOW-FROM', 'https://pagure.io/ 2'],
#  ['allow-from', 'https://1.251.32.58/ 2'],
#  ['ALLOW-FROM', 'http://inside.di.dk 2'],
#  ['ALLOW-FROM',
#   'https://sites-cm-malvernpl-production.tridion.sdlproducts.com https://sites-cm-malvernpl-test.tridion.sdlproducts.com https://sites-cm-malvernpl-development.tridion.sdlproducts.com 2'],
#  ['ALLOW-FROM', '(hamiltonhealthsciences.ca, hhsva.ca) 2'],
#  ['trsustseal.enamad.ir', '2'],
#  ['ALLOW-FROM', 'https://apps.wika.com/ 2'],
#  ['ALLOW-FROM', 'https://player.vimeo.com 2'],
#  ['ALLOW-FROM', 'https://my-*.donateblood.com.au 2'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://apps.accesskent.com/ 2'],
#  ['ALLOW-FROM',
#   '*.richmondamerican.com *.zillow.com *.newhomesource.com *.casasnuevasaqui.com 2'],
#  ['ALLOW-FROM', 'youtube.com 2'],
#  ['ALLOW-FROM', 'https://tami.bg/ 2'],
#  ['ALLOW-FROM', 'https://billetterie.chatelet.com 2'],
#  ['ALLOW-FROM', 'https://www.google.com/ 2'],
#  ["'ALLOW-FROM", "https://www.growingio.com' 2"],
#  ['ALLOW-FROM',
#   'www.helixstudios.com www.spankthishookups.com www.spankthis.com 2'],
#  ['ALLOW-FROM', 'https://www.qa.usfinancialcapability.org/* 2'],
#  ['ALLOW-FROM', 'https://openbuffalo.org 2'],
#  ['ALLOW-FROM', 'https://granicus.com 2'],
#  ['Allow-From:', 'SAMEORIGIN 2'],
#  ['ALLOW-FROM', 'https://sobanet.baloise.ch/ 2'],
#  ['ALLOW-FROM', 'https://libertyutilities.com 2'],
#  ['ALLOW-FROM', 'https://go.comeet.co/ 2'],
#  ['ALLOW-FROM', 'https://www.wpcuonline.net/ 2'],
#  ['ALLOW-FROM', 'https://novaskolinn.eloomi.com 2'],
#  ['ALLOW-FROM', 'www.homecredit.cz www.homecredit.sk *.ci360.sas.com 2'],
#  ['ALLOW-FROM', 'speedtestcustom.com 2'],
#  ['ALLOW-FROM', 'virtual-tours.msccruises.com 2'],
#  ['ALLOW-FROM', 'https://socialdev.zalopay.vn 2'],
#  ['ALLOW-FROM',
#   'https://promericagt.custhelp.com https://promericaopa.custhelp.com https://wstasacambio.bancopromerica.com.gt https://stags.bluekai.com https://tags.bkrtx.com https://vars.hotjar.com/ https://promericagt--tst1.custhelp.com https://enlz-prod1-apps6.builder.ocp.oraclecloud.com https://ventus.enalog.se https://channels.onemarketer.cl https://www.gstatic.com/ https://www.google.com/recaptcha/ https://optimize.google.com https://www.youtube.com 2'],
#  ['allow-from', 'api.metergroup.com 2'],
#  ['ALLOW-FROM', 'https://umap.occitanie-en-scene.fr 2'],
#  ['ALLOW-FROM', 'https://*.santpau.cat 2'],
#  ["'sameorigin'", 'https://*.datadoghq.com  2'],
#  ['ALLOW-FROM',
#   '*.etniabarcelona.com *.intranet-etniabarcelona.com *.extranet-etniabarcelona.com 2'],
#  ['ALLOW-FROM', 'SAMEDOMAIN; *.equitystory.com; *.eqs.com 2'],
#  ['ALLOW-FROM', '*.cat.mch.govt.nz/ 2'],
#  ['ALLOW-FROM',
#   'https://watershed-studio.netlify.app https://watershedlrs.com https://watershed.com https://staging.watershedlrs.com 2'],
#  ['ALLOW-FROM', 'https://psfsprd.shawinc.com 2'],
#  ['allow-from', 'https://app.pixelpop.co 2'],
#  [':', 'DENY 2'],
#  ['SAMEORIGIN;', 'always 2'],
#  ['ALLOW-FROM',
#   'https://b.yjtag.jp, ALLOW-FROM https://googletagmanager.com, ALLOW-FROM https://youtube.com, ALLOW-FROM https://slideshare.net, ALLOW-FROM https://facebook.com, ALLOW-FROM https://google.com, ALLOW-FROM https://dis.as.criteo.com, ALLOW-FROM https://staticxx.facebook.com, ALLOW-FROM https://widgets.getpocket.com, ALLOW-FROM https://app.chatplus.jp, ALLOW-FROM https://public.slidesharecdn.com, ALLOW-FROM https://www.slideshare.net, ALLOW-FROM https://synergy.mil.movie, ALLOW-FROM https://www.facebook.com 2'],
#  ['ALLOW-FROM', 'https://www4.hcdn.gob.ar/ 2'],
#  ['ALLOW-FROM', 'http://www.langnese.de, SAMEORIGIN 2'],
#  ['ALLOW-FROM', '*.hudongba.com *.hdb.com *.qq.com 2'],
#  ['ALLOW-FROM',
#   'https://www.slipcase.com http://marketplace.marsh.com https://brokersnexus.com https://www.insubuy.com https://www.ficoh.com/world-trips/ 2'],
#  ['https://www.rslcontent.co.uk/', '2'],
#  ['allow-from', 'https://izeselet.hu/ 2'],
#  ['ALLOW-FROM', 'https://tongji.baidu.com 2'],
#  ['ALLOW-FROM', 'https://viewlift.com 2'],
#  ['ALLOW-FROM', 'https://plm.corp.global 2'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://secure.safecharge.com 2'],
#  ['ALLOW-FROM', 'https://findmyforevermate.com 2'],
#  ['sameorigin',
#   'allow-from https://testdk.game.daum.net, https://dk.game.daum.net, https://game.daum.net, http://fishinghero.game.picaon.com, http://nativex.game.picaon.com, http://pristontale.hangame.com, https://ace.game.naver.com 2'],
#  ['ALLOW-FROM', 'https://service.ariba.com 2'],
#  ['ALLOW-FROM', 'https://hmtest.live800.com 2'],
#  ['ALLOW-FROM', 'https://app.contentful.com 2'],
#  ['ALLOW-FROM',
#   'https://fampay.in, ALLOW-FROM https://*.fampay.in, ALLOW-FROM https://www.famapp.in, ALLOW-FROM https://*.famapp.in 2'],
#  ['ALLOW', 'FROM http://members-local.kellymadisonmedia.com/ 2'],
#  ['ALLOW-FROM', 'https://www.paypal.com 2'],
#  ['Allow-From', 'http://www.growingio.com 2'],
#  ['ALLOW-FROM', 'https://sendvid.com/ https://www.youtube.com/ 2'],
#  ['ALLOW-FROM', 'https://digital.bankofsingapore.com 2'],
#  ['ALLOW-FROM', 'https://www.6jaa8.com/home/index 2'],
#  ['ALLOW-FROM', 'https://*.vinculumgroup.com,*.vineretail.com 2'],
#  ['ALLOW-FROM', 'https://app.storyblok.com 2'],
#  ['ALLOW-FROM', 'https://youtu.be/ 2'],
#  ['ALLOW-FROM', 'https://*.theturkey.dev 2'],
#  ['ALLOW-FROM', 'qonecta.com 2'],
#  ['ALLOW_ALL', '2'],
#  ['DENY;', '2'],
#  ['ALLOW-FROM', 'https://preview.codecanyon.net/ 2'],
#  ['disabled', '2'],
#  ['ALLOW-FROM',
#   'http://ariba.com/,https://ariba.com,https://punchoutcommerce.com 2'],
#  ['ALLOW-FROM',
#   'https://ekoop.tarimkredi.org.tr https://narline.bereket.com.tr/ https://rcnarline.bereket.com.tr/ 2'],
#  ['allow-from',
#   'https://appgrowing.cn,https://ccsight.cn,https://kuaixp.com 2'],
#  ['allow-from',
#   'https://*.acdagents.com/ https://vpm.org/ https://www.wgbh.org/ https://www.wqed.org/ https://ww2.kqed.org/ https://www.kqed.org/ https://www.kqed.org/ https://www.acddirect.com/ https://www.callswithoutwalls.com/ https://pledgecart.org/ https://teamup.com/ https://bento.pbs.org/ 2'],
#  ['ALLOW-FROM', 'https://tabory.mojeup.sk 2'],
#  ['SAMEORIGIN,', 'SAMEORIGIN, SAMEORIGIN, SAMEORIGIN 2'],
#  ['ALLOW-FROM',
#   'http://forter.pathfactory.com https://resources.fraudlab.com https://forter.pathfactory.com https://resources.forter.com http://resources.forter.com 1'],
#  ['ALLOW-FROM',
#   'ietf.org *.ietf.org meetecho.com *.meetecho.com gather.town *.gather.town 1'],
#  ['ALLOW-FROM', 'https://times.hinet.net 1'],
#  ['ALLOW-FROM', 'https://create.kahoot.it 1'],
#  ['ALLOW-FROM', 'https://www.jpost.com 1'],
#  ['ALLOW-FROM', 'https://redcross.org/ 1'],
#  ['ALLOW-FROM', 'https://*.dhs.gov 1'],
#  ['ALLOW-FROM', 'https://quip.com 1'],
#  ['ALLOW-FROM', 'https://adm.findagrave.com 1'],
#  ['ALLOW-FROM', 'https://resources.mulesoft.com/ 1'],
#  ['ALLOW-FROM',
#   'https://resources.signifyd.com/ https://signifyd.pathfactory.com/ 1'],
#  ['SAMEORIGIN,', 'allow-from https://vodafone.lookbookhq.com 1'],
#  ['ALLOW-FROM',
#   'https://www.dealer.com/ https://new-ddc-develop.go-vip.net/ https://us.dealertrack.com/ https://us-qa.dealertrack.com/ https://us-dev.dealertrack.com/ https://ddc-2023.go-vip.net/ https://ddc-2023.go-vip.net/main/ 1'],
#  ['SAMEORIGIN', 'https://cms.zscaler.com 1'],
#  ['ALLOW-FROM',
#   'storeadmin.hmv.com hmv-live-admin-app-holding.azurewebsites.net 1'],
#  ['ALLOW-FROM', 'miami.edu 1'],
#  ['ALLOW', 'FROM http://awards.ratingruneta.ru/ 1'],
#  ['ALLOW-FROM', 'https://momoco.momoshop.com.tw 1'],
#  ['ALLOW-FROM', '*.hku.hk 1'],
#  ['ALLOW-FROM', 'https://calendar.google.com/ 1'],
#  ['ALLOW-FROM', 'https://*.dingtalk.com 1'],
#  ['\\"sameorigin\\"', '1'],
#  ['ALLOW-FROM', 'https://cs.elnacional.cat 1'],
#  ['ALLOW-FROM', 'https://www.scotiabank.com 1'],
#  ['ALLOW-FROM', '*.on24.com 1'],
#  ['ALLOW-FROM', 'user.paziresh24.com 1'],
#  ['allow-from', 'https://nonprofitdirectory.guidestar.org 1'],
#  ['ALLOW-FROM',
#   'https://www.yealink.com,https://search.google.com,https://analytics.google.com,https://tagmanager.google.com 1'],
#  ['allow-from', 'https://stat-01.ccc.eu  https://ccc.eu 1'],
#  ['allow-from', 'https://fashion-connect.store/ 1'],
#  ['ALLOW-FROM', 'https://www.shahrekhabar.com/ 1'],
#  ['ALLOW-FROM', 'https://compass.grandviewresearch.com/ 1'],
#  ['allow-from', 'https://*.orbi.kr 1'],
#  ['ALLOW-FROM',
#   'https://staging.certification.vuejs.org https://certification.vuejs.org https://certificates.dev https://staging.certificates.dev https://alemira.com https://*.alemira.com 1'],
#  ['ALLOW-FROM',
#   'SAMEORIGIN https://esirket.com https://app.mukellef.co https://app-beta.mukellef.co https://app.bizimsiparis.com https://bizimsiparis.com https://findara.co https://dgpfdemo.dgpays.com https://bilanco.co https://app.bilanco.co 1'],
#  ['ALLOW-FROM', 'https://account.oneplus.com 1'],
#  ['ALLOW-FROM', 'nsone.net 1'],
#  ['allow-from',
#   'https://thdomain.thnic.co.th/ https://webreg.thnic.co.th/ https://www.thnic.co.th/ 1'],
#  ['ALLOW-FROM', 'http://vis.vu.edu.pk 1'],
#  ['ALLOW-FROM', 'https://bi.dreame.tech/ 1'],
#  ['ALLOW-FROM', 'https://sm.q10.com/*,  http://webvisor.com/* 1'],
#  ['allow-from', 'https://mydev.kinsta.com/ 1'],
#  ['allow-from',
#   'https://appnews.etracker.com/, allow-from https://fhhportal.ondataport.de/, allow-from https://fonts.hamburg.de/ 1'],
#  ['ALLOW-FROM', 'https://org2.passportindia.gov.in 1'],
#  ['SAMEORIGIN,', 'allow-from https://meine.deutsche-bank.de 1'],
#  ['ALLOW-FROM', 'https://rippling.highspot.com 1'],
#  ['ALLOW-FROM',
#   'https://application.axisbank.co.in https://www.axisbank.com 1'],
#  ['ALLOW-FROM',
#   'http://www.kayak.com.au, ALLOW-FROM http://www.momondo.com.au, ALLOW-FROM http://www.cheapflights.com.au, ALLOW-FROM http://www.ca.kayak.com, ALLOW-FROM http://www.momondo.ca, ALLOW-FROM http://www.cheapflights.ca, ALLOW-FROM http://www.cn.kayak.com, ALLOW-FROM http://www.momondo.com.cn, ALLOW-FROM http://www.kayak.com.hk, ALLOW-FROM http://www.momondo.hk, ALLOW-FROM http://www.cheapflights.com.hk, ALLOW-FROM http://www.kayak.co.in, ALLOW-FROM http://www.momondo.in, ALLOW-FROM http://www.in.cheapflights.com, ALLOW-FROM http://www.kayak.co.id, ALLOW-FROM http://www.cheapflights.co.id  , ALLOW-FROM http://www.kayak.co.jp, ALLOW-FROM http://www.kayak.co.kr, ALLOW-FROM http://www.kayak.com.my, ALLOW-FROM http://www.cheapflights.com.my, ALLOW-FROM http://www.nz.kayak.com, ALLOW-FROM http://www.momondo.co.nz, ALLOW-FROM http://www.cheapflights.co.nz, ALLOW-FROM http://www.cheapflights.com.ph, ALLOW-FROM http://www.kayak.com.ph, ALLOW-FROM http://www.kayak.sg, ALLOW-FROM http://www.cheapflights.com.sg, ALLOW-FROM http://www.tw.kayak.com, ALLOW-FROM http://www.momondo.tw, ALLOW-FROM http://www.kayak.co.th, ALLOW-FROM http://www.kayak.co.uk, ALLOW-FROM http://www.momondo.co.uk, ALLOW-FROM http://www.cheapflights.co.uk, ALLOW-FROM http://www.checkfelix.co.uk, ALLOW-FROM http://www.kayak.com, ALLOW-FROM http://www.momondo.com, ALLOW-FROM http://www.cheapflights.com, ALLOW-FROM http://www.ae.cheapflights.com, ALLOW-FROM http://www.kayak.ae, ALLOW-FROM http://global.cheapflights.com, ALLOW-FROM http://global.momondo.com, ALLOW-FROM http://kayak.de, ALLOW-FROM http://momondo.de, ALLOW-FROM http://swoodoo.com, ALLOW-FROM http://kayak.fr, ALLOW-FROM http://momondo.fr, ALLOW-FROM http://www.ampify.ga, ALLOW-FROM http://cdn.ampproject.org, ALLOW-FROM http://www-malaysiaairlines-com.cdn.ampproject.org, ALLOW-FROM https://www.kayak.com.au, ALLOW-FROM https://www.momondo.com.au, ALLOW-FROM https://www.cheapflights.com.au, ALLOW-FROM https://www.ca.kayak.com, ALLOW-FROM https://www.momondo.ca, ALLOW-FROM https://www.cheapflights.ca, ALLOW-FROM https://www.cn.kayak.com, ALLOW-FROM https://www.momondo.com.cn, ALLOW-FROM https://www.kayak.com.hk, ALLOW-FROM https://www.momondo.hk, ALLOW-FROM https://www.cheapflights.com.hk, ALLOW-FROM https://www.kayak.co.in, ALLOW-FROM https://www.momondo.in, ALLOW-FROM https://www.in.cheapflights.com, ALLOW-FROM https://www.kayak.co.id, ALLOW-FROM https://www.cheapflights.co.id  , ALLOW-FROM https://www.kayak.co.jp, ALLOW-FROM https://www.kayak.co.kr, ALLOW-FROM https://www.kayak.com.my, ALLOW-FROM https://www.cheapflights.com.my, ALLOW-FROM https://www.nz.kayak.com, ALLOW-FROM https://www.momondo.co.nz, ALLOW-FROM https://www.cheapflights.co.nz, ALLOW-FROM https://www.cheapflights.com.ph, ALLOW-FROM https://www.kayak.com.ph, ALLOW-FROM https://www.kayak.sg, ALLOW-FROM https://www.cheapflights.com.sg, ALLOW-FROM https://www.tw.kayak.com, ALLOW-FROM https://www.momondo.tw, ALLOW-FROM https://www.kayak.co.th, ALLOW-FROM https://www.kayak.co.uk, ALLOW-FROM https://www.momondo.co.uk, ALLOW-FROM https://www.cheapflights.co.uk, ALLOW-FROM https://www.checkfelix.co.uk, ALLOW-FROM https://www.kayak.com, ALLOW-FROM https://www.momondo.com, ALLOW-FROM https://www.cheapflights.com, ALLOW-FROM https://www.ae.cheapflights.com, ALLOW-FROM https://www.kayak.ae, ALLOW-FROM https://global.cheapflights.com, ALLOW-FROM https://global.momondo.com, ALLOW-FROM https://kayak.de, ALLOW-FROM https://momondo.de, ALLOW-FROM https://swoodoo.com, ALLOW-FROM https://kayak.fr, ALLOW-FROM https://momondo.fr, ALLOW-FROM https://www.ampify.ga, ALLOW-FROM https://cdn.ampproject.org, ALLOW-FROM https://www-malaysiaairlines-com.cdn.ampproject.org, ALLOW-FROM https://www.oneworld.com/, ALLOW-FROM https://mobile-api.oneworld.com/, ALLOW-FROM https://www.malaysiaairlines.com/, ALLOW-FROM https://digital.malaysiaairlines.com/, ALLOW-FROM https://ma-stage64-01.adobecqms.net/, ALLOW-FROM https://ma-sit64.adobecqms.net/, ALLOW-FROM https://ma-dev64.adobecq ...
#  ['ALLOW-FROM',
#   'https://ws.whu.edu.cn,https://oir.whu.edu.cn,https://law.whu.edu.cn 1'],
#  ['ALLOW-FROM',
#   'https://app.reskyt.com/ https://app.casadellibro.com/ https://www.casadellibro.com/ 1'],
#  ['ALLOW-FROM', 'https://web.facebook.com/ 1'],
#  ['ALLOW-FROM', 'https://usfca.instructure.com 1'],
#  ['ALLOW-FROM', 'https://tongji.baidu.com/,https://www.jiguang.cn/ 1'],
#  ['ALLOW-FROM', 'https://pro.panopto.com 1'],
#  ['ALLOW-FROM',
#   'https://www.bestprice.gr https://webcache.googleusercontent.com https://static.googleusercontent.com 1'],
#  ['allow-from', 'https://secondscreen-assets.naoz.live 1'],
#  ['ALLOW-FROM', 'http://www.wanikani.com 1'],
#  ['ALLOW-FROM', '*.zte.com.cn 1'],
#  ['ALLOW-FROM=sandiego.ares.atlas-sys.com,',
#   'ALLOW-FROM=ami.responsivedesign.is 1'],
#  ['SAMEORIGIN?', '1'],
#  ['Allow-From', 'https://wehco-arkansas-online.preview.zephr.com 1'],
#  ['Allow-From',
#   'us.creativecdn.com *.encuentra24.com *.inmobiliaria24.com *.casas24.com *.carros24.com encuentra24.zendesk.com *.youtube.com view.atdmt.com www.facebook.com www.google.com encuentra24.wufoo.com.mx encuentra24.ticforum-ca.com tpc.googlesyndication.com googleads.g.doubleclick.net storage.googleapis.com js.stripe.com e24.unityducruet.com cotizador.unityducruet.com api-js.datadome.co s.ytimg.com www-widgetapi.js googlesyndication.com youtube.com teads.tv 1'],
#  ['ALLOW-FROM', 'https://www.estrategiaconcursos.com.br 1'],
#  ['ALLOW-FROM', 'https://layout-cms.ktvu.com 1'],
#  ['ALLOW-FROM', 'https://iisdnet.sharepoint.com 1'],
#  ['ALLOW-FROM', 'https://wwwssl.aena.es/ 1'],
#  ['ALLOW-FROM', 'http://tongji.baidu.com 1'],
#  ['ALLOW-FROM', 'http://www.dove.com, SAMEORIGIN 1'],
#  ['ALLOW-FROM', 'https://secure.comm100.com 1'],
#  ['ALLOW-FROM', 'promo.bank.gov.ua 1'],
#  ['allow-from', 'https://liveshopping.bonprix.fr/ 1'],
#  ['ALLOW-FROM', 'https://www.dizigom1.com/ 1'],
#  ['ALLOW-FROM', 'https://maps.google.com/ 1'],
#  ['Allow-From', 'https://wehco-time-free-press.preview.zephr.com 1'],
#  ['ALLOW-FROM', 'https://preview.edulastic.com 1'],
#  ['ALLOW-FROM', 'http://icv.stuba.sk/ 1'],
#  ['ALLOW-FROM',
#   'https://account.krisp.ai https://dev.account.krisp.ai https://stage.account.krisp.ai https://krisp-blog-dev.krisp.ai https://krisp.ai https://highspot.com 1'],
#  ['ALLOW-FROM', ' http://*.gov.cn/ https://*.gov.cn  1'],
#  ['ALLOW-FROM', 'HTTPS://1.SHOP.IRCAM.FR/ 1'],
#  ['ALLOW-FROM', '*.mintegral.com *.mobvista.com 1'],
#  ['ALLOW-FROM',
#   '*.untangle.com edge.arista.com *.edge.arista.com untangle.com *.untanglesystems.com untanglesystems.com ws.zoominfo.com ws-assets.zoominfo.com 1'],
#  ['allow-from', 'https://console.dnspod.cn 1'],
#  ['ALLOW-FROM', 'https://*.insta360.com 1'],
#  ['ALLOW-FROM', 'https://layout-cms.fox6now.com 1'],
#  ['ALLOW-FROM', 'http://media.chvnoticias.cl/ 1'],
#  ['ALLOW-FROM',
#   'https://oss.ctyun.cn https://bcp.ctyun.cn https://www.ctyun.cn https://ocss.ctyun.cn 1'],
#  ['ALLOW-FROM', 'https://thebarn.anaplan.com/ 1'],
#  ['sameorigin', 'allow-from www.facebook.com 1'],
#  ['ALLOW-FROM', 'publicidad.primicia.com.ve 1'],
#  ['ALLOW-FROM', 'https://murdoch-au.libwizard.com 1'],
#  ['ALLOW-FROM', 'https://www.inria.fr/ 1'],
#  ['ALLOW-FROM', 'https://*.elections.eg 1'],
#  ['ALLOW-FROM', 'https://sensors.geekbuying.com/ 1'],
#  ['ALLOW-FROM', 'https://www.azleg.granicus.com/ 1'],
#  ['ALLOW-FROM', "'self' https://t1-integration.ru https://www.google.com 1"],
#  ['ALLOW-FROM',
#   'https://domo.seismic.com, ALLOW-FROM https://domo.pathfactory.com 1'],
#  ['ALLOW-FROM', 'http://milliemlak.gov.tr http://www.milliemlak.gov.tr 1'],
#  ['ALLOW-FROM',
#   'http//:*.brookes.ac.uk https//:*.brookes.ac.uk http://local-brookes.* https://local-brookes.* http://dev-cms.brookes.ac.uk.* https://dev-cms.brookes.ac.uk.* 1'],
#  ['ALLOW-FROM', 'https://tickets.fi.edu 1'],
#  ['ALLOW-FROM', 'https://a.cms.omniupdate.com https://my2.siteimprove.com 1'],
#  ['ALLOW-FROM', '*.hopper.com 1'],
#  ['ALLOW-FROM',
#   'https://youtu.be https://bid.g.doubleclick.net https://streetview.my https://safedepositboxjb.streetview.my https://uat.hlisb.com.my https://hlbmc.demdex.net https://tags.tiqcdn.com/ https://survey.hlb.com.my/ https://www.hlb.com.my/ https://www.facebook.com/ https://www.vivocha.com/ https://www.youtube.com/ https://staticxx.facebook.com/ https://www.googletagmanager.com/ https://gateway.hlb.com.my/ https://gateway.hlb.com.my:8446/ https://www.google.com/ https://optimize.google.com/ https://hongleongbank.sc.omtrdc.net/ https://dpm.demdex.net/ https://www.ecbanking.com.my  https://gms.hongleong.com.my https://apply-merchant1.hlb.com.my 1'],
#  ['ALLOW-FROM', 'https://workspace.hansel.io 1'],
#  ['ALLOW-FROM', 'http://192.168.225.3/ 1'],
#  ['allow-from', 'https://www.wallstreetmojo.com 1'],
#  ['ALLOW-FROM', 'https://autel.wpengine.com 1'],
#  ['ALLOW-FROM',
#   'https://plasticsfinder.com/ https://accstorefront.c119puhg-mtprodcus1-d1-public.model-t.cc.commerce.ondemand.com/ https://accstorefront.c119puhg-mtprodcus1-s1-public.model-t.cc.commerce.ondemand.com/ 1'],
#  ['ALLOW-FROM', 'https://informatica.seismic.com 1'],
#  ['ALLOW-FROM', 'https://catalog.legion.org/ 1'],
#  ['ALLOW-FROM', '*.kaltura.com/ *.wistia.com/ 1'],
#  ['webvisor.com', '1'],
#  ['ALLOW-FROM', 'https://teams.microsoft.com/ 1'],
#  ['Allow-From', '*.zum.com 1'],
#  ['ALLOW-FROM',
#   '*.omappapi.com *.optinmonster.com/ *.monstercampaigns.com *.hubspot.com *.flickr.com https://live.staticflickr.com https://embedr.flickr.com https://servedbyadbutler.com https://adbutler.com 1'],
#  ['ALLOW-FROM',
#   'https://*.tatacliq.com/ https://*.tataque.com/ https://*.tataunistore.com/ https://*.tatadigital.com cdn.appdynamics.com 1'],
#  ['ALLOW-FROM', 'https://www.greenvelope.com/ 1'],
#  ['ALLOW-FROM', 'planet.pathfactory.com 1'],
#  ['allow-from',
#   'https://digitaltag.eu/, allow-from https://stage.digitaltag.eu/ 1'],
#  ['Allow-From', 'https://desk.thejc.atexcloud.io 1'],
#  ['ALLOW-FROM', 'https://plexsystems.lookbookhq.com 1'],
#  ['ALLOW-FROM', 'https://render.otoy.com/ 1'],
#  ['ALLOW-FROM', 'https://account.oneplus.in 1'],
#  [':',
#   'allow-from https://bbs.elecfans.com https://www.elecfans.com https://www.hqchip.com https://tongji.baidu.com https://skin.elecfans.com 1'],
#  ['allow-from',
#   'https://www.lakeheadu.ca https://wd-www.lakeheadu.ca https://myinfo.lakeheadu.ca https://erpwp.lakeheadu.ca https://wd-cc.lakeheadu.ca 1'],
#  ['ALLOW-FROM', 'www.drom.ru auto.drom.ru 1'],
#  ['https://dongqiudi.fun.tv/', '1'],
#  ['ALLOW-FROM', 'https://www.tapinto.net/ 1'],
#  ['ALLOW-FROM',
#   'https://*.open.com.cn,http://*.imooc.com,https://*.imooc.com 1'],
#  ['ALLOW-FROM', 'SAMEORIGIN, *.testberichte.de 1'],
#  ['ALLOW-FROM', 'https://www.bannerhealth.com 1'],
#  ['ALLOW-FROM', 'https://anton.app https://solocode.com 1'],
#  ['https://*.rehau.com', '1'],
#  ['ALLOW-FROM', 'https://apps.americafirst.com 1'],
#  ['ALLOW-FROM',
#   'https://jionews.com/, ALLOW-FROM https://jionewsdev1.jio.ril.com/ 1'],
#  ['ALLOW-FROM', 'https://indianaspark.com 1'],
#  ['ALLOW-FROM',
#   'https://www.youtube.com https://giphy.com https://vimeo.com https://clario.co https://www.slideshare.net https://apps.apple.com 1'],
#  ['ALLOW-FROM', 'http://www.fjsen.com/,http://news.fjsen.com/ 1'],
#  ['ALLOW-FROM', 'https://archivo.cancilleria.gov.co 1'],
#  ['ALLOW-FROM', 'https://transamerica.com 1'],
#  ['allow-from', '*.csx.com 1'],
#  ['ALLOW-FROM', 'https://layout-cms.fox26houston.com 1'],
#  ['ALLOW-FROM',
#   '^https?:\\/\\/([^\\/]+\\.)?(sitronics\\.com|webvisor\\.com|metri[ck]a\\.yandex\\.(com|ru|by|com\\.tr))\\/ 1'],
#  ['ALLOW-FROM',
#   'http://*.jschina.com.cn https://*.jschina.com.cn https://www.720yun.com http://hotels.ctrip.com 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://www.cotswoldoutdoor.com 1'],
#  ['ALLOW-FROM', 'https://nescafegold-winteredition.arweb.app/ 1'],
#  ['ALLOW-FROM', 'mychart.ohiohealth.com 1'],
#  ['ALLOW-FROM',
#   'https://signup.buildbox.com http://login-redirect.buildbox.com https://www.surveymonkey.com/r/K3GMYZC https://www.surveymonkey.com/r/QRNB36V https://www.surveymonkey.com 1'],
#  ['ALLOW-FROM', 'https://www.googletagmanager.com 1'],
#  ['ALLOW-FROM',
#   'eagleinvest.futureadvisor.com;firstrepublicbank.experiencecloud.adobe.com;10to8.com;us.10to8.com;firstrepublic.seismic.com 1'],
#  ['ALLOW-FROM', 'https://my.wellspan.org 1'],
#  ['ALLOW-FROM', 'mto.mizrahi-tefahot.co.il 1'],
#  ['ALLOW-FROM', 'vikatan.com 1'],
#  ['ALLOW-FROM', 'https://www.pccw.com/ 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM=https://anznz.experiencecloud.adobe.com/ 1'],
#  ['ALLOW-FROM', 'https://*.duga.jp 1'],
#  ['ALLOW-FROM',
#   'https://bureauveritas.sharepoint.com/sites/OneBV/en-US/sitepages/place-locator.aspx 1'],
#  ['ALLOW-FROM', 'https://3care.tri.co.id 1'],
#  ['ALLOW-FROM', 'http://www.knorr.com, SAMEORIGIN 1'],
#  ['ALLOW-FROM', 'https://lancloud.ru 1'],
#  ['ALLOW-FROM', 'https://mk.apply.creditkarma.com 1'],
#  ['ALLOW-FROM', 'https://coinpedia.org 1'],
#  ['ALLOW-FROM', 'https://bruegel.org 1'],
#  ['allow-from', 'https://cno.cnb.com/ 1'],
#  ['Allow-From', 'https://beyond.mohegansun.com 1'],
#  ['reclaimhosting.com', '1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://www.asadventure.com 1'],
#  ['ALLOW-FROM', 'paynearme.com 1'],
#  ['ALLOW-FROM', 'https://www.sephora.ae/ 1'],
#  ['ALLOW-FROM', 'https://www.lyrahealth.com 1'],
#  ['SAMEORIGIN:', 'no-referrer 1'],
#  ['ALLOW-FROM', 'https://www.origamirisk.com 1'],
#  ['allow-from', 'https://my.uis.edu 1'],
#  ['ALLOW-FROM', 'https://crm.comwave.net/ 1'],
#  ['"ALLOW-FROM', 'https://www.capitaliqpro.spglobal.cn" 1'],
#  ['ALLOW-FROM', 'baran-music.com 1'],
#  ['https://adcb-dreamhome.bayut.com', '1'],
#  ['ALLOW-FROM',
#   'https://www.securitybank.com, ALLOW-FROM https://securitybank.com 1'],
#  ['ALLOW-FROM', 'opendatav2.rks-gov.net 1'],
#  ['ALLOW-FROM', 'https://explore.textio.com 1'],
#  ['ALLOW-FROM',
#   'https://www2.cityofhope.org, ALLOW-FROM https://request.cityofhope.org, ALLOW-FROM https://learn.cityofhope.org, ALLOW-FROM https://events.cityofhope.org, ALLOW-FROM https://stg-www.cityofhope.org/ 1'],
#  ['ALLOW-FROM', 'https://*.vivasorteoficial.com.br 1'],
#  ['*.uninove.br', '1'],
#  ['ALLOW-FROM=https://www.boomset.com,',
#   'ALLOW-FROM=https://www.virtual.boomset.com 1'],
#  ['ALLOW-FROM', 'https://kb.netgear.com/ 1'],
#  ['ALLOW-FROM',
#   'https://www.orbea.com https://orbea.altabox.net https://orbeaweb.altabox.net https://stories.orbea.com 1'],
#  ['karlsruhe.de', '1'],
#  ['ALLOW-FROM', 'egym.my.salesforce.com 1'],
#  ['ALLOW-FROM', 'https://www.govplanet.com 1'],
#  ['ALLOW-FROM', 'https://go.raptortech.com 1'],
#  ['ALLOW-FROM', 'firesidegatherings.com 1'],
#  ['ALLOW-FROM', 'https://vr-easy.com 1'],
#  ['ALLOW-FROM', 'https://myservice.ottawa.ca 1'],
#  ['ALLOW-FROM', 'https://www.bitforex.com https://coin360.com 1'],
#  ['ALLOW-FROM', 'https://www.effektenbank.de 1'],
#  ['ALLOW-FROM', 'https://instaread.co 1'],
#  ['ALLOW-FROM',
#   'http://bvmf.bmfbovespa.com.br, http://www2.bmfbovespa.com.br, http://www.bmf.com.br, http://www2.bmf.com.br, https://www2.cetip.com.br, http://estatisticas.cetip.com.br, https://sistemasweb.b3.com.br/ 1'],
#  ['ALLOW-FROM', 'http://mdahops.org/ 1'],
#  ['ALLOW-FROM', 'SAMEDOMAIN,*.softonic.com,*softoniclabs.com,*.zerogpt.com 1'],
#  ['allow-from', '(alpha.tazeros.com) 1'],
#  ['allow-from', 'https://app.buildfire.com 1'],
#  ['ALLOW-FROM',
#   'https://jobs.veralto.com https://aurora-dev.videojet.com https://aurora.videojet.com 1'],
#  ['SAMEORIGIN',
#   'https://193.105.74.4/  https://62.140.31.104/ https://www.gstatic.com/ https://www.google.com/recaptcha/ https://platform-use.ci360.sas.com https://individeo.com/ https://www.youtube.com/ https://www.produbanco.com.ec/ https://estella01.prd.net.ec/api/heartbeat https://cdn.botframework.com/ https://*.hotjar.com https://*.hotjar.io 1'],
#  ['ALLOW-FROM', 'https://help.dav.org/ 1'],
# ...
#  ['ALLOW-FROM', 'zuozhe.qimao.com 1'],
#  ['ALLOW-FROM', ' https://savethechildren.ailnd.com 1'],
#  ['ALLOW-FROM', 'https://sgz.lingxigames.com 1'],
#  ['ALLOW-FROM', 'https://axonify.seismic.com 1'],
#  ['ALLOW-FROM', 'https://dy2.ktu.edu.tr/ 1'],
#  ['ALLOW-FROM', 'https://members.puppyfinder.com 1'],
#  ['ALLOW-FROM', 'https://www.amtc.community 1'],
#  ['ALLOW-FROM', 'https://connectplus.iaapa.org 1'],
#  ['ALLOW-FROM', 'https://stcu-frontend.netlify.app/ 1'],
#  ['allow-from', 'https://csi.instructure.com/ 1'],
#  ['ALLOW-FROM',
#   'https://www.nowanimes.com/ https://nowanimes.com/ https://www.xpanimes.com/ https://xpanimes.com/ http://trueliketop.org/ https://megatecnobr.com/ https://www.legiaotec.club/ https://tectecno.com/ https://tecnodisco.com/ https://uptecnologia.org/ https://techdiniz.com/ 1'],
#  ['ALLOW-FROM', 'SAMEORIGIN, qa-boschpt.kittelberger.net 1'],
#  ['https://artspaces.kunstmatrix.com', '1'],
#  ['ALLOW-FROM',
#   'www.dgliteracy.org,dgliteracy.org,test-rif-digital.pantheonsite.io 1'],
#  ['allow-from', '*.jandi.com 1'],
#  ['ALLOW-FROM', 'https://www.dankeanke.de/ 1'],
#  ['"allow-from', 'https://fairobserver.exposure.co/" 1'],
#  ['ALLOW-FROM', 'https://layout-cms.livenowfox.com 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://440.coutts.com/ 1'],
#  ['ALLOW-FROM', 'sigoweb.chilexpress.cl 1'],
#  ['Allow-From', 'https://wehco-texarkana-gazette.preview.zephr.com 1'],
#  ['ALLOW-FROM', '*.winks.com.ar *.selina.com 1'],
#  ['ALLOW-FROM', 'internist.ru 1'],
#  ['ALLOW-FROM', 'tgtcms.com 1'],
#  ['ALLOW-FROM', 'https://m.devcrm.monamie.kz 1'],
#  ['ALLOW-FROM', 'http://bhu.ac.in 1'],
#  ['allow-from', 'https://mywallet.deals/ 1'],
#  ['ALLOW-FROM',
#   'http://bdew.betau14.uhura.de/ https://www.oberhessengas.de/ https://www.stwb.de/ http://www.sw-soltau.de/ https://energiemarkt.sw-soltau.de/ https://www.rheinhessische.de/ https://www.ewbautzen.de/ https://stadtwerke-emden.de/ https://www.swtenergie.de/ https://www.stadtwerke-freudenstadt.de/ https://www.stadtwerke-landshut.de/ https://www.swbk.de/ https://www.backnangstrom.de/ https://queichtal-energie-offenbach.de/ https://www.stadtwerke-dueren.de/ https://www.gemeindewerke-stockelsdorf.de/ https://www.stadtwerke-itzehoe.de/ https://www.e-werk-mittelbaden.de/ https://swe-emmendingen.de/ https://www.energie-nordhausen.de/ https://stadtwerke-burg.de/ https://www.stadtwerke-pirna.de/ https://www.stadtwerke-landsberg.de/ http://www.ew-bitz.de/ http://www.fa-gammertingen.de/ http://www.fa-winterlingen.de/ http://www.albstadtwerke.de/ 1'],
#  ['ALLOW-FROM', 'https://digitalisasi.isef.co.id/main/prm 1'],
#  ['ALLOW-FROM', 'https://*.zsxq.com/ 1'],
#  ['ALLOW-FROM', 'http://www.thetrumpet.co.uk 1'],
#  ['ALLOW-FROM', 'https://www.visitdallas.com/ 1'],
#  ['ALLOW-FROM', 'https://mc.yandex.ru 1'],
#  ['ALLOW-FROM',
#   'https://*.lawdegree.mc.edu https://mc.meritpages.com  https://www.meritpages.com https://forms.monday.com https://diplomasondemandweb.com https://calendly.com 1'],
#  ['ALLOW-FROM', 'digitaledge.net 1'],
#  ['ALLOW-FROM', 'https://www.ubivent.com/ 1'],
#  ['ALLOW-FROM', 'casinoportugal-static.casinomodule.com 1'],
#  ['ALLOW-FROM', 'http://portais.guarulhos.sp.gov.br/ 1'],
#  ['allow-from', 'https://flotasconectadas.michelin.com.ar/ 1'],
#  ['ALLOW-FROM', 'https://www.tv9hindi.com/ 1'],
#  ['ALLOW-FROM', 'https://relaunch.karlstorz.com 1'],
#  ['ALLOW-FROM', 'facebook.net 1'],
#  ['ALLOW-FROM',
#   'www.premierhealth.com premierhealth-consumer.azurewebsites.net mct.premierhealthpartners.org mychart.premierhealthpartners.org 1'],
#  ['ALLOW-FROM', 'https://stag1.purina.ru 1'],
#  ['ALLOW-FROM', 'http://www.magnumicecream.com, SAMEORIGIN 1'],
#  ['ALLOW-FROM', 'https://o1o7n13lbjs48rop542iunx3-wpengine.netdna-ssl.com 1'],
#  ['ALLOW-FROM', 'http://*.hf365.com  https://*.hf365.com 1'],
#  ['ALLOW-FROM', '*.everaccountable.com 1'],
#  ['ALLOW-FROM', 'https://intranet.m800.com 1'],
#  ['ALLOW-FROM', 'http://www.funivie.org 1'],
#  ['Allow-From', 'https://library.mulesoft.com 1'],
#  ['ALLOW-FROM', 'https://umc.shzxcloud.com 1'],
#  ['ALLOW-FROM', 'https://www.pcagearbox.org 1'],
#  ['ALLOW-FROM', 'https://acyi.maps.arcgis.com 1'],
#  ['ALLOW-FROM', 'https://insights.hotjar.com/ 1'],
#  ['*.upce.cz', '1'],
#  ['ALLOW_FROM',
#   'HTTPS://PORTAL.BAKAI.KG, ALLOW-FROM HTTPS://B24.BAKAI.KG, ALLOW-FROM HTTPS://BAKAI24.BAKAI.KG, ALLOW-FROM HTTPS://BAKAI.KG, ALLOW-FROM HTTPS://WWW.BAKAI.KG, ALLOW-FROM HTTPS://CDN.BAKAI.KG 1'],
#  ['ALLOW-FROM', 'https://www.menards.com/ 1'],
#  ['ALLOW-FROM', 'http://webadmin.sedgwick.gov/ 1'],
#  ['allow-from', 'https://bzfe9.prod.se.ble.de/ 1'],
#  ['ALLOW-FROM', '*.brinksinc.com 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://www.snowandrock.com 1'],
#  ['ALLOW-FROM', 'codeweek.de 1'],
#  ['ALLOW-FROM', 'https://www.lotame.com// 1'],
#  ['ALLOW_FROM', 'https://okamba.experiencecloud.adobe.com 1'],
#  ['ALLOW-FROM',
#   '= https://mychart.valleywisehealth.org, https://mycharttst.valleywisehealth.org 1'],
#  ['dialer.bookmyforex.com', '1'],
#  ['ALLOW-FROM',
#   'https://www.resulticks.com https://*.resulticks.com https://www.go.resul.io https://resources-go.resul.io 1'],
#  ['ALLOW-FROM', 'https://www.aapg.org/ 1'],
#  ["'allow-from", "support.aejuice.com' 1"],
#  ['allow-from', 'https://youtube.com https://kuchnialidla.pl 1'],
#  ['ALLOW-FROM', 'experience.adobe.com 1'],
#  ['ALLOW-FROM', 'https://pos.uhaul.net 1'],
#  ['ALLOW-FROM',
#   'truetour.app visitingmedia.com 360.visitingmedia.com my.matterport.com 1'],
#  ['allow-from', 'https://livepreview.dwd.de 1'],
#  ['FITMETRIX', '1'],
#  ['ALLOW-FROM', 'my.adminforge.de 1'],
#  ['ALLOW-FROM', 'https://static.fotor.com.cn 1'],
#  ['ALLOW-FROM', 'https://editor.fo.ru/ 1'],
#  ['same', '1'],
#  ['ALLOW-FROM', 'https://thuvienhoclieu.com/ 1'],
#  ['ALLOW-FROM', 'https://exposuizo.com.ar/ 1'],
#  ['ALLOW-FROM', 'https://smart-bdash.com/ 1'],
#  ['ALLOW-FROM',
#   'www.directvote.net directvote.net apps.asrt.org dev1.apps.asrt.org local.apps.asrt.org beta.apps.asrt.org convapps.asrt.org 1'],
#  ['allow-from',
#   'https://fcm.googleapis.com https://mc.yandex.ru https://mc.yandex.az https://mc.yandex.by  https://mc.yandex.co.il  https://mc.yandex.com  https://mc.yandex.com.am  https://mc.yandex.com.ge  https://mc.yandex.com.tr  https://mc.yandex.ee  https://mc.yandex.fr  https://mc.yandex.kg  https://mc.yandex.kz  https://mc.yandex.lt  https://mc.yandex.lv  https://mc.yandex.md  https://mc.yandex.tj  https://mc.yandex.tm  https://mc.yandex.ua  https://mc.yandex.uz  https://mc.webvisor.com  https://mc.webvisor.org  https://yastatic.net 1'],
#  ['ALLOW-FROM', 'http://gwennet.ca 1'],
#  ['ALLOW-FROM', 'https://www.visit.fonterra.com 1'],
#  ['ALLOW-FROM', 'https://*.pospal.cn/ 1'],
#  ['ALLOW-FROM', 'https://devcentral.f5.com 1'],
#  ['allow-from', 'https://www.bizcn.com/ 1'],
#  ['ALLOW-FROM', 'http://zaproszenia.zakopane.pl/ 1'],
#  ['ALLOW-FROM',
#   'https://www.snapeda.com https://sibalco.weserve.ch https://shop-sibalco.weserve.ch https://*.sibalco.ch https://shop.powell.com https://www.tc-componentes.es 1'],
#  ['ALLOW-FROM', 'https://search-embed.chsli.org.pagescdn.com 1'],
#  ['ALLOWFROM', 'https://www.facebook.com 1'],
#  ['ALLOW-FROM', '*.originlab.com 1'],
#  ['http://dzair-foot.com/', '1'],
#  ['ALLOW-FROM', 'ufcuconnect.ufcunet.ad 1'],
#  ['allow-from', 'https://apps.timesolv.com/App/Login.aspx 1'],
#  ['ALLOW-FROM', 'https://b130skc.myraidbox.de 1'],
#  ['ALLOW-FROM', 'https://detalika.ru/ 1'],
#  ['allow-from', '*.salesforce.com *.force.com *.trailhead.sfdc.sh 1'],
#  ['ALLOW-FROM', 'ceros.com 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM=https://back-office.kameleoon.com/ 1'],
#  ['https://petplanvet.co.uk', '1'],
#  ['ALLOW-FROM', 'https://us-creditninja.vergic.com 1'],
#  ['ALLOW-FROM',
#   'https://www.synology.cn https://*.facebook.com https://tongji.baidu.com 1'],
#  ['ALLOW-FROM', 'https://inversiones.suramexico.com 1'],
#  ['ALLOW-FROM', 'https://web.demandbase.com 1'],
#  ['ALLOW-FROM', 'https://*.lifehopeandtruth.com 1'],
#  ['ALLOW-FROM', 'https://ok.ru/ 1'],
#  ['ALLOW-FROM', 'https://getdrupe.com 1'],
#  ['ALLOW-FROM',
#   'resources.a10networks.com, info.a10networks.com, glm.a10networks.com 1'],
#  ['Allow-From', 'https://dbc.dreamisland.ru/ 1'],
#  ['allow-from', 'https://digitalexpo.e-estonia.com/ 1'],
#  ['ALLOW-FROM', 'https://amadeus.seismic.com 1'],
#  ['ALLOW-FROM', 'http://job4you.com.ua 1'],
#  ['ALLOW-FROM', 'https://portal.okanagan.bc.ca 1'],
#  ['allow-from', 'https://untilgone-com.cdn.ampproject.org 1'],
#  ['Allow-From',
#   'https://wehco-hot-springs-sentinel-record.preview.zephr.com 1'],
#  ['ALLOW-FROM', 'https://pinpai.baidu.com 1'],
#  ['ALLOW-FROM', 'https://secure-lc.livechatinc.com 1'],
#  ['ALLOW-FROM',
#   'http://www.slipcase.com https://www.slipcase.com https://marketplace.marsh.com 1'],
#  ['allow-from', 'https://liveshopping.bonprix.ch/ 1'],
#  ['ALLOW-FROM',
#   'https://hansa-autoversicherung.de, https://lumen.da-dg.com, https://www.wigger-versicherung.de, https://www.elbtor-versicherungen.de, https://www.sternauto-versicherung.de 1'],
#  ['Allow-From', 'http://obss.tech 1'],
#  ['ALLOW-FROM', 'https://outreach.perimeterinstitute.ca 1'],
#  ['ALLOW', 'FROM https://www.bilet.com  https://obilet.com 1'],
#  ['ALLOW-FROM', 'https://www.perrigo.com/ 1'],
#  ['ALLOW-FROM', 'https://privada.lasalle.edu.co/ 1'],
#  ['SAMEORIGIN,', 'GOFORIT 1'],
#  ['allow-from', 'https://www.facebook.com/BristolStreetMotors/ 1'],
#  ['SAMEORIGIN,',
#   'ALLOW-FROM https://adminv3.luxauto.lu, ALLOW-FROM http://www.lessentiel.lu, ALLOW-FROM https://www.lessentiel.lu, ALLOW-FROM http://www.garage-pauly.lu, ALLOW-FROM https://www.garage-pauly.lu, ALLOW-FROM http://www.gti.lu, ALLOW-FROM http://automobiles-cr.lu, ALLOW-FROM http://www.automobiles-cr.lu, ALLOW-FROM https://www.garagethielen.lu, ALLOW-FROM http://www.reiserbann.lu, ALLOW-FROM https://www.reiserbann.lu, ALLOW-FROM https://www.smartcenter.lu, ALLOW-FROM https://www.marval.lu, ALLOW-FROM https://www.garagecastermans.lu, ALLOW-FROM http://www.schneiders.lu, ALLOW-FROM https://www.serviceautomobile.lu, ALLOW-FROM https://www.pirsch.lu, ALLOW-FROM https://www.grand-garage-mondercange.lu, ALLOW-FROM http://www.diegrenzgaenger.lu, ALLOW-FROM https://www.diegrenzgaenger.lu, ALLOW-FROM http://www.lesfrontaliers.lu, ALLOW-FROM https://www.lesfrontaliers.lu, ALLOW-FROM https://colle.lu, ALLOW-FROM https://actions-autodis.lu 1'],
#  ['ALLOW-FROM', 'https://directory.scouting.org 1'],
#  ['ALLOW-FROM', 'https://www.gov.co/ 1'],
#  ['ALLOW-FROM', 'https://americanlifestylemag.com 1'],
#  ['ALLOW-FROM', 'https://www.fameex.com/en-US 1'],
#  ['ALLOW-FROM',
#   'https://www.infranetworking.com https://status.infranetworking.com https://google.com https://www.google.com https://panel.infranetworking.com https://blog.infranetworking.com https://static.hotjar.com https://www.googletagmanager.com 1'],
#  ['ALLOW-FROM',
#   'metrika.yandex.ru; metrika.yandex.by; metrica.yandex.com; metrica.yandex.com.tr; webvisor.com; *.webvisor.com 1'],
#  ['https://agromosa.com', '1'],
#  ['ALLOW-FROM', 'https://id-test.devs.yu.edu.kz/ 1'],
#  ['ALLOW-FROM', 'https://secure.afca.org.au 1'],
#  ['ALLOW-FROM', 'account.kemnaker.go.id 1'],
#  ['ALLOW-FROM', 'https://querobolsa.com.br 1'],
#  ['ALLOW-FROM', 'https://n1866.secure.force.com 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://sites.google.com 1'],
#  ['allow-from', 'https://www.lxcluster.at/ 1'],
#  ['ALLOW-FROM', 'https://clients.uschedule.com 1'],
#  ['ALLOW-FROM',
#   'frontos.outsourcing.com.co dev.sistemagestionpredialeaabogota.com.co qa.sistemagestionpredialeaabogota.com.co 1'],
#  ['ALLOW-FROM', 'https://hd.co.th/ https://www.honestdocs.co/ SAMEORIGIN 1'],
#  ['www.facebook.com', '1'],
#  ['ALLOW-FROM',
#   'https://dev-credo.telgoo5.com https://demo-credo.telgoo5.com https://credo.telgoo5.com/ 1'],
#  ['ALLOW-FROM',
#   'http://*.lottery.gov.cn https://*.lottery.gov.cn http://*.sporttery.cn https://*.sporttery.cn 1'],
#  ['ALLOW-FROM',
#   'https://www.youtube.com https://beta.startup.id http://startup.local 1'],
#  ['ALLOW-FROM=http://www.youtube.com', '1'],
#  ['ALLOW-FROM', '*.monday.com *.iframetester.com 1'],
#  ['ALLOW-FROM', 'https://showroom.selsey.pl 1'],
#  ['Allow-From', '*.worldvision.ca 1'],
#  ['ALLOW-FROM', 'http://projects.findnderd.com/ 1'],
#  ['ALLOW-FROM', 'http://www.hellmanns.com, SAMEORIGIN 1'],
#  ['ALLOW-FROM', 'https://ixserv.med.tu-dresden.de/ 1'],
#  ['allow-from', 'https://analyse.redmedical.de 1'],
#  ['ALLOW-FROM', 'https://immoscout24.ch 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://frasersproperty.marketing.adobe.com/ 1'],
#  ['ALLOW-FROM', 'https://web.charityengine.net 1'],
#  ['ALLOW-FROM', 'http://edu.auto3n.ru 1'],
#  ['ALLOW-FROM', 'http://www.otto.de/, ALLOW-FROM https://develop.otto.de/ 1'],
#  ['ALLOW-FROM',
#   'https://kennisbank.nijmegen.nl/ https://kentekencheck.opwegnaarzes.nl/ 1'],
#  ['ALLOW-FROM', 'super.com staging.super.com *.super.com www.super.com 1'],
#  ['ALLOW-FROM', 'https://champion100.com/ 1'],
#  ['ALLOW-FROM', 'https://www.citavi.com 1'],
#  ['ALLOW-FROM', 'https://www.illinoislegalaid.org 1'],
#  ['ALLOW-FROM', 'https://www.sneac.edu.cn 1'],
#  ['sameorigin', '*.addthis.com 1'],
#  ['https://harga-emas.org/',
#   'https://pluang-production-uploads.s3-ap-southeast-1.amazonaws.com 1'],
#  ['ALLOW-FROM', 'https://mychart.crh.org mychart.crh.org 1'],
#  ['ALLOW-FROM',
#   'https://eawag.ch/ https://www.eawag.ch/ http://lib4ri.ch/ http://www.lib4ri.ch/ 1'],
#  ['ALLOW-FROM',
#   'http://eweb.tennantco.com, ALLOW-FROM http://eweb.tennantco.com 1'],
#  ['ALLOW-FROM', 'https://mapping.kirklees.gov.uk/ 1'],
#  ['ALLOW-FROM', 'sharepoint.com 1'],
#  ['ALLOW-FROM', 'https://cumbria-stage.codeenigma.net 1'],
#  ['ALLOW-FROM', 'https://www.allergyasthmaimm.com 1'],
#  ['https://*.clientpoint.net,', 'https://clientpoint.net 1'],
#  ['ALLOW-FROM', 'https://selfhighspeed.hostsaurus.com/ 1'],
#  ['Allow-From', 'https://wehco-whole-hog-sports.preview.zephr.com 1'],
#  ['ALLOW-FROM', 'https://loteriaspuertorico.com 1'],
#  ['ALLOW-FROM:', 'awards.ratingruneta.ru 1'],
#  ['Header', 'always set X-Frame-Options "SAMEORIGIN" 1'],
#  ['ALLOW-FROM', 'https://www.as-goal.com 1'],
#  ['ALLOW-FROM', 'https://www.tessian.com/book-demo/\xa0 1'],
#  ['ALLOW-FROM', 'https://www.teamaligned.com 1'],
#  ['ALLOW-FROM',
#   'https://www.energiaxxi.com https://www.endesaclientes.com https://tempoconbisbal.com http://www.endesadiagnosticoenergetico.com http://www.endesadiagnosticoenergetico.com https://www.facebook.es https://www.facebook.com https://www.aaff.endesaclientes.com 1'],
#  ['ALLOW-FROM', '*.greenheck.com *.accurex.crm.dynamics.com 1'],
#  ['ALLOW-FROM', 'https://app.evaluate.com, http://app.evaluate.com 1'],
#  ['SAMEORIGIN,', 'SAMEORIGIN, ALLOW-FROM https://www.kutxabank.es 1'],
#  ['ALLOW-FROM', '*.upbet.com 1'],
#  ['ALLOW-FROM', 'https://cqrl.in/ 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://mail.missiveapp.com 1'],
#  ['allow-from', 'amboss.com 1'],
#  ['ALLOW-FROM', 'https://insights.ltts.com/ 1'],
#  ['DENYALLOW-FROM',
#   'https://www.googletagmanager.com/ ALLOW-FROM  https://*.11st.co.kr ALLOW-FROM *://*.kumhotire.com ALLOW-FROM *://*.kumhotire.co.kr 1'],
#  ['allow-from', '*.webvisor.com 1'],
#  ['ALLOW-FROM', 'https://*.greenmountainenergy.com 1'],
#  ['ALLOW-FROM', 'dev.ragingbull.com 1'],
#  ['ALLOW-FROM', 'https://infoabende.bachheimer.com 1'],
#  ['ALLOW-FROM', 'https://matomo.sundsvall.se/ 1'],
#  ['DENY,SAMEORIGIN,ALLOW-FROM',
#   '"https://www.citytouch.com.bd/",ALLOW-FROM "https://ibank.citybankplc.com/" 1'],
#  ['ALLOW-ACCESS',
#   'https://myavcadmin.avc.edu, https://myavc.avc.edu, https://my.avc.edu 1'],
#  ['ALLOW-FROM', 'http://www.univ-setif2.dz/ 1'],
#  ['"ALLOW-FROM', 'https://sensors.xtadmins.com/" 1'],
#  ['ALLOW-FROM', 'https://intranet.aduana.gob.bo/ 1'],
#  ['SAMEORIGIN,', 'ALLOW-FROM https://www.runnersneed.com 1'],
#  ['ALLOW-FROM',
#   'https://enseignement-a-distance.educastream.com https://www.educastream.com https://educastream.dev https://po-george.educastream.dev http://test-prepmyfuture.herokuapp.com/ https://*.1to1progress.com https://1to1.educastream.com/ https://lms.educastream.com https://*.7speaking.com lms-1to1.educastream.com  https://*.educastream.com 1'],
#  ['ALLOW-FROM', 'https://iframe.mpowafin.co.za 1'],
#  ['ALLOW-FROM',
#   'https://a3c4be7c91bd110bf544226878bff4df.safeframe.googlesyndication.com/ 1'],
#  ...]

# %%
label = "XFO"
header_name = "x-frame-options"
alt_names = ["frame-options", "x-frame-option", "x-frames-options", "content-security-policy", "x_frame_options", "xframeoptions"]
block_values = ["DENY"]
allow_values = ["ALLOWALL"] # This value does not really exist but has some special meaning for processing multiple values (https://html.spec.whatwg.org/multipage/document-lifecycle.html#the-x-frame-options-header)
partial_values = ["SAMEORIGIN"]
legacy_values = [f"ALLOW-FROM {origin_s}"]

# TODO: add other values from the above sources
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
basic_values = ["", "INVALID", "null", "*", URL_REP]
# https://wpt.fyi/results/x-frame-options?label=master&label=experimental&aligned&q=x-frame
wpt_values = []
# https://github.com/hen95/HTTPHeaderBrowserTesting
siewert_values = []
# https://crawler.ninja/files/xfo-values.txt
crawler_ninja_values = []
own_values = []
other_values = basic_values + wpt_values + siewert_values + crawler_ninja_values + own_values
other_values = expand_urls(other_values)

# %%
other_values
# Out:
# ['',
#  'INVALID',
#  'null',
#  '*',
#  'sub.headers.websec.saarland',
#  'https://sub.headers.websec.saarland',
#  'http://sub.headers.websec.saarland',
#  'https://sub.headers.websec.saarland:443',
#  'https://sub.headers.websec.saarland/',
#  'https://sub.headers.websec.saarland:443/',
#  'https://headers.websec.saarland',
#  'https://sub.sub.headers.websec.saarland',
#  '*.headers.websec.saarland',
#  '*.sub.headers.websec.saarland']

# %%
# TODO: add next header
label = "CSP"
header_name = ""
alt_names = []
block_values = []
allow_values = []
partial_values = []
legacy_values = []
# Always start with the empty value and then an INVALID value (e.g., "INVALID"), after that both valid and invalid values can be added
# We use the first two in `mult_headers_test`
other_values = ["", "INVALID"]
other_values = expand_urls(other_values)

# %%
ht = HeaderTests(label, header_name, alt_names, block_values, allow_values, partial_values, legacy_values, other_values)
ht.create_all_tests()
#ht.save_responses()
# Out:
# 2544
# [([('x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-option', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frames-options', 'DENY')], 'XFO', 200, 'parsing'), ([('content-security-policy', 'DENY')], 'XFO', 200, 'parsing'), ([('x_frame_options', 'DENY')], 'XFO', 200, 'parsing'), ([('xframeoptions', 'DENY')], 'XFO', 200, 'parsing'), ([('0x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options(', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsx', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame^-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame\x11-options', 'DENY')], 'XFO', 200, 'parsing'), ([('\x18x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsz', 'DENY')], 'XFO', 200, 'parsing'), ([(',x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsF', 'DENY')], 'XFO', 200, 'parsing'), ([('\x00x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsn', 'DENY')], 'XFO', 200, 'parsing'), ([('kx-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('"x-frame-options"', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsY', 'DENY')], 'XFO', 200, 'parsing'), ([('#x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\t', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options=', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options ', 'DENY')], 'XFO', 200, 'parsing'), ([('\x15x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\x0b', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame\x15-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-framey-options', 'DENY')], 'XFO', 200, 'parsing'), ([('[x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frameq-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\x01', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options?', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame\x19-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-framen-options', 'DENY')], 'XFO', 200, 'parsing'), ([('tx-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame;-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options<', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame\x14-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsG', 'DENY')], 'XFO', 200, 'parsing'), ([(';x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('\x07x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsQ', 'DENY')], 'XFO', 200, 'parsing'), ([('Px-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frameQ-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsK', 'DENY')], 'XFO', 200, 'parsing'), ([('Ax-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('7x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options$', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\x06', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\x18', 'DENY')], 'XFO', 200, 'parsing'), ([('x-framex-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsD', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame?-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frameR-options', 'DENY')], 'XFO', 200, 'parsing'), ([('dx-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frameP-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\x05', 'DENY')], 'XFO', 200, 'parsing'), ([('4x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-optionsE', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame(-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\xa0a', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options^', 'DENY')], 'XFO', 200, 'parsing'), ([('\x19x-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('Jx-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\x17', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame-options\x02', 'DENY')], 'XFO', 200, 'parsing'), ([('x-frame\\-options', 'DENY')], 'XFO', 200, 'parsing'), ([('qx-frame-options', 'DENY')], 'XFO', 200, 'parsing'), ([('5x-frame-o ...
